# %% [markdown]
# # Experiment 2C: Ablation - Oversample & Augmentation Strength
#
# **Experiment:** Exp 2C
#
# Ablation studies 2-3: oversample baseline comparison + weak vs strong augmentation (Tables 5.20-5.21).
#
# ---

# %%
import os
# !pip install gdown --upgrade

if os.path.isdir("/content/drive/MyDrive/colab-sg2-ada-pytorch"):
    # %cd "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/JunTierSS/stylegan2-ada
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/JunTierSS/stylegan2-ada
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/splits/by_patient_30test1/train.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/trainori_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/trainori.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/trainori.zip" -d "/content/localdata/trainori_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/trainori_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/trainori_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/trainori.zip
# Contenido de /content/localdata/trainori_unzipped
# total 128K
# drwxr-xr-x 5 root root 4.0K Nov 25 22:40 .
# drwxr-xr-x 3 root root 4.0K Nov 25 22:40 ..
# drwxr-xr-x 2 root root  52K Nov 25 22:40 glioma
# drwxr-xr-x 2 root root  32K Nov 25 22:40 meningioma
# drwxr-xr-x 2 root root  36K Nov 25 22:40 pituitary

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/splits/by_patient_30test1/test.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/testori_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/testori.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/testori.zip" -d "/content/localdata/testori_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/testori_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/testori_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/testori.zip
# Contenido de /content/localdata/testori_unzipped
# total 64K
# drwxr-xr-x 5 root root 4.0K Nov 25 22:40 .
# drwxr-xr-x 4 root root 4.0K Nov 25 22:40 ..
# drwxr-xr-x 2 root root  24K Nov 25 22:40 glioma
# drwxr-xr-x 2 root root  12K Nov 25 22:40 meningioma
# drwxr-xr-x 2 root root  20K Nov 25 22:41 pituitary

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/datasetinge/testreducido.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/test_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/test.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/test.zip" -d "/content/localdata/test_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/test_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/test_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/test.zip
# Contenido de /content/localdata/test_unzipped
# total 12K
# drwxr-xr-x 3 root root 4.0K Nov 25 22:41 .
# drwxr-xr-x 5 root root 4.0K Nov 25 22:41 ..
# drwxrwxrwx 5 root root 4.0K Nov 10 21:19 testreducido

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/datasetinge/trainreducido.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/train_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/train.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/train.zip" -d "/content/localdata/train_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/train_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/train_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/train.zip
# Contenido de /content/localdata/train_unzipped
# total 12K
# drwxr-xr-x 3 root root 4.0K Nov 25 22:41 .
# drwxr-xr-x 6 root root 4.0K Nov 25 22:41 ..
# drwxrwxrwx 5 root root 4.0K Nov 10 21:19 trainreducido

# %%
pip install ninja
# Out:
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.13.0

# %%
pip install opensimplex
# Out:
# Collecting opensimplex
#   Downloading opensimplex-0.4.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from opensimplex) (2.0.2)
# Downloading opensimplex-0.4.5.1-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.4.5.1

# %%
import os, re, io, json, time, argparse, random, csv, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional

import numpy as np
from PIL import Image, ImageOps

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms, models
import torchvision.transforms.functional as TF
import torchvision

from sklearn.model_selection import StratifiedShuffleSplit

# %%
# -*- coding: utf-8 -*-
"""
K-Fold training (by patient) for brain tumor classification (ResNet50)
Experiment 2C - B1 ablation:
 - Setting A: real-only with naive oversampling (balance_mode='oversample', no GAN)
 - Setting B: GAN-balanced (real + synthetic up to max real class) (balance_mode='gan_balance')

Features:
- No-leak by patient_id (groups)
- StratifiedGroupKFold if available; fallback to GroupKFold
- Optional StyleGAN2-ADA augmentation:
    * Real-only run (no GAN)
    * GAN-balanced run: per fold, adds GAN images up to the max real class (by number of REAL images)
- Per-fold metrics + CV summary
- OOF (out-of-fold) predictions & metrics
- External TEST evaluation per fold + K-fold ensemble
- Optional internal TEST (INTTEST) + ensemble
- Optional final fine-tuning epochs using only REAL images
"""

import os, re, io, json, time, random, csv, math, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional
from dataclasses import dataclass, asdict

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
)

# ====== Splitters ======
try:
    from sklearn.model_selection import StratifiedGroupKFold
    HAS_SGTK = True
except Exception:
    HAS_SGTK = False
    from sklearn.model_selection import GroupKFold

# ====== Utils ======


def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
    try:
        torch.set_float32_matmul_precision("high")
    except Exception:
        pass


def timestamp() -> str:
    return time.strftime("%Y%m%d-%H%M%S")


def extract_patient_id(p: Path) -> str:
    stem = p.stem
    token = stem.split("_")[0]
    return token.strip().lower()


IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}

# ====== Config ======


@dataclass
class Config:
    data_root: str
    out_dir: str
    test_root: str = ""
    gan_pkl: str = ""
    images_per_class: int = 0        # only used if balance_gan_to_max=False
    truncation: float = 1.0
    internal_test_ratio: float = 0.0   # optional: holdout before CV
    image_size: int = 256
    batch_size: int = 32
    epochs: int = 15
    lr: float = 1e-3
    weight_decay: float = 1e-4
    num_workers: int = 4
    seed: int = 42
    kfolds: int = 5
    amp: bool = True
    pretrained: bool = True
    train_full_after_cv: bool = False   # optional: retrain on full pool at end

    # Fine-tuning only on REAL images (last epochs)
    fine_tune_real_epochs: int = 0      # 0 = disabled

    # GAN balancing
    balance_gan_to_max: bool = False    # if True, n_per_class = max real class (global)

    # NEW: ablation mode
    #  - "none": no class balancing, optional append of all synth images
    #  - "gan_balance": per-fold balanced real+GAN up to max real class (per fold)
    #  - "oversample": real-only oversampling up to max real class (per fold)
    balance_mode: str = "none"


# ====== Dataset ======


class MRIDataset(Dataset):
    def __init__(
        self,
        items: List[Tuple[Path, int, str]],
        image_size: int = 256,
        aug: bool = False,
    ):
        self.items = items
        self.image_size = image_size
        self.aug = aug

        mean = [0.5, 0.5, 0.5]
        std = [0.5, 0.5, 0.5]

        if aug:
            self.tf = transforms.Compose([
                transforms.RandomResizedCrop(image_size, scale=(0.9, 1.0), ratio=(0.95, 1.05)),
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.RandomRotation(10),
                transforms.ToTensor(),
            ])
        else:
            self.tf = transforms.Compose([
                transforms.Resize((image_size, image_size)),
                transforms.ToTensor(),
            ])

        self.norm = transforms.Normalize(mean=mean, std=std)

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        path, y, pid = self.items[idx]
        img = Image.open(path).convert("L")
        img = self.tf(img)           # [1,H,W]
        img = img.repeat(3, 1, 1)    # [3,H,W]
        img = self.norm(img)
        return img, y, str(path), pid


# ====== Scan & Helpers ======


def scan_folder(root: Path) -> Tuple[List[Tuple[Path, int, str]], List[str]]:
    assert root.is_dir(), f"Not a directory: {root}"
    class_names = sorted([d.name for d in root.iterdir() if d.is_dir()])
    items: List[Tuple[Path, int, str]] = []
    for ci, cname in enumerate(class_names):
        cdir = root / cname
        for p in cdir.rglob("*"):
            if p.suffix.lower() in IMG_EXTS:
                pid = extract_patient_id(p)
                items.append((p, ci, pid))
    return items, class_names


def ensure_no_overlap(ids_a: List[str], ids_b: List[str]) -> Tuple[int, List[str]]:
    a = set(ids_a)
    b = set(ids_b)
    inter = sorted(a.intersection(b))
    return len(inter), inter


def summarize_id_counts(
    items: List[Tuple[Path, int, str]],
    class_names: List[str],
    split_name: str,
    out_dir: Path,
):
    from collections import defaultdict

    ids_by_class = defaultdict(set)
    imgs_by_class = defaultdict(int)
    all_ids = set()

    for p, ci, pid in items:
        ids_by_class[ci].add(pid)
        imgs_by_class[ci] += 1
        all_ids.add(pid)

    print(f"[ID-STATS] {split_name}: unique patient IDs total = {len(all_ids)} | images = {len(items)}")
    for ci, cname in enumerate(class_names):
        print(f"  - {cname}: ids={len(ids_by_class[ci])} images={imgs_by_class[ci]}")

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"id_counts_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["class", "n_unique_ids", "n_images"])
        for ci, cname in enumerate(class_names):
            w.writerow([cname, len(ids_by_class[ci]), imgs_by_class[ci]])
        w.writerow(["__TOTAL__", len(all_ids), len(items)])


# ====== Model ======


def build_model(num_classes: int, pretrained: bool = True) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m


# ====== Evaluation ======


@torch.no_grad()
def evaluate(
    model: nn.Module,
    loader: DataLoader,
    device: torch.device,
    class_names: List[str],
    split_name: str,
    out_dir: Path,
):
    model.eval()
    all_probs, all_preds, all_labels = [], [], []
    all_paths, all_pids = [], []

    for imgs, ys, paths, pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        all_paths.extend(list(paths))
        all_pids.extend(list(pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, len(class_names)))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)

    acc = float(accuracy_score(labels, preds)) if len(labels) else 0.0
    prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
        labels, preds, average="macro", zero_division=0
    )
    prec_weighted, rec_weighted, f1_weighted, _ = precision_recall_fscore_support(
        labels, preds, average="weighted", zero_division=0
    )
    per_class = classification_report(
        labels, preds, target_names=class_names, output_dict=True, zero_division=0
    )
    cm = confusion_matrix(labels, preds, labels=list(range(len(class_names))))

    metrics = {
        "overall": {
            "accuracy": acc,
            "precision_macro": prec_macro,
            "recall_macro": rec_macro,
            "f1_macro": f1_macro,
            "precision_weighted": prec_weighted,
            "recall_weighted": rec_weighted,
            "f1_weighted": f1_weighted,
            "num_samples": len(labels),
        },
        "per_class": per_class,
    }

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"metrics_{split_name}.json", "w", encoding="utf-8") as f:
        json.dump(metrics, f, indent=2)

    with open(out_dir / f"metrics_overall_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow([
            "split",
            "accuracy",
            "precision_macro",
            "recall_macro",
            "f1_macro",
            "precision_weighted",
            "recall_weighted",
            "f1_weighted",
            "num_samples",
        ])
        o = metrics["overall"]
        w.writerow([
            split_name,
            o["accuracy"],
            o["precision_macro"],
            o["recall_macro"],
            o["f1_macro"],
            o["precision_weighted"],
            o["recall_weighted"],
            o["f1_weighted"],
            o["num_samples"],
        ])

    with open(out_dir / f"per_class_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["class", "precision", "recall", "f1", "support"])
        for cname in class_names:
            row = per_class.get(
                cname,
                {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
            )
            w.writerow([
                cname,
                row.get("precision", 0),
                row.get("recall", 0),
                row.get("f1-score", 0),
                row.get("support", 0),
            ])

    with open(out_dir / f"confusion_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["true\\pred"] + class_names)
        for i, cname in enumerate(class_names):
            w.writerow([cname] + list(cm[i]))

    with open(out_dir / f"predictions_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
        for i in range(len(labels)):
            w.writerow([
                all_paths[i],
                all_pids[i],
                class_names[labels[i]],
                class_names[preds[i]],
            ] + list(map(float, probs[i].tolist())))

    return metrics, cm


@torch.no_grad()
def infer_loader(model: nn.Module, loader: DataLoader, device: torch.device):
    model.eval()
    paths, pids = [], []
    all_probs, all_preds, all_labels = [], [], []
    for imgs, ys, batch_paths, batch_pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        paths.extend(list(batch_paths))
        pids.extend(list(batch_pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, 0))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)
    return {"probs": probs, "preds": preds, "labels": labels, "paths": paths, "pids": pids}


# ====== Optional GAN loader (TRAIN only) ======


@torch.no_grad()
def _load_stylegan2_ada_G(gan_pkl: str, device: torch.device):
    try:
        import dnnlib  # noqa: F401
        from training import network as _dummy  # noqa: F401
        from legacy import load_network_pkl
    except Exception:
        try:
            from torch_utils import misc as _m  # noqa: F401
            from torch_utils import training_stats as _ts  # noqa: F401
            from legacy import load_network_pkl
        except Exception:
            return None
    try:
        with open(gan_pkl, "rb") as f:
            data = load_network_pkl(f)
        G_ema = data.get("G_ema", None) or data.get("G", None)
        if G_ema is None:
            return None
        G_ema = G_ema.to(device)
        G_ema.eval()
        return G_ema
    except Exception:
        return None


@torch.no_grad()
def maybe_generate_gan_images(
    gan_pkl: str,
    class_names: List[str],
    n_per_class: int,
    truncation: float,
    out_dir: Path,
    device: torch.device,
    seed: int = 42,
) -> Optional[Path]:
    if (not gan_pkl) or n_per_class <= 0:
        return None

    G = _load_stylegan2_ada_G(gan_pkl, device)
    if G is None:
        print("[GAN] Could not load StyleGAN2-ADA G_ema. Skipping GAN augmentation.")
        return None
    if getattr(G, "c_dim", 0) <= 0:
        print("[GAN] Generator is not conditional (c_dim=0). Skipping.")
        return None

    rng = np.random.RandomState(seed)
    synth_root = out_dir / "gan_synth"
    for cname in class_names:
        (synth_root / cname).mkdir(parents=True, exist_ok=True)

    batch = 16
    for ci, cname in enumerate(class_names):
        saved = 0
        while saved < n_per_class:
            bs = min(batch, n_per_class - saved)
            z = torch.from_numpy(rng.randn(bs, G.z_dim)).to(device)
            c = torch.zeros(bs, G.c_dim, device=device)
            c[:, ci] = 1.0
            try:
                img = G(z, c, truncation_psi=float(truncation), noise_mode="const")
            except TypeError:
                img = G(z, c, truncation_psi=float(truncation))
            img = (img * 127.5 + 128).clamp(0, 255).to(torch.uint8).cpu()
            for k in range(bs):
                x = img[k]
                if x.shape[0] == 1:
                    arr = x[0].numpy()
                    pil = Image.fromarray(arr).convert("L")
                else:
                    arr = x.permute(1, 2, 0).numpy()
                    pil = Image.fromarray(arr).convert("L")
                fname = synth_root / cname / f"gan_{cname}_{saved + k:05d}.png"
                pil.save(fname)
            saved += bs
        print(f"[GAN] Saved {saved} images for class '{cname}'")
    return synth_root


def collate_fn(batch):
    imgs, ys, paths, pids = zip(*batch)
    return torch.stack(imgs, dim=0), torch.tensor(ys, dtype=torch.long), list(paths), list(pids)


# ====== Helper: balanced train subset (real + GAN) ======


def build_balanced_train_subset(
    real_train_subset: List[Tuple[Path, int, str]],
    synth_items: List[Tuple[Path, int, str]],
    num_classes: int,
    seed: int,
) -> List[Tuple[Path, int, str]]:
    """
    Takes:
      - real_train_subset: REAL images (for that fold)
      - synth_items: ALL synthetic images (scanned from gan_synth/)
    Returns:
      - list with REAL + enough GAN images per class to match the largest REAL class
    """
    from collections import defaultdict

    # Real by class
    real_by_class: Dict[int, List[Tuple[Path, int, str]]] = defaultdict(list)
    for item in real_train_subset:
        _, ci, _ = item
        real_by_class[ci].append(item)

    # GAN by class
    synth_by_class: Dict[int, List[Tuple[Path, int, str]]] = defaultdict(list)
    for item in synth_items:
        _, ci, _ = item
        synth_by_class[ci].append(item)

    # Target = size of the largest REAL class (per fold)
    counts_real = [len(real_by_class[c]) for c in range(num_classes)]
    target = max(counts_real) if counts_real else 0
    print(f"[BAL] Real class counts (fold): {counts_real} -> target={target}")

    rng = random.Random(seed)
    balanced: List[Tuple[Path, int, str]] = list(real_train_subset)

    for ci in range(num_classes):
        need = target - len(real_by_class[ci])
        if need <= 0:
            continue
        pool = synth_by_class[ci]
        if not pool:
            print(f"[BAL] WARNING: no GAN images for class {ci}, cannot fully balance.")
            continue
        # sample with replacement if need > len(pool)
        for _ in range(need):
            balanced.append(rng.choice(pool))

    return balanced


# ====== Helper: oversampled train subset (real-only) ======


def build_oversampled_train_subset(
    real_train_subset: List[Tuple[Path, int, str]],
    num_classes: int,
    seed: int,
) -> List[Tuple[Path, int, str]]:
    """
    Simple class-balanced oversampling using only REAL images.
    For each class, duplicates real samples (with replacement) until
    reaching the size of the largest real class in the fold.
    """
    from collections import defaultdict

    real_by_class: Dict[int, List[Tuple[Path, int, str]]] = defaultdict(list)
    for item in real_train_subset:
        _, ci, _ = item
        real_by_class[ci].append(item)

    counts_real = [len(real_by_class[c]) for c in range(num_classes)]
    target = max(counts_real) if counts_real else 0
    print(f"[OVERSAMPLE] Real class counts (fold): {counts_real} -> target={target}")

    rng = random.Random(seed)
    oversampled: List[Tuple[Path, int, str]] = []

    for ci in range(num_classes):
        items_c = real_by_class[ci]
        if not items_c:
            print(f"[OVERSAMPLE] WARNING: class {ci} has no real samples in this fold.")
            continue
        # keep all real samples
        oversampled.extend(items_c)
        # add extra copies until target
        need = target - len(items_c)
        for _ in range(need):
            oversampled.append(rng.choice(items_c))

    print(f"[OVERSAMPLE] Fold train size: real={len(real_train_subset)} -> oversampled={len(oversampled)}")
    return oversampled


# ====== K-Fold Train (CV + OOF + TEST + INTTEST ensemble) ======


def train_kfold(cfg: Config):
    if cfg.fine_tune_real_epochs < 0 or cfg.fine_tune_real_epochs > cfg.epochs:
        raise ValueError("fine_tune_real_epochs must be between 0 and cfg.epochs")

    base_run = Path(cfg.out_dir) / f"kfold_{cfg.kfolds}f_run_{timestamp()}"
    base_run.mkdir(parents=True, exist_ok=True)
    with open(base_run / "config.json", "w", encoding="utf-8") as f:
        json.dump(asdict(cfg), f, indent=2)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"[Device] Using {device}")

    # Scan pool
    all_items, class_names = scan_folder(Path(cfg.data_root))
    print(f"[Scan] Pool images: {len(all_items)} | Classes: {class_names}")

    # Optional internal-test holdout (by patient)
    inttest_subset: List[Tuple[Path, int, str]] = []
    if cfg.internal_test_ratio and cfg.internal_test_ratio > 0:
        from sklearn.model_selection import GroupShuffleSplit

        X_all = np.arange(len(all_items))
        y_all = np.array([lbl for _, lbl, _ in all_items])
        g_all = np.array([pid for _, _, pid in all_items])
        gss = GroupShuffleSplit(n_splits=1, test_size=cfg.internal_test_ratio, random_state=cfg.seed)
        trval_idx, inttest_idx = next(gss.split(X_all, y_all, g_all))
        base_pool = [all_items[i] for i in trval_idx]
        inttest_subset = [all_items[i] for i in inttest_idx]
        print(f"[Split] Internal test: {len(inttest_subset)} images ({cfg.internal_test_ratio * 100:.1f}%)")
    else:
        base_pool = all_items

    # External test (leak-sanitized vs pool & internal test)
    ext_subset: List[Tuple[Path, int, str]] = []
    if cfg.test_root and len(cfg.test_root.strip()) > 0 and Path(cfg.test_root).exists():
        ext_items, _ = scan_folder(Path(cfg.test_root))
        ids_pool = set(pid for _, _, pid in base_pool)
        if len(inttest_subset) > 0:
            ids_pool |= set(pid for _, _, pid in inttest_subset)
        for it in ext_items:
            if it[2] not in ids_pool:
                ext_subset.append(it)
        removed = len(ext_items) - len(ext_subset)
        if removed > 0:
            print(f"[LEAK-FIX] Removed {removed} overlapping ext-test images by patient ID.")
        print(f"[Scan] External test images (sanitized): {len(ext_subset)}")

    # Build folds grouped by patient (REAL only)
    X = np.arange(len(base_pool))
    y = np.array([lbl for _, lbl, _ in base_pool])
    groups = np.array([pid for _, _, pid in base_pool])

    if cfg.kfolds < 2:
        raise ValueError("kfolds must be >= 2")

    if HAS_SGTK:
        splitter = StratifiedGroupKFold(n_splits=cfg.kfolds, shuffle=True, random_state=cfg.seed)
        folds_iter = list(splitter.split(X, y, groups))
        print("[Split] Using StratifiedGroupKFold")
    else:
        splitter = GroupKFold(n_splits=cfg.kfolds)
        folds_iter = list(splitter.split(X, groups=groups))
        print("[Split] Using GroupKFold (no stratification)")

    # ===== Pre-generate GAN synth once =====
    synth_items: List[Tuple[Path, int, str]] = []
    synth_root: Optional[Path] = None
    if cfg.gan_pkl and cfg.gan_pkl.strip():
        # if we want to balance, ignore images_per_class and use global max of REALS
        if cfg.balance_gan_to_max:
            from collections import defaultdict

            real_counts_global = defaultdict(int)
            for _, ci, _ in base_pool:
                real_counts_global[ci] += 1
            counts_vec = [real_counts_global[ci] for ci in range(len(class_names))]
            n_per_class = max(counts_vec) if counts_vec else 0
            print(
                f"[GAN] balance_gan_to_max=True -> global real counts per class = {counts_vec}, "
                f"using n_per_class={n_per_class}"
            )
        else:
            n_per_class = cfg.images_per_class

        if n_per_class > 0:
            synth_root = maybe_generate_gan_images(
                gan_pkl=cfg.gan_pkl,
                class_names=class_names,
                n_per_class=n_per_class,
                truncation=cfg.truncation,
                out_dir=base_run,
                device=device,
                seed=cfg.seed,
            )
            if synth_root is not None:
                synth_items, _ = scan_folder(synth_root)
                print(f"[GAN] Synth images generated (global): {len(synth_items)}")
        else:
            print("[GAN] n_per_class <= 0 -> no synthetic images will be generated.")
    else:
        print("[GAN] gan_pkl empty -> NO GAN will be used.")

    # Prepare fixed loaders for ensembles (TEST and INTTEST)
    test_loader_fixed: Optional[DataLoader] = None
    test_ref_paths = test_ref_pids = test_ref_labels = None
    if len(ext_subset) > 0:
        test_ds_fixed = MRIDataset(ext_subset, image_size=cfg.image_size, aug=False)
        test_loader_fixed = DataLoader(
            test_ds_fixed,
            batch_size=cfg.batch_size,
            shuffle=False,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

    inttest_loader_fixed: Optional[DataLoader] = None
    int_ref_paths = int_ref_pids = int_ref_labels = None
    if len(inttest_subset) > 0:
        int_ds_fixed = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
        inttest_loader_fixed = DataLoader(
            int_ds_fixed,
            batch_size=cfg.batch_size,
            shuffle=False,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

    # ===== OOF buffers =====
    n_pool = len(base_pool)
    n_cls = len(class_names)
    oof_probs = np.full((n_pool, n_cls), np.nan, dtype=np.float32)
    oof_pred = np.full((n_pool,), -1, dtype=np.int64)
    oof_true = np.full((n_pool,), -1, dtype=np.int64)
    oof_path = [""] * n_pool
    oof_pid = [""] * n_pool

    # For ensembles
    test_probs_folds: List[np.ndarray] = []
    inttest_probs_folds: List[np.ndarray] = []

    # Per-fold training
    cv_rows = []
    for fold_id, (tr_idx, va_idx) in enumerate(folds_iter, start=1):
        print(f"\n===== FOLD {fold_id}/{cfg.kfolds} =====")
        set_seed(cfg.seed + fold_id)

        fold_dir = base_run / f"fold_{fold_id:02d}"
        fold_dir.mkdir(parents=True, exist_ok=True)

        # REAL train subset and VAL subset
        real_train_subset = [base_pool[i] for i in tr_idx]
        val_subset = [base_pool[i] for i in va_idx]

        # Leak checks (REAL only)
        ids_train = [pid for _, _, pid in real_train_subset]
        ids_val = [pid for _, _, pid in val_subset]
        inter_n, inter_ids = ensure_no_overlap(ids_train, ids_val)
        if inter_n > 0:
            raise RuntimeError(
                f"[LEAK ERROR] Train↔Val share {inter_n} patient IDs (fold {fold_id}): {inter_ids[:10]}"
            )

        if len(inttest_subset) > 0:
            ids_int = [pid for _, _, pid in inttest_subset]
            n1, _ = ensure_no_overlap(ids_train, ids_int)
            n2, _ = ensure_no_overlap(ids_val, ids_int)
            if n1 > 0 or n2 > 0:
                raise RuntimeError("[LEAK ERROR] Fold and INTTEST share patients")

        # ===== build train_subset according to balance_mode =====
        if cfg.balance_mode == "gan_balance" and len(synth_items) > 0:
            # GAN-balanced: real + just enough synthetic to match max real class per fold
            train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + fold_id,
            )
            print(
                f"[BAL] Fold {fold_id}: real={len(real_train_subset)} | "
                f"train_balanced(real+GAN)={len(train_subset)}"
            )

        elif cfg.balance_mode == "oversample":
            # Oversampling: only REAL images, duplicated to match max class
            train_subset = build_oversampled_train_subset(
                real_train_subset=real_train_subset,
                num_classes=len(class_names),
                seed=cfg.seed + fold_id,
            )
            print(
                f"[OVERSAMPLE] Fold {fold_id}: using oversampled real-only train set, "
                f"n={len(train_subset)}"
            )

        else:
            # No explicit balancing: optionally append all synthetic images (if any)
            train_subset = list(real_train_subset)
            if len(synth_items) > 0:
                train_subset = train_subset + synth_items
                print(
                    f"[TRAIN] Fold {fold_id}: real={len(real_train_subset)} + "
                    f"synth={len(synth_items)} -> {len(train_subset)}"
                )
            else:
                print(f"[TRAIN] Fold {fold_id}: only real images, n={len(real_train_subset)}")

        # Stats CSV
        summarize_id_counts(train_subset, class_names, f"fold{fold_id}_train", fold_dir)
        summarize_id_counts(val_subset, class_names, f"fold{fold_id}_val", fold_dir)
        if len(inttest_subset) > 0:
            summarize_id_counts(inttest_subset, class_names, f"fold{fold_id}_inttest", fold_dir)
        if len(ext_subset) > 0:
            summarize_id_counts(ext_subset, class_names, f"fold{fold_id}_test", fold_dir)

        # Loaders
        train_ds = MRIDataset(train_subset, image_size=cfg.image_size, aug=True)
        real_train_ds = MRIDataset(real_train_subset, image_size=cfg.image_size, aug=True)
        val_ds = MRIDataset(val_subset, image_size=cfg.image_size, aug=False)

        train_loader = DataLoader(
            train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )
        real_train_loader = DataLoader(
            real_train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )
        val_loader = DataLoader(
            val_ds,
            batch_size=cfg.batch_size,
            shuffle=False,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

        inttest_loader = None
        if len(inttest_subset) > 0:
            int_ds = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
            inttest_loader = DataLoader(
                int_ds,
                batch_size=cfg.batch_size,
                shuffle=False,
                num_workers=cfg.num_workers,
                pin_memory=True,
                collate_fn=collate_fn,
            )

        # For TEST per fold we use fixed loader
        test_loader = test_loader_fixed

        # Model/optimizer
        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()

        amp_enabled = (cfg.amp and device.type == "cuda")
        scaler = torch.amp.GradScaler("cuda", enabled=amp_enabled)

        best_f1 = -1.0

        # Epoch split: main (train_subset) + fine-tuning (real-only)
        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft = cfg.fine_tune_real_epochs

        # ----- Phase 1: train with train_subset (real + GAN or real-only) -----
        for epoch in range(1, epochs_main + 1):
            model.train()
            running_loss = 0.0
            n_seen = 0
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(
                model,
                val_loader,
                device,
                class_names,
                split_name="val",
                out_dir=fold_dir,
            )
            f1_macro = m_val["overall"]["f1_macro"]
            acc_val = m_val["overall"]["accuracy"]
            print(
                f"[Fold {fold_id} | Epoch {epoch:03d}] "
                f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | "
                f"val_f1_macro={f1_macro:.4f}"
            )

            torch.save(
                {"model": model.state_dict(), "epoch": epoch, "class_names": class_names},
                fold_dir / "last.ckpt",
            )

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save(
                    {"model": model.state_dict(), "epoch": epoch, "class_names": class_names},
                    fold_dir / "best.ckpt",
                )
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved.")

        # ----- Phase 2: fine-tuning only with REAL images -----
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            running_loss = 0.0
            n_seen = 0
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(
                model,
                val_loader,
                device,
                class_names,
                split_name="val",
                out_dir=fold_dir,
            )
            f1_macro = m_val["overall"]["f1_macro"]
            acc_val = m_val["overall"]["accuracy"]
            print(
                f"[Fold {fold_id} | FT Epoch {epoch:03d}] "
                f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | "
                f"val_f1_macro={f1_macro:.4f}"
            )

            torch.save(
                {"model": model.state_dict(), "epoch": epoch, "class_names": class_names},
                fold_dir / "last.ckpt",
            )

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save(
                    {"model": model.state_dict(), "epoch": epoch, "class_names": class_names},
                    fold_dir / "best.ckpt",
                )
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved (fine-tune).")

        # Re-evaluate BEST and collect OOF for this fold
        best = torch.load(fold_dir / "best.ckpt", map_location=device)
        model.load_state_dict(best["model"])

        print(f"[Fold {fold_id}] Re-evaluating BEST on VAL (and collecting OOF)...")
        m_val_best, _ = evaluate(
            model,
            val_loader,
            device,
            class_names,
            split_name="val_best",
            out_dir=fold_dir,
        )

        # Collect arrays for OOF
        val_inf = infer_loader(model, val_loader, device)  # same order as val_subset (shuffle=False)
        for j, base_i in enumerate(va_idx):
            oof_probs[base_i] = val_inf["probs"][j]
            oof_pred[base_i] = int(val_inf["preds"][j])
            oof_true[base_i] = int(val_inf["labels"][j])
            oof_path[base_i] = val_inf["paths"][j]
            oof_pid[base_i] = val_inf["pids"][j]

        # Row base with full VAL metrics
        row = {
            "fold": fold_id,
            "val_acc": m_val_best["overall"]["accuracy"],
            "val_precision_macro": m_val_best["overall"]["precision_macro"],
            "val_recall_macro": m_val_best["overall"]["recall_macro"],
            "val_f1_macro": m_val_best["overall"]["f1_macro"],
            "val_precision_weighted": m_val_best["overall"]["precision_weighted"],
            "val_recall_weighted": m_val_best["overall"]["recall_weighted"],
            "val_f1_weighted": m_val_best["overall"]["f1_weighted"],
            "val_n": m_val_best["overall"]["num_samples"],
        }

        # INTERNAL TEST per fold + probs for ensemble
        if inttest_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on INTERNAL TEST...")
            m_int, _ = evaluate(
                model,
                inttest_loader,
                device,
                class_names,
                split_name="inttest",
                out_dir=fold_dir,
            )
            row.update({
                "int_acc": m_int["overall"]["accuracy"],
                "int_precision_macro": m_int["overall"]["precision_macro"],
                "int_recall_macro": m_int["overall"]["recall_macro"],
                "int_f1_macro": m_int["overall"]["f1_macro"],
                "int_precision_weighted": m_int["overall"]["precision_weighted"],
                "int_recall_weighted": m_int["overall"]["recall_weighted"],
                "int_f1_weighted": m_int["overall"]["f1_weighted"],
                "int_n": m_int["overall"]["num_samples"],
            })
            t_int = infer_loader(model, inttest_loader, device)
            inttest_probs_folds.append(t_int["probs"])
            if int_ref_paths is None:
                int_ref_paths = t_int["paths"]
                int_ref_pids = t_int["pids"]
                int_ref_labels = t_int["labels"]

        # EXTERNAL TEST per fold + probs for ensemble
        if test_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on EXTERNAL TEST...")
            m_ext, _ = evaluate(
                model,
                test_loader,
                device,
                class_names,
                split_name="test",
                out_dir=fold_dir,
            )
            row.update({
                "test_acc": m_ext["overall"]["accuracy"],
                "test_precision_macro": m_ext["overall"]["precision_macro"],
                "test_recall_macro": m_ext["overall"]["recall_macro"],
                "test_f1_macro": m_ext["overall"]["f1_macro"],
                "test_precision_weighted": m_ext["overall"]["precision_weighted"],
                "test_recall_weighted": m_ext["overall"]["recall_weighted"],
                "test_f1_weighted": m_ext["overall"]["f1_weighted"],
                "test_n": m_ext["overall"]["num_samples"],
            })
            t_inf = infer_loader(model, test_loader, device)
            test_probs_folds.append(t_inf["probs"])
            if test_ref_paths is None:
                test_ref_paths = t_inf["paths"]
                test_ref_pids = t_inf["pids"]
                test_ref_labels = t_inf["labels"]

        cv_rows.append(row)

    # === CV summary (mean ± std) ===
    summary_csv = base_run / "cv_summary.csv"
    keys = sorted(set().union(*[r.keys() for r in cv_rows]))
    with open(summary_csv, "w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=keys)
        w.writeheader()
        for r in cv_rows:
            w.writerow(r)

    def _agg_for(prefix: str) -> Dict[str, Tuple[Optional[float], Optional[float]]]:
        metrics = [
            "acc",
            "precision_macro",
            "recall_macro",
            "f1_macro",
            "precision_weighted",
            "recall_weighted",
            "f1_weighted",
        ]
        out: Dict[str, Tuple[Optional[float], Optional[float]]] = {}
        for m in metrics:
            col = f"{prefix}_{m}"
            vals = [float(r[col]) for r in cv_rows if col in r]
            if len(vals) == 0:
                out[m] = (None, None)
            else:
                out[m] = (float(np.mean(vals)), float(np.std(vals)))
        return out

    cv_stats_full = {
        "kfolds": cfg.kfolds,
        "val": _agg_for("val"),
        "inttest": _agg_for("int") if any(("int_acc" in r) for r in cv_rows) else {},
        "test": _agg_for("test") if any(("test_acc" in r) for r in cv_rows) else {},
    }
    with open(base_run / "cv_summary_full.json", "w", encoding="utf-8") as f:
        json.dump(cv_stats_full, f, indent=2)

    with open(base_run / "cv_summary_full.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["split", "metric", "mean", "std", "k"])
        for split in ["val", "inttest", "test"]:
            if split not in cv_stats_full or not cv_stats_full[split]:
                continue
            for metric, (mu, sd) in cv_stats_full[split].items():
                if mu is None:
                    continue
                w.writerow([split, metric, mu, sd, cfg.kfolds])

    print("[CV] Summary (mean±std) written to cv_summary_full.{json,csv}")

    # === OOF metrics & artifacts ===
    valid_mask = (~np.isnan(oof_probs).any(axis=1)) & (oof_true != -1)
    oof_probs_v = oof_probs[valid_mask]
    oof_pred_v = oof_pred[valid_mask]
    oof_true_v = oof_true[valid_mask]
    oof_path_v = [oof_path[i] for i, ok in enumerate(valid_mask) if ok]
    oof_pid_v = [oof_pid[i] for i, ok in enumerate(valid_mask) if ok]

    if len(oof_true_v) > 0:
        acc = float(accuracy_score(oof_true_v, oof_pred_v))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average="macro", zero_division=0
        )
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average="weighted", zero_division=0
        )
        per_class = classification_report(
            oof_true_v,
            oof_pred_v,
            target_names=class_names,
            output_dict=True,
            zero_division=0,
        )
        cm = confusion_matrix(
            oof_true_v,
            oof_pred_v,
            labels=list(range(len(class_names))),
        )

        oof_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(oof_true_v)),
            },
            "per_class": per_class,
        }
        with open(base_run / "oof_metrics.json", "w", encoding="utf-8") as f:
            json.dump(oof_metrics, f, indent=2)

        with open(base_run / "metrics_overall_oof.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow([
                "split",
                "accuracy",
                "precision_macro",
                "recall_macro",
                "f1_macro",
                "precision_weighted",
                "recall_weighted",
                "f1_weighted",
                "num_samples",
            ])
            o = oof_metrics["overall"]
            w.writerow([
                "oof",
                o["accuracy"],
                o["precision_macro"],
                o["recall_macro"],
                o["f1_macro"],
                o["precision_weighted"],
                o["recall_weighted"],
                o["f1_weighted"],
                o["num_samples"],
            ])

        with open(base_run / "per_class_oof.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["class", "precision", "recall", "f1", "support"])
            for cname in class_names:
                row = per_class.get(
                    cname,
                    {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
                )
                w.writerow([
                    cname,
                    row.get("precision", 0),
                    row.get("recall", 0),
                    row.get("f1-score", 0),
                    row.get("support", 0),
                ])

        with open(base_run / "confusion_oof.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "oof_predictions.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
            for i in range(len(oof_true_v)):
                w.writerow([
                    oof_path_v[i],
                    oof_pid_v[i],
                    class_names[oof_true_v[i]],
                    class_names[oof_pred_v[i]],
                ] + list(map(float, oof_probs_v[i].tolist())))

    # === TEST ensemble (avg across folds) ===
    if test_loader_fixed is not None and len(test_probs_folds) > 0:
        probs_stack = np.stack(test_probs_folds, axis=0)     # [K, N_test, C]
        probs_mean = probs_stack.mean(axis=0)               # [N_test, C]
        preds_ens = probs_mean.argmax(axis=1)

        acc = float(accuracy_score(test_ref_labels, preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            test_ref_labels,
            preds_ens,
            average="macro",
            zero_division=0,
        )
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            test_ref_labels,
            preds_ens,
            average="weighted",
            zero_division=0,
        )
        per_class = classification_report(
            test_ref_labels,
            preds_ens,
            target_names=class_names,
            output_dict=True,
            zero_division=0,
        )
        cm = confusion_matrix(
            test_ref_labels,
            preds_ens,
            labels=list(range(len(class_names))),
        )

        test_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(test_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_test_ensemble.json", "w", encoding="utf-8") as f:
            json.dump(test_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_test_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow([
                "split",
                "accuracy",
                "precision_macro",
                "recall_macro",
                "f1_macro",
                "precision_weighted",
                "recall_weighted",
                "f1_weighted",
                "num_samples",
            ])
            o = test_ens_metrics["overall"]
            w.writerow([
                "test_ensemble",
                o["accuracy"],
                o["precision_macro"],
                o["recall_macro"],
                o["f1_macro"],
                o["precision_weighted"],
                o["recall_weighted"],
                o["f1_weighted"],
                o["num_samples"],
            ])

        with open(base_run / "per_class_test_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["class", "precision", "recall", "f1", "support"])
            for cname in class_names:
                row = per_class.get(
                    cname,
                    {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
                )
                w.writerow([
                    cname,
                    row.get("precision", 0),
                    row.get("recall", 0),
                    row.get("f1-score", 0),
                    row.get("support", 0),
                ])

        with open(base_run / "confusion_test_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "test_ensemble_predictions.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
            for i in range(len(test_ref_labels)):
                w.writerow([
                    test_ref_paths[i],
                    test_ref_pids[i],
                    class_names[int(test_ref_labels[i])],
                    class_names[int(preds_ens[i])],
                ] + list(map(float, probs_mean[i].tolist())))

    # === INTTEST ensemble (avg across folds) ===
    if inttest_loader_fixed is not None and len(inttest_probs_folds) > 0:
        int_probs_stack = np.stack(inttest_probs_folds, axis=0)  # [K, N_int, C]
        int_probs_mean = int_probs_stack.mean(axis=0)           # [N_int, C]
        int_preds_ens = int_probs_mean.argmax(axis=1)

        acc = float(accuracy_score(int_ref_labels, int_preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            int_ref_labels,
            int_preds_ens,
            average="macro",
            zero_division=0,
        )
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            int_ref_labels,
            int_preds_ens,
            average="weighted",
            zero_division=0,
        )
        per_class = classification_report(
            int_ref_labels,
            int_preds_ens,
            target_names=class_names,
            output_dict=True,
            zero_division=0,
        )
        cm = confusion_matrix(
            int_ref_labels,
            int_preds_ens,
            labels=list(range(len(class_names))),
        )

        int_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(int_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_inttest_ensemble.json", "w", encoding="utf-8") as f:
            json.dump(int_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_inttest_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow([
                "split",
                "accuracy",
                "precision_macro",
                "recall_macro",
                "f1_macro",
                "precision_weighted",
                "recall_weighted",
                "f1_weighted",
                "num_samples",
            ])
            o = int_ens_metrics["overall"]
            w.writerow([
                "inttest_ensemble",
                o["accuracy"],
                o["precision_macro"],
                o["recall_macro"],
                o["f1_macro"],
                o["precision_weighted"],
                o["recall_weighted"],
                o["f1_weighted"],
                o["num_samples"],
            ])

        with open(base_run / "per_class_inttest_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["class", "precision", "recall", "f1", "support"])
            for cname in class_names:
                row = per_class.get(
                    cname,
                    {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
                )
                w.writerow([
                    cname,
                    row.get("precision", 0),
                    row.get("recall", 0),
                    row.get("f1-score", 0),
                    row.get("support", 0),
                ])

        with open(base_run / "confusion_inttest_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "inttest_ensemble_predictions.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
            for i in range(len(int_ref_labels)):
                w.writerow([
                    int_ref_paths[i],
                    int_ref_pids[i],
                    class_names[int(int_ref_labels[i])],
                    class_names[int(int_preds_ens[i])],
                ] + list(map(float, int_probs_mean[i].tolist())))

    # (Optional) train on FULL pool and evaluate test once
    if cfg.train_full_after_cv:
        print("\n[Full Train] Training with full pool (no internal test)...")
        run_full = base_run / "full_train"
        run_full.mkdir(parents=True, exist_ok=True)

        real_train_subset = list(base_pool)

        if cfg.balance_mode == "gan_balance" and len(synth_items) > 0:
            full_train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + 999,
            )
            print(
                f"[Full Train] real={len(real_train_subset)} | "
                f"train_balanced(real+GAN)={len(full_train_subset)}"
            )
        elif cfg.balance_mode == "oversample":
            full_train_subset = build_oversampled_train_subset(
                real_train_subset=real_train_subset,
                num_classes=len(class_names),
                seed=cfg.seed + 999,
            )
            print(
                f"[Full Train] real={len(real_train_subset)} | "
                f"oversampled(real-only)={len(full_train_subset)}"
            )
        else:
            full_train_subset = real_train_subset + (synth_items if len(synth_items) > 0 else [])
            print(
                f"[Full Train] real={len(real_train_subset)} + synth={len(synth_items)} "
                f"-> {len(full_train_subset)}"
            )

        train_ds = MRIDataset(full_train_subset, image_size=cfg.image_size, aug=False)
        real_train_ds = MRIDataset(real_train_subset, image_size=cfg.image_size, aug=False)

        train_loader = DataLoader(
            train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )
        real_train_loader = DataLoader(
            real_train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()
        amp_enabled = (cfg.amp and device.type == "cuda")
        scaler = torch.amp.GradScaler("cuda", enabled=amp_enabled)

        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft = cfg.fine_tune_real_epochs

        # Full-train Phase 1: full_train_subset (real + synth balanced or not)
        for epoch in range(1, epochs_main + 1):
            model.train()
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        # Full-train Phase 2: REAL only
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        torch.save(
            {"model": model.state_dict(), "class_names": class_names},
            run_full / "final_full.ckpt",
        )

        if test_loader_fixed is not None:
            print("[Full Train] Evaluating on TEST ...")
            evaluate(
                model,
                test_loader_fixed,
                device,
                class_names,
                split_name="test_full",
                out_dir=run_full,
            )

    print(f"\n[Artifacts] Saved at: {base_run}")
    return base_run

# %%
# run_b1_ablation.py

from pathlib import Path

# === Paths (ADAPT TO YOUR SETUP) ===
data_root="/content/localdata/train_unzipped/trainreducido",
test_root="/content/localdata/test_unzipped/testreducido",
out_dir="/content/drive/MyDrive/TESIS/StyleGan2/5koversample",
gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl"

# Common configuration for all B1 runs
common_kwargs = dict(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    image_size=256,
    batch_size=32,
    epochs=20,
    lr=1e-3,
    weight_decay=1e-4,
    num_workers=4,
    seed=122,
    kfolds=5,
    amp=True,
    pretrained=True,
    internal_test_ratio=0.0,
    fine_tune_real_epochs=0,
    train_full_after_cv=True,
)

# B1.1: Real-only with naive oversampling (no GAN)
cfg_b1_real_oversample = Config(
    out_dir="runs/2c_b1_real_oversample",
    gan_pkl="",                 # no GAN
    images_per_class=0,
    balance_gan_to_max=False,
    balance_mode="oversample",  # <-- oversampling real-only
    **common_kwargs,
)

# B1.2: GAN-balanced (real + synthetic) with weak augmentation
cfg_b1_gan_balance = Config(
    out_dir="runs/2c_b1_gan_balance",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    images_per_class=0,         # ignored when balance_gan_to_max=True
    balance_gan_to_max=True,    # global real max per class
    balance_mode="gan_balance", # <-- GAN-balanced
    **common_kwargs,
)

if __name__ == "__main__":
    experiments = [
        ("B1_real_oversample", cfg_b1_real_oversample)
    ]

    for name, cfg in experiments:
        print(f"\n==== Running {name} ====")
        run_dir = train_kfold(cfg)
        print(f"{name} finished. Artifacts in: {run_dir}")
# Out:
# ==== Running B1_real_oversample ====
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] gan_pkl empty -> NO GAN will be used.
#
# ===== FOLD 1/5 =====
# [OVERSAMPLE] Real class counts (fold): [499, 304, 491] -> target=499
# [OVERSAMPLE] Fold train size: real=1294 -> oversampled=1497
# [OVERSAMPLE] Fold 1: using oversampled real-only train set, n=1497
# [ID-STATS] fold1_train: unique patient IDs total = 125 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=46 images=499
#   - pituitary: ids=38 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.5469 | val_acc=0.7134 | val_f1_macro=0.6612
# [Fold 1] New best (F1_macro=0.6612) saved.
# [Fold 1 | Epoch 002] train_loss=0.2454 | val_acc=0.6352 | val_f1_macro=0.6273
# [Fold 1 | Epoch 003] train_loss=0.2182 | val_acc=0.6710 | val_f1_macro=0.6352
# [Fold 1 | Epoch 004] train_loss=0.2084 | val_acc=0.7590 | val_f1_macro=0.7579
# [Fold 1] New best (F1_macro=0.7579) saved.
# [Fold 1 | Epoch 005] train_loss=0.1587 | val_acc=0.9121 | val_f1_macro=0.9088
# [Fold 1] New best (F1_macro=0.9088) saved.
# [Fold 1 | Epoch 006] train_loss=0.1619 | val_acc=0.8730 | val_f1_macro=0.8663
# [Fold 1 | Epoch 007] train_loss=0.1381 | val_acc=0.8436 | val_f1_macro=0.8483
# [Fold 1 | Epoch 008] train_loss=0.1071 | val_acc=0.9055 | val_f1_macro=0.9050
# [Fold 1 | Epoch 009] train_loss=0.1647 | val_acc=0.8795 | val_f1_macro=0.8781
# [Fold 1 | Epoch 010] train_loss=0.1208 | val_acc=0.8502 | val_f1_macro=0.8488
# [Fold 1 | Epoch 011] train_loss=0.0958 | val_acc=0.9023 | val_f1_macro=0.9065
# [Fold 1 | Epoch 012] train_loss=0.0690 | val_acc=0.8990 | val_f1_macro=0.9053
# [Fold 1 | Epoch 013] train_loss=0.0297 | val_acc=0.9023 | val_f1_macro=0.9038
# [Fold 1 | Epoch 014] train_loss=0.0275 | val_acc=0.9316 | val_f1_macro=0.9335
# [Fold 1] New best (F1_macro=0.9335) saved.
# [Fold 1 | Epoch 015] train_loss=0.0361 | val_acc=0.9283 | val_f1_macro=0.9290
# [Fold 1 | Epoch 016] train_loss=0.0261 | val_acc=0.9186 | val_f1_macro=0.9189
# [Fold 1 | Epoch 017] train_loss=0.0154 | val_acc=0.9316 | val_f1_macro=0.9321
# [Fold 1 | Epoch 018] train_loss=0.0186 | val_acc=0.9218 | val_f1_macro=0.9227
# [Fold 1 | Epoch 019] train_loss=0.0170 | val_acc=0.9316 | val_f1_macro=0.9326
# [Fold 1 | Epoch 020] train_loss=0.0121 | val_acc=0.9316 | val_f1_macro=0.9328
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [OVERSAMPLE] Real class counts (fold): [524, 342, 422] -> target=524
# [OVERSAMPLE] Fold train size: real=1288 -> oversampled=1572
# [OVERSAMPLE] Fold 2: using oversampled real-only train set, n=1572
# [ID-STATS] fold2_train: unique patient IDs total = 124 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=47 images=524
#   - pituitary: ids=33 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.4392 | val_acc=0.8211 | val_f1_macro=0.8072
# [Fold 2] New best (F1_macro=0.8072) saved.
# [Fold 2 | Epoch 002] train_loss=0.2527 | val_acc=0.8211 | val_f1_macro=0.8048
# [Fold 2 | Epoch 003] train_loss=0.2444 | val_acc=0.5335 | val_f1_macro=0.5033
# [Fold 2 | Epoch 004] train_loss=0.2400 | val_acc=0.7508 | val_f1_macro=0.7167
# [Fold 2 | Epoch 005] train_loss=0.2129 | val_acc=0.9010 | val_f1_macro=0.8671
# [Fold 2] New best (F1_macro=0.8671) saved.
# [Fold 2 | Epoch 006] train_loss=0.1569 | val_acc=0.9297 | val_f1_macro=0.9147
# [Fold 2] New best (F1_macro=0.9147) saved.
# [Fold 2 | Epoch 007] train_loss=0.1705 | val_acc=0.9137 | val_f1_macro=0.8969
# [Fold 2 | Epoch 008] train_loss=0.1607 | val_acc=0.9042 | val_f1_macro=0.8885
# [Fold 2 | Epoch 009] train_loss=0.1186 | val_acc=0.8850 | val_f1_macro=0.8611
# [Fold 2 | Epoch 010] train_loss=0.1528 | val_acc=0.9073 | val_f1_macro=0.8864
# [Fold 2 | Epoch 011] train_loss=0.0797 | val_acc=0.9010 | val_f1_macro=0.8807
# [Fold 2 | Epoch 012] train_loss=0.0802 | val_acc=0.8946 | val_f1_macro=0.8625
# [Fold 2 | Epoch 013] train_loss=0.2577 | val_acc=0.8690 | val_f1_macro=0.8488
# [Fold 2 | Epoch 014] train_loss=0.0983 | val_acc=0.9073 | val_f1_macro=0.8803
# [Fold 2 | Epoch 015] train_loss=0.0675 | val_acc=0.9105 | val_f1_macro=0.8873
# [Fold 2 | Epoch 016] train_loss=0.0680 | val_acc=0.8882 | val_f1_macro=0.8626
# [Fold 2 | Epoch 017] train_loss=0.0527 | val_acc=0.8978 | val_f1_macro=0.8706
# [Fold 2 | Epoch 018] train_loss=0.0644 | val_acc=0.9042 | val_f1_macro=0.8824
# [Fold 2 | Epoch 019] train_loss=0.0524 | val_acc=0.9010 | val_f1_macro=0.8772
# [Fold 2 | Epoch 020] train_loss=0.0622 | val_acc=0.9105 | val_f1_macro=0.8899
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [OVERSAMPLE] Real class counts (fold): [506, 301, 450] -> target=506
# [OVERSAMPLE] Fold train size: real=1257 -> oversampled=1518
# [OVERSAMPLE] Fold 3: using oversampled real-only train set, n=1518
# [ID-STATS] fold3_train: unique patient IDs total = 125 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=46 images=506
#   - pituitary: ids=35 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.4554 | val_acc=0.6105 | val_f1_macro=0.5850
# [Fold 3] New best (F1_macro=0.5850) saved.
# [Fold 3 | Epoch 002] train_loss=0.2340 | val_acc=0.8663 | val_f1_macro=0.8589
# [Fold 3] New best (F1_macro=0.8589) saved.
# [Fold 3 | Epoch 003] train_loss=0.2459 | val_acc=0.6948 | val_f1_macro=0.6880
# [Fold 3 | Epoch 004] train_loss=0.1851 | val_acc=0.6047 | val_f1_macro=0.5762
# [Fold 3 | Epoch 005] train_loss=0.2211 | val_acc=0.8430 | val_f1_macro=0.8350
# [Fold 3 | Epoch 006] train_loss=0.1621 | val_acc=0.8837 | val_f1_macro=0.8765
# [Fold 3] New best (F1_macro=0.8765) saved.
# [Fold 3 | Epoch 007] train_loss=0.1216 | val_acc=0.8256 | val_f1_macro=0.8260
# [Fold 3 | Epoch 008] train_loss=0.1269 | val_acc=0.8372 | val_f1_macro=0.8207
# [Fold 3 | Epoch 009] train_loss=0.0881 | val_acc=0.8779 | val_f1_macro=0.8738
# [Fold 3 | Epoch 010] train_loss=0.0637 | val_acc=0.8488 | val_f1_macro=0.8458
# [Fold 3 | Epoch 011] train_loss=0.0732 | val_acc=0.8401 | val_f1_macro=0.8297
# [Fold 3 | Epoch 012] train_loss=0.0775 | val_acc=0.8808 | val_f1_macro=0.8766
# [Fold 3] New best (F1_macro=0.8766) saved.
# [Fold 3 | Epoch 013] train_loss=0.0326 | val_acc=0.8459 | val_f1_macro=0.8444
# [Fold 3 | Epoch 014] train_loss=0.0328 | val_acc=0.8953 | val_f1_macro=0.8920
# [Fold 3] New best (F1_macro=0.8920) saved.
# [Fold 3 | Epoch 015] train_loss=0.0282 | val_acc=0.8866 | val_f1_macro=0.8838
# [Fold 3 | Epoch 016] train_loss=0.0193 | val_acc=0.9041 | val_f1_macro=0.8988
# [Fold 3] New best (F1_macro=0.8988) saved.
# [Fold 3 | Epoch 017] train_loss=0.0167 | val_acc=0.8924 | val_f1_macro=0.8869
# [Fold 3 | Epoch 018] train_loss=0.0070 | val_acc=0.9012 | val_f1_macro=0.8965
# [Fold 3 | Epoch 019] train_loss=0.0128 | val_acc=0.8895 | val_f1_macro=0.8852
# [Fold 3 | Epoch 020] train_loss=0.0196 | val_acc=0.8895 | val_f1_macro=0.8852
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [OVERSAMPLE] Real class counts (fold): [450, 370, 424] -> target=450
# [OVERSAMPLE] Fold train size: real=1244 -> oversampled=1350
# [OVERSAMPLE] Fold 4: using oversampled real-only train set, n=1350
# [ID-STATS] fold4_train: unique patient IDs total = 125 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=51 images=450
#   - pituitary: ids=34 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.5915 | val_acc=0.6246 | val_f1_macro=0.4869
# [Fold 4] New best (F1_macro=0.4869) saved.
# [Fold 4 | Epoch 002] train_loss=0.3575 | val_acc=0.8599 | val_f1_macro=0.8241
# [Fold 4] New best (F1_macro=0.8241) saved.
# [Fold 4 | Epoch 003] train_loss=0.2500 | val_acc=0.9300 | val_f1_macro=0.8947
# [Fold 4] New best (F1_macro=0.8947) saved.
# [Fold 4 | Epoch 004] train_loss=0.2305 | val_acc=0.6078 | val_f1_macro=0.5852
# [Fold 4 | Epoch 005] train_loss=0.3791 | val_acc=0.8711 | val_f1_macro=0.8209
# [Fold 4 | Epoch 006] train_loss=0.2157 | val_acc=0.8655 | val_f1_macro=0.8015
# [Fold 4 | Epoch 007] train_loss=0.1896 | val_acc=0.8796 | val_f1_macro=0.7996
# [Fold 4 | Epoch 008] train_loss=0.1422 | val_acc=0.9468 | val_f1_macro=0.8992
# [Fold 4] New best (F1_macro=0.8992) saved.
# [Fold 4 | Epoch 009] train_loss=0.1236 | val_acc=0.9384 | val_f1_macro=0.9045
# [Fold 4] New best (F1_macro=0.9045) saved.
# [Fold 4 | Epoch 010] train_loss=0.1705 | val_acc=0.9216 | val_f1_macro=0.8627
# [Fold 4 | Epoch 011] train_loss=0.1488 | val_acc=0.9524 | val_f1_macro=0.9234
# [Fold 4] New best (F1_macro=0.9234) saved.
# [Fold 4 | Epoch 012] train_loss=0.0858 | val_acc=0.9664 | val_f1_macro=0.9594
# [Fold 4] New best (F1_macro=0.9594) saved.
# [Fold 4 | Epoch 013] train_loss=0.0780 | val_acc=0.9664 | val_f1_macro=0.9565
# [Fold 4 | Epoch 014] train_loss=0.1121 | val_acc=0.9636 | val_f1_macro=0.9408
# [Fold 4 | Epoch 015] train_loss=0.0572 | val_acc=0.9608 | val_f1_macro=0.9387
# [Fold 4 | Epoch 016] train_loss=0.0459 | val_acc=0.9692 | val_f1_macro=0.9593
# [Fold 4 | Epoch 017] train_loss=0.0393 | val_acc=0.9664 | val_f1_macro=0.9572
# [Fold 4 | Epoch 018] train_loss=0.0390 | val_acc=0.9580 | val_f1_macro=0.9387
# [Fold 4 | Epoch 019] train_loss=0.0311 | val_acc=0.9580 | val_f1_macro=0.9384
# [Fold 4 | Epoch 020] train_loss=0.0336 | val_acc=0.9664 | val_f1_macro=0.9540
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [OVERSAMPLE] Real class counts (fold): [557, 307, 457] -> target=557
# [OVERSAMPLE] Fold train size: real=1321 -> oversampled=1671
# [OVERSAMPLE] Fold 5: using oversampled real-only train set, n=1671
# [ID-STATS] fold5_train: unique patient IDs total = 125 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=42 images=557
#   - pituitary: ids=36 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.4408 | val_acc=0.5536 | val_f1_macro=0.4887
# [Fold 5] New best (F1_macro=0.4887) saved.
# [Fold 5 | Epoch 002] train_loss=0.3054 | val_acc=0.6786 | val_f1_macro=0.6527
# [Fold 5] New best (F1_macro=0.6527) saved.
# [Fold 5 | Epoch 003] train_loss=0.2229 | val_acc=0.7250 | val_f1_macro=0.7209
# [Fold 5] New best (F1_macro=0.7209) saved.
# [Fold 5 | Epoch 004] train_loss=0.2339 | val_acc=0.8929 | val_f1_macro=0.8858
# [Fold 5] New best (F1_macro=0.8858) saved.
# [Fold 5 | Epoch 005] train_loss=0.1709 | val_acc=0.9000 | val_f1_macro=0.8977
# [Fold 5] New best (F1_macro=0.8977) saved.
# [Fold 5 | Epoch 006] train_loss=0.1803 | val_acc=0.6821 | val_f1_macro=0.6861
# [Fold 5 | Epoch 007] train_loss=0.2081 | val_acc=0.7286 | val_f1_macro=0.7133
# [Fold 5 | Epoch 008] train_loss=0.1244 | val_acc=0.7786 | val_f1_macro=0.7624
# [Fold 5 | Epoch 009] train_loss=0.1873 | val_acc=0.8071 | val_f1_macro=0.8049
# [Fold 5 | Epoch 010] train_loss=0.1410 | val_acc=0.8357 | val_f1_macro=0.8360
# [Fold 5 | Epoch 011] train_loss=0.0930 | val_acc=0.8857 | val_f1_macro=0.8849
# [Fold 5 | Epoch 012] train_loss=0.1044 | val_acc=0.8964 | val_f1_macro=0.8961
# [Fold 5 | Epoch 013] train_loss=0.0638 | val_acc=0.8714 | val_f1_macro=0.8710
# [Fold 5 | Epoch 014] train_loss=0.0580 | val_acc=0.8607 | val_f1_macro=0.8614
# [Fold 5 | Epoch 015] train_loss=0.0616 | val_acc=0.8679 | val_f1_macro=0.8675
# [Fold 5 | Epoch 016] train_loss=0.0422 | val_acc=0.8500 | val_f1_macro=0.8501
# [Fold 5 | Epoch 017] train_loss=0.0382 | val_acc=0.9036 | val_f1_macro=0.9028
# [Fold 5] New best (F1_macro=0.9028) saved.
# [Fold 5 | Epoch 018] train_loss=0.0351 | val_acc=0.9179 | val_f1_macro=0.9167
# [Fold 5] New best (F1_macro=0.9167) saved.
# [Fold 5 | Epoch 019] train_loss=0.0290 | val_acc=0.9000 | val_f1_macro=0.8993
# [Fold 5 | Epoch 020] train_loss=0.0464 | val_acc=0.9071 | val_f1_macro=0.9064
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [OVERSAMPLE] Real class counts (fold): [634, 406, 561] -> target=634
# [OVERSAMPLE] Fold train size: real=1601 -> oversampled=1902
# [Full Train] real=1601 | oversampled(real-only)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: runs/2c_b1_real_oversample/kfold_5f_run_20251125-235412
# B1_real_oversample finished. Artifacts in: runs/2c_b1_real_oversample/kfold_5f_run_20251125-235412

# %%
# exp2c_b2_kfold_resnet.py

# -*- coding: utf-8 -*-
"""
Experiment 2C - Ablation B2: effect of data augmentation strength (real-only oversampling)
- K-Fold training (by patient) for brain tumor classification (ResNet50)
- No-leak by patient_id (groups)
- Real-only data (no GAN), with per-fold oversampling to balance classes
- Two main settings:
    * Weak augmentation (baseline)
    * Strong classical augmentation (B2)
- Per-fold metrics + CV summary
- OOF (out-of-fold) predictions & metrics (one row per pool sample, predicted by a model that did not see it)
- Optional external TEST evaluation per fold + K-fold ensemble (avg probs across folds)
- Optional INTERNAL TEST evaluation (holdout before CV) + ensemble
"""

import os
import json
import time
import csv
import math
import random
from dataclasses import dataclass, asdict
from pathlib import Path
from typing import List, Tuple, Dict, Optional

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

from sklearn.metrics import (
    accuracy_score,
    precision_recall_fscore_support,
    classification_report,
    confusion_matrix,
)

# ====== Splitters (StratifiedGroupKFold if available) ======
try:
    from sklearn.model_selection import StratifiedGroupKFold
    HAS_SGTK = True
except Exception:
    HAS_SGTK = False
    from sklearn.model_selection import GroupKFold


# ====== Utils ======

def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
    try:
        torch.set_float32_matmul_precision("high")
    except Exception:
        pass


def timestamp() -> str:
    return time.strftime("%Y%m%d-%H%M%S")


def extract_patient_id(p: Path) -> str:
    # Assumes filenames like "<patientID>_something.png"
    stem = p.stem
    token = stem.split("_")[0]
    return token.strip().lower()


IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}


# ====== Config ======

@dataclass
class Config:
    data_root: str
    out_dir: str
    test_root: str = ""
    internal_test_ratio: float = 0.0   # optional: holdout before CV (by patient)
    image_size: int = 256
    batch_size: int = 32
    epochs: int = 15
    lr: float = 1e-3
    weight_decay: float = 1e-4
    num_workers: int = 4
    seed: int = 42
    kfolds: int = 5
    amp: bool = True
    pretrained: bool = True
    train_full_after_cv: bool = False   # optional: retrain on full pool at end

    # Fine-tuning only on REAL images (last epochs)
    fine_tune_real_epochs: int = 0      # 0 = disabled

    # Ablation B2: augmentation strength
    strong_aug: bool = False            # False = weak aug, True = strong aug


# ====== Dataset ======

class MRIDataset(Dataset):
    def __init__(
        self,
        items: List[Tuple[Path, int, str]],
        image_size: int = 256,
        aug: bool = False,
        strong_aug: bool = False,
    ):
        self.items = items
        self.image_size = image_size
        self.aug = aug
        self.strong_aug = strong_aug

        mean = [0.5, 0.5, 0.5]
        std = [0.5, 0.5, 0.5]

        if not aug:
            # Validation / test: no spatial augmentation
            self.tf = transforms.Compose([
                transforms.Resize((image_size, image_size)),
                transforms.ToTensor(),
            ])
        else:
            if strong_aug:
                # Strong classical augmentation (B2)
                self.tf = transforms.Compose([
                    transforms.RandomResizedCrop(image_size, scale=(0.7, 1.0), ratio=(0.9, 1.1)),
                    transforms.RandomHorizontalFlip(),
                    transforms.RandomVerticalFlip(),
                    transforms.RandomRotation(15),
                    transforms.ColorJitter(brightness=0.2, contrast=0.2),
                    transforms.RandomAffine(degrees=0, translate=(0.05, 0.05), shear=5),
                    transforms.GaussianBlur(kernel_size=3),
                    transforms.ToTensor(),
                ])
            else:
                # Weak augmentation (baseline)
                self.tf = transforms.Compose([
                    transforms.RandomResizedCrop(image_size, scale=(0.9, 1.0), ratio=(0.95, 1.05)),
                    transforms.RandomHorizontalFlip(),
                    transforms.RandomVerticalFlip(),
                    transforms.RandomRotation(10),
                    transforms.ToTensor(),
                ])

        self.norm = transforms.Normalize(mean=mean, std=std)

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        path, y, pid = self.items[idx]
        img = Image.open(path).convert("L")
        img = self.tf(img)           # [1,H,W]
        img = img.repeat(3, 1, 1)    # [3,H,W]
        img = self.norm(img)
        return img, y, str(path), pid


# ====== Scan & Helpers ======

def scan_folder(root: Path) -> Tuple[List[Tuple[Path, int, str]], List[str]]:
    assert root.is_dir(), f"Not a directory: {root}"
    class_names = sorted([d.name for d in root.iterdir() if d.is_dir()])
    items: List[Tuple[Path, int, str]] = []
    for ci, cname in enumerate(class_names):
        cdir = root / cname
        for p in cdir.rglob("*"):
            if p.suffix.lower() in IMG_EXTS:
                pid = extract_patient_id(p)
                items.append((p, ci, pid))
    return items, class_names


def ensure_no_overlap(ids_a: List[str], ids_b: List[str]) -> Tuple[int, List[str]]:
    a = set(ids_a)
    b = set(ids_b)
    inter = sorted(a.intersection(b))
    return len(inter), inter


def summarize_id_counts(
    items: List[Tuple[Path, int, str]],
    class_names: List[str],
    split_name: str,
    out_dir: Path,
):
    from collections import defaultdict

    ids_by_class = defaultdict(set)
    imgs_by_class = defaultdict(int)
    all_ids = set()

    for p, ci, pid in items:
        ids_by_class[ci].add(pid)
        imgs_by_class[ci] += 1
        all_ids.add(pid)

    print(f"[ID-STATS] {split_name}: unique patient IDs total = {len(all_ids)} | images = {len(items)}")
    for ci, cname in enumerate(class_names):
        print(f"  - {cname}: ids={len(ids_by_class[ci])} images={imgs_by_class[ci]}")

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"id_counts_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["class", "n_unique_ids", "n_images"])
        for ci, cname in enumerate(class_names):
            w.writerow([cname, len(ids_by_class[ci]), imgs_by_class[ci]])
        w.writerow(["__TOTAL__", len(all_ids), len(items)])


# ====== Model ======

def build_model(num_classes: int, pretrained: bool = True) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m


# ====== Evaluation Helpers ======

@torch.no_grad()
def evaluate(
    model: nn.Module,
    loader: DataLoader,
    device: torch.device,
    class_names: List[str],
    split_name: str,
    out_dir: Path,
):
    model.eval()
    all_probs, all_preds, all_labels = [], [], []
    all_paths, all_pids = [], []

    for imgs, ys, paths, pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        all_paths.extend(list(paths))
        all_pids.extend(list(pids))

    if all_probs:
        probs = np.concatenate(all_probs, axis=0)
        preds = np.concatenate(all_preds, axis=0)
        labels = np.concatenate(all_labels, axis=0)
    else:
        probs = np.zeros((0, len(class_names)))
        preds = np.zeros((0,), dtype=np.int64)
        labels = np.zeros((0,), dtype=np.int64)

    acc = float(accuracy_score(labels, preds)) if len(labels) else 0.0
    prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
        labels, preds, average="macro", zero_division=0
    )
    prec_weighted, rec_weighted, f1_weighted, _ = precision_recall_fscore_support(
        labels, preds, average="weighted", zero_division=0
    )
    per_class = classification_report(
        labels, preds, target_names=class_names, output_dict=True, zero_division=0
    )
    cm = confusion_matrix(labels, preds, labels=list(range(len(class_names))))

    metrics = {
        "overall": {
            "accuracy": acc,
            "precision_macro": prec_macro,
            "recall_macro": rec_macro,
            "f1_macro": f1_macro,
            "precision_weighted": prec_weighted,
            "recall_weighted": rec_weighted,
            "f1_weighted": f1_weighted,
            "num_samples": len(labels),
        },
        "per_class": per_class,
    }

    out_dir.mkdir(parents=True, exist_ok=True)

    # JSON metrics
    with open(out_dir / f"metrics_{split_name}.json", "w", encoding="utf-8") as f:
        json.dump(metrics, f, indent=2)

    # Overall CSV
    with open(out_dir / f"metrics_overall_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow([
            "split",
            "accuracy",
            "precision_macro",
            "recall_macro",
            "f1_macro",
            "precision_weighted",
            "recall_weighted",
            "f1_weighted",
            "num_samples",
        ])
        o = metrics["overall"]
        w.writerow([
            split_name,
            o["accuracy"],
            o["precision_macro"],
            o["recall_macro"],
            o["f1_macro"],
            o["precision_weighted"],
            o["recall_weighted"],
            o["f1_weighted"],
            o["num_samples"],
        ])

    # Per-class CSV
    with open(out_dir / f"per_class_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["class", "precision", "recall", "f1", "support"])
        for cname in class_names:
            row = per_class.get(
                cname,
                {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
            )
            w.writerow([
                cname,
                row.get("precision", 0),
                row.get("recall", 0),
                row.get("f1-score", 0),
                row.get("support", 0),
            ])

    # Confusion matrix CSV
    with open(out_dir / f"confusion_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["true\\pred"] + class_names)
        for i, cname in enumerate(class_names):
            w.writerow([cname] + list(cm[i]))

    # Predictions CSV
    with open(out_dir / f"predictions_{split_name}.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
        for i in range(len(labels)):
            w.writerow([
                all_paths[i],
                all_pids[i],
                class_names[int(labels[i])],
                class_names[int(preds[i])],
            ] + list(map(float, probs[i].tolist())))

    return metrics, cm


@torch.no_grad()
def infer_loader(
    model: nn.Module,
    loader: DataLoader,
    device: torch.device,
):
    model.eval()
    paths, pids = [], []
    all_probs, all_preds, all_labels = [], [], []

    for imgs, ys, batch_paths, batch_pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        paths.extend(list(batch_paths))
        pids.extend(list(batch_pids))

    if all_probs:
        probs = np.concatenate(all_probs, axis=0)
        preds = np.concatenate(all_preds, axis=0)
        labels = np.concatenate(all_labels, axis=0)
    else:
        probs = np.zeros((0, 0))
        preds = np.zeros((0,), dtype=np.int64)
        labels = np.zeros((0,), dtype=np.int64)

    return {
        "probs": probs,
        "preds": preds,
        "labels": labels,
        "paths": paths,
        "pids": pids,
    }


def collate_fn(batch):
    imgs, ys, paths, pids = zip(*batch)
    return (
        torch.stack(imgs, dim=0),
        torch.tensor(ys, dtype=torch.long),
        list(paths),
        list(pids),
    )


# ====== Helper: build oversampled real-only subset ======

def build_oversampled_train_subset(
    real_train_subset: List[Tuple[Path, int, str]],
    num_classes: int,
    seed: int,
) -> List[Tuple[Path, int, str]]:
    """
    Real-only per-fold oversampling:
    - Compute the number of real samples per class.
    - Find target = max_real_count.
    - For each class c, if count(c) < target, sample with replacement from its own pool
      until reaching target.
    """
    from collections import defaultdict

    rng = random.Random(seed)

    real_by_class: Dict[int, List[Tuple[Path, int, str]]] = defaultdict(list)
    for item in real_train_subset:
        _, ci, _ = item
        real_by_class[ci].append(item)

    counts_real = [len(real_by_class[c]) for c in range(num_classes)]
    target = max(counts_real) if counts_real else 0
    print(f"[OVERSAMPLE] Real class counts (fold): {counts_real} -> target={target}")

    balanced: List[Tuple[Path, int, str]] = []

    for ci in range(num_classes):
        pool = real_by_class[ci]
        if not pool:
            print(f"[OVERSAMPLE] WARNING: no real images for class index {ci}")
            continue
        # Always include the original samples
        balanced.extend(pool)
        need = target - len(pool)
        for _ in range(max(0, need)):
            balanced.append(rng.choice(pool))

    print(f"[OVERSAMPLE] Fold oversampled size: {len(balanced)}")
    return balanced


# ====== K-Fold Train (Experiment 2C - B2) ======

def train_kfold(cfg: Config):
    if cfg.fine_tune_real_epochs < 0 or cfg.fine_tune_real_epochs > cfg.epochs:
        raise ValueError("fine_tune_real_epochs must be between 0 and cfg.epochs")

    base_run = Path(cfg.out_dir) / f"b2_{cfg.kfolds}f_run_{timestamp()}"
    base_run.mkdir(parents=True, exist_ok=True)
    with open(base_run / "config.json", "w", encoding="utf-8") as f:
        json.dump(asdict(cfg), f, indent=2)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"[Device] Using {device}")

    # Scan pool
    all_items, class_names = scan_folder(Path(cfg.data_root))
    print(f"[Scan] Pool images: {len(all_items)} | Classes: {class_names}")

    # Optional internal-test holdout (by patient)
    inttest_subset: List[Tuple[Path, int, str]] = []
    if cfg.internal_test_ratio and cfg.internal_test_ratio > 0:
        from sklearn.model_selection import GroupShuffleSplit

        X_all = np.arange(len(all_items))
        y_all = np.array([lbl for _, lbl, _ in all_items])
        g_all = np.array([pid for _, _, pid in all_items])

        gss = GroupShuffleSplit(
            n_splits=1,
            test_size=cfg.internal_test_ratio,
            random_state=cfg.seed,
        )
        trval_idx, inttest_idx = next(gss.split(X_all, y_all, g_all))
        base_pool = [all_items[i] for i in trval_idx]
        inttest_subset = [all_items[i] for i in inttest_idx]
        print(f"[Split] Internal test: {len(inttest_subset)} images ({cfg.internal_test_ratio * 100:.1f}%)")
    else:
        base_pool = all_items

    # External test (leak-sanitized vs pool & internal test)
    ext_subset: List[Tuple[Path, int, str]] = []
    if cfg.test_root and len(cfg.test_root.strip()) > 0 and Path(cfg.test_root).exists():
        ext_items, _ = scan_folder(Path(cfg.test_root))
        ids_pool = set(pid for _, _, pid in base_pool)
        if len(inttest_subset) > 0:
            ids_pool |= set(pid for _, _, pid in inttest_subset)
        for it in ext_items:
            if it[2] not in ids_pool:
                ext_subset.append(it)
        removed = len(ext_items) - len(ext_subset)
        if removed > 0:
            print(f"[LEAK-FIX] Removed {removed} overlapping ext-test images by patient ID.")
        print(f"[Scan] External test images (sanitized): {len(ext_subset)}")

    # Build folds grouped by patient (REAL only)
    X = np.arange(len(base_pool))
    y = np.array([lbl for _, lbl, _ in base_pool])
    groups = np.array([pid for _, _, pid in base_pool])

    if cfg.kfolds < 2:
        raise ValueError("kfolds must be >= 2")

    if HAS_SGTK:
        splitter = StratifiedGroupKFold(
            n_splits=cfg.kfolds,
            shuffle=True,
            random_state=cfg.seed,
        )
        folds_iter = list(splitter.split(X, y, groups))
        print("[Split] Using StratifiedGroupKFold")
    else:
        splitter = GroupKFold(n_splits=cfg.kfolds)
        folds_iter = list(splitter.split(X, groups=groups))
        print("[Split] Using GroupKFold (no stratification)")

    # Prepare fixed loaders for ensembles (TEST and INTTEST)
    test_loader_fixed: Optional[DataLoader] = None
    test_ref_paths = test_ref_pids = test_ref_labels = None
    if len(ext_subset) > 0:
        test_ds_fixed = MRIDataset(
            ext_subset,
            image_size=cfg.image_size,
            aug=False,
            strong_aug=False,
        )
        test_loader_fixed = DataLoader(
            test_ds_fixed,
            batch_size=cfg.batch_size,
            shuffle=False,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

    inttest_loader_fixed: Optional[DataLoader] = None
    int_ref_paths = int_ref_pids = int_ref_labels = None
    if len(inttest_subset) > 0:
        int_ds_fixed = MRIDataset(
            inttest_subset,
            image_size=cfg.image_size,
            aug=False,
            strong_aug=False,
        )
        inttest_loader_fixed = DataLoader(
            int_ds_fixed,
            batch_size=cfg.batch_size,
            shuffle=False,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

    # OOF buffers (for base_pool)
    n_pool = len(base_pool)
    n_cls = len(class_names)
    oof_probs = np.full((n_pool, n_cls), np.nan, dtype=np.float32)
    oof_pred = np.full((n_pool,), -1, dtype=np.int64)
    oof_true = np.full((n_pool,), -1, dtype=np.int64)
    oof_path = [""] * n_pool
    oof_pid = [""] * n_pool

    # For ensembles
    test_probs_folds: List[np.ndarray] = []
    inttest_probs_folds: List[np.ndarray] = []

    cv_rows = []

    # ===== Per-fold training =====
    for fold_id, (tr_idx, va_idx) in enumerate(folds_iter, start=1):
        print(f"\n===== FOLD {fold_id}/{cfg.kfolds} =====")
        set_seed(cfg.seed + fold_id)

        fold_dir = base_run / f"fold_{fold_id:02d}"
        fold_dir.mkdir(parents=True, exist_ok=True)

        real_train_subset = [base_pool[i] for i in tr_idx]
        val_subset = [base_pool[i] for i in va_idx]

        # Leak checks
        ids_train = [pid for _, _, pid in real_train_subset]
        ids_val = [pid for _, _, pid in val_subset]
        inter_n, inter_ids = ensure_no_overlap(ids_train, ids_val)
        if inter_n > 0:
            raise RuntimeError(
                f"[LEAK ERROR] Train↔Val share {inter_n} patient IDs (fold {fold_id}): {inter_ids[:10]}"
            )

        if len(inttest_subset) > 0:
            ids_int = [pid for _, _, pid in inttest_subset]
            n1, _ = ensure_no_overlap(ids_train, ids_int)
            n2, _ = ensure_no_overlap(ids_val, ids_int)
            if n1 > 0 or n2 > 0:
                raise RuntimeError("[LEAK ERROR] Fold and INTTEST share patients")

        # Build oversampled train subset (real-only)
        train_subset = build_oversampled_train_subset(
            real_train_subset=real_train_subset,
            num_classes=len(class_names),
            seed=cfg.seed + fold_id,
        )

        # Stats CSVs
        summarize_id_counts(train_subset, class_names, f"fold{fold_id}_train", fold_dir)
        summarize_id_counts(real_train_subset, class_names, f"fold{fold_id}_train_real_only", fold_dir)
        summarize_id_counts(val_subset, class_names, f"fold{fold_id}_val", fold_dir)
        if len(inttest_subset) > 0:
            summarize_id_counts(inttest_subset, class_names, f"fold{fold_id}_inttest", fold_dir)
        if len(ext_subset) > 0:
            summarize_id_counts(ext_subset, class_names, f"fold{fold_id}_test", fold_dir)

        # Loaders
        train_ds = MRIDataset(
            train_subset,
            image_size=cfg.image_size,
            aug=True,
            strong_aug=cfg.strong_aug,
        )
        real_train_ds = MRIDataset(
            real_train_subset,
            image_size=cfg.image_size,
            aug=True,
            strong_aug=cfg.strong_aug,
        )
        val_ds = MRIDataset(
            val_subset,
            image_size=cfg.image_size,
            aug=False,
            strong_aug=False,
        )

        train_loader = DataLoader(
            train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )
        real_train_loader = DataLoader(
            real_train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )
        val_loader = DataLoader(
            val_ds,
            batch_size=cfg.batch_size,
            shuffle=False,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

        inttest_loader = None
        if len(inttest_subset) > 0:
            int_ds = MRIDataset(
                inttest_subset,
                image_size=cfg.image_size,
                aug=False,
                strong_aug=False,
            )
            inttest_loader = DataLoader(
                int_ds,
                batch_size=cfg.batch_size,
                shuffle=False,
                num_workers=cfg.num_workers,
                pin_memory=True,
                collate_fn=collate_fn,
            )

        test_loader = test_loader_fixed

        # Model & optimiser
        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=cfg.lr,
            weight_decay=cfg.weight_decay,
        )
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()

        amp_enabled = cfg.amp and device.type == "cuda"
        scaler = torch.amp.GradScaler("cuda", enabled=amp_enabled)

        best_f1 = -1.0

        # Epoch split: main (train_subset) + fine-tuning (real only)
        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft = cfg.fine_tune_real_epochs

        # ----- Phase 1: train with oversampled train_subset -----
        for epoch in range(1, epochs_main + 1):
            model.train()
            running_loss = 0.0
            n_seen = 0

            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(
                model,
                val_loader,
                device,
                class_names,
                split_name="val",
                out_dir=fold_dir,
            )

            f1_macro = m_val["overall"]["f1_macro"]
            acc_val = m_val["overall"]["accuracy"]
            print(
                f"[Fold {fold_id} | Epoch {epoch:03d}] "
                f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}"
            )

            # Save last checkpoint
            torch.save(
                {
                    "model": model.state_dict(),
                    "epoch": epoch,
                    "class_names": class_names,
                },
                fold_dir / "last.ckpt",
            )

            # Track best by F1-macro
            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save(
                    {
                        "model": model.state_dict(),
                        "epoch": epoch,
                        "class_names": class_names,
                    },
                    fold_dir / "best.ckpt",
                )
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved.")

        # ----- Phase 2: optional fine-tuning with real-only subset -----
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            running_loss = 0.0
            n_seen = 0

            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(
                model,
                val_loader,
                device,
                class_names,
                split_name="val",
                out_dir=fold_dir,
            )

            f1_macro = m_val["overall"]["f1_macro"]
            acc_val = m_val["overall"]["accuracy"]
            print(
                f"[Fold {fold_id} | FT Epoch {epoch:03d}] "
                f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}"
            )

            torch.save(
                {
                    "model": model.state_dict(),
                    "epoch": epoch,
                    "class_names": class_names,
                },
                fold_dir / "last.ckpt",
            )

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save(
                    {
                        "model": model.state_dict(),
                        "epoch": epoch,
                        "class_names": class_names,
                    },
                    fold_dir / "best.ckpt",
                )
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved (fine-tune).")

        # Re-evaluate BEST and collect OOF for this fold
        best = torch.load(fold_dir / "best.ckpt", map_location=device)
        model.load_state_dict(best["model"])

        print(f"[Fold {fold_id}] Re-evaluating BEST on VAL (and collecting OOF)...")
        m_val_best, _ = evaluate(
            model,
            val_loader,
            device,
            class_names,
            split_name="val_best",
            out_dir=fold_dir,
        )

        # Collect arrays for OOF
        val_inf = infer_loader(model, val_loader, device)  # same order as val_subset (shuffle=False)
        for j, base_i in enumerate(va_idx):
            oof_probs[base_i] = val_inf["probs"][j]
            oof_pred[base_i] = int(val_inf["preds"][j])
            oof_true[base_i] = int(val_inf["labels"][j])
            oof_path[base_i] = val_inf["paths"][j]
            oof_pid[base_i] = val_inf["pids"][j]

        # Row base with full VAL metrics
        row = {
            "fold": fold_id,
            "val_acc": m_val_best["overall"]["accuracy"],
            "val_precision_macro": m_val_best["overall"]["precision_macro"],
            "val_recall_macro": m_val_best["overall"]["recall_macro"],
            "val_f1_macro": m_val_best["overall"]["f1_macro"],
            "val_precision_weighted": m_val_best["overall"]["precision_weighted"],
            "val_recall_weighted": m_val_best["overall"]["recall_weighted"],
            "val_f1_weighted": m_val_best["overall"]["f1_weighted"],
            "val_n": m_val_best["overall"]["num_samples"],
        }

        # INTERNAL TEST per fold + probs for ensemble
        if inttest_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on INTERNAL TEST...")
            m_int, _ = evaluate(
                model,
                inttest_loader,
                device,
                class_names,
                split_name="inttest",
                out_dir=fold_dir,
            )
            row.update({
                "int_acc": m_int["overall"]["accuracy"],
                "int_precision_macro": m_int["overall"]["precision_macro"],
                "int_recall_macro": m_int["overall"]["recall_macro"],
                "int_f1_macro": m_int["overall"]["f1_macro"],
                "int_precision_weighted": m_int["overall"]["precision_weighted"],
                "int_recall_weighted": m_int["overall"]["recall_weighted"],
                "int_f1_weighted": m_int["overall"]["f1_weighted"],
                "int_n": m_int["overall"]["num_samples"],
            })

            t_int = infer_loader(model, inttest_loader, device)
            inttest_probs_folds.append(t_int["probs"])
            if int_ref_paths is None:
                int_ref_paths = t_int["paths"]
                int_ref_pids = t_int["pids"]
                int_ref_labels = t_int["labels"]

        # EXTERNAL TEST per fold + probs for ensemble
        if test_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on EXTERNAL TEST...")
            m_ext, _ = evaluate(
                model,
                test_loader,
                device,
                class_names,
                split_name="test",
                out_dir=fold_dir,
            )
            row.update({
                "test_acc": m_ext["overall"]["accuracy"],
                "test_precision_macro": m_ext["overall"]["precision_macro"],
                "test_recall_macro": m_ext["overall"]["recall_macro"],
                "test_f1_macro": m_ext["overall"]["f1_macro"],
                "test_precision_weighted": m_ext["overall"]["precision_weighted"],
                "test_recall_weighted": m_ext["overall"]["recall_weighted"],
                "test_f1_weighted": m_ext["overall"]["f1_weighted"],
                "test_n": m_ext["overall"]["num_samples"],
            })

            t_inf = infer_loader(model, test_loader, device)
            test_probs_folds.append(t_inf["probs"])
            if test_ref_paths is None:
                test_ref_paths = t_inf["paths"]
                test_ref_pids = t_inf["pids"]
                test_ref_labels = t_inf["labels"]

        cv_rows.append(row)

    # === CV summary (mean ± std) ===
    summary_csv = base_run / "cv_summary.csv"
    keys = sorted(set().union(*[r.keys() for r in cv_rows]))
    with open(summary_csv, "w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(f, fieldnames=keys)
        w.writeheader()
        for r in cv_rows:
            w.writerow(r)

    def _agg_for(prefix: str):
        metrics = [
            "acc",
            "precision_macro",
            "recall_macro",
            "f1_macro",
            "precision_weighted",
            "recall_weighted",
            "f1_weighted",
        ]
        out = {}
        for m in metrics:
            col = f"{prefix}_{m}"
            vals = [float(r[col]) for r in cv_rows if col in r]
            if len(vals) == 0:
                out[m] = (None, None)
            else:
                out[m] = (float(np.mean(vals)), float(np.std(vals)))
        return out

    cv_stats_full = {
        "kfolds": cfg.kfolds,
        "val": _agg_for("val"),
        "inttest": _agg_for("int") if any(("int_acc" in r) for r in cv_rows) else {},
        "test": _agg_for("test") if any(("test_acc" in r) for r in cv_rows) else {},
    }

    with open(base_run / "cv_summary_full.json", "w", encoding="utf-8") as f:
        json.dump(cv_stats_full, f, indent=2)

    with open(base_run / "cv_summary_full.csv", "w", newline="", encoding="utf-8") as f:
        w = csv.writer(f)
        w.writerow(["split", "metric", "mean", "std", "k"])
        for split in ["val", "inttest", "test"]:
            if split not in cv_stats_full or not cv_stats_full[split]:
                continue
            for metric, (mu, sd) in cv_stats_full[split].items():
                if mu is None:
                    continue
                w.writerow([split, metric, mu, sd, cfg.kfolds])

    print("[CV] Summary (mean±std) written to cv_summary_full.{json,csv}")

    # === OOF metrics & artifacts ===
    valid_mask = (~np.isnan(oof_probs).any(axis=1)) & (oof_true != -1)
    oof_probs_v = oof_probs[valid_mask]
    oof_pred_v = oof_pred[valid_mask]
    oof_true_v = oof_true[valid_mask]
    oof_path_v = [oof_path[i] for i, ok in enumerate(valid_mask) if ok]
    oof_pid_v = [oof_pid[i] for i, ok in enumerate(valid_mask) if ok]

    if len(oof_true_v) > 0:
        acc = float(accuracy_score(oof_true_v, oof_pred_v))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average="macro", zero_division=0
        )
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average="weighted", zero_division=0
        )
        per_class = classification_report(
            oof_true_v,
            oof_pred_v,
            target_names=class_names,
            output_dict=True,
            zero_division=0,
        )
        cm = confusion_matrix(
            oof_true_v,
            oof_pred_v,
            labels=list(range(len(class_names))),
        )

        oof_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(oof_true_v)),
            },
            "per_class": per_class,
        }

        with open(base_run / "oof_metrics.json", "w", encoding="utf-8") as f:
            json.dump(oof_metrics, f, indent=2)

        with open(base_run / "metrics_overall_oof.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow([
                "split",
                "accuracy",
                "precision_macro",
                "recall_macro",
                "f1_macro",
                "precision_weighted",
                "recall_weighted",
                "f1_weighted",
                "num_samples",
            ])
            o = oof_metrics["overall"]
            w.writerow([
                "oof",
                o["accuracy"],
                o["precision_macro"],
                o["recall_macro"],
                o["f1_macro"],
                o["precision_weighted"],
                o["recall_weighted"],
                o["f1_weighted"],
                o["num_samples"],
            ])

        with open(base_run / "per_class_oof.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["class", "precision", "recall", "f1", "support"])
            for cname in class_names:
                row = per_class.get(
                    cname,
                    {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
                )
                w.writerow([
                    cname,
                    row.get("precision", 0),
                    row.get("recall", 0),
                    row.get("f1-score", 0),
                    row.get("support", 0),
                ])

        with open(base_run / "confusion_oof.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "oof_predictions.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(
                ["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names]
            )
            for i in range(len(oof_true_v)):
                w.writerow([
                    oof_path_v[i],
                    oof_pid_v[i],
                    class_names[int(oof_true_v[i])],
                    class_names[int(oof_pred_v[i])],
                ] + list(map(float, oof_probs_v[i].tolist())))

    # === TEST ensemble (avg across folds) ===
    if test_loader_fixed is not None and len(test_probs_folds) > 0:
        probs_stack = np.stack(test_probs_folds, axis=0)  # [K, N_test, C]
        probs_mean = probs_stack.mean(axis=0)             # [N_test, C]
        preds_ens = probs_mean.argmax(axis=1)

        acc = float(accuracy_score(test_ref_labels, preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average="macro", zero_division=0
        )
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average="weighted", zero_division=0
        )
        per_class = classification_report(
            test_ref_labels,
            preds_ens,
            target_names=class_names,
            output_dict=True,
            zero_division=0,
        )
        cm = confusion_matrix(
            test_ref_labels,
            preds_ens,
            labels=list(range(len(class_names))),
        )

        test_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(test_ref_labels)),
            },
            "per_class": per_class,
        }

        with open(base_run / "metrics_test_ensemble.json", "w", encoding="utf-8") as f:
            json.dump(test_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_test_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow([
                "split",
                "accuracy",
                "precision_macro",
                "recall_macro",
                "f1_macro",
                "precision_weighted",
                "recall_weighted",
                "f1_weighted",
                "num_samples",
            ])
            o = test_ens_metrics["overall"]
            w.writerow([
                "test_ensemble",
                o["accuracy"],
                o["precision_macro"],
                o["recall_macro"],
                o["f1_macro"],
                o["precision_weighted"],
                o["recall_weighted"],
                o["f1_weighted"],
                o["num_samples"],
            ])

        with open(base_run / "per_class_test_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["class", "precision", "recall", "f1", "support"])
            for cname in class_names:
                row = per_class.get(
                    cname,
                    {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
                )
                w.writerow([
                    cname,
                    row.get("precision", 0),
                    row.get("recall", 0),
                    row.get("f1-score", 0),
                    row.get("support", 0),
                ])

        with open(base_run / "confusion_test_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "test_ensemble_predictions.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(
                ["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names]
            )
            for i in range(len(test_ref_labels)):
                w.writerow([
                    test_ref_paths[i],
                    test_ref_pids[i],
                    class_names[int(test_ref_labels[i])],
                    class_names[int(preds_ens[i])],
                ] + list(map(float, probs_mean[i].tolist())))

    # === INTTEST ensemble (avg across folds) ===
    if inttest_loader_fixed is not None and len(inttest_probs_folds) > 0:
        int_probs_stack = np.stack(inttest_probs_folds, axis=0)  # [K, N_int, C]
        int_probs_mean = int_probs_stack.mean(axis=0)            # [N_int, C]
        int_preds_ens = int_probs_mean.argmax(axis=1)

        acc = float(accuracy_score(int_ref_labels, int_preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average="macro", zero_division=0
        )
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average="weighted", zero_division=0
        )
        per_class = classification_report(
            int_ref_labels,
            int_preds_ens,
            target_names=class_names,
            output_dict=True,
            zero_division=0,
        )
        cm = confusion_matrix(
            int_ref_labels,
            int_preds_ens,
            labels=list(range(len(class_names))),
        )

        int_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(int_ref_labels)),
            },
            "per_class": per_class,
        }

        with open(base_run / "metrics_inttest_ensemble.json", "w", encoding="utf-8") as f:
            json.dump(int_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_inttest_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow([
                "split",
                "accuracy",
                "precision_macro",
                "recall_macro",
                "f1_macro",
                "precision_weighted",
                "recall_weighted",
                "f1_weighted",
                "num_samples",
            ])
            o = int_ens_metrics["overall"]
            w.writerow([
                "inttest_ensemble",
                o["accuracy"],
                o["precision_macro"],
                o["recall_macro"],
                o["f1_macro"],
                o["precision_weighted"],
                o["recall_weighted"],
                o["f1_weighted"],
                o["num_samples"],
            ])

        with open(base_run / "per_class_inttest_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["class", "precision", "recall", "f1", "support"])
            for cname in class_names:
                row = per_class.get(
                    cname,
                    {"precision": 0, "recall": 0, "f1-score": 0, "support": 0},
                )
                w.writerow([
                    cname,
                    row.get("precision", 0),
                    row.get("recall", 0),
                    row.get("f1-score", 0),
                    row.get("support", 0),
                ])

        with open(base_run / "confusion_inttest_ensemble.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "inttest_ensemble_predictions.csv", "w", newline="", encoding="utf-8") as f:
            w = csv.writer(f)
            w.writerow(
                ["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names]
            )
            for i in range(len(int_ref_labels)):
                w.writerow([
                    int_ref_paths[i],
                    int_ref_pids[i],
                    class_names[int(int_ref_labels[i])],
                    class_names[int(int_preds_ens[i])],
                ] + list(map(float, int_probs_mean[i].tolist())))

    # (Optional) train on FULL pool and evaluate test once
    if cfg.train_full_after_cv:
        print("\n[Full Train] Training with full pool (no internal test)...")
        run_full = base_run / "full_train"
        run_full.mkdir(parents=True, exist_ok=True)

        real_train_subset = list(base_pool)

        full_train_subset = build_oversampled_train_subset(
            real_train_subset=real_train_subset,
            num_classes=len(class_names),
            seed=cfg.seed + 999,
        )
        print(
            f"[Full Train] real={len(real_train_subset)} "
            f"| oversampled(real-only)={len(full_train_subset)}"
        )

        train_ds = MRIDataset(
            full_train_subset,
            image_size=cfg.image_size,
            aug=True,
            strong_aug=cfg.strong_aug,
        )
        real_train_ds = MRIDataset(
            real_train_subset,
            image_size=cfg.image_size,
            aug=True,
            strong_aug=cfg.strong_aug,
        )

        train_loader = DataLoader(
            train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )
        real_train_loader = DataLoader(
            real_train_ds,
            batch_size=cfg.batch_size,
            shuffle=True,
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
        )

        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=cfg.lr,
            weight_decay=cfg.weight_decay,
        )
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()
        amp_enabled = cfg.amp and device.type == "cuda"
        scaler = torch.amp.GradScaler("cuda", enabled=amp_enabled)

        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft = cfg.fine_tune_real_epochs

        # Full-train Phase 1: oversampled full_train_subset
        for epoch in range(1, epochs_main + 1):
            model.train()
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        # Full-train Phase 2: real-only
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast("cuda", enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        torch.save(
            {"model": model.state_dict(), "class_names": class_names},
            run_full / "final_full.ckpt",
        )

        if test_loader_fixed is not None:
            print("[Full Train] Evaluating on TEST ...")
            evaluate(
                model,
                test_loader_fixed,
                device,
                class_names,
                split_name="test_full",
                out_dir=run_full,
            )

    print(f"\n[Artifacts] Saved at: {base_run}")
    return base_run

# %%
# ====== Main launcher for B2 (weak vs strong augmentation) ======

def main():
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",


    common_kwargs = dict(
        data_root="/content/localdata/train_unzipped/trainreducido",
        test_root="/content/localdata/test_unzipped/testreducido",
        image_size=256,
        batch_size=32,
        epochs=20,
        lr=1e-3,
        weight_decay=1e-4,
        num_workers=4,
        seed=122,
        kfolds=5,
        amp=True,
        pretrained=True,
        internal_test_ratio=0.0,
        fine_tune_real_epochs=0,
        train_full_after_cv=True,
    )

    # B2.1: Real-only, oversampling, WEAK augmentation
    cfg_b2_weak_aug = Config(
        out_dir="runs/2c_b2_real_oversample_weak_aug",
        strong_aug=False,
        **common_kwargs,
    )

    # B2.2: Real-only, oversampling, STRONG augmentation
    cfg_b2_strong_aug = Config(
        out_dir="runs/2c_b2_real_oversample_strong_aug",
        strong_aug=True,
        **common_kwargs,
    )

    experiments = [
        ("B2_weak_aug", cfg_b2_weak_aug),
        ("B2_strong_aug", cfg_b2_strong_aug),
    ]

    for name, cfg in experiments:
        print(f"\n==== Running {name} ====")
        run_dir = train_kfold(cfg)
        print(f"{name} finished. Artifacts in: {run_dir}")


if __name__ == "__main__":
    main()
# Out:
# ==== Running B2_weak_aug ====
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
#
# ===== FOLD 1/5 =====
# [OVERSAMPLE] Real class counts (fold): [499, 304, 491] -> target=499
# [OVERSAMPLE] Fold oversampled size: 1497
# [ID-STATS] fold1_train: unique patient IDs total = 125 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=46 images=499
#   - pituitary: ids=38 images=499
# [ID-STATS] fold1_train_real_only: unique patient IDs total = 125 | images = 1294
#   - glioma: ids=41 images=499
#   - meningioma: ids=46 images=304
#   - pituitary: ids=38 images=491
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.5469 | val_acc=0.7134 | val_f1_macro=0.6612
# [Fold 1] New best (F1_macro=0.6612) saved.
# [Fold 1 | Epoch 002] train_loss=0.2454 | val_acc=0.6352 | val_f1_macro=0.6273
# [Fold 1 | Epoch 003] train_loss=0.2182 | val_acc=0.6710 | val_f1_macro=0.6352
# [Fold 1 | Epoch 004] train_loss=0.2084 | val_acc=0.7590 | val_f1_macro=0.7579
# [Fold 1] New best (F1_macro=0.7579) saved.
# [Fold 1 | Epoch 005] train_loss=0.1587 | val_acc=0.9121 | val_f1_macro=0.9088
# [Fold 1] New best (F1_macro=0.9088) saved.
# [Fold 1 | Epoch 006] train_loss=0.1619 | val_acc=0.8730 | val_f1_macro=0.8663
# [Fold 1 | Epoch 007] train_loss=0.1381 | val_acc=0.8436 | val_f1_macro=0.8483
# [Fold 1 | Epoch 008] train_loss=0.1071 | val_acc=0.9055 | val_f1_macro=0.9050
# [Fold 1 | Epoch 009] train_loss=0.1647 | val_acc=0.8795 | val_f1_macro=0.8781
# [Fold 1 | Epoch 010] train_loss=0.1208 | val_acc=0.8502 | val_f1_macro=0.8488
# [Fold 1 | Epoch 011] train_loss=0.0958 | val_acc=0.9023 | val_f1_macro=0.9065
# [Fold 1 | Epoch 012] train_loss=0.0690 | val_acc=0.8990 | val_f1_macro=0.9053
# [Fold 1 | Epoch 013] train_loss=0.0297 | val_acc=0.9023 | val_f1_macro=0.9038
# [Fold 1 | Epoch 014] train_loss=0.0275 | val_acc=0.9316 | val_f1_macro=0.9335
# [Fold 1] New best (F1_macro=0.9335) saved.
# [Fold 1 | Epoch 015] train_loss=0.0361 | val_acc=0.9283 | val_f1_macro=0.9290
# [Fold 1 | Epoch 016] train_loss=0.0261 | val_acc=0.9186 | val_f1_macro=0.9189
# [Fold 1 | Epoch 017] train_loss=0.0154 | val_acc=0.9316 | val_f1_macro=0.9321
# [Fold 1 | Epoch 018] train_loss=0.0186 | val_acc=0.9218 | val_f1_macro=0.9227
# [Fold 1 | Epoch 019] train_loss=0.0170 | val_acc=0.9316 | val_f1_macro=0.9326
# [Fold 1 | Epoch 020] train_loss=0.0121 | val_acc=0.9316 | val_f1_macro=0.9328
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [OVERSAMPLE] Real class counts (fold): [524, 342, 422] -> target=524
# [OVERSAMPLE] Fold oversampled size: 1572
# [ID-STATS] fold2_train: unique patient IDs total = 124 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=47 images=524
#   - pituitary: ids=33 images=524
# [ID-STATS] fold2_train_real_only: unique patient IDs total = 124 | images = 1288
#   - glioma: ids=44 images=524
#   - meningioma: ids=47 images=342
#   - pituitary: ids=33 images=422
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.4392 | val_acc=0.8211 | val_f1_macro=0.8072
# [Fold 2] New best (F1_macro=0.8072) saved.
# [Fold 2 | Epoch 002] train_loss=0.2527 | val_acc=0.8211 | val_f1_macro=0.8048
# [Fold 2 | Epoch 003] train_loss=0.2444 | val_acc=0.5335 | val_f1_macro=0.5033
# [Fold 2 | Epoch 004] train_loss=0.2400 | val_acc=0.7508 | val_f1_macro=0.7167
# [Fold 2 | Epoch 005] train_loss=0.2129 | val_acc=0.9010 | val_f1_macro=0.8671
# [Fold 2] New best (F1_macro=0.8671) saved.
# [Fold 2 | Epoch 006] train_loss=0.1569 | val_acc=0.9297 | val_f1_macro=0.9147
# [Fold 2] New best (F1_macro=0.9147) saved.
# [Fold 2 | Epoch 007] train_loss=0.1705 | val_acc=0.9137 | val_f1_macro=0.8969
# [Fold 2 | Epoch 008] train_loss=0.1607 | val_acc=0.9042 | val_f1_macro=0.8885
# [Fold 2 | Epoch 009] train_loss=0.1186 | val_acc=0.8850 | val_f1_macro=0.8611
# [Fold 2 | Epoch 010] train_loss=0.1528 | val_acc=0.9073 | val_f1_macro=0.8864
# [Fold 2 | Epoch 011] train_loss=0.0797 | val_acc=0.9010 | val_f1_macro=0.8807
# [Fold 2 | Epoch 012] train_loss=0.0802 | val_acc=0.8946 | val_f1_macro=0.8625
# [Fold 2 | Epoch 013] train_loss=0.2577 | val_acc=0.8690 | val_f1_macro=0.8488
# [Fold 2 | Epoch 014] train_loss=0.0983 | val_acc=0.9073 | val_f1_macro=0.8803
# [Fold 2 | Epoch 015] train_loss=0.0675 | val_acc=0.9105 | val_f1_macro=0.8873
# [Fold 2 | Epoch 016] train_loss=0.0680 | val_acc=0.8882 | val_f1_macro=0.8626
# [Fold 2 | Epoch 017] train_loss=0.0527 | val_acc=0.8978 | val_f1_macro=0.8706
# [Fold 2 | Epoch 018] train_loss=0.0644 | val_acc=0.9042 | val_f1_macro=0.8824
# [Fold 2 | Epoch 019] train_loss=0.0524 | val_acc=0.9010 | val_f1_macro=0.8772
# [Fold 2 | Epoch 020] train_loss=0.0622 | val_acc=0.9105 | val_f1_macro=0.8899
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [OVERSAMPLE] Real class counts (fold): [506, 301, 450] -> target=506
# [OVERSAMPLE] Fold oversampled size: 1518
# [ID-STATS] fold3_train: unique patient IDs total = 125 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=46 images=506
#   - pituitary: ids=35 images=506
# [ID-STATS] fold3_train_real_only: unique patient IDs total = 125 | images = 1257
#   - glioma: ids=44 images=506
#   - meningioma: ids=46 images=301
#   - pituitary: ids=35 images=450
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.4554 | val_acc=0.6105 | val_f1_macro=0.5850
# [Fold 3] New best (F1_macro=0.5850) saved.
# [Fold 3 | Epoch 002] train_loss=0.2340 | val_acc=0.8663 | val_f1_macro=0.8589
# [Fold 3] New best (F1_macro=0.8589) saved.
# [Fold 3 | Epoch 003] train_loss=0.2459 | val_acc=0.6948 | val_f1_macro=0.6880
# [Fold 3 | Epoch 004] train_loss=0.1851 | val_acc=0.6047 | val_f1_macro=0.5762
# [Fold 3 | Epoch 005] train_loss=0.2211 | val_acc=0.8430 | val_f1_macro=0.8350
# [Fold 3 | Epoch 006] train_loss=0.1622 | val_acc=0.8837 | val_f1_macro=0.8765
# [Fold 3] New best (F1_macro=0.8765) saved.
# [Fold 3 | Epoch 007] train_loss=0.1224 | val_acc=0.8256 | val_f1_macro=0.8261
# [Fold 3 | Epoch 008] train_loss=0.1317 | val_acc=0.8634 | val_f1_macro=0.8501
# [Fold 3 | Epoch 009] train_loss=0.0830 | val_acc=0.8808 | val_f1_macro=0.8759
# [Fold 3 | Epoch 010] train_loss=0.0559 | val_acc=0.8750 | val_f1_macro=0.8703
# [Fold 3 | Epoch 011] train_loss=0.0717 | val_acc=0.8721 | val_f1_macro=0.8632
# [Fold 3 | Epoch 012] train_loss=0.0846 | val_acc=0.8401 | val_f1_macro=0.8398
# [Fold 3 | Epoch 013] train_loss=0.0411 | val_acc=0.8576 | val_f1_macro=0.8556
# [Fold 3 | Epoch 014] train_loss=0.0339 | val_acc=0.8750 | val_f1_macro=0.8726
# [Fold 3 | Epoch 015] train_loss=0.0276 | val_acc=0.8953 | val_f1_macro=0.8911
# [Fold 3] New best (F1_macro=0.8911) saved.
# [Fold 3 | Epoch 016] train_loss=0.0193 | val_acc=0.9041 | val_f1_macro=0.8988
# [Fold 3] New best (F1_macro=0.8988) saved.
# [Fold 3 | Epoch 017] train_loss=0.0195 | val_acc=0.9070 | val_f1_macro=0.9022
# [Fold 3] New best (F1_macro=0.9022) saved.
# [Fold 3 | Epoch 018] train_loss=0.0084 | val_acc=0.9041 | val_f1_macro=0.9003
# [Fold 3 | Epoch 019] train_loss=0.0129 | val_acc=0.9041 | val_f1_macro=0.8999
# [Fold 3 | Epoch 020] train_loss=0.0149 | val_acc=0.9041 | val_f1_macro=0.9003
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [OVERSAMPLE] Real class counts (fold): [450, 370, 424] -> target=450
# [OVERSAMPLE] Fold oversampled size: 1350
# [ID-STATS] fold4_train: unique patient IDs total = 125 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=51 images=450
#   - pituitary: ids=34 images=450
# [ID-STATS] fold4_train_real_only: unique patient IDs total = 125 | images = 1244
#   - glioma: ids=40 images=450
#   - meningioma: ids=51 images=370
#   - pituitary: ids=34 images=424
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.5915 | val_acc=0.6246 | val_f1_macro=0.4869
# [Fold 4] New best (F1_macro=0.4869) saved.
# [Fold 4 | Epoch 002] train_loss=0.3575 | val_acc=0.8599 | val_f1_macro=0.8241
# [Fold 4] New best (F1_macro=0.8241) saved.
# [Fold 4 | Epoch 003] train_loss=0.2500 | val_acc=0.9300 | val_f1_macro=0.8947
# [Fold 4] New best (F1_macro=0.8947) saved.
# [Fold 4 | Epoch 004] train_loss=0.2305 | val_acc=0.6078 | val_f1_macro=0.5852
# [Fold 4 | Epoch 005] train_loss=0.3791 | val_acc=0.8711 | val_f1_macro=0.8209
# [Fold 4 | Epoch 006] train_loss=0.2157 | val_acc=0.8655 | val_f1_macro=0.8015
# [Fold 4 | Epoch 007] train_loss=0.1896 | val_acc=0.8796 | val_f1_macro=0.7996
# [Fold 4 | Epoch 008] train_loss=0.1422 | val_acc=0.9468 | val_f1_macro=0.8992
# [Fold 4] New best (F1_macro=0.8992) saved.
# [Fold 4 | Epoch 009] train_loss=0.1236 | val_acc=0.9384 | val_f1_macro=0.9045
# [Fold 4] New best (F1_macro=0.9045) saved.
# [Fold 4 | Epoch 010] train_loss=0.1705 | val_acc=0.9216 | val_f1_macro=0.8627
# [Fold 4 | Epoch 011] train_loss=0.1488 | val_acc=0.9524 | val_f1_macro=0.9234
# [Fold 4] New best (F1_macro=0.9234) saved.
# [Fold 4 | Epoch 012] train_loss=0.0858 | val_acc=0.9664 | val_f1_macro=0.9594
# [Fold 4] New best (F1_macro=0.9594) saved.
# [Fold 4 | Epoch 013] train_loss=0.0780 | val_acc=0.9664 | val_f1_macro=0.9565
# [Fold 4 | Epoch 014] train_loss=0.1121 | val_acc=0.9636 | val_f1_macro=0.9408
# [Fold 4 | Epoch 015] train_loss=0.0572 | val_acc=0.9608 | val_f1_macro=0.9387
# [Fold 4 | Epoch 016] train_loss=0.0459 | val_acc=0.9692 | val_f1_macro=0.9593
# [Fold 4 | Epoch 017] train_loss=0.0393 | val_acc=0.9664 | val_f1_macro=0.9572
# [Fold 4 | Epoch 018] train_loss=0.0390 | val_acc=0.9580 | val_f1_macro=0.9387
# [Fold 4 | Epoch 019] train_loss=0.0311 | val_acc=0.9580 | val_f1_macro=0.9384
# [Fold 4 | Epoch 020] train_loss=0.0336 | val_acc=0.9664 | val_f1_macro=0.9540
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [OVERSAMPLE] Real class counts (fold): [557, 307, 457] -> target=557
# [OVERSAMPLE] Fold oversampled size: 1671
# [ID-STATS] fold5_train: unique patient IDs total = 125 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=42 images=557
#   - pituitary: ids=36 images=557
# [ID-STATS] fold5_train_real_only: unique patient IDs total = 125 | images = 1321
#   - glioma: ids=47 images=557
#   - meningioma: ids=42 images=307
#   - pituitary: ids=36 images=457
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.4408 | val_acc=0.5536 | val_f1_macro=0.4887
# [Fold 5] New best (F1_macro=0.4887) saved.
# [Fold 5 | Epoch 002] train_loss=0.3054 | val_acc=0.6786 | val_f1_macro=0.6527
# [Fold 5] New best (F1_macro=0.6527) saved.
# [Fold 5 | Epoch 003] train_loss=0.2229 | val_acc=0.7250 | val_f1_macro=0.7209
# [Fold 5] New best (F1_macro=0.7209) saved.
# [Fold 5 | Epoch 004] train_loss=0.2339 | val_acc=0.8929 | val_f1_macro=0.8858
# [Fold 5] New best (F1_macro=0.8858) saved.
# [Fold 5 | Epoch 005] train_loss=0.1709 | val_acc=0.9000 | val_f1_macro=0.8977
# [Fold 5] New best (F1_macro=0.8977) saved.
# [Fold 5 | Epoch 006] train_loss=0.1803 | val_acc=0.6821 | val_f1_macro=0.6861
# [Fold 5 | Epoch 007] train_loss=0.2081 | val_acc=0.7286 | val_f1_macro=0.7133
# [Fold 5 | Epoch 008] train_loss=0.1244 | val_acc=0.7786 | val_f1_macro=0.7624
# [Fold 5 | Epoch 009] train_loss=0.1873 | val_acc=0.8071 | val_f1_macro=0.8049
# [Fold 5 | Epoch 010] train_loss=0.1410 | val_acc=0.8357 | val_f1_macro=0.8360
# [Fold 5 | Epoch 011] train_loss=0.0930 | val_acc=0.8857 | val_f1_macro=0.8849
# [Fold 5 | Epoch 012] train_loss=0.1044 | val_acc=0.8964 | val_f1_macro=0.8961
# [Fold 5 | Epoch 013] train_loss=0.0638 | val_acc=0.8714 | val_f1_macro=0.8710
# [Fold 5 | Epoch 014] train_loss=0.0580 | val_acc=0.8607 | val_f1_macro=0.8614
# [Fold 5 | Epoch 015] train_loss=0.0616 | val_acc=0.8679 | val_f1_macro=0.8675
# [Fold 5 | Epoch 016] train_loss=0.0422 | val_acc=0.8500 | val_f1_macro=0.8501
# [Fold 5 | Epoch 017] train_loss=0.0382 | val_acc=0.9036 | val_f1_macro=0.9028
# [Fold 5] New best (F1_macro=0.9028) saved.
# [Fold 5 | Epoch 018] train_loss=0.0351 | val_acc=0.9179 | val_f1_macro=0.9167
# [Fold 5] New best (F1_macro=0.9167) saved.
# [Fold 5 | Epoch 019] train_loss=0.0290 | val_acc=0.9000 | val_f1_macro=0.8993
# [Fold 5 | Epoch 020] train_loss=0.0464 | val_acc=0.9071 | val_f1_macro=0.9064
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [OVERSAMPLE] Real class counts (fold): [634, 406, 561] -> target=634
# [OVERSAMPLE] Fold oversampled size: 1902
# [Full Train] real=1601 | oversampled(real-only)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: runs/2c_b2_real_oversample_weak_aug/b2_5f_run_20251125-231957
# B2_weak_aug finished. Artifacts in: runs/2c_b2_real_oversample_weak_aug/b2_5f_run_20251125-231957
#
# ==== Running B2_strong_aug ====
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
#
# ===== FOLD 1/5 =====
# [OVERSAMPLE] Real class counts (fold): [499, 304, 491] -> target=499
# [OVERSAMPLE] Fold oversampled size: 1497
# [ID-STATS] fold1_train: unique patient IDs total = 125 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=46 images=499
#   - pituitary: ids=38 images=499
# [ID-STATS] fold1_train_real_only: unique patient IDs total = 125 | images = 1294
#   - glioma: ids=41 images=499
#   - meningioma: ids=46 images=304
#   - pituitary: ids=38 images=491
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.5631 | val_acc=0.7948 | val_f1_macro=0.7883
# [Fold 1] New best (F1_macro=0.7883) saved.
# [Fold 1 | Epoch 002] train_loss=0.3401 | val_acc=0.8078 | val_f1_macro=0.8015
# [Fold 1] New best (F1_macro=0.8015) saved.
# [Fold 1 | Epoch 003] train_loss=0.3203 | val_acc=0.8925 | val_f1_macro=0.8934
# [Fold 1] New best (F1_macro=0.8934) saved.
# [Fold 1 | Epoch 004] train_loss=0.2506 | val_acc=0.8241 | val_f1_macro=0.8353
# [Fold 1 | Epoch 005] train_loss=0.2409 | val_acc=0.8241 | val_f1_macro=0.8012
# [Fold 1 | Epoch 006] train_loss=0.1935 | val_acc=0.8925 | val_f1_macro=0.9013
# [Fold 1] New best (F1_macro=0.9013) saved.
# [Fold 1 | Epoch 007] train_loss=0.2249 | val_acc=0.8567 | val_f1_macro=0.8504
# [Fold 1 | Epoch 008] train_loss=0.1903 | val_acc=0.8176 | val_f1_macro=0.8120
# [Fold 1 | Epoch 009] train_loss=0.1885 | val_acc=0.9186 | val_f1_macro=0.9217
# [Fold 1] New best (F1_macro=0.9217) saved.
# [Fold 1 | Epoch 010] train_loss=0.1639 | val_acc=0.9186 | val_f1_macro=0.9209
# [Fold 1 | Epoch 011] train_loss=0.1230 | val_acc=0.9283 | val_f1_macro=0.9290
# [Fold 1] New best (F1_macro=0.9290) saved.
# [Fold 1 | Epoch 012] train_loss=0.1113 | val_acc=0.9218 | val_f1_macro=0.9239
# [Fold 1 | Epoch 013] train_loss=0.0884 | val_acc=0.8990 | val_f1_macro=0.9054
# [Fold 1 | Epoch 014] train_loss=0.0696 | val_acc=0.9414 | val_f1_macro=0.9422
# [Fold 1] New best (F1_macro=0.9422) saved.
# [Fold 1 | Epoch 015] train_loss=0.0612 | val_acc=0.9186 | val_f1_macro=0.9244
# [Fold 1 | Epoch 016] train_loss=0.0482 | val_acc=0.9446 | val_f1_macro=0.9458
# [Fold 1] New best (F1_macro=0.9458) saved.
# [Fold 1 | Epoch 017] train_loss=0.0429 | val_acc=0.9349 | val_f1_macro=0.9390
# [Fold 1 | Epoch 018] train_loss=0.0376 | val_acc=0.9511 | val_f1_macro=0.9542
# [Fold 1] New best (F1_macro=0.9542) saved.
# [Fold 1 | Epoch 019] train_loss=0.0399 | val_acc=0.9479 | val_f1_macro=0.9501
# [Fold 1 | Epoch 020] train_loss=0.0276 | val_acc=0.9446 | val_f1_macro=0.9474
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [OVERSAMPLE] Real class counts (fold): [524, 342, 422] -> target=524
# [OVERSAMPLE] Fold oversampled size: 1572
# [ID-STATS] fold2_train: unique patient IDs total = 124 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=47 images=524
#   - pituitary: ids=33 images=524
# [ID-STATS] fold2_train_real_only: unique patient IDs total = 124 | images = 1288
#   - glioma: ids=44 images=524
#   - meningioma: ids=47 images=342
#   - pituitary: ids=33 images=422
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.5665 | val_acc=0.8435 | val_f1_macro=0.7688
# [Fold 2] New best (F1_macro=0.7688) saved.
# [Fold 2 | Epoch 002] train_loss=0.3352 | val_acc=0.5048 | val_f1_macro=0.4794
# [Fold 2 | Epoch 003] train_loss=0.3116 | val_acc=0.7700 | val_f1_macro=0.7668
# [Fold 2 | Epoch 004] train_loss=0.2963 | val_acc=0.7923 | val_f1_macro=0.7632
# [Fold 2 | Epoch 005] train_loss=0.1993 | val_acc=0.8818 | val_f1_macro=0.8463
# [Fold 2] New best (F1_macro=0.8463) saved.
# [Fold 2 | Epoch 006] train_loss=0.2061 | val_acc=0.7955 | val_f1_macro=0.7830
# [Fold 2 | Epoch 007] train_loss=0.2654 | val_acc=0.8946 | val_f1_macro=0.8724
# [Fold 2] New best (F1_macro=0.8724) saved.
# [Fold 2 | Epoch 008] train_loss=0.1849 | val_acc=0.8626 | val_f1_macro=0.8275
# [Fold 2 | Epoch 009] train_loss=0.1733 | val_acc=0.8307 | val_f1_macro=0.8093
# [Fold 2 | Epoch 010] train_loss=0.2655 | val_acc=0.8882 | val_f1_macro=0.8597
# [Fold 2 | Epoch 011] train_loss=0.1798 | val_acc=0.8594 | val_f1_macro=0.8408
# [Fold 2 | Epoch 012] train_loss=0.1079 | val_acc=0.8946 | val_f1_macro=0.8729
# [Fold 2] New best (F1_macro=0.8729) saved.
# [Fold 2 | Epoch 013] train_loss=0.1002 | val_acc=0.8722 | val_f1_macro=0.8542
# [Fold 2 | Epoch 014] train_loss=0.1179 | val_acc=0.8658 | val_f1_macro=0.8386
# [Fold 2 | Epoch 015] train_loss=0.0731 | val_acc=0.8818 | val_f1_macro=0.8671
# [Fold 2 | Epoch 016] train_loss=0.1077 | val_acc=0.8946 | val_f1_macro=0.8668
# [Fold 2 | Epoch 017] train_loss=0.0882 | val_acc=0.8754 | val_f1_macro=0.8515
# [Fold 2 | Epoch 018] train_loss=0.0892 | val_acc=0.8754 | val_f1_macro=0.8501
# [Fold 2 | Epoch 019] train_loss=0.0746 | val_acc=0.8786 | val_f1_macro=0.8547
# [Fold 2 | Epoch 020] train_loss=0.0768 | val_acc=0.8786 | val_f1_macro=0.8587
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [OVERSAMPLE] Real class counts (fold): [506, 301, 450] -> target=506
# [OVERSAMPLE] Fold oversampled size: 1518
# [ID-STATS] fold3_train: unique patient IDs total = 125 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=46 images=506
#   - pituitary: ids=35 images=506
# [ID-STATS] fold3_train_real_only: unique patient IDs total = 125 | images = 1257
#   - glioma: ids=44 images=506
#   - meningioma: ids=46 images=301
#   - pituitary: ids=35 images=450
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.5812 | val_acc=0.4680 | val_f1_macro=0.4162
# [Fold 3] New best (F1_macro=0.4162) saved.
# [Fold 3 | Epoch 002] train_loss=0.2658 | val_acc=0.8140 | val_f1_macro=0.8151
# [Fold 3] New best (F1_macro=0.8151) saved.
# [Fold 3 | Epoch 003] train_loss=0.3151 | val_acc=0.8052 | val_f1_macro=0.8025
# [Fold 3 | Epoch 004] train_loss=0.2546 | val_acc=0.5436 | val_f1_macro=0.4648
# [Fold 3 | Epoch 005] train_loss=0.2342 | val_acc=0.8459 | val_f1_macro=0.8405
# [Fold 3] New best (F1_macro=0.8405) saved.
# [Fold 3 | Epoch 006] train_loss=0.2207 | val_acc=0.8692 | val_f1_macro=0.8592
# [Fold 3] New best (F1_macro=0.8592) saved.
# [Fold 3 | Epoch 007] train_loss=0.1753 | val_acc=0.6744 | val_f1_macro=0.5936
# [Fold 3 | Epoch 008] train_loss=0.1573 | val_acc=0.8430 | val_f1_macro=0.8357
# [Fold 3 | Epoch 009] train_loss=0.1263 | val_acc=0.8081 | val_f1_macro=0.8030
# [Fold 3 | Epoch 010] train_loss=0.1143 | val_acc=0.8343 | val_f1_macro=0.8336
# [Fold 3 | Epoch 011] train_loss=0.1115 | val_acc=0.8372 | val_f1_macro=0.8293
# [Fold 3 | Epoch 012] train_loss=0.0868 | val_acc=0.8721 | val_f1_macro=0.8652
# [Fold 3] New best (F1_macro=0.8652) saved.
# [Fold 3 | Epoch 013] train_loss=0.0607 | val_acc=0.8576 | val_f1_macro=0.8547
# [Fold 3 | Epoch 014] train_loss=0.0477 | val_acc=0.8314 | val_f1_macro=0.8306
# [Fold 3 | Epoch 015] train_loss=0.0470 | val_acc=0.8401 | val_f1_macro=0.8390
# [Fold 3 | Epoch 016] train_loss=0.0403 | val_acc=0.8692 | val_f1_macro=0.8664
# [Fold 3] New best (F1_macro=0.8664) saved.
# [Fold 3 | Epoch 017] train_loss=0.0336 | val_acc=0.8837 | val_f1_macro=0.8784
# [Fold 3] New best (F1_macro=0.8784) saved.
# [Fold 3 | Epoch 018] train_loss=0.0169 | val_acc=0.8750 | val_f1_macro=0.8710
# [Fold 3 | Epoch 019] train_loss=0.0248 | val_acc=0.8663 | val_f1_macro=0.8633
# [Fold 3 | Epoch 020] train_loss=0.0348 | val_acc=0.8663 | val_f1_macro=0.8633
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [OVERSAMPLE] Real class counts (fold): [450, 370, 424] -> target=450
# [OVERSAMPLE] Fold oversampled size: 1350
# [ID-STATS] fold4_train: unique patient IDs total = 125 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=51 images=450
#   - pituitary: ids=34 images=450
# [ID-STATS] fold4_train_real_only: unique patient IDs total = 125 | images = 1244
#   - glioma: ids=40 images=450
#   - meningioma: ids=51 images=370
#   - pituitary: ids=34 images=424
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.6684 | val_acc=0.5322 | val_f1_macro=0.3386
# [Fold 4] New best (F1_macro=0.3386) saved.
# [Fold 4 | Epoch 002] train_loss=0.4537 | val_acc=0.7927 | val_f1_macro=0.7071
# [Fold 4] New best (F1_macro=0.7071) saved.
# [Fold 4 | Epoch 003] train_loss=0.3250 | val_acc=0.8768 | val_f1_macro=0.8408
# [Fold 4] New best (F1_macro=0.8408) saved.
# [Fold 4 | Epoch 004] train_loss=0.3419 | val_acc=0.9244 | val_f1_macro=0.8822
# [Fold 4] New best (F1_macro=0.8822) saved.
# [Fold 4 | Epoch 005] train_loss=0.3583 | val_acc=0.8739 | val_f1_macro=0.7808
# [Fold 4 | Epoch 006] train_loss=0.3054 | val_acc=0.7115 | val_f1_macro=0.6197
# [Fold 4 | Epoch 007] train_loss=0.3465 | val_acc=0.9580 | val_f1_macro=0.9093
# [Fold 4] New best (F1_macro=0.9093) saved.
# [Fold 4 | Epoch 008] train_loss=0.2333 | val_acc=0.9356 | val_f1_macro=0.8925
# [Fold 4 | Epoch 009] train_loss=0.2029 | val_acc=0.8936 | val_f1_macro=0.8520
# [Fold 4 | Epoch 010] train_loss=0.2488 | val_acc=0.8852 | val_f1_macro=0.8450
# [Fold 4 | Epoch 011] train_loss=0.2075 | val_acc=0.9524 | val_f1_macro=0.9142
# [Fold 4] New best (F1_macro=0.9142) saved.
# [Fold 4 | Epoch 012] train_loss=0.1615 | val_acc=0.9160 | val_f1_macro=0.8681
# [Fold 4 | Epoch 013] train_loss=0.1403 | val_acc=0.9468 | val_f1_macro=0.9343
# [Fold 4] New best (F1_macro=0.9343) saved.
# [Fold 4 | Epoch 014] train_loss=0.1137 | val_acc=0.9664 | val_f1_macro=0.9512
# [Fold 4] New best (F1_macro=0.9512) saved.
# [Fold 4 | Epoch 015] train_loss=0.1009 | val_acc=0.9384 | val_f1_macro=0.9347
# [Fold 4 | Epoch 016] train_loss=0.0783 | val_acc=0.9552 | val_f1_macro=0.9385
# [Fold 4 | Epoch 017] train_loss=0.0709 | val_acc=0.9720 | val_f1_macro=0.9552
# [Fold 4] New best (F1_macro=0.9552) saved.
# [Fold 4 | Epoch 018] train_loss=0.0693 | val_acc=0.9692 | val_f1_macro=0.9495
# [Fold 4 | Epoch 019] train_loss=0.0712 | val_acc=0.9692 | val_f1_macro=0.9518
# [Fold 4 | Epoch 020] train_loss=0.0543 | val_acc=0.9720 | val_f1_macro=0.9540
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [OVERSAMPLE] Real class counts (fold): [557, 307, 457] -> target=557
# [OVERSAMPLE] Fold oversampled size: 1671
# [ID-STATS] fold5_train: unique patient IDs total = 125 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=42 images=557
#   - pituitary: ids=36 images=557
# [ID-STATS] fold5_train_real_only: unique patient IDs total = 125 | images = 1321
#   - glioma: ids=47 images=557
#   - meningioma: ids=42 images=307
#   - pituitary: ids=36 images=457
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.5800 | val_acc=0.7429 | val_f1_macro=0.7156
# [Fold 5] New best (F1_macro=0.7156) saved.
# [Fold 5 | Epoch 002] train_loss=0.4144 | val_acc=0.5714 | val_f1_macro=0.5671
# [Fold 5 | Epoch 003] train_loss=0.3141 | val_acc=0.7750 | val_f1_macro=0.7681
# [Fold 5] New best (F1_macro=0.7681) saved.
# [Fold 5 | Epoch 004] train_loss=0.3142 | val_acc=0.7036 | val_f1_macro=0.6944
# [Fold 5 | Epoch 005] train_loss=0.2501 | val_acc=0.4893 | val_f1_macro=0.4591
# [Fold 5 | Epoch 006] train_loss=0.2681 | val_acc=0.6357 | val_f1_macro=0.5965
# [Fold 5 | Epoch 007] train_loss=0.2253 | val_acc=0.8607 | val_f1_macro=0.8586
# [Fold 5] New best (F1_macro=0.8586) saved.
# [Fold 5 | Epoch 008] train_loss=0.1705 | val_acc=0.8500 | val_f1_macro=0.8477
# [Fold 5 | Epoch 009] train_loss=0.1983 | val_acc=0.9143 | val_f1_macro=0.9126
# [Fold 5] New best (F1_macro=0.9126) saved.
# [Fold 5 | Epoch 010] train_loss=0.1812 | val_acc=0.8679 | val_f1_macro=0.8673
# [Fold 5 | Epoch 011] train_loss=0.1387 | val_acc=0.8821 | val_f1_macro=0.8815
# [Fold 5 | Epoch 012] train_loss=0.1590 | val_acc=0.8714 | val_f1_macro=0.8710
# [Fold 5 | Epoch 013] train_loss=0.1124 | val_acc=0.8071 | val_f1_macro=0.8092
# [Fold 5 | Epoch 014] train_loss=0.1217 | val_acc=0.8929 | val_f1_macro=0.8919
# [Fold 5 | Epoch 015] train_loss=0.1000 | val_acc=0.8607 | val_f1_macro=0.8613
# [Fold 5 | Epoch 016] train_loss=0.0718 | val_acc=0.8536 | val_f1_macro=0.8538
# [Fold 5 | Epoch 017] train_loss=0.0633 | val_acc=0.8643 | val_f1_macro=0.8644
# [Fold 5 | Epoch 018] train_loss=0.0578 | val_acc=0.8857 | val_f1_macro=0.8852
# [Fold 5 | Epoch 019] train_loss=0.0631 | val_acc=0.8821 | val_f1_macro=0.8819
# [Fold 5 | Epoch 020] train_loss=0.0715 | val_acc=0.8857 | val_f1_macro=0.8853
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [OVERSAMPLE] Real class counts (fold): [634, 406, 561] -> target=634
# [OVERSAMPLE] Fold oversampled size: 1902
# [Full Train] real=1601 | oversampled(real-only)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: runs/2c_b2_real_oversample_strong_aug/b2_5f_run_20251125-232645
# B2_strong_aug finished. Artifacts in: runs/2c_b2_real_oversample_strong_aug/b2_5f_run_20251125-232645
