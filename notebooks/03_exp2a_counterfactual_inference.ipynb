# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# !pip install gdown --upgrade

if os.path.isdir("/content/drive/MyDrive/colab-sg2-ada-pytorch"):
    # %cd "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/JunTierSS/stylegan2-ada
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/JunTierSS/stylegan2-ada
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/xai_batch_testset/classification-20251117T160336Z-1-001.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/class_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/class.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/class.zip" -d "/content/localdata/class"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/class_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/class_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/class.zip
# Contenido de /content/localdata/class_unzipped
# total 8.0K
# drwxr-xr-x 2 root root 4.0K Dec 11 01:31 .
# drwxr-xr-x 4 root root 4.0K Dec 11 01:31 ..

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/splits/by_patient_30test1/train.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/trainori_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/trainori.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/trainori.zip" -d "/content/localdata/trainori_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/trainori_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/trainori_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/trainori.zip
# Contenido de /content/localdata/trainori_unzipped
# total 120K
# drwxr-xr-x 5 root root 4.0K Dec 11 01:31 .
# drwxr-xr-x 5 root root 4.0K Dec 11 01:31 ..
# drwxr-xr-x 2 root root  48K Dec 11 01:31 glioma
# drwxr-xr-x 2 root root  28K Dec 11 01:31 meningioma
# drwxr-xr-x 2 root root  36K Dec 11 01:31 pituitary

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/splits/by_patient_30test1/test.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/testori_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/testori.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/testori.zip" -d "/content/localdata/testori_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/testori_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/testori_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/testori.zip
# Contenido de /content/localdata/testori_unzipped
# total 68K
# drwxr-xr-x 5 root root 4.0K Dec 11 01:31 .
# drwxr-xr-x 6 root root 4.0K Dec 11 01:31 ..
# drwxr-xr-x 2 root root  28K Dec 11 01:31 glioma
# drwxr-xr-x 2 root root  12K Dec 11 01:31 meningioma
# drwxr-xr-x 2 root root  20K Dec 11 01:31 pituitary

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/datasetinge/testreducido.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/test_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/test.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/test.zip" -d "/content/localdata/test_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/test_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/test_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/test.zip
# Contenido de /content/localdata/test_unzipped
# total 12K
# drwxr-xr-x 3 root root 4.0K Dec 11 01:31 .
# drwxr-xr-x 7 root root 4.0K Dec 11 01:31 ..
# drwxrwxrwx 5 root root 4.0K Nov 10 21:19 testreducido

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/datasetinge/trainreducido.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/train_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/train.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/train.zip" -d "/content/localdata/train_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/train_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/train_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/train.zip
# Contenido de /content/localdata/train_unzipped
# total 12K
# drwxr-xr-x 3 root root 4.0K Dec 11 01:31 .
# drwxr-xr-x 8 root root 4.0K Dec 11 01:31 ..
# drwxrwxrwx 5 root root 4.0K Nov 10 21:19 trainreducido

# %%
pip install ninja
# Out:
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.13.0

# %%
pip install opensimplex
# Out:
# Collecting opensimplex
#   Downloading opensimplex-0.4.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from opensimplex) (2.0.2)
# Downloading opensimplex-0.4.5.1-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.4.5.1

# %%
import os, re, io, json, time, argparse, random, csv, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional

import numpy as np
from PIL import Image, ImageOps

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms, models
import torchvision.transforms.functional as TF
import torchvision

from sklearn.model_selection import StratifiedShuffleSplit

# %% [markdown]
# ##creating

# %%
# -*- coding: utf-8 -*-
"""
K-Fold training (by patient) for brain tumor classification (ResNet50)
- No-leak by patient_id (groups)
- StratifiedGroupKFold if available; fallback to GroupKFold
- Optional StyleGAN2-ADA augmentation:
    * Real-only run (no GAN)
    * GAN-balanced run: para cada fold se agrega GAN hasta igualar la clase mayor (por nº de imágenes REALES)
- Per-fold metrics + CV summary
- OOF (out-of-fold) predictions & metrics (one row per pool sample, predicted by a model that didn't see it)
- External TEST evaluation per fold + K-fold ensemble (avg probs across folds)
- Full INTTEST metrics per fold + INTTEST ensemble, and CV summary with mean±std for VAL/INTTEST/TEST
- Optional final fine-tuning epochs using only REAL images (no GAN) per fold and in full-train

Author: Jun + ChatGPT
"""

import os, re, io, json, time, random, csv, math, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional
from dataclasses import dataclass, asdict

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support,
    classification_report, confusion_matrix
)

# ====== Splitters ======
try:
    from sklearn.model_selection import StratifiedGroupKFold
    HAS_SGTK = True
except Exception:
    HAS_SGTK = False
    from sklearn.model_selection import GroupKFold

# ====== Utils ======

def set_seed(seed: int = 42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
    try:
        torch.set_float32_matmul_precision("high")
    except Exception:
        pass

def timestamp() -> str:
    return time.strftime("%Y%m%d-%H%M%S")

def extract_patient_id(p: Path) -> str:
    stem = p.stem
    token = stem.split("_")[0]
    return token.strip().lower()

IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}

# ====== Config ======

@dataclass
class Config:
    data_root: str
    out_dir: str
    test_root: str = ""
    gan_pkl: str = ""
    images_per_class: int = 0        # sólo se usa si balance_gan_to_max=False
    truncation: float = 1.0
    internal_test_ratio: float = 0.0   # optional: holdout before CV
    image_size: int = 256
    batch_size: int = 32
    epochs: int = 15
    lr: float = 1e-3
    weight_decay: float = 1e-4
    num_workers: int = 4
    seed: int = 42
    kfolds: int = 5
    amp: bool = True
    pretrained: bool = True
    train_full_after_cv: bool = False   # optional: retrain on full pool at end

    # Fine-tuning final sólo con reales
    fine_tune_real_epochs: int = 0      # 0 = desactivado

    # NUEVO: balancear clases con GAN hasta la clase mayor de REALES
    balance_gan_to_max: bool = False

# ====== Dataset ======

class MRIDataset(Dataset):
    def __init__(self, items: List[Tuple[Path, int, str]], image_size: int = 256, aug: bool = False):
        self.items = items
        self.image_size = image_size
        self.aug = aug
        mean = [0.5, 0.5, 0.5]; std = [0.5, 0.5, 0.5]
        if aug:
            self.tf = transforms.Compose([
                transforms.RandomResizedCrop(image_size, scale=(0.9, 1.0), ratio=(0.95, 1.05)),
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.RandomRotation(10),
                transforms.ToTensor(),
            ])
        else:
            self.tf = transforms.Compose([
                transforms.Resize((image_size, image_size)),
                transforms.ToTensor(),
            ])
        self.norm = transforms.Normalize(mean=mean, std=std)

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        path, y, pid = self.items[idx]
        img = Image.open(path).convert("L")
        img = self.tf(img)           # [1,H,W]
        img = img.repeat(3, 1, 1)    # [3,H,W]
        img = self.norm(img)
        return img, y, str(path), pid

# ====== Scan & Helpers ======

def scan_folder(root: Path) -> Tuple[List[Tuple[Path,int,str]], List[str]]:
    assert root.is_dir(), f"Not a directory: {root}"
    class_names = sorted([d.name for d in root.iterdir() if d.is_dir()])
    items: List[Tuple[Path,int,str]] = []
    for ci, cname in enumerate(class_names):
        cdir = root / cname
        for p in cdir.rglob("*"):
            if p.suffix.lower() in IMG_EXTS:
                pid = extract_patient_id(p)
                items.append((p, ci, pid))
    return items, class_names

def ensure_no_overlap(ids_a: List[str], ids_b: List[str]) -> Tuple[int, List[str]]:
    a = set(ids_a); b = set(ids_b)
    inter = sorted(a.intersection(b))
    return len(inter), inter

def summarize_id_counts(items: List[Tuple[Path,int,str]], class_names: List[str], split_name: str, out_dir: Path):
    from collections import defaultdict
    ids_by_class = defaultdict(set); imgs_by_class = defaultdict(int); all_ids = set()
    for p, ci, pid in items:
        ids_by_class[ci].add(pid)
        imgs_by_class[ci] += 1
        all_ids.add(pid)

    print(f"[ID-STATS] {split_name}: unique patient IDs total = {len(all_ids)} | images = {len(items)}")
    for ci, cname in enumerate(class_names):
        print(f"  - {cname}: ids={len(ids_by_class[ci])} images={imgs_by_class[ci]}")

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"id_counts_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["class", "n_unique_ids", "n_images"])
        for ci, cname in enumerate(class_names):
            w.writerow([cname, len(ids_by_class[ci]), imgs_by_class[ci]])
        w.writerow(["__TOTAL__", len(all_ids), len(items)])

# ====== Model ======

def build_model(num_classes: int, pretrained: bool = True) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m

# ====== Eval (writes artifacts) ======

@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, device: torch.device, class_names: List[str], split_name: str, out_dir: Path):
    model.eval()
    all_probs, all_preds, all_labels = [], [], []
    all_paths, all_pids = [], []

    for imgs, ys, paths, pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        all_paths.extend(list(paths))
        all_pids.extend(list(pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, len(class_names)))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)

    acc = float(accuracy_score(labels, preds)) if len(labels) else 0.0
    prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)
    prec_weighted, rec_weighted, f1_weighted, _ = precision_recall_fscore_support(labels, preds, average='weighted', zero_division=0)
    per_class = classification_report(labels, preds, target_names=class_names, output_dict=True, zero_division=0)
    cm = confusion_matrix(labels, preds, labels=list(range(len(class_names))))

    metrics = {
        "overall": {
            "accuracy": acc,
            "precision_macro": prec_macro,
            "recall_macro": rec_macro,
            "f1_macro": f1_macro,
            "precision_weighted": prec_weighted,
            "recall_weighted": rec_weighted,
            "f1_weighted": f1_weighted,
            "num_samples": len(labels),
        },
        "per_class": per_class,
    }

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"metrics_{split_name}.json", 'w', encoding='utf-8') as f:
        json.dump(metrics, f, indent=2)

    with open(out_dir / f"metrics_overall_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro","precision_weighted","recall_weighted","f1_weighted","num_samples"])
        o = metrics['overall']
        w.writerow([split_name, o['accuracy'], o['precision_macro'], o['recall_macro'], o['f1_macro'],
                    o['precision_weighted'], o['recall_weighted'], o['f1_weighted'], o['num_samples']])

    with open(out_dir / f"per_class_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["class", "precision", "recall", "f1", "support"])
        for cname in class_names:
            row = per_class.get(cname, {"precision":0, "recall":0, "f1-score":0, "support":0})
            w.writerow([cname, row.get("precision",0), row.get("recall",0),
                        row.get("f1-score",0), row.get("support",0)])

    with open(out_dir / f"confusion_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["true\\pred"] + class_names)
        for i, cname in enumerate(class_names):
            w.writerow([cname] + list(cm[i]))

    with open(out_dir / f"predictions_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
        for i in range(len(labels)):
            w.writerow([all_paths[i], all_pids[i], class_names[labels[i]],
                        class_names[preds[i]]] + list(map(float, probs[i].tolist())))

    return metrics, cm

# Helper: fast inference to collect arrays (for OOF & ensemble)
@torch.no_grad()
def infer_loader(model: nn.Module, loader: DataLoader, device: torch.device):
    model.eval()
    paths, pids = [], []
    all_probs, all_preds, all_labels = [], [], []
    for imgs, ys, batch_paths, batch_pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        paths.extend(list(batch_paths))
        pids.extend(list(batch_pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, 0))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)
    return {"probs": probs, "preds": preds, "labels": labels, "paths": paths, "pids": pids}

# ====== Optional GAN loader (TRAIN only) ======

@torch.no_grad()
def _load_stylegan2_ada_G(gan_pkl: str, device: torch.device):
    try:
        import dnnlib
        from training import network as _dummy
        from legacy import load_network_pkl
    except Exception:
        try:
            from torch_utils import misc as _m  # noqa
            from torch_utils import training_stats as _ts  # noqa
            from legacy import load_network_pkl
        except Exception:
            return None
    try:
        with open(gan_pkl, 'rb') as f:
            data = load_network_pkl(f)
        G_ema = data.get('G_ema', None) or data.get('G', None)
        if G_ema is None:
            return None
        G_ema = G_ema.to(device)
        G_ema.eval()
        return G_ema
    except Exception:
        return None

@torch.no_grad()
def maybe_generate_gan_images(gan_pkl: str,
                              class_names: List[str],
                              n_per_class: int,
                              truncation: float,
                              out_dir: Path,
                              device: torch.device,
                              seed: int = 42) -> Optional[Path]:
    if (not gan_pkl) or n_per_class <= 0:
        return None
    G = _load_stylegan2_ada_G(gan_pkl, device)
    if G is None:
        print("[GAN] Could not load StyleGAN2-ADA G_ema. Skipping GAN augmentation.")
        return None
    if getattr(G, 'c_dim', 0) <= 0:
        print("[GAN] Generator is not conditional (c_dim=0). Skipping.")
        return None

    rng = np.random.RandomState(seed)
    synth_root = out_dir / "gan_synth"
    for cname in class_names:
        (synth_root / cname).mkdir(parents=True, exist_ok=True)

    batch = 16
    for ci, cname in enumerate(class_names):
        saved = 0
        while saved < n_per_class:
            bs = min(batch, n_per_class - saved)
            z = torch.from_numpy(rng.randn(bs, G.z_dim)).to(device)
            c = torch.zeros(bs, G.c_dim, device=device); c[:, ci] = 1.0
            try:
                img = G(z, c, truncation_psi=float(truncation), noise_mode='const')
            except TypeError:
                img = G(z, c, truncation_psi=float(truncation))
            img = (img * 127.5 + 128).clamp(0,255).to(torch.uint8).cpu()
            for k in range(bs):
                x = img[k]
                if x.shape[0] == 1:
                    arr = x[0].numpy()
                    pil = Image.fromarray(arr).convert('L')
                else:
                    arr = x.permute(1,2,0).numpy()
                    pil = Image.fromarray(arr).convert('L')
                fname = synth_root / cname / f"gan_{cname}_{saved+k:05d}.png"
                pil.save(fname)
            saved += bs
        print(f"[GAN] Saved {saved} images for class '{cname}'")
    return synth_root

def collate_fn(batch):
    imgs, ys, paths, pids = zip(*batch)
    return torch.stack(imgs, dim=0), torch.tensor(ys, dtype=torch.long), list(paths), list(pids)

# ====== Helper: construir subset balanceado real + GAN ======

def build_balanced_train_subset(real_train_subset: List[Tuple[Path,int,str]],
                                synth_items: List[Tuple[Path,int,str]],
                                num_classes: int,
                                seed: int) -> List[Tuple[Path,int,str]]:
    """
    Toma:
      - real_train_subset: sólo imágenes reales de ese fold
      - synth_items: TODAS las sintéticas (escaneadas desde gan_synth/)
    Devuelve:
      - lista con reales + suficientes GAN por clase para igualar la clase mayor (en REALES).
    """
    from collections import defaultdict

    # Reales por clase
    real_by_class: Dict[int, List[Tuple[Path,int,str]]] = defaultdict(list)
    for item in real_train_subset:
        _, ci, _ = item
        real_by_class[ci].append(item)

    # GAN por clase
    synth_by_class: Dict[int, List[Tuple[Path,int,str]]] = defaultdict(list)
    for item in synth_items:
        _, ci, _ = item
        synth_by_class[ci].append(item)

    # Target = tamaño de la clase mayor (sólo contando REALES)
    counts_real = [len(real_by_class[c]) for c in range(num_classes)]
    target = max(counts_real) if counts_real else 0
    print(f"[BAL] Real class counts (fold): {counts_real} -> target={target}")

    rng = random.Random(seed)
    balanced: List[Tuple[Path,int,str]] = list(real_train_subset)

    for ci in range(num_classes):
        need = target - len(real_by_class[ci])
        if need <= 0:
            continue
        pool = synth_by_class[ci]
        if not pool:
            print(f"[BAL] WARNING: no GAN images for class {ci}, cannot fully balance.")
            continue
        # muestramos con reemplazo si need > len(pool)
        for _ in range(need):
            balanced.append(rng.choice(pool))

    return balanced

# ====== K-Fold Train (CV + OOF + TEST + INTTEST ensemble) ======

def train_kfold(cfg: Config):
    if cfg.fine_tune_real_epochs < 0 or cfg.fine_tune_real_epochs > cfg.epochs:
        raise ValueError("fine_tune_real_epochs must be between 0 and cfg.epochs")

    base_run = Path(cfg.out_dir) / f"kfold_{cfg.kfolds}f_run_{timestamp()}"
    base_run.mkdir(parents=True, exist_ok=True)
    with open(base_run / 'config.json', 'w', encoding='utf-8') as f:
        json.dump(asdict(cfg), f, indent=2)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"[Device] Using {device}")

    # Scan pool
    all_items, class_names = scan_folder(Path(cfg.data_root))
    print(f"[Scan] Pool images: {len(all_items)} | Classes: {class_names}")

    # Optional internal-test holdout (by patient)
    inttest_subset: List[Tuple[Path,int,str]] = []
    if cfg.internal_test_ratio and cfg.internal_test_ratio > 0:
        from sklearn.model_selection import GroupShuffleSplit
        X_all = np.arange(len(all_items))
        y_all = np.array([lbl for _, lbl, _ in all_items])
        g_all = np.array([pid for _, _, pid in all_items])
        gss = GroupShuffleSplit(n_splits=1, test_size=cfg.internal_test_ratio, random_state=cfg.seed)
        trval_idx, inttest_idx = next(gss.split(X_all, y_all, g_all))
        base_pool = [all_items[i] for i in trval_idx]
        inttest_subset = [all_items[i] for i in inttest_idx]
        print(f"[Split] Internal test: {len(inttest_subset)} images ({cfg.internal_test_ratio*100:.1f}%)")
    else:
        base_pool = all_items

    # External test (leak-sanitized vs pool & internal test)
    ext_subset: List[Tuple[Path,int,str]] = []
    if cfg.test_root and len(cfg.test_root.strip()) > 0 and Path(cfg.test_root).exists():
        ext_items, _ = scan_folder(Path(cfg.test_root))
        ids_pool = set(pid for _,_,pid in base_pool)
        if len(inttest_subset) > 0:
            ids_pool |= set(pid for _,_,pid in inttest_subset)
        for it in ext_items:
            if it[2] not in ids_pool:
                ext_subset.append(it)
        removed = len(ext_items) - len(ext_subset)
        if removed > 0:
            print(f"[LEAK-FIX] Removed {removed} overlapping ext-test images by patient ID.")
        print(f"[Scan] External test images (sanitized): {len(ext_subset)}")

    # Build folds grouped by patient (SOLO con REALES)
    X = np.arange(len(base_pool))
    y = np.array([lbl for _, lbl, _ in base_pool])
    groups = np.array([pid for _, _, pid in base_pool])

    if cfg.kfolds < 2:
        raise ValueError("kfolds must be >= 2")

    if HAS_SGTK:
        splitter = StratifiedGroupKFold(n_splits=cfg.kfolds, shuffle=True, random_state=cfg.seed)
        folds_iter = list(splitter.split(X, y, groups))
        print("[Split] Using StratifiedGroupKFold")
    else:
        splitter = GroupKFold(n_splits=cfg.kfolds)
        folds_iter = list(splitter.split(X, groups=groups))
        print("[Split] Using GroupKFold (no stratification)")

    # ===== Pre-generate GAN synth una sola vez =====
    synth_items: List[Tuple[Path,int,str]] = []
    synth_root: Optional[Path] = None
    if cfg.gan_pkl and cfg.gan_pkl.strip():
        # si queremos balancear, ignoramos images_per_class y usamos el máximo global de REALES
        if cfg.balance_gan_to_max:
            from collections import defaultdict
            real_counts_global = defaultdict(int)
            for _, ci, _ in base_pool:
                real_counts_global[ci] += 1
            # Vector ordenado por índice de clase
            counts_vec = [real_counts_global[ci] for ci in range(len(class_names))]
            n_per_class = max(counts_vec) if counts_vec else 0
            print(f"[GAN] balance_gan_to_max=True -> global real counts per class = {counts_vec}, using n_per_class={n_per_class}")
        else:
            n_per_class = cfg.images_per_class

        if n_per_class > 0:
            synth_root = maybe_generate_gan_images(
                gan_pkl=cfg.gan_pkl,
                class_names=class_names,
                n_per_class=n_per_class,
                truncation=cfg.truncation,
                out_dir=base_run,
                device=device,
                seed=cfg.seed,
            )
            if synth_root is not None:
                synth_items, _ = scan_folder(synth_root)
                print(f"[GAN] Synth images generated (global): {len(synth_items)}")
        else:
            print("[GAN] n_per_class <= 0 -> no synthetic images will be generated.")
    else:
        print("[GAN] gan_pkl empty -> NO GAN will be used.")

    # Prepare fixed loaders for ensembles (TEST e INTTEST)
    test_loader_fixed: Optional[DataLoader] = None
    test_ref_paths = test_ref_pids = test_ref_labels = None
    if len(ext_subset) > 0:
        test_ds_fixed = MRIDataset(ext_subset, image_size=cfg.image_size, aug=False)
        test_loader_fixed = DataLoader(test_ds_fixed, batch_size=cfg.batch_size, shuffle=False,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        # Se rellenan luego con infer_loader

    inttest_loader_fixed: Optional[DataLoader] = None
    int_ref_paths = int_ref_pids = int_ref_labels = None
    if len(inttest_subset) > 0:
        int_ds_fixed = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
        inttest_loader_fixed = DataLoader(int_ds_fixed, batch_size=cfg.batch_size, shuffle=False,
                                          num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

    # ===== OOF buffers =====
    n_pool = len(base_pool)
    n_cls = len(class_names)
    oof_probs = np.full((n_pool, n_cls), np.nan, dtype=np.float32)
    oof_pred  = np.full((n_pool,), -1, dtype=np.int64)
    oof_true  = np.full((n_pool,), -1, dtype=np.int64)
    oof_path  = [""] * n_pool
    oof_pid   = [""] * n_pool

    # For ensembles
    test_probs_folds: List[np.ndarray] = []
    inttest_probs_folds: List[np.ndarray] = []

    # Per-fold training
    cv_rows = []
    for fold_id, (tr_idx, va_idx) in enumerate(folds_iter, start=1):
        print(f"\n===== FOLD {fold_id}/{cfg.kfolds} =====")
        set_seed(cfg.seed + fold_id)

        fold_dir = base_run / f"fold_{fold_id:02d}"
        fold_dir.mkdir(parents=True, exist_ok=True)

        # REAL train subset and VAL subset
        real_train_subset = [base_pool[i] for i in tr_idx]
        val_subset        = [base_pool[i] for i in va_idx]

        # Leak checks (sólo reales)
        ids_train = [pid for _,_,pid in real_train_subset]
        ids_val   = [pid for _,_,pid in val_subset]
        inter_n, inter_ids = ensure_no_overlap(ids_train, ids_val)
        if inter_n > 0:
            raise RuntimeError(f"[LEAK ERROR] Train↔Val share {inter_n} patient IDs (fold {fold_id}): {inter_ids[:10]}")

        if len(inttest_subset) > 0:
            ids_int = [pid for _,_,pid in inttest_subset]
            n1,_ = ensure_no_overlap(ids_train, ids_int)
            n2,_ = ensure_no_overlap(ids_val, ids_int)
            if n1>0 or n2>0:
                raise RuntimeError("[LEAK ERROR] Fold and INTTEST share patients")

        # ===== construir train_subset =====
        if cfg.balance_gan_to_max and len(synth_items) > 0:
            train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + fold_id,
            )
            print(f"[BAL] Fold {fold_id}: real={len(real_train_subset)} | train_balanced(real+GAN)={len(train_subset)}")
        else:
            # sin balanceo: opcionalmente append de todo synth_items
            train_subset = list(real_train_subset)
            if len(synth_items) > 0:
                train_subset = train_subset + synth_items
                print(f"[TRAIN] Fold {fold_id}: real={len(real_train_subset)} + synth={len(synth_items)} -> {len(train_subset)}")
            else:
                print(f"[TRAIN] Fold {fold_id}: only real images, n={len(real_train_subset)}")

        # Stats CSV
        summarize_id_counts(train_subset, class_names, f'fold{fold_id}_train', fold_dir)
        summarize_id_counts(val_subset,   class_names, f'fold{fold_id}_val',   fold_dir)
        if len(inttest_subset) > 0:
            summarize_id_counts(inttest_subset, class_names, f'fold{fold_id}_inttest', fold_dir)
        if len(ext_subset) > 0:
            summarize_id_counts(ext_subset,     class_names, f'fold{fold_id}_test',    fold_dir)

        # Loaders
        train_ds       = MRIDataset(train_subset,       image_size=cfg.image_size, aug=True)
        real_train_ds  = MRIDataset(real_train_subset,  image_size=cfg.image_size, aug=True)
        val_ds         = MRIDataset(val_subset,         image_size=cfg.image_size, aug=False)

        train_loader      = DataLoader(train_ds,      batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        real_train_loader = DataLoader(real_train_ds, batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        val_loader        = DataLoader(val_ds,        batch_size=cfg.batch_size, shuffle=False,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        inttest_loader = None
        if len(inttest_subset) > 0:
            int_ds = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
            inttest_loader = DataLoader(int_ds, batch_size=cfg.batch_size, shuffle=False,
                                        num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        # Para TEST por fold usamos loader fijo
        test_loader = test_loader_fixed

        # Model/optim
        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()

        amp_enabled = (cfg.amp and device.type == 'cuda')
        scaler = torch.amp.GradScaler('cuda', enabled=amp_enabled)

        best_f1 = -1.0

        # Epoch split: main (train_subset) + fine-tuning (real only)
        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft   = cfg.fine_tune_real_epochs

        # ----- Phase 1: train con train_subset (real + GAN o sólo real) -----
        for epoch in range(1, epochs_main + 1):
            model.train()
            running_loss = 0.0; n_seen = 0
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(model, val_loader, device, class_names,
                                split_name='val', out_dir=fold_dir)
            f1_macro = m_val['overall']['f1_macro']
            acc_val  = m_val['overall']['accuracy']
            print(f"[Fold {fold_id} | Epoch {epoch:03d}] "
                  f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}")

            torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                       fold_dir / 'last.ckpt')

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                           fold_dir / 'best.ckpt')
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved.")

        # ----- Phase 2: fine-tuning sólo con REALES -----
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            running_loss = 0.0; n_seen = 0
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(model, val_loader, device, class_names,
                                split_name='val', out_dir=fold_dir)
            f1_macro = m_val['overall']['f1_macro']
            acc_val  = m_val['overall']['accuracy']
            print(f"[Fold {fold_id} | FT Epoch {epoch:03d}] "
                  f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}")

            torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                       fold_dir / 'last.ckpt')

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                           fold_dir / 'best.ckpt')
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved (fine-tune).")

        # Re-eval BEST and collect OOF for this fold
        best = torch.load(fold_dir / 'best.ckpt', map_location=device)
        model.load_state_dict(best['model'])

        print(f"[Fold {fold_id}] Re-evaluating BEST on VAL (and collecting OOF)...")
        m_val_best, _ = evaluate(model, val_loader, device, class_names,
                                 split_name='val_best', out_dir=fold_dir)

        # Collect arrays for OOF
        val_inf = infer_loader(model, val_loader, device)  # same order as val_subset (shuffle=False)
        for j, base_i in enumerate(va_idx):
            oof_probs[base_i] = val_inf["probs"][j]
            oof_pred[base_i]  = int(val_inf["preds"][j])
            oof_true[base_i]  = int(val_inf["labels"][j])
            oof_path[base_i]  = val_inf["paths"][j]
            oof_pid[base_i]   = val_inf["pids"][j]

        # Row base with full VAL metrics
        row = {
            "fold": fold_id,
            "val_acc": m_val_best["overall"]["accuracy"],
            "val_precision_macro": m_val_best["overall"]["precision_macro"],
            "val_recall_macro": m_val_best["overall"]["recall_macro"],
            "val_f1_macro": m_val_best["overall"]["f1_macro"],
            "val_precision_weighted": m_val_best["overall"]["precision_weighted"],
            "val_recall_weighted": m_val_best["overall"]["recall_weighted"],
            "val_f1_weighted": m_val_best["overall"]["f1_weighted"],
            "val_n": m_val_best["overall"]["num_samples"],
        }

        # INTERNAL TEST per fold + probs for ensemble
        if inttest_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on INTERNAL TEST...")
            m_int, _ = evaluate(model, inttest_loader, device, class_names,
                                split_name='inttest', out_dir=fold_dir)
            row.update({
                "int_acc": m_int["overall"]["accuracy"],
                "int_precision_macro": m_int["overall"]["precision_macro"],
                "int_recall_macro": m_int["overall"]["recall_macro"],
                "int_f1_macro": m_int["overall"]["f1_macro"],
                "int_precision_weighted": m_int["overall"]["precision_weighted"],
                "int_recall_weighted": m_int["overall"]["recall_weighted"],
                "int_f1_weighted": m_int["overall"]["f1_weighted"],
                "int_n": m_int["overall"]["num_samples"],
            })
            t_int = infer_loader(model, inttest_loader, device)
            inttest_probs_folds.append(t_int["probs"])
            if int_ref_paths is None:
                int_ref_paths  = t_int["paths"]
                int_ref_pids   = t_int["pids"]
                int_ref_labels = t_int["labels"]

        # EXTERNAL TEST per fold + probs for ensemble
        if test_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on EXTERNAL TEST...")
            m_ext, _ = evaluate(model, test_loader, device, class_names,
                                split_name='test', out_dir=fold_dir)
            row.update({
                "test_acc": m_ext["overall"]["accuracy"],
                "test_precision_macro": m_ext["overall"]["precision_macro"],
                "test_recall_macro": m_ext["overall"]["recall_macro"],
                "test_f1_macro": m_ext["overall"]["f1_macro"],
                "test_precision_weighted": m_ext["overall"]["precision_weighted"],
                "test_recall_weighted": m_ext["overall"]["recall_weighted"],
                "test_f1_weighted": m_ext["overall"]["f1_weighted"],
                "test_n": m_ext["overall"]["num_samples"],
            })
            t_inf = infer_loader(model, test_loader, device)
            test_probs_folds.append(t_inf["probs"])
            if test_ref_paths is None:
                test_ref_paths  = t_inf["paths"]
                test_ref_pids   = t_inf["pids"]
                test_ref_labels = t_inf["labels"]

        cv_rows.append(row)

    # === CV summary (mean ± std) ===
    summary_csv = base_run / "cv_summary.csv"
    keys = sorted(set().union(*[r.keys() for r in cv_rows]))
    with open(summary_csv, 'w', newline='', encoding='utf-8') as f:
        w = csv.DictWriter(f, fieldnames=keys)
        w.writeheader()
        for r in cv_rows:
            w.writerow(r)

    def _agg_for(prefix: str) -> Dict[str, Tuple[Optional[float], Optional[float]]]:
        metrics = ["acc","precision_macro","recall_macro","f1_macro",
                   "precision_weighted","recall_weighted","f1_weighted"]
        out: Dict[str, Tuple[Optional[float], Optional[float]]] = {}
        for m in metrics:
            col = f"{prefix}_{m}"
            vals = [float(r[col]) for r in cv_rows if col in r]
            if len(vals) == 0:
                out[m] = (None, None)
            else:
                out[m] = (float(np.mean(vals)), float(np.std(vals)))
        return out

    cv_stats_full = {
        "kfolds": cfg.kfolds,
        "val":     _agg_for("val"),
        "inttest": _agg_for("int") if any(("int_acc" in r) for r in cv_rows) else {},
        "test":    _agg_for("test") if any(("test_acc" in r) for r in cv_rows) else {},
    }
    with open(base_run / "cv_summary_full.json", 'w', encoding='utf-8') as f:
        json.dump(cv_stats_full, f, indent=2)

    with open(base_run / "cv_summary_full.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["split","metric","mean","std","k"])
        for split in ["val","inttest","test"]:
            if split not in cv_stats_full or not cv_stats_full[split]:
                continue
            for metric, (mu, sd) in cv_stats_full[split].items():
                if mu is None:
                    continue
                w.writerow([split, metric, mu, sd, cfg.kfolds])

    print("[CV] Summary (mean±std) written to cv_summary_full.{json,csv}")

    # === OOF metrics & artifacts ===
    valid_mask = (~np.isnan(oof_probs).any(axis=1)) & (oof_true != -1)
    oof_probs_v = oof_probs[valid_mask]
    oof_pred_v  = oof_pred[valid_mask]
    oof_true_v  = oof_true[valid_mask]
    oof_path_v  = [oof_path[i] for i, ok in enumerate(valid_mask) if ok]
    oof_pid_v   = [oof_pid[i]  for i, ok in enumerate(valid_mask) if ok]

    if len(oof_true_v) > 0:
        acc = float(accuracy_score(oof_true_v, oof_pred_v))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average='weighted', zero_division=0)
        per_class = classification_report(
            oof_true_v, oof_pred_v, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(oof_true_v, oof_pred_v, labels=list(range(len(class_names))))

        oof_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(oof_true_v)),
            },
            "per_class": per_class,
        }
        with open(base_run / "oof_metrics.json", 'w', encoding='utf-8') as f:
            json.dump(oof_metrics, f, indent=2)

        with open(base_run / "metrics_overall_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = oof_metrics['overall']
            w.writerow(["oof", o['accuracy'], o['precision_macro'], o['recall_macro'],
                        o['f1_macro'], o['precision_weighted'], o['recall_weighted'],
                        o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "oof_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(oof_true_v)):
                w.writerow([oof_path_v[i], oof_pid_v[i],
                            class_names[oof_true_v[i]],
                            class_names[oof_pred_v[i]]] +
                           list(map(float, oof_probs_v[i].tolist())))

    # === TEST ensemble (avg across folds) ===
    if test_loader_fixed is not None and len(test_probs_folds) > 0:
        probs_stack = np.stack(test_probs_folds, axis=0)     # [K, N_test, C]
        probs_mean  = probs_stack.mean(axis=0)               # [N_test, C]
        preds_ens   = probs_mean.argmax(axis=1)

        acc = float(accuracy_score(test_ref_labels, preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average='weighted', zero_division=0)
        per_class = classification_report(
            test_ref_labels, preds_ens, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(test_ref_labels, preds_ens, labels=list(range(len(class_names))))

        test_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(test_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_test_ensemble.json", 'w', encoding='utf-8') as f:
            json.dump(test_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = test_ens_metrics['overall']
            w.writerow(["test_ensemble", o['accuracy'], o['precision_macro'],
                        o['recall_macro'], o['f1_macro'], o['precision_weighted'],
                        o['recall_weighted'], o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "test_ensemble_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(test_ref_labels)):
                w.writerow([test_ref_paths[i], test_ref_pids[i],
                            class_names[int(test_ref_labels[i])],
                            class_names[int(preds_ens[i])]] +
                           list(map(float, probs_mean[i].tolist())))

    # === INTTEST ensemble (avg across folds) ===
    if inttest_loader_fixed is not None and len(inttest_probs_folds) > 0:
        int_probs_stack = np.stack(inttest_probs_folds, axis=0)  # [K, N_int, C]
        int_probs_mean  = int_probs_stack.mean(axis=0)           # [N_int, C]
        int_preds_ens   = int_probs_mean.argmax(axis=1)

        acc = float(accuracy_score(int_ref_labels, int_preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average='weighted', zero_division=0)
        per_class = classification_report(
            int_ref_labels, int_preds_ens, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(int_ref_labels, int_preds_ens, labels=list(range(len(class_names))))

        int_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(int_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_inttest_ensemble.json", 'w', encoding='utf-8') as f:
            json.dump(int_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = int_ens_metrics['overall']
            w.writerow(["inttest_ensemble", o['accuracy'], o['precision_macro'],
                        o['recall_macro'], o['f1_macro'], o['precision_weighted'],
                        o['recall_weighted'], o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "inttest_ensemble_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(int_ref_labels)):
                w.writerow([int_ref_paths[i], int_ref_pids[i],
                            class_names[int(int_ref_labels[i])],
                            class_names[int(int_preds_ens[i])]] +
                           list(map(float, int_probs_mean[i].tolist())))

    # (Optional) train on FULL pool and evaluate test once
    if cfg.train_full_after_cv:
        print("\n[Full Train] Training with full pool (no internal test)...")
        run_full = base_run / "full_train"
        run_full.mkdir(parents=True, exist_ok=True)

        real_train_subset = list(base_pool)

        if cfg.balance_gan_to_max and len(synth_items) > 0:
            full_train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + 999,
            )
            print(f"[Full Train] real={len(real_train_subset)} | train_balanced(real+GAN)={len(full_train_subset)}")
        else:
            full_train_subset = real_train_subset + (synth_items if len(synth_items) > 0 else [])
            print(f"[Full Train] real={len(real_train_subset)} + synth={len(synth_items)} -> {len(full_train_subset)}")

        train_ds      = MRIDataset(full_train_subset, image_size=cfg.image_size, aug=False)
        real_train_ds = MRIDataset(real_train_subset, image_size=cfg.image_size, aug=False)

        train_loader      = DataLoader(train_ds,      batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        real_train_loader = DataLoader(real_train_ds, batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()
        amp_enabled = (cfg.amp and device.type == 'cuda')
        scaler = torch.amp.GradScaler('cuda', enabled=amp_enabled)

        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft   = cfg.fine_tune_real_epochs

        # Full-train Phase 1: full_train_subset (real + synth balanceado o no)
        for epoch in range(1, epochs_main + 1):
            model.train()
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        # Full-train Phase 2: sólo reales
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        torch.save({'model': model.state_dict(), 'class_names': class_names},
                   run_full / 'final_full.ckpt')

        if test_loader_fixed is not None:
            print("[Full Train] Evaluating on TEST ...")
            evaluate(model, test_loader_fixed, device, class_names,
                     split_name='test_full', out_dir=run_full)

    print(f"\n[Artifacts] Saved at: {base_run}")
    return base_run

# %% [markdown]
# no correr

# %%
# === Batch projector with N per class + ETA + prototype computation ===
#
# It does:
#   1) For each class in DATA_ROOT/<class>/*.png
#        -> projects up to N_PER_CLASS images with projector.py
#        -> saves projected_w.npz under PROJ_ROOT/<class>/<image_stem>/
#   2) For each class, loads ALL projected_w.npz from PROJ_ROOT
#        -> computes mean W+ prototype
#        -> saves PROTO_ROOT/<class>_prototype_mean.npz
#
# Assumes:
#   - projector.py is in the current repo (StyleGAN2-ADA)
#   - projector.py saves np.savez(..., w=...)
#
# This uses GPU because projector.py uses CUDA.
aa
from pathlib import Path
from typing import List, Dict
import subprocess
import numpy as np
import time
import random

# --------------------
# CONFIG
# --------------------

# Folder with images per class (train or test, doesn't matter)
DATA_ROOT = Path("/content/localdata/test_unzipped/testreducido")

# Where all per-image projections will be stored
PROJ_ROOT = Path("/content/drive/MyDrive/TESIS/projections_batch_all")

# Where class prototypes (means) will be stored
PROTO_ROOT = Path("/content/drive/MyDrive/TESIS/prototypes")

# Your StyleGAN2-ADA network
NETWORK_PKL = Path(
    "/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/"
    "00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/"
    "network-snapshot-000600.pkl"
)

# projector.py script (from sg2-ada repo)
PROJECTOR_SCRIPT = Path("projector.py")

# Classes (subfolders of DATA_ROOT). If None, we infer them automatically.
CLASSES: List[str] = ["glioma", "meningioma", "pituitary"]
# CLASSES = None  # alternative: infer automatically

# Max number of images to project per class:
#   - N_PER_CLASS = None  -> use ALL images per class
#   - N_PER_CLASS = 50    -> project at most 50 per class
N_PER_CLASS: int | None = 10

# Projector hyperparameters
NUM_STEPS = 300
BASE_SEED = 122

# Shuffle images before taking first N_PER_CLASS?
SHUFFLE = True

# Valid image extensions
IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}


# --------------------
# Utility functions
# --------------------

def load_last_w(npz_path: Path) -> np.ndarray:
    """
    Load the last W+ code from an npz file.

    Supports:
      - w.shape == [T, num_ws, w_dim]  (projector steps)
      - w.shape == [num_ws, w_dim]     (already a single W+)
      - w.shape == [1, num_ws, w_dim]  (StyleGAN projector variant)
    """
    if not npz_path.is_file():
        raise FileNotFoundError(f"NPZ not found: {npz_path}")
    data = np.load(str(npz_path))
    if "w" not in data:
        raise RuntimeError(f"'w' key not found in {npz_path}")
    w = data["w"]
    if w.ndim == 3:
        # [T, num_ws, w_dim] or [1, num_ws, w_dim]
        return w[-1]  # last step or the only one
    elif w.ndim == 2:
        return w
    else:
        raise RuntimeError(f"Unexpected 'w' shape in {npz_path}: {w.shape}")


def run_projector(
    projector_script: Path,
    network_pkl: Path,
    image_path: Path,
    outdir: Path,
    num_steps: int,
    seed: int,
) -> Path:
    """
    Run projector.py on a single image.

    Equivalent to:
        python projector.py --network=... --target=... --outdir=... \
                            --num-steps=... --seed=...
    """
    outdir.mkdir(parents=True, exist_ok=True)

    cmd = [
        "python",
        str(projector_script),
        f"--network={network_pkl}",
        f"--target={image_path}",
        f"--outdir={outdir}",
        f"--num-steps={num_steps}",
        f"--seed={seed}",
    ]

    print(f"[PROJECTOR] {image_path.name} -> {outdir}")
    print("  CMD:", " ".join(cmd))

    result = subprocess.run(cmd, check=False, capture_output=True, text=True)
    print("[PROJECTOR] STDOUT:")
    print(result.stdout)
    print("[PROJECTOR] STDERR:")
    print(result.stderr)

    if result.returncode != 0:
        raise RuntimeError(
            f"projector.py failed with exit code {result.returncode} "
            f"for image {image_path}"
        )

    proj_npz = outdir / "projected_w.npz"
    if not proj_npz.is_file():
        raise FileNotFoundError(
            f"Expected projected_w.npz not found in {outdir}. "
            f"Check projector.py (it must save np.savez(..., w=...))."
        )

    return proj_npz


def run_projection_for_all_images(
    data_root: Path,
    proj_root: Path,
    network_pkl: Path,
    projector_script: Path,
    classes: List[str] | None = None,
    num_steps: int = 200,
    base_seed: int = 0,
    n_per_class: int | None = None,
    shuffle: bool = True,
) -> None:
    """
    Project up to n_per_class images per class and show a global ETA.

    Input structure:
      data_root/<class>/*.png

    Output structure:
      proj_root/<class>/<image_stem>/projected_w.npz
    """
    data_root = Path(data_root)
    proj_root = Path(proj_root)
    proj_root.mkdir(parents=True, exist_ok=True)

    # 1) Infer classes if not given
    if classes is None:
        classes = [d.name for d in data_root.iterdir() if d.is_dir()]
    print(f"[INFO] Using classes: {classes}")

    # 2) Collect images per class
    class_to_imgs: Dict[str, List[Path]] = {}
    total_tasks = 0

    for cls in classes:
        cls_dir = data_root / cls
        if not cls_dir.is_dir():
            print(f"[WARN] Class dir not found: {cls_dir}, skipping.")
            continue

        img_paths = sorted(
            p for p in cls_dir.rglob("*") if p.suffix.lower() in IMG_EXTS
        )
        if not img_paths:
            print(f"[WARN] No images in {cls_dir}, skipping.")
            continue

        if shuffle:
            random.shuffle(img_paths)

        if n_per_class is not None and len(img_paths) > n_per_class:
            img_paths = img_paths[:n_per_class]

        class_to_imgs[cls] = img_paths
        total_tasks += len(img_paths)
        print(f"[CLASS] {cls}: {len(img_paths)} images will be projected.")

    if total_tasks == 0:
        print("[INFO] No images to project. Exiting.")
        return

    print(f"\n[INFO] Total images to project: {total_tasks}")

    # 3) Main loop with ETA
    processed = 0
    global_idx = 0
    start_time = time.time()

    def _fmt_time(t: float) -> str:
        m = int(t // 60)
        s = int(t % 60)
        return f"{m:02d}:{s:02d}"

    for cls, img_paths in class_to_imgs.items():
        print(f"\n[RUN] Class {cls}: {len(img_paths)} images")
        for img_path in img_paths:
            stem = img_path.stem
            outdir = proj_root / cls / stem
            proj_npz = outdir / "projected_w.npz"

            processed += 1
            global_idx += 1

            if proj_npz.is_file():
                print(f"[SKIP] {proj_npz} already exists.")
            else:
                seed = base_seed + global_idx
                try:
                    run_projector(
                        projector_script=projector_script,
                        network_pkl=network_pkl,
                        image_path=img_path,
                        outdir=outdir,
                        num_steps=num_steps,
                        seed=seed,
                    )
                except Exception as e:
                    print(f"[ERROR] Failed on {img_path}: {e}")
                    # Continue with next image
                    continue

            # Update ETA
            elapsed = time.time() - start_time
            avg_per_img = elapsed / processed
            remaining_imgs = total_tasks - processed
            eta_sec = remaining_imgs * avg_per_img

            print(
                f"[ETA] {processed}/{total_tasks} "
                f"({processed/total_tasks*100:.1f}%) | "
                f"elapsed={_fmt_time(elapsed)} | remaining~{_fmt_time(eta_sec)}"
            )

    print("\n[DONE] All projections attempted.")


def compute_class_prototypes(
    proj_root: Path,
    proto_root: Path,
    classes: List[str] | None = None,
) -> None:
    """
    For each class, load ALL projected_w.npz from:
        proj_root/<class>/*/projected_w.npz
    compute the mean W+ and save to:
        proto_root/<class>_prototype_mean.npz  (key 'w')
    """
    proj_root = Path(proj_root)
    proto_root = Path(proto_root)
    proto_root.mkdir(parents=True, exist_ok=True)

    # If classes not provided, infer them from proj_root subfolders
    if classes is None:
        classes = [d.name for d in proj_root.iterdir() if d.is_dir()]

    print(f"[PROTO] Computing prototypes for classes: {classes}")

    for cls in classes:
        class_proj_dir = proj_root / cls
        if not class_proj_dir.is_dir():
            print(f"[PROTO] No projections for class '{cls}' at {class_proj_dir}, skipping.")
            continue

        npz_paths = sorted(class_proj_dir.rglob("projected_w.npz"))
        if not npz_paths:
            print(f"[PROTO] No projected_w.npz found under {class_proj_dir}, skipping.")
            continue

        ws = []
        for p in npz_paths:
            w = load_last_w(p)
            ws.append(w)
            print(f"[PROTO] Loaded {p}, w.shape={w.shape}")

        ws_stack = np.stack(ws, axis=0)  # [N, num_ws, w_dim]
        proto_w = ws_stack.mean(axis=0)  # [num_ws, w_dim]

        out_npz = proto_root / f"{cls}_prototype_mean.npz"
        np.savez(out_npz, w=proto_w)
        print(f"[PROTO] Saved {cls} prototype -> {out_npz}, w.shape={proto_w.shape}")

    print("\n[PROTO] All prototypes computed.")


# --------------------
# Main / Snippet usage
# --------------------

if __name__ == "__main__":
    # 1) Project up to N_PER_CLASS images per class with ETA
    run_projection_for_all_images(
        data_root=DATA_ROOT,
        proj_root=PROJ_ROOT,
        network_pkl=NETWORK_PKL,
        projector_script=PROJECTOR_SCRIPT,
        classes=CLASSES,
        num_steps=NUM_STEPS,
        base_seed=BASE_SEED,
        n_per_class=N_PER_CLASS,  # set to None to use ALL images
        shuffle=SHUFFLE,
    )

    # 2) Compute prototypes and save under PROTO_ROOT
    compute_class_prototypes(
        proj_root=PROJ_ROOT,
        proto_root=PROTO_ROOT,
        classes=CLASSES,
    )
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# step  190/300: dist 0.3275 loss 9.6955
# step  191/300: dist 0.3243 loss 12.2001
# step  192/300: dist 0.3290 loss 19.6964
# step  193/300: dist 0.3244 loss 28.7027
# step  194/300: dist 0.3280 loss 23.7034
# step  195/300: dist 0.3250 loss 9.3935
# step  196/300: dist 0.3257 loss 8.9543
# step  197/300: dist 0.3248 loss 18.2037
# step  198/300: dist 0.3247 loss 17.3433
# step  199/300: dist 0.3255 loss 10.9903
# step  200/300: dist 0.3242 loss 12.4885
# step  201/300: dist 0.3256 loss 11.6004
# step  202/300: dist 0.3238 loss 3.3768
# step  203/300: dist 0.3261 loss 3.0488
# step  204/300: dist 0.3235 loss 9.0543
# step  205/300: dist 0.3247 loss 7.6454
# step  206/300: dist 0.3244 loss 4.7066
# step  207/300: dist 0.3233 loss 5.8229
# step  208/300: dist 0.3240 loss 4.0201
# step  209/300: dist 0.3232 loss 2.6966
# step  210/300: dist 0.3232 loss 5.1903
# step  211/300: dist 0.3250 loss 3.8923
# step  212/300: dist 0.3227 loss 1.1918
# step  213/300: dist 0.3244 loss 2.8690
# step  214/300: dist 0.3245 loss 3.4237
# step  215/300: dist 0.3241 loss 1.9944
# step  216/300: dist 0.3253 loss 2.9174
# step  217/300: dist 0.3216 loss 3.9579
# step  218/300: dist 0.3233 loss 5.3428
# step  285/300: dist 0.3161 loss 0.3174
# step  286/300: dist 0.3160 loss 0.3166
# step  287/300: dist 0.3160 loss 0.3162
# step  288/300: dist 0.3160 loss 0.3163
# step  289/300: dist 0.3160 loss 0.3165
# step  290/300: dist 0.3160 loss 0.3165
# step  291/300: dist 0.3160 loss 0.3164
# step  292/300: dist 0.3160 loss 0.3163
# step  293/300: dist 0.3160 loss 0.3161
# step  294/300: dist 0.3160 loss 0.3161
# step  295/300: dist 0.3159 loss 0.3160
# step  296/300: dist 0.3160 loss 0.3160
# step  297/300: dist 0.3160 loss 0.3160
# step  298/300: dist 0.3159 loss 0.3160
# step  299/300: dist 0.3159 loss 0.3160
# step  300/300: dist 0.3160 loss 0.3160
# Elapsed: 23.8 s
# Saving optimization progress video "/content/drive/MyDrive/TESIS/projections_batch_all/meningioma/102420_meningioma_0006/proj.mp4"
#
# [PROJECTOR] STDERR:
# W1115 19:51:42.159000 50738 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1115 19:51:42.159000 50738 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# W1115 19:51:45.215000 50738 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1115 19:51:45.215000 50738 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/projector.py:192: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:835.)
#   logprint(f'step {step+1:>4d}/{num_steps}: dist {float(dist):.4f} loss {float(loss):.4f}')
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/projector.py:282: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(synth_img, mode='L').save(f'{outdir}/proj.png')
#
# [ETA] 15/30 (50.0%) | elapsed=08:40 | remaining~08:40
# [PROJECTOR] 113435_meningioma_0018.png -> /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/113435_meningioma_0018
#   CMD: python projector.py --network=/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl --target=/content/localdata/test_unzipped/testreducido/meningioma/113435_meningioma_0018.png --outdir=/content/drive/MyDrive/TESIS/projections_batch_all/meningioma/113435_meningioma_0018 --num-steps=300 --seed=138
# [PROJECTOR] STDOUT:
# Loading networks from "/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/300: dist 0.4900 loss 16573.7598
# step    2/300: dist 0.4907 loss 37584.5312
# step    3/300: dist 0.4870 loss 36447.3086
# step    4/300: dist 0.4804 loss 34280.8789
# step    5/300: dist 0.4784 loss 31247.1738
# step    6/300: dist 0.4710 loss 27675.7812
# step    7/300: dist 0.4592 loss 23943.2910
# step    8/300: dist 0.4513 loss 20334.1465
# step    9/300: dist 0.4458 loss 17014.9043
# step   10/300: dist 0.4464 loss 13723.4307
# step   11/300: dist 0.4395 loss 10358.2832
# step   12/300: dist 0.4383 loss 7126.3271
# step   13/300: dist 0.4347 loss 4468.4385
# step   14/300: dist 0.4280 loss 2961.9055
# step   15/300: dist 0.4254 loss 2900.5217
# step   16/300: dist 0.4201 loss 4071.8953
# step   17/300: dist 0.4164 loss 5610.3481
# step   18/300: dist 0.4165 loss 6666.1934
# step   19/300: dist 0.4127 loss 6961.2466
# step   20/300: dist 0.4129 loss 6597.3926
# step   21/300: dist 0.4078 loss 5840.7920
# step   22/300: dist 0.4024 loss 4858.9634
# step   23/300: dist 0.4009 loss 3713.2905
# step   24/300: dist 0.3954 loss 2552.1160
# step   25/300: dist 0.3912 loss 1540.4126
# step   26/300: dist 0.3921 loss 889.3113
# step   27/300: dist 0.3873 loss 661.0729
# step  295/300: dist 0.2899 loss 0.2905
# step  296/300: dist 0.2899 loss 0.2906
# step  297/300: dist 0.2899 loss 0.2907
# step  298/300: dist 0.2899 loss 0.2907
# step  299/300: dist 0.2899 loss 0.2907
# step  300/300: dist 0.2899 loss 0.2907
# Elapsed: 23.8 s
# Saving optimization progress video "/content/drive/MyDrive/TESIS/projections_batch_all/meningioma/113435_meningioma_0018/proj.mp4"
#
# [PROJECTOR] STDERR:
# W1115 19:52:17.160000 50956 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1115 19:52:17.160000 50956 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# W1115 19:52:20.178000 50956 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1115 19:52:20.178000 50956 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/projector.py:192: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:835.)
#   logprint(f'step {step+1:>4d}/{num_steps}: dist {float(dist):.4f} loss {float(loss):.4f}')
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/projector.py:282: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(synth_img, mode='L').save(f'{outdir}/proj.png')
#
# [ETA] 16/30 (53.3%) | elapsed=09:15 | remaining~08:05
# [PROJECTOR] 102714_meningioma_0001.png -> /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/102714_meningioma_0001
#   CMD: python projector.py --network=/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl --target=/content/localdata/test_unzipped/testreducido/meningioma/102714_meningioma_0001.png --outdir=/content/drive/MyDrive/TESIS/projections_batch_all/meningioma/102714_meningioma_0001 --num-steps=300 --seed=139
# [PROJECTOR] STDOUT:
# Loading networks from "/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/300: dist 0.4898 loss 6285.5859
# step    2/300: dist 0.4889 loss 5775.7896
# step    3/300: dist 0.4869 loss 4972.0967
# step    4/300: dist 0.4825 loss 3734.4075
# step    5/300: dist 0.4763 loss 2551.8621
# step    6/300: dist 0.4678 loss 1839.6445
# step    7/300: dist 0.4609 loss 1824.5210
# step    8/300: dist 0.4527 loss 2202.7156
# step    9/300: dist 0.4418 loss 2418.4023
# step   10/300: dist 0.4307 loss 2354.9185
# step   11/300: dist 0.4252 loss 2183.6377
# step   12/300: dist 0.4305 loss 2059.8840
# step   13/300: dist 0.4361 loss 2162.0525
# step   14/300: dist 0.4307 loss 2227.4219
# step   15/300: dist 0.4193 loss 1928.2054
# step   16/300: dist 0.4173 loss 1480.2765
# step   17/300: dist 0.4089 loss 1126.5685
# step   18/300: dist 0.4064 loss 955.9933
# step   19/300: dist 0.4026 loss 888.6935
# step   20/300: dist 0.3969 loss 861.0724
# step   21/300: dist 0.3848 loss 848.1686
# step   22/300: dist 0.3742 loss 901.5855
# step   23/300: dist 0.3801 loss 1004.2057
# step   24/300: dist 0.3633 loss 996.0438
# step   25/300: dist 0.3640 loss 830.3236
# step   26/300: dist 0.3590 loss 593.8054
# step   27/300: dist 0.3443 loss 412.0558
# step   28/300: dist 0.3343 loss 292.3598
# step   29/300: dist 0.3308 loss 217.5498
# step   30/300: dist 0.3201 loss 227.7899
# step   31/300: dist 0.3130 loss 282.6497
# step   32/300: dist 0.3272 loss 341.6920
# step   33/300: dist 0.3284 loss 365.8268
# step   34/300: dist 0.3183 loss 309.7150
# step   35/300: dist 0.3224 loss 200.3551
# step   36/300: dist 0.3248 loss 107.5943
# step   37/300: dist 0.3189 loss 93.7566
torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1115 19:52:52.013000 51172 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# W1115 19:52:55.040000 51172 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1115 19:52:55.040000 51172 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/projector.py:192: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:835.)
#   logprint(f'step {step+1:>4d}/{num_steps}: dist {float(dist):.4f} loss {float(loss):.4f}')
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/projector.py:282: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(synth_img, mode='L').save(f'{outdir}/proj.png')
#
# [ETA] 17/30 (56.7%) | elapsed=09:50 | remaining~07:31
# [PROJECTOR] 107494_meningioma_0010.png -> /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/107494_meningioma_0010
#   CMD: python projector.py --network=/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl --target=/content/localdata/test_unzipped/testreducido/meningioma/107494_meningioma_0010.png --outdir=/content/drive/MyDrive/TESIS/projections_batch_all/meningioma/107494_meningioma_0010 --num-steps=300 --seed=140
# [PROJECTOR] STDOUT:
# Loading networks from "/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/300: dist 0.4528 loss 5921.3994
# step    2/300: dist 0.4527 loss 19317.8965
# step    3/300: dist 0.4499 loss 18134.8223
# step    4/300: dist 0.4441 loss 16034.3740
# step    5/300: dist 0.4384 loss 13439.7617
# step    6/300: dist 0.4311 loss 10783.1846
# step    7/300: dist 0.4305 loss 8211.7900
# step    8/300: dist 0.4257 loss 5845.0693
# step    9/300: dist 0.3848 loss 3969.4026
# step   10/300: dist 0.3856 loss 2904.0315
# step   11/300: dist 0.3803 loss 2609.2715
# step   12/300: dist 0.3700 loss 2668.4597
# step   13/300: dist 0.3745 loss 2966.9089
# step   14/300: dist 0.3680 loss 3454.1799
# step   15/300: dist 0.3576 loss 3795.5105
# step   16/300: dist 0.3506 loss 3650.9268
# step   17/300: dist 0.3484 loss 3161.4822
# step   18/300: dist 0.3481 loss 2726.6802
# step   19/300: dist 0.3441 loss 2378.4832
# step   20/300: dist 0.3389 loss 1927.5894
# step   21/300: dist 0.3355 loss 1486.9575
# step   22/300: dist 0.3304 loss 1213.8229
# step   23/300: dist 0.3209 loss 1075.6691
# step   24/300: dist 0.3212 loss 1030.8536
# step   25/300: dist 0.3219 loss 1057.1174
# step   26/300: dist 0.3192 loss 1130.4335
# step   27/300: dist 0.3133 loss 1155.8120
# step   28/300: dist 0.3151 loss 1089.7661
# step   29/300: dist 0.3115 loss 1002.3908
# step   30/300: dist 0.3058 loss 902.4805
# step   31/300: dist 0.3046 loss 775.8898
# step   32/300: dist 0.3056 loss 649.9012
# step   33/300: dist 0.3041 loss 577.3523
# step   34/300: dist 0.3007 loss 555.9013
# step   35/300: dist 0.3040 loss 542.1339
# step   36/300: dist 0.2953 loss 531.8340
# step   37/300: dist 0.2935 loss 488.9874
# step   38/300: dist 0.2896 loss 410.7122
# step   39/300: dist 0.2930 loss 315.4807
# step   40/300: dist 0.2930 loss 231.2147
# step   41/300: dist 0.2886 loss 165.6286
# step   42/300: dist 0.2869 loss 116.2873
# step   43/300: dist 0.2841 loss 100.8322
# step   44/300: dist 0.2836 loss 115.0861
# step   45/300: dist 0.2820 loss 141.8148
# step   46/300: dist 0.2817 loss 170.8795
# step   47/300: dist 0.2767 loss 191.5914
# step   48/300: dist 0.2800 loss 188.8050
# step   49/300: dist 0.2737 loss 160.2754
# step   50/300: dist 0.2800 loss 123.9167
# step   51/300: dist 0.2718 loss 93.6508
# step   52/300: dist 0.2801 loss 73.1934
# step   53/300: dist 0.2694 loss 63.4710
# step   54/300: dist 0.2762 loss 67.3560
# step   55/300: dist 0.2741 loss 76.3345
# step   56/300: dist 0.2699 loss 77.9676
# step   57/300: dist 0.2714 loss 68.1210
# step   58/300: dist 0.2656 loss 50.4174
# step   59/300: dist 0.2727 loss 30.6035
# step   60/300: dist 0.2737 loss 14.6760
# step   61/300: dist 0.2668 loss 9.3112
# step   62/300: dist 0.2686 loss 13.5258
# step   63/300: dist 0.2704 loss 22.4959
# step   64/300: dist 0.2721 loss 31.8487
# step   65/300: dist 0.2673 loss 37.5092
# step   66/300: dist 0.2686 loss 35.2254
# step   67/300: dist 0.2653 loss 27.9998
# step   68/300: dist 0.2652 loss 21.1675
# step   69/300: dist 0.2636 loss 16.2192
# step   70/300: dist 0.2653 loss 11.9279
# step   71/300: dist 0.2636 loss 10.1117
# step   72/300: dist 0.2589 loss 12.1467
# step   73/300: dist 0.2572 loss 15.9283
# step   74/300: dist 0.2585 loss 16.9172
# step   75/300: dist 0.2587 loss 14.0070
# step   76/300: dist 0.2571 loss 10.2011
# step   77/300: dist 0.2553 loss 8.3519
# step   78/300: dist 0.2531 loss 8.0595
# step   79/300: dist 0.2530 loss 9.1491
# step   80/300: dist 0.2531 loss 12.1155
# step   81/300: dist 0.2522 loss 15.7942
# step   82/300: dist 0.2504 loss 14.6522
# step   83/300: dist 0.2502 loss 8.9929
# step   84/300: dist 0.2547 loss 9.0046
# step   85/300: dist 0.2518 loss 11.9787
# step   86/300: dist 0.2504 loss 7.8327
# step   87/300: dist 0.2526 loss 3.8379
# step   88/300: dist 0.2548 loss 8.5848
# step   89/300: dist 0.2524 loss 11.8834
# step   90/300: dist 0.2543 loss 9.4092
# step   91/300: dist 0.2473 loss 8.6402
# step   92/300: dist 0.2541 loss 7.0599
# step   93/300: dist 0.2491 loss 3.3766
# step   94/300: dist 0.2525 loss 4.3142
# step   95/300: dist 0.2479 loss 6.1122
# step   96/300: dist 0.2541 loss 2.9329
# step   97/300: dist 0.2499 loss 1.6402
# step   98/300: dist 0.2591 loss 4.4170
# step   99/300: dist 0.2503 loss 4.4373
# step  100/300: dist 0.2564 loss 2.3134
# step  101/300: dist 0.2588 loss 2.0112
# step  102/300: dist 0.2463 loss 2.4277
# step  103/300: dist 0.2625 loss 2.6454
# step  104/300: dist 0.2591 loss 2.6041
# step  105/300: dist 0.2465 loss 1.6462
# step  106/300: dist 0.2559 loss 1.2630
# step  107/300: dist 0.2519 loss 2.0463
# step  108/300: dist 0.2462 loss 1.8398
# step  109/300: dist 0.2483 loss 0.8851
# step  110/300: dist 0.2467 loss 1.1455
# step  111/300: dist 0.2499 loss 1.6107
# step  112/300: dist 0.2444 loss 0.9704
# step  113/300: dist 0.2496 loss 0.5821
projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/107248_meningioma_0012/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/107494_meningioma_0010/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/113435_meningioma_0011/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/113435_meningioma_0018/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/meningioma/99308_meningioma_0009/projected_w.npz, w.shape=(14, 512)
# [PROTO] Saved meningioma prototype -> /content/drive/MyDrive/TESIS/prototypes/meningioma_prototype_mean.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/101029_pituitary_0003/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/101029_pituitary_0014/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/108858_pituitary_0012/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/112074_pituitary_0006/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/112649_pituitary_0002/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/112649_pituitary_0009/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/112847_pituitary_0006/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/112847_pituitary_0012/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/97599_pituitary_0002/projected_w.npz, w.shape=(14, 512)
# [PROTO] Loaded /content/drive/MyDrive/TESIS/projections_batch_all/pituitary/98874_pituitary_0013/projected_w.npz, w.shape=(14, 512)
# [PROTO] Saved pituitary prototype -> /content/drive/MyDrive/TESIS/prototypes/pituitary_prototype_mean.npz, w.shape=(14, 512)
#
# [PROTO] All prototypes computed.

# %%
from pathlib import Path
from typing import Dict, List
from collections import defaultdict
import subprocess
import shutil
import numpy as np
import time

IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}


def load_last_w(npz_path: Path) -> np.ndarray:
    if not npz_path.is_file():
        raise FileNotFoundError(f"NPZ not found: {npz_path}")
    data = np.load(str(npz_path))
    if "w" not in data:
        raise RuntimeError(f"'w' key not found in {npz_path}")
    w = data["w"]
    if w.ndim == 3:
        return w[-1]
    elif w.ndim == 2:
        return w
    else:
        raise RuntimeError(f"Unexpected 'w' shape in {npz_path}: {w.shape}")


def run_projector(
    projector_script: Path,
    network_pkl: Path,
    image_path: Path,
    outdir: Path,
    num_steps: int,
    seed: int,
    device: str = "cuda",
) -> Path:
    outdir.mkdir(parents=True, exist_ok=True)

    cmd = [
        "python",
        str(projector_script),
        f"--network={network_pkl}",
        f"--target={image_path}",
        f"--outdir={outdir}",
        f"--num-steps={num_steps}",
        f"--seed={seed}",
        f"--device={device}",
    ]

    print("[PROJECTOR] Running:")
    print(" ", " ".join(cmd))

    result = subprocess.run(cmd, check=False, capture_output=True, text=True)
    print("[PROJECTOR] STDOUT:")
    print(result.stdout)
    print("[PROJECTOR] STDERR:")
    print(result.stderr)

    if result.returncode != 0:
        raise RuntimeError(
            f"projector.py failed with exit code {result.returncode} "
            f"for image {image_path}"
        )

    proj_npz = outdir / "projected_w.npz"
    if not proj_npz.is_file():
        raise FileNotFoundError(
            f"Expected projected_w.npz not found in {outdir}. "
            f"Check projector.py (it must save np.savez(..., w=...))."
        )
    return proj_npz



def extract_patient_id(image_path: Path) -> str:
    stem = image_path.stem
    parts = stem.split("_")
    if len(parts) >= 1:
        return parts[0]
    return stem


def select_frames_by_percentile(frames_dir: Path, k: int) -> List[Path]:
    if not frames_dir.is_dir():
        raise FileNotFoundError(f"Frames directory not found: {frames_dir}")

    frames = sorted(frames_dir.glob("frame*.png"))
    if not frames:
        raise FileNotFoundError(f"No frame*.png found in {frames_dir}")

    n = len(frames)
    if k <= 0:
        return []
    if k >= n:
        return frames

    if k == 1:
        ps = [0.5]
    else:
        step = 1.0 / (k + 1)
        ps = [step * (i + 1) for i in range(k)]

    idxs: List[int] = []
    for p in ps:
        idx = int(round(p * (n - 1)))
        idxs.append(idx)

    idxs = sorted(set(idxs))
    return [frames[i] for i in idxs]


def _format_eta(seconds: float) -> str:
    seconds = int(seconds)
    h = seconds // 3600
    m = (seconds % 3600) // 60
    s = seconds % 60
    if h > 0:
        return f"{h:d}h {m:02d}m {s:02d}s"
    elif m > 0:
        return f"{m:d}m {s:02d}s"
    else:
        return f"{s:d}s"


def run_xai_counterfactual_from_folder(
    test_root: Path,
    network_pkl: Path,
    outdir_root: Path,
    projector_script: Path,
    generate_script: Path,
    proto_root: Path,
    classes: List[str],
    class_to_index: Dict[str, int],
    num_steps: int = 200,
    seed: int = 0,
    frames: int = 32,
    interp_mode: str = "linear",
    easing: str = "linear",
    truncation_psi: float = 1.0,
    noise_mode: str = "const",
    fps: int = 24,
    frames_to_keep_per_class: int = 1,
    max_images_per_patient: int = 0,
    device: str = "cuda",

) -> None:
    test_root = Path(test_root)
    network_pkl = Path(network_pkl)
    outdir_root = Path(outdir_root)
    projector_script = Path(projector_script)
    generate_script = Path(generate_script)
    proto_root = Path(proto_root)

    proj_root = outdir_root / "projection"
    pairs_root = outdir_root / "pairs"
    interps_root = outdir_root / "interpolations"
    classif_root = outdir_root / "classification"

    for d in [proj_root, pairs_root, interps_root, classif_root]:
        d.mkdir(parents=True, exist_ok=True)

    prototypes: Dict[str, np.ndarray] = {}
    for cls in classes:
        proto_path = proto_root / f"{cls}_prototype_mean.npz"
        if not proto_path.is_file():
            raise FileNotFoundError(
                f"Prototype for class '{cls}' not found at {proto_path}. "
                f"Run your prototype-building step first."
            )
        w_proto = load_last_w(proto_path)
        prototypes[cls] = w_proto
        print(f"[PROTO] Loaded {cls} prototype with shape {w_proto.shape} from {proto_path}")

    per_patient_counts: Dict[str, int] = defaultdict(int)
    cases: List[tuple] = []

    for true_cls in classes:
        cls_dir = test_root / true_cls
        if not cls_dir.is_dir():
            print(f"[WARN] Test class dir not found: {cls_dir}, skipping.")
            continue

        img_paths = sorted(
            p for p in cls_dir.rglob("*") if p.suffix.lower() in IMG_EXTS
        )
        if not img_paths:
            print(f"[WARN] No images found under {cls_dir}, skipping.")
            continue

        for img_path in img_paths:
            patient_id = extract_patient_id(img_path)
            current_count = per_patient_counts[patient_id]

            if max_images_per_patient > 0 and current_count >= max_images_per_patient:
                continue

            per_patient_counts[patient_id] += 1
            img_idx = per_patient_counts[patient_id]
            cases.append((true_cls, img_path, patient_id, img_idx))

    total_cases = len(cases)
    if total_cases == 0:
        print("[INFO] No cases to process. Exiting.")
        return

    print(f"[INFO] Total cases to process (patient-image pairs): {total_cases}")

    start_time = time.time()

    for case_i, (true_cls, img_path, patient_id, img_idx) in enumerate(cases, start=1):
        elapsed = time.time() - start_time
        if case_i == 1:
            elapsed_str = _format_eta(elapsed)
            eta_str = "estimating..."
        else:
            avg_per_case = elapsed / (case_i - 1)
            remaining = total_cases - (case_i - 1)
            eta_sec = avg_per_case * remaining
            elapsed_str = _format_eta(elapsed)
            eta_str = _format_eta(eta_sec)

        print(
            f"\n[PROGRESS] Case {case_i}/{total_cases} | "
            f"elapsed={elapsed_str} | ETA={eta_str}"
        )

        print(f"[CASE] Patient {patient_id} (img #{img_idx} for this patient, true class: {true_cls})")
        print(f"       Using image: {img_path}")

        proj_dir = proj_root / true_cls / f"{patient_id}_i{img_idx:02d}"
        proj_npz = run_projector(
            projector_script=projector_script,
            network_pkl=network_pkl,
            image_path=img_path,
            outdir=proj_dir,
            num_steps=num_steps,
            seed=seed,
        )
        w_real = load_last_w(proj_npz)
        print(f"[INFO] Loaded w_real from {proj_npz} with shape {w_real.shape}")

        case_classif_dir = classif_root / patient_id
        case_classif_dir.mkdir(parents=True, exist_ok=True)
        real_dest = case_classif_dir / f"real_{true_cls}_i{img_idx:02d}.png"
        shutil.copy2(img_path, real_dest)
        print(f"[CLASSIF] Saved real image -> {real_dest}")

        for target_cls in classes:
            w_proto = prototypes[target_cls]
            if w_real.shape != w_proto.shape:
                raise RuntimeError(
                    f"Shape mismatch for patient {patient_id}, target '{target_cls}': "
                    f"w_real {w_real.shape} vs w_proto {w_proto.shape}"
                )

            w_pair = np.stack([w_real, w_proto], axis=0)

            pair_dir = pairs_root / patient_id
            pair_dir.mkdir(parents=True, exist_ok=True)
            pair_npz = pair_dir / f"{patient_id}_i{img_idx:02d}_to_{target_cls}.npz"
            np.savez(pair_npz, w=w_pair)
            print(f"[PAIR] Saved W pair -> {pair_npz} (shape={w_pair.shape})")

            outdir_cls = interps_root / patient_id / f"i{img_idx:02d}" / target_cls
            outdir_cls.mkdir(parents=True, exist_ok=True)

            class_idx = class_to_index.get(target_cls, 0)

            cmd = [
                "python", str(generate_script),
                "--network", str(network_pkl),
                "--space=w",
                "--process=interpolation",
                "--projected-w", str(pair_npz),
                "--interpolation", interp_mode,
                "--easing", easing,
                "--frames", str(frames),
                "--trunc", str(truncation_psi),
                "--noise-mode", noise_mode,
                "--fps", str(fps),
                "--class", str(class_idx),
                "--outdir", str(outdir_cls),
            ]

            print(f"[GEN] Running interpolation to '{target_cls}' for patient {patient_id}, image #{img_idx}:")
            print(" ", " ".join(cmd))

            result = subprocess.run(cmd, check=False, capture_output=True, text=True)
            print("[GEN] STDOUT:")
            print(result.stdout)
            print("[GEN] STDERR:")
            print(result.stderr)

            if result.returncode != 0:
                raise RuntimeError(
                    f"generate.py failed for patient {patient_id}, img #{img_idx}, "
                    f"target '{target_cls}' with exit code {result.returncode}"
                )

            frames_dir = outdir_cls / "frames"
            frames_to_copy = select_frames_by_percentile(frames_dir, frames_to_keep_per_class)

            for j, frame_path in enumerate(frames_to_copy, start=1):
                cf_dest = case_classif_dir / f"cf_to_{target_cls}_i{img_idx:02d}_f{j:02d}.png"
                shutil.copy2(frame_path, cf_dest)
                print(f"[CLASSIF] Saved frame {frame_path.name} -> {cf_dest}")

    total_elapsed = time.time() - start_time
    print(f"\n[DONE] XAI counterfactual batch finished in {_format_eta(total_elapsed)}.")
    print(f"Classification images per patient are under: {classif_root}")

# %%
from pathlib import Path

test_root = Path("/content/localdata/test_unzipped/testreducido")
network_pkl = Path("/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl")
outdir_root = Path("/content/drive/MyDrive/TESIS/xai_batch_testsetexterno")

projector_script = Path("projector.py")
generate_script = Path("generate.py")
proto_root = Path("/content/drive/MyDrive/TESIS/prototypes")

classes = ["glioma", "meningioma", "pituitary"]
class_to_index = {"glioma": 0, "meningioma": 1, "pituitary": 2}

run_xai_counterfactual_from_folder(
    test_root=test_root,
    network_pkl=network_pkl,
    outdir_root=outdir_root,
    projector_script=projector_script,
    generate_script=generate_script,
    proto_root=proto_root,
    classes=classes,
    class_to_index=class_to_index,
    num_steps=300,
    seed=0,
    frames=120,
    interp_mode="linear",
    easing="linear",
    truncation_psi=1.0,
    noise_mode="const",
    fps=120,
    frames_to_keep_per_class=3,  # 25%, 50%, 75%
    max_images_per_patient=3,     # <-- CLAVE: hasta 3 imágenes por paciente
    device="cuda"

)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '/content/drive/MyDrive/TESIS/xai_batch_testset/interpolations/98871/i03/pituitary/frames/frame%04d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, gray(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x58b346a6d600] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x58b346a6d600] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x58b346a6d600] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/TESIS/xai_batch_testset/interpolations/98871/i03/pituitary/interpolation-linear-120fps.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 120 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    5 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A dup=4 drop=0 speed=   0x
# frame=  124 fps=0.0 q=-1.0 Lsize=      48kB time=00:00:01.00 bitrate= 388.5kbits/s dup=4 drop=0 speed=8.49x
# video:46kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.949648%
# [libx264 @ 0x58b346a6d600] frame I:1     Avg QP:25.50  size:  5477
# [libx264 @ 0x58b346a6d600] frame P:120   Avg QP:28.73  size:   345
# [libx264 @ 0x58b346a6d600] frame B:3     Avg QP:28.33  size:    13
# [libx264 @ 0x58b346a6d600] consecutive B-frames: 96.8%  0.0%  0.0%  3.2%
# [libx264 @ 0x58b346a6d600] mb I  I16..4:  7.4% 64.5% 28.1%
# [libx264 @ 0x58b346a6d600] mb P  I16..4:  0.0%  0.0%  0.0%  P16..4: 17.8%  5.1%  5.0%  0.0%  0.0%    skip:72.1%
# [libx264 @ 0x58b346a6d600] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  0.1%  0.0%  0.0%  direct: 0.0%  skip:99.9%  L0: 0.0% L1:100.0% BI: 0.0%
# [libx264 @ 0x58b346a6d600] 8x8 transform intra:61.2% inter:61.2%
# [libx264 @ 0x58b346a6d600] coded y,uvDC,uvAC intra: 66.8% 0.0% 0.0% inter: 8.0% 0.0% 0.0%
# [libx264 @ 0x58b346a6d600] i16 v,h,dc,p: 32% 24% 12% 32%
# [libx264 @ 0x58b346a6d600] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28%  9% 17%  8%  6%  8%  6% 13%  7%
# [libx264 @ 0x58b346a6d600] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 12% 12%  5% 11% 14%  8%  7%  5%
# [libx264 @ 0x58b346a6d600] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x58b346a6d600] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x58b346a6d600] ref P L0: 85.2%  9.9%  3.3%  1.7%
# [libx264 @ 0x58b346a6d600] kb/s:362.91
#
# [CLASSIF] Saved frame frame0030.png -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98871/cf_to_pituitary_i03_f01.png
# [CLASSIF] Saved frame frame0060.png -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98871/cf_to_pituitary_i03_f02.png
# [CLASSIF] Saved frame frame0089.png -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98871/cf_to_pituitary_i03_f03.png
#
# [PROGRESS] Case 195/197 | elapsed=3h 20m 09s | ETA=3m 05s
# [CASE] Patient 98874 (img #1 for this patient, true class: pituitary)
#        Using image: /content/localdata/test_unzipped/testreducido/pituitary/98874_pituitary_0001.png
# [PROJECTOR] Running:
#   python projector.py --network=/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl --target=/content/localdata/test_unzipped/testreducido/pituitary/98874_pituitary_0001.png --outdir=/content/drive/MyDrive/TESIS/xai_batch_testset/projection/pituitary/98874_i01 --num-steps=300 --seed=0 --device=cuda
# [PROJECTOR] STDOUT:
# Using device: cuda
# Loading networks from "/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/300: dist 0.4264 loss 9553.3760
# step    2/300: dist 0.4251 loss 13245.1309
# step    3/300: dist 0.4203 loss 12052.5439
# step    4/300: dist 0.4075 loss 9996.8740
# step    5/300: dist 0.3908 loss 7549.4629
# step    6/300: dist 0.3623 loss 5102.0669
# step    7/300: dist 0.3564 loss 3083.2668
# step    8/300: dist 0.3576 loss 1927.0216
# step    9/300: dist 0.3539 loss 1810.7062
# step   10/300: dist 0.3552 loss 2600.2664
# step   11/300: dist 0.3598 loss 3852.6963
# step   12/300: dist 0.3663 loss 4973.5996
# step   13/300: dist 0.3602 loss 5444.4126
# step   14/300: dist 0.3552 loss 5291.9409
# step   15/300: dist 0.3445 loss 4758.5811
# step   16/300: dist 0.3332 loss 3976.8149
# step   17/300: dist 0.3271 loss 3091.3118
# step   18/300: dist 0.3206 loss 2457.9819
# step   19/300: dist 0.3195 loss 2082.5315
# step   20/300: dist 0.3187 loss 1752.7264
# step   21/300: dist 0.3184 loss 1476.4572
# step   22/300: dist 0.3142 loss 1370.9851
# step   23/300: dist 0.3114 loss 1371.1947
# step   24/300: dist 0.3067 loss 1340.6116
# step   25/300: dist 0.3014 loss 1241.9977
# step   26/300: dist 0.2963 loss 1206.6464
# step   27/300: dist 0.2960 loss 1214.9672
# step   28/300: dist 0.2951 loss 1195.5282
# step   29/300: dist 0.2934 loss 1109.4790
# step   30/300: dist 0.2905 loss 934.8628
# step   31/300: dist 0.2894 loss 741.5985
# step   32/300: dist 0.2895 loss 560.1118
# step   33/300: dist 0.2865 loss 396.9994
# step   34/300: dist 0.2822 loss 305.8185
# step   35/300: dist 0.2822 loss 293.4182
# step   36/300: dist 0.2788 loss 337.0404
# step   37/300: dist 0.2770 loss 404.3207
# step   38/300: dist 0.2765 loss 459.2426
# step   39/300: dist 0.2772 loss 447.2861
# step   40/300: dist 0.2748 loss 382.4350
# step   41/300: dist 0.2738 loss 303.0966
# step   42/300: dist 0.2729 loss 219.8543
# step   43/300: dist 0.2710 loss 146.0213
# step   44/300: dist 0.2698 loss 104.7474
# step   45/300: dist 0.2685 loss 113.4504
DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(synth_img, mode='L').save(f'{outdir}/proj.png')
#
# [INFO] Loaded w_real from /content/drive/MyDrive/TESIS/xai_batch_testset/projection/pituitary/98874_i01/projected_w.npz with shape (14, 512)
# [CLASSIF] Saved real image -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98874/real_pituitary_i01.png
# [PAIR] Saved W pair -> /content/drive/MyDrive/TESIS/xai_batch_testset/pairs/98874/98874_i01_to_glioma.npz (shape=(2, 14, 512))
# [GEN] Running interpolation to 'glioma' for patient 98874, image #1:
#   python generate.py --network /content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl --space=w --process=interpolation --projected-w /content/drive/MyDrive/TESIS/xai_batch_testset/pairs/98874/98874_i01_to_glioma.npz --interpolation linear --easing linear --frames 120 --trunc 1.0 --noise-mode const --fps 120 --class 0 --outdir /content/drive/MyDrive/TESIS/xai_batch_testset/interpolations/98874/i01/glioma
# [GEN] STDOUT:
# Loading networks from "/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl"...
# Generating image for frame 0/120 ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for frame 1/120 ...
# Generating image for frame 2/120 ...
# Generating image for frame 3/120 ...
# Generating image for frame 4/120 ...
# Generating image for frame 5/120 ...
# Generating image for frame 6/120 ...
# Generating image for frame 7/120 ...
# Generating image for frame 8/120 ...
# Generating image for frame 9/120 ...
# Generating image for frame 10/120 ...
# Generating image for frame 11/120 ...
# Generating image for frame 12/120 ...
# Generating image for frame 13/120 ...
# Generating image for frame 14/120 ...
# Generating image for frame 15/120 ...
# Generating image for frame 16/120 ...
# Generating image for frame 17/120 ...
# Generating image for frame 18/120 ...
# Generating image for frame 19/120 ...
# Generating image for frame 20/120 ...
# Generating image for frame 21/120 ...
# Generating image for frame 22/120 ...
# Generating image for frame 23/120 ...
# Generating image for frame 24/120 ...
# Generating image for frame 25/120 ...
# Generating image for frame 26/120 ...
# Generating image for frame 27/120 ...
# Generating image for frame 28/120 ...
# Generating image for frame 29/120 ...
# Generating image for frame 30/120 ...
# Generating image for frame 31/120 ...
# Generating image for frame 32/120 ...
# Generating image for frame 33/120 ...
# Generating image for frame 34/120 ...
# Generating image for frame 35/120 ...
# Generating image for frame 36/120 ...
# Generating image for frame 37/120 ...
# Generating image for frame 38/120 ...
# Generating image for frame 39/120 ...
# Generating image for frame 40/120 ...
# Generating image for frame 41/120 ...
# Generating image for frame 42/120 ...
# Generating image for frame 43/120 ...
# Generating image for frame 44/120 ...
# Generating image for frame 45/120 ...
# Generating image for frame 46/120 ...
# Generating image for frame 47/120 ...
# Generating image for frame 48/120 ...
# Generating image for frame 49/120 ...
# Generating image for frame 50/120 ...
# Generating image for frame 51/120 ...
# Generating image for frame 52/120 ...
# Generating image for frame 53/120 ...
# Generating image for frame 54/120 ...
# Generating image for frame 55/120 ...
# Generating image for frame 56/120 ...
# Generating image for frame 57/120 ...
# Generating image for frame 58/120 ...
# Generating image for frame 59/120 ...
# Generating image for frame 60/120 ...
# Generating image for frame 61/120 ...
# Generating image for frame 62/120 ...
# Generating image for frame 63/120 ...
# Generating image for frame 64/120 ...
# Generating image for frame 65/120 ...
# Generating image for frame 66/120 ...
# Generating image for frame 67/120 ...
# Generating image for frame 68/120 ...
# Generating image for frame 69/120 ...
# Generating image for frame 70/120 ...
# Generating image for frame 71/120 ...
# Generating image for frame 72/120 ...
# Generating image for frame 73/120 ...
# Generating image for frame 74/120 ...
# Generating image for frame 75/120 ...
# Generating image for frame 76/120 ...
# Generating image for frame 77/120 ...
# Generating image for frame 78/120 ...
# Generating image for frame 79/120 ...
# Generating image for frame 80/120 ...
# Generating image for frame 81/120 ...
# Generating image for frame 82/120 ...
# Generating image for frame 83/120 ...
# Generating image for frame 84/120 ...
# Generating image for frame 85/120 ...
# Generating image for frame 86/120 ...
# Generating image for frame 87/120 ...
# Generating image for frame 88/120 ...
# Generating image for frame 89/120 ...
# Generating image for frame 90/120 ...
# Generating image for frame 91/120 ...
# Generating image for frame 92/120 ...
# Generating image for frame 93/120 ...
# Generating image for frame 94/120 ...
# Generating image for frame 95/120 ...
# Generating image for frame 96/120 ...
# Generating image for frame 97/120 ...
# Generating image for frame 98/120 ...
# Generating image for frame 99/120 ...
# Generating image for frame 100/120 ...
# Generating image for frame 101/120 ...
# Generating image for frame 102/120 ...
# Generating image for frame 103/120 ...
# Generating image for frame 104/120 ...
# Generating image for frame 105/120 ...
# Generating image for frame 106/120 ...
# Generating image for frame 107/120 ...
# Generating image for frame 108/120 ...
# Generating image for frame 109/120 ...
# Generating image for frame 110/120 ...
# Generating image for frame 111/120 ...
# Generating image for frame 112/120 ...
# Generating image for frame 113/120 ...
# Generating image for frame 114/120 ...
# Generating image for frame 115/120 ...
# Generating image for frame 116/120 ...
# Generating image for frame 117/120 ...
# Generating image for frame 118/120 ...
# Generating image for frame 119/120 ...
#
# [GEN] STDERR:
# W1116 23:54:58.810000 120265 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1116 23:54:58.810000 120265 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# W1116 23:54:58.855000 120265 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1116 23:54:58.855000 120265 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
# ...
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/generate.py:156: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(arr[:, :, 0], mode='L').save(out_path)
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '/content/drive/MyDrive/TESIS/xai_batch_testset/interpolations/98874/i03/pituitary/frames/frame%04d.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, gray(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x59839ca808c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x59839ca808c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x59839ca808c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/TESIS/xai_batch_testset/interpolations/98874/i03/pituitary/interpolation-linear-120fps.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 120 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    5 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A dup=4 drop=0 speed=   0x
# frame=  124 fps=0.0 q=-1.0 Lsize=      49kB time=00:00:01.00 bitrate= 397.5kbits/s dup=4 drop=0 speed=8.61x
# video:48kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.880430%
# [libx264 @ 0x59839ca808c0] frame I:1     Avg QP:25.40  size:  4585
# [libx264 @ 0x59839ca808c0] frame P:120   Avg QP:28.63  size:   362
# [libx264 @ 0x59839ca808c0] frame B:3     Avg QP:28.33  size:    16
# [libx264 @ 0x59839ca808c0] consecutive B-frames: 96.8%  0.0%  0.0%  3.2%
# [libx264 @ 0x59839ca808c0] mb I  I16..4: 11.3% 68.8% 19.9%
# [libx264 @ 0x59839ca808c0] mb P  I16..4:  0.1%  0.1%  0.0%  P16..4: 19.2%  5.2%  4.7%  0.0%  0.0%    skip:70.7%
# [libx264 @ 0x59839ca808c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.0%  0.0%  0.0%  direct: 0.0%  skip:99.0%  L0: 0.0% L1:100.0% BI: 0.0%
# [libx264 @ 0x59839ca808c0] 8x8 transform intra:66.3% inter:63.0%
# [libx264 @ 0x59839ca808c0] coded y,uvDC,uvAC intra: 56.3% 0.0% 0.0% inter: 8.4% 0.0% 0.0%
# [libx264 @ 0x59839ca808c0] i16 v,h,dc,p: 45% 32%  2% 21%
# [libx264 @ 0x59839ca808c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 11% 27%  5%  6%  7%  3%  9%  5%
# [libx264 @ 0x59839ca808c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 11% 12%  6%  8% 10%  8% 10%  6%
# [libx264 @ 0x59839ca808c0] i8c dc,h,v,p: 100%  0%  0%  0%
# [libx264 @ 0x59839ca808c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x59839ca808c0] ref P L0: 80.0% 13.3%  5.2%  1.5%
# [libx264 @ 0x59839ca808c0] kb/s:371.76
#
# [CLASSIF] Saved frame frame0030.png -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98874/cf_to_pituitary_i03_f01.png
# [CLASSIF] Saved frame frame0060.png -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98874/cf_to_pituitary_i03_f02.png
# [CLASSIF] Saved frame frame0089.png -> /content/drive/MyDrive/TESIS/xai_batch_testset/classification/98874/cf_to_pituitary_i03_f03.png
#
# [DONE] XAI counterfactual batch finished in 3h 23m 12s.
# Classification images per patient are under: /content/drive/MyDrive/TESIS/xai_batch_testset/classification

# %% [markdown]
# ##model

# %%
pip install lpips
# Out:
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.23.0+cu126)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.2)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %%
# ensemble_cnn_lpips_patient_gated_norm.py
# -*- coding: utf-8 -*-

from pathlib import Path
from typing import List, Dict, Optional
import csv
import re

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, models

from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

import lpips  # pip install lpips


def lpips_distances_to_probs(
    D: np.ndarray,
    temp: float = 0.2,
) -> np.ndarray:
    """
    Convierte distancias LPIPS D (más chico = mejor) en probabilidades.

    Pasos:
      1) Trabaja solo con valores finitos.
      2) Normaliza D a [0,1] usando (D - min) / (max - min).
      3) Aplica softmax(-D_norm / temp) para que la clase con
         menor distancia tenga prob más alta.
    """
    D = np.asarray(D, dtype=np.float32)
    C = D.shape[0]

    # Mascara de valores finitos
    finite_mask = np.isfinite(D)
    if not finite_mask.any():
        # Si TODO es inf, devolvemos uniforme
        return np.ones(C, dtype=np.float32) / float(C)

    # Extrae rango de los valores finitos
    D_finite = D[finite_mask]
    d_min = float(D_finite.min())
    d_max = float(D_finite.max())

    # Normalizamos el rango a [0,1]
    D_norm = np.zeros_like(D, dtype=np.float32)
    if d_max > d_min:
        D_norm = (D - d_min) / (d_max - d_min)
    else:
        # Si todas las distancias son iguales, no hay info:
        # usamos distribución uniforme
        return np.ones(C, dtype=np.float32) / float(C)

    # Los infinitos los mandamos al peor caso (1.0)
    D_norm[~finite_mask] = 1.0

    # Softmax con temperatura (más chico = distribución más "picuda")
    logits = -D_norm / max(temp, 1e-6)
    logits = logits - logits.max()  # por estabilidad numérica
    e = np.exp(logits)
    p = e / e.sum()

    return p.astype(np.float32)


def ensemble_cnn_lpips_patient_gated(
    classification_root: Path,
    model: nn.Module,
    class_names: List[str],
    out_csv: Path,
    device: Optional[str] = None,
    image_size: int = 256,
    frame_weights: Optional[Dict[int, float]] = None,
    class_weights: Optional[Dict[str, float]] = None,
    alpha_cnn: float = 0.5,
    tau_cnn: float = 0.80,
    tau_lpips: float = 0.70,
    lpips_temp: float = 0.2,   # <<< temperatura para LPIPS normalizado
):
    """
    Patient-level ensemble de:
      (1) CNN (probabilidades agregadas sobre imágenes generadas)
      (2) LPIPS (inference by generation, real vs generadas)

    GATED ENSEMBLE:

      - Si max(p_cnn) >= tau_cnn  -> usamos solo CNN:
            p_ens = p_cnn
      - Else, si max(p_lpips) >= tau_lpips -> usamos solo LPIPS:
            p_ens = p_lpips
      - Else -> mezcla suave:
            p_ens = alpha_cnn * p_cnn + (1 - alpha_cnn) * p_lpips

    LPIPS -> prob se calcula con lpips_distances_to_probs(D, temp=lpips_temp).
    """

    classification_root = Path(classification_root)
    out_csv = Path(out_csv)

    # ---- Device ----
    if device is None:
        device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"[INFO] Using device (ensemble gated): {device}")

    # ---- CNN model ----
    model = model.to(device)
    model.eval()

    # ---- LPIPS network ----
    lpips_fn = lpips.LPIPS(net='alex').to(device)
    lpips_fn.eval()

    num_classes = len(class_names)
    class_to_idx = {c: i for i, c in enumerate(class_names)}
    idx_to_class = {i: c for c, i in class_to_idx.items()}

    # ---- Default weights ----
    if frame_weights is None:
        frame_weights = {1: 1/3, 2: 1/3, 3: 1/3}
    print(f"[INFO] frame_weights (ensemble) = {frame_weights}")

    if class_weights is None:
        class_weights = {c: 1.0 for c in class_names}
    print(f"[INFO] class_weights (ensemble) = {class_weights}")

    # ---- Transforms ----
    resize_tf = transforms.Resize((image_size, image_size))
    to_tensor = transforms.ToTensor()
    norm_cnn = transforms.Normalize(mean=[0.5, 0.5, 0.5],
                                    std=[0.5, 0.5, 0.5])

    def preprocess_cnn(pil_img: Image.Image) -> torch.Tensor:
        img = pil_img.convert("L")
        img = resize_tf(img)
        t = to_tensor(img)         # [1,H,W]
        t = t.repeat(3, 1, 1)      # [3,H,W]
        t = norm_cnn(t)
        return t

    def preprocess_lpips(pil_img: Image.Image) -> torch.Tensor:
        img = pil_img.convert("L")
        img = resize_tf(img)
        t = to_tensor(img)         # [1,H,W] in [0,1]
        t = t.repeat(3, 1, 1)      # [3,H,W]
        t = t * 2.0 - 1.0          # [-1,1]
        return t.unsqueeze(0)      # [1,3,H,W]

    # ---- Patient folders ----
    patient_dirs = [d for d in classification_root.iterdir() if d.is_dir()]
    patient_dirs = sorted(patient_dirs, key=lambda p: p.name)

    print(f"[INFO] Found {len(patient_dirs)} patient folders in {classification_root}")

    real_pattern = re.compile(r"^real_([^_]+)(?:_i(\d+))?$")
    cf_pattern = re.compile(r"^cf_to_([a-zA-Z0-9]+)(?:_i(\d+))?_f(\d+)$")

    all_rows = []

    y_true_all = []
    y_pred_cnn_all = []
    y_pred_lpips_all = []
    y_pred_ens_all = []

    for patient_dir in patient_dirs:
        patient_id = patient_dir.name

        # ===== Real images (for LPIPS) =====
        real_files = list(patient_dir.glob("real_*.png"))
        if not real_files:
            print(f"[WARN] No real_*.png for patient {patient_id}, skipping.")
            continue

        real_by_idx: Dict[int, Path] = {}
        true_cls = None

        for rf in real_files:
            m_real = real_pattern.match(rf.stem)
            if not m_real:
                continue
            cls = m_real.group(1)
            idx_str = m_real.group(2)

            if true_cls is None:
                true_cls = cls
            elif cls != true_cls:
                print(f"[WARN] Multiple classes in real_*.png for patient {patient_id}, skipping.")
                true_cls = None
                break

            idx_img = int(idx_str) if idx_str is not None else 0
            real_by_idx[idx_img] = rf

        if true_cls is None or true_cls not in class_to_idx:
            print(f"[WARN] Could not determine valid true class for patient {patient_id}, skipping.")
            continue

        true_idx = class_to_idx[true_cls]

        real_tensor_cache: Dict[int, torch.Tensor] = {}

        # ===== Generated images =====
        cf_files = sorted(patient_dir.glob("cf_to_*.png"))
        if not cf_files:
            print(f"[WARN] No cf_to_*.png for patient {patient_id}, skipping.")
            continue

        print(f"\n[PATIENT] {patient_id} | y_true = {true_cls} | #generated images = {len(cf_files)}")

        # Aggregadores CNN
        sum_probs_cnn = torch.zeros(num_classes, device=device)
        sum_w_cnn = 0.0

        # Aggregadores LPIPS
        sum_d_per_target = {c_idx: 0.0 for c_idx in range(num_classes)}
        sum_w_per_target = {c_idx: 0.0 for c_idx in range(num_classes)}
        count_imgs_per_target = {c_idx: 0 for c_idx in range(num_classes)}

        for img_path in cf_files:
            m_cf = cf_pattern.match(img_path.stem)
            if not m_cf:
                print(f"[WARN] Filename {img_path.name} does not match cf pattern, skipping.")
                continue

            target_cls = m_cf.group(1)
            idx_str = m_cf.group(2)
            frame_str = m_cf.group(3)

            if target_cls not in class_to_idx:
                print(f"[WARN] target_cls '{target_cls}' not in class_names, skipping {img_path.name}.")
                continue

            target_idx = class_to_idx[target_cls]
            img_idx = int(idx_str) if idx_str is not None else 0

            # Frame index
            try:
                frame_idx = int(frame_str)
            except Exception:
                frame_idx = None

            # Weights
            w_frame = frame_weights.get(frame_idx, 1.0)
            w_cls = class_weights.get(target_cls, 1.0)
            w_total = w_cls * w_frame

            # ---------- CNN ----------
            pil_cf = Image.open(img_path)
            x_cnn = preprocess_cnn(pil_cf).unsqueeze(0).to(device)
            with torch.no_grad():
                logits = model(x_cnn)
                probs = F.softmax(logits, dim=1)[0]  # [num_classes]
            sum_probs_cnn += w_total * probs
            sum_w_cnn += w_total

            # ---------- LPIPS ----------
            real_path = real_by_idx.get(img_idx, real_files[0])

            if img_idx not in real_tensor_cache:
                real_pil = Image.open(real_path)
                real_t = preprocess_lpips(real_pil).to(device)
                real_tensor_cache[img_idx] = real_t
            else:
                real_t = real_tensor_cache[img_idx]

            cf_t = preprocess_lpips(pil_cf).to(device)

            with torch.no_grad():
                d_lpips = lpips_fn(real_t, cf_t).item()

            sum_d_per_target[target_idx] += w_total * d_lpips
            sum_w_per_target[target_idx] += w_total
            count_imgs_per_target[target_idx] += 1

        # ===== CNN: prob paciente =====
        if sum_w_cnn == 0.0:
            print(f"[WARN] sum_w_cnn == 0 for patient {patient_id}, skipping.")
            continue

        p_cnn = (sum_probs_cnn / sum_w_cnn).detach().cpu().numpy()
        pred_idx_cnn = int(p_cnn.argmax())
        pred_cls_cnn = idx_to_class[pred_idx_cnn]
        max_p_cnn = float(p_cnn.max())

        # ===== LPIPS: distancias promedio -> prob normalizada =====
        D = np.zeros(num_classes, dtype=np.float32)
        for c_idx in range(num_classes):
            if sum_w_per_target[c_idx] > 0:
                D[c_idx] = float(sum_d_per_target[c_idx] / sum_w_per_target[c_idx])
            else:
                D[c_idx] = np.inf

        # D -> probs usando normalización min-max + temperatura
        p_lpips = lpips_distances_to_probs(D, temp=lpips_temp)
        pred_idx_lpips = int(p_lpips.argmax())
        pred_cls_lpips = idx_to_class[pred_idx_lpips]
        max_p_lpips = float(p_lpips.max())

        # ===== Ensemble (gated) =====
        if max_p_cnn >= tau_cnn:
            p_ens = p_cnn.copy()
            gate_mode = "cnn_only"
        elif max_p_lpips >= tau_lpips:
            p_ens = p_lpips.copy()
            gate_mode = "lpips_only"
        else:
            p_ens = alpha_cnn * p_cnn + (1.0 - alpha_cnn) * p_lpips
            gate_mode = "mixed"

        pred_idx_ens = int(p_ens.argmax())
        pred_cls_ens = idx_to_class[pred_idx_ens]

        print(f"  -> p_cnn       = {p_cnn}  (max={max_p_cnn:.3f})")
        print(f"  -> D (LPIPS)   = {D}")
        print(f"  -> p_lpips     = {p_lpips} (max={max_p_lpips:.3f})")
        print(f"  -> gate_mode   = {gate_mode}")
        print(f"  -> p_ensemble  = {p_ens}")
        print(f"  -> y_pred_cnn      = {pred_cls_cnn}")
        print(f"  -> y_pred_lpips    = {pred_cls_lpips}")
        print(f"  -> y_pred_ensemble = {pred_cls_ens}")

        y_true_all.append(true_idx)
        y_pred_cnn_all.append(pred_idx_cnn)
        y_pred_lpips_all.append(pred_idx_lpips)
        y_pred_ens_all.append(pred_idx_ens)

        row = {
            "patient_id": patient_id,
            "y_true": true_cls,
            "y_pred_cnn": pred_cls_cnn,
            "y_pred_lpips": pred_cls_lpips,
            "y_pred_ensemble": pred_cls_ens,
            "gate_mode": gate_mode,
            "max_p_cnn": max_p_cnn,
            "max_p_lpips": max_p_lpips,
        }
        for i, c in enumerate(class_names):
            row[f"p_cnn_{c}"] = float(p_cnn[i])
            row[f"D_{c}"] = float(D[i]) if np.isfinite(D[i]) else float("inf")
            row[f"p_lpips_{c}"] = float(p_lpips[i])
            row[f"p_ens_{c}"] = float(p_ens[i])
            row[f"n_imgs_{c}"] = int(count_imgs_per_target[i])
            row[f"sum_w_{c}"] = float(sum_w_per_target[i])

        all_rows.append(row)

    # ===== Save CSV =====
    out_csv.parent.mkdir(parents=True, exist_ok=True)
    fieldnames = (
        ["patient_id", "y_true", "y_pred_cnn", "y_pred_lpips", "y_pred_ensemble",
         "gate_mode", "max_p_cnn", "max_p_lpips"]
        + [f"p_cnn_{c}" for c in class_names]
        + [f"D_{c}" for c in class_names]
        + [f"p_lpips_{c}" for c in class_names]
        + [f"p_ens_{c}" for c in class_names]
        + [f"n_imgs_{c}" for c in class_names]
        + [f"sum_w_{c}" for c in class_names]
    )

    with out_csv.open("w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for r in all_rows:
            writer.writerow(r)

    print(f"\n[INFO] Saved patient-level GATED ENSEMBLE results to: {out_csv}")

    # ===== Global metrics =====
    if len(y_true_all) == 0:
        print("[WARN] No patients evaluated. Check your classification_root.")
        return None

    results = {}

    # CNN
    acc_cnn = accuracy_score(y_true_all, y_pred_cnn_all)
    f1_cnn = f1_score(y_true_all, y_pred_cnn_all, average="macro")
    print("\n[METRICS] CNN (prob-based aggregation):")
    print(f"  Accuracy: {acc_cnn:.4f}")
    print(f"  F1-macro: {f1_cnn:.4f}")
    print("  Classification report:")
    print(classification_report(y_true_all, y_pred_cnn_all, target_names=class_names, digits=4))
    print("  Confusion matrix:")
    print(confusion_matrix(y_true_all, y_pred_cnn_all))
    results["cnn"] = {"accuracy": float(acc_cnn), "f1_macro": float(f1_cnn)}

    # LPIPS
    acc_lpips = accuracy_score(y_true_all, y_pred_lpips_all)
    f1_lpips = f1_score(y_true_all, y_pred_lpips_all, average="macro")
    print("\n[METRICS] LPIPS (inference by generation, normalized):")
    print(f"  Accuracy: {acc_lpips:.4f}")
    print(f"  F1-macro: {f1_lpips:.4f}")
    print("  Classification report:")
    print(classification_report(y_true_all, y_pred_lpips_all, target_names=class_names, digits=4))
    print("  Confusion matrix:")
    print(confusion_matrix(y_true_all, y_pred_lpips_all))
    results["lpips"] = {"accuracy": float(acc_lpips), "f1_macro": float(f1_lpips)}

    # Ensemble (gated)
    acc_ens = accuracy_score(y_true_all, y_pred_ens_all)
    f1_ens = f1_score(y_true_all, y_pred_ens_all, average="macro")
    print("\n[METRICS] GATED ENSEMBLE (alpha_cnn = %.2f, tau_cnn = %.2f, tau_lpips = %.2f, lpips_temp = %.2f):"
          % (alpha_cnn, tau_cnn, tau_lpips, lpips_temp))
    print(f"  Accuracy: {acc_ens:.4f}")
    print(f"  F1-macro: {f1_ens:.4f}")
    print("  Classification report:")
    print(classification_report(y_true_all, y_pred_ens_all, target_names=class_names, digits=4))
    print("  Confusion matrix:")
    print(confusion_matrix(y_true_all, y_pred_ens_all))
    results["ensemble_gated"] = {"accuracy": float(acc_ens), "f1_macro": float(f1_ens)}

    results["n_patients"] = len(y_true_all)
    return results

# %%
from pathlib import Path
import csv, json   # <-- nuevos imports para el grid summary
import torch
import torch.nn as nn
from torchvision import models

# === Rutas ===
classification_root = Path("/content/localdata/class/classification")
ckpt_path = "/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/inge1.3fold/full_train/final_full.ckpt"

# === Clases ===
class_names = ["glioma", "meningioma", "pituitary"]

# === Modelo CNN ===
def build_model(num_classes: int, pretrained: bool = False) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m

checkpoint = torch.load(ckpt_path, map_location="cuda")
model = build_model(num_classes=len(class_names), pretrained=False)
if "model" in checkpoint:
    model.load_state_dict(checkpoint["model"])
else:
    model.load_state_dict(checkpoint)

# === Pesos por frame y por clase (los mismos que ya usas) ===
frame_weights = {
    1: 2,
    2: 0.3,
    3: 1,
}

class_weights = {
    "glioma": 400,
    "meningioma": 0.3,
    "pituitary": 1.0,
}

# === Carpeta donde guardar los CSV de cada combinación ===
grid_out_dir = Path("/content/drive/MyDrive/TESIS/xai_batch_testset/grid_ensemble_lpipsnorm")
grid_out_dir.mkdir(parents=True, exist_ok=True)

# === Definir el grid de hiperparámetros ===
alpha_cnn_grid   = [0.5, 0.7, 0.9]
tau_cnn_grid     = [0.80, 0.90, 0.95]
tau_lpips_grid   = [0.70, 0.80, 0.90]
lpips_temp_grid  = [0.5, 0.7, 0.9]

grid_results = []

total_configs = (
    len(alpha_cnn_grid)
    * len(tau_cnn_grid)
    * len(tau_lpips_grid)
    * len(lpips_temp_grid)
)
print(f"[GRID] Total configs to evaluate: {total_configs}")

cfg_idx = 0

for alpha_cnn in alpha_cnn_grid:
    for tau_cnn in tau_cnn_grid:
        for tau_lpips in tau_lpips_grid:
            for lpips_temp in lpips_temp_grid:
                cfg_idx += 1
                print("\n" + "=" * 70)
                print(f"[GRID] Config {cfg_idx}/{total_configs} | "
                      f"alpha_cnn={alpha_cnn:.2f}, tau_cnn={tau_cnn:.2f}, "
                      f"tau_lpips={tau_lpips:.2f}, lpips_temp={lpips_temp:.2f}")

                # Nombre de archivo para esta combinación
                cfg_name = (
                    f"a{alpha_cnn:.2f}_tc{tau_cnn:.2f}_tl{tau_lpips:.2f}_T{lpips_temp:.2f}"
                    .replace(".", "p")
                )
                out_csv_cfg = grid_out_dir / f"results_{cfg_name}.csv"

                # Ejecutar evaluación para esta combinación
                res = ensemble_cnn_lpips_patient_gated(
                    classification_root=classification_root,
                    model=model,
                    class_names=class_names,
                    out_csv=out_csv_cfg,
                    device=None,             # o "cuda" si quieres forzar GPU
                    image_size=256,
                    frame_weights=frame_weights,
                    class_weights=class_weights,
                    alpha_cnn=alpha_cnn,
                    tau_cnn=tau_cnn,
                    tau_lpips=tau_lpips,
                    lpips_temp=lpips_temp,
                )

                if res is None:
                    print("[GRID] WARNING: res is None (no patients?) – skipping metrics.")
                    continue

                # Guardar resultados de esta combinación
                row = {
                    "alpha_cnn": float(alpha_cnn),
                    "tau_cnn": float(tau_cnn),
                    "tau_lpips": float(tau_lpips),
                    "lpips_temp": float(lpips_temp),
                    "acc_cnn": res["cnn"]["accuracy"],
                    "f1_cnn": res["cnn"]["f1_macro"],
                    "acc_lpips": res["lpips"]["accuracy"],
                    "f1_lpips": res["lpips"]["f1_macro"],
                    "acc_ensemble": res["ensemble_gated"]["accuracy"],
                    "f1_ensemble": res["ensemble_gated"]["f1_macro"],
                    "n_patients": res["n_patients"],
                    "out_csv": str(out_csv_cfg),
                }
                grid_results.append(row)

# === Guardar resumen global del grid search ===
summary_csv = grid_out_dir / "grid_summary_lpipsnorm.csv"
fieldnames = [
    "alpha_cnn", "tau_cnn", "tau_lpips", "lpips_temp",
    "acc_cnn", "f1_cnn",
    "acc_lpips", "f1_lpips",
    "acc_ensemble", "f1_ensemble",
    "n_patients", "out_csv",
]

with summary_csv.open("w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for r in grid_results:
        writer.writerow(r)

print(f"\n[GRID] Saved grid summary to: {summary_csv}")

# (Opcional) Mostrar el top-5 por F1 del ensemble
try:
    import pandas as pd
    df = pd.DataFrame(grid_results)
    df_top = df.sort_values("f1_ensemble", ascending=False).head(5)
    print("\n[GRID] Top-5 configs by F1_ensemble:")
    print(df_top)
except ImportError:
    if grid_results:
        best = max(grid_results, key=lambda r: r["f1_ensemble"])
        print("\n[GRID] Best config by F1_ensemble:")
        print(json.dumps(best, indent=2))
# Out:
# [GRID] Total configs to evaluate: 81
#
# ======================================================================
# [GRID] Config 1/81 | alpha_cnn=0.50, tau_cnn=0.80, tau_lpips=0.70, lpips_temp=0.50
# [INFO] Using device (ensemble gated): cuda
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [INFO] frame_weights (ensemble) = {1: 2, 2: 0.3, 3: 1}
# [INFO] class_weights (ensemble) = {'glioma': 400, 'meningioma': 0.3, 'pituitary': 1.0}
# [INFO] Found 68 patient folders in /content/localdata/class/classification
#
# [PATIENT] 101029 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.05880123 0.04282852 0.89837   ]  (max=0.898)
#   -> D (LPIPS)   = [0.26241094 0.28325713 0.21245256]
#   -> p_lpips     = [0.17681302 0.09812629 0.7250607 ] (max=0.725)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05880123 0.04282852 0.89837   ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101082 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.01764533 0.9271509  0.05520365]  (max=0.927)
#   -> D (LPIPS)   = [0.27446947 0.2708344  0.29261586]
#   -> p_lpips     = [0.38681853 0.5400884  0.07309302] (max=0.540)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01764533 0.9271509  0.05520365]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 101724 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10999078 0.19776064 0.6922485 ]  (max=0.692)
#   -> D (LPIPS)   = [0.22606193 0.23705442 0.1835412 ]
#   -> p_lpips     = [0.15237482 0.10103939 0.7465858 ] (max=0.747)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.15237482 0.10103939 0.7465858 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101797 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.2725743  0.7262002  0.00122545]  (max=0.726)
#   -> D (LPIPS)   = [0.15931454 0.1999399  0.22137481]
#   -> p_lpips     = [0.7115589  0.19214211 0.09629902] (max=0.712)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.7115589  0.19214211 0.09629902]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 102075 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.22499348 0.7095861  0.06542044]  (max=0.710)
#   -> D (LPIPS)   = [0.22106811 0.22819519 0.23189758]
#   -> p_lpips     = [0.7125159  0.19105554 0.09642854] (max=0.713)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.7125159  0.19105554 0.09642854]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 102420 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.9200412e-02 9.5016962e-01 6.3025148e-04]  (max=0.950)
#   -> D (LPIPS)   = [0.21633242 0.18679282 0.25658804]
#   -> p_lpips     = [0.27420473 0.6392783  0.08651691] (max=0.639)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.9200412e-02 9.5016962e-01 6.3025148e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102714 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [1.0695639e-02 9.8859143e-01 7.1317330e-04]  (max=0.989)
#   -> D (LPIPS)   = [0.20514031 0.17160968 0.25475118]
#   -> p_lpips     = [0.28221115 0.6322263  0.08556253] (max=0.632)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [1.0695639e-02 9.8859143e-01 7.1317330e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102818 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.3887455  0.50333583 0.10791877]  (max=0.503)
#   -> D (LPIPS)   = [0.2838913  0.263191   0.29081172]
#   -> p_lpips     = [0.16440327 0.7359911  0.09960556] (max=0.736)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.16440327 0.7359911  0.09960556]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102985 | y_true = meningioma | #generated images = 18
#   -> p_cnn       = [0.20268539 0.77666515 0.02064927]  (max=0.777)
#   -> D (LPIPS)   = [0.33997402 0.32388234 0.32761768]
#   -> p_lpips     = [0.0767234  0.56691355 0.3563631 ] (max=0.567)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.13970439 0.67178935 0.18850619]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 103046 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.01402741 0.00740414 0.97856814]  (max=0.979)
#   -> D (LPIPS)   = [0.28607473 0.29963562 0.2358825 ]
#   -> p_lpips     = [0.15426826 0.10081369 0.744918  ] (max=0.745)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01402741 0.00740414 0.97856814]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 103731 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.09332734 0.02401109 0.8826613 ]  (max=0.883)
#   -> D (LPIPS)   = [0.23927592 0.26269922 0.2077677 ]
#   -> p_lpips     = [0.21855453 0.09315059 0.6882949 ] (max=0.688)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.09332734 0.02401109 0.8826613 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 104684 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.04114664 0.00396847 0.9548845 ]  (max=0.955)
#   -> D (LPIPS)   = [0.29366422 0.30793333 0.2533874 ]
#   -> p_lpips     = [0.16746071 0.09924112 0.7332982 ] (max=0.733)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.04114664 0.00396847 0.9548845 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 105936 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.27415067 0.05945286 0.6663964 ]  (max=0.666)
#   -> D (LPIPS)   = [0.38576433 0.38960946 0.37033376]
#   -> p_lpips     = [0.15084782 0.10122142 0.74793077] (max=0.748)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.15084782 0.10122142 0.74793077]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 106494 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.3131546  0.6851171  0.00172825]  (max=0.685)
#   -> D (LPIPS)   = [0.17481415 0.23241411 0.19456731]
#   -> p_lpips     = [0.61013365 0.08257261 0.3072937 ] (max=0.610)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.4616441  0.38384485 0.15451097]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 107190 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.10218839 0.8923044  0.00550694]  (max=0.892)
#   -> D (LPIPS)   = [0.3086259  0.2916909  0.33951348]
#   -> p_lpips     = [0.3025527  0.61430955 0.08313775] (max=0.614)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10218839 0.8923044  0.00550694]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107248 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.1821512  0.8138684  0.00398028]  (max=0.814)
#   -> D (LPIPS)   = [0.2806108  0.26920402 0.28919795]
#   -> p_lpips     = [0.21960801 0.68736696 0.09302501] (max=0.687)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.1821512  0.8138684  0.00398028]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107429 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.3704647  0.05234618 0.577189  ]  (max=0.577)
#   -> D (LPIPS)   = [0.37784588 0.37551624 0.36966488]
#   -> p_lpips     = [0.09845926 0.17401975 0.727521  ] (max=0.728)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.09845926 0.17401975 0.727521  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107494 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.12992649 0.60647446 0.26359883]  (max=0.606)
#   -> D (LPIPS)   = [0.21099102 0.23249143 0.20343024]
#   -> p_lpips     = [0.34360644 0.07824404 0.57814956] (max=0.578)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.23676646 0.34235924 0.42087418]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107747 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.05872681 0.9389876  0.00228564]  (max=0.939)
#   -> D (LPIPS)   = [0.1422056  0.1639802  0.21555595]
#   -> p_lpips     = [0.592555   0.32725137 0.0801936 ] (max=0.593)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05872681 0.9389876  0.00228564]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 108858 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.08102877 0.23464216 0.6843289 ]  (max=0.684)
#   -> D (LPIPS)   = [0.22146118 0.22632821 0.21675205]
#   -> p_lpips     = [0.24778919 0.08966573 0.6625451 ] (max=0.663)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.16440898 0.16215394 0.673437  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 109350 | y_true = meningioma | #generated images = 18
#   -> p_cnn       = [0.29527646 0.7025341  0.00218939]  (max=0.703)
#   -> D (LPIPS)   = [0.3161229  0.31038043 0.32828218]
#   -> p_lpips     = [0.31680778 0.60175365 0.0814385 ] (max=0.602)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.30604213 0.65214384 0.04181395]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109471 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.2177707  0.37653035 0.4056989 ]  (max=0.406)
#   -> D (LPIPS)   = [0.27741235 0.24258201 0.28512684]
#   -> p_lpips     = [0.14625558 0.7519756  0.10176883] (max=0.752)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.14625558 0.7519756  0.10176883]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109898 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.24558346 0.12290494 0.63151157]  (max=0.632)
#   -> D (LPIPS)   = [0.32553896 0.3138283  0.3200682 ]
#   -> p_lpips     = [0.09145336 0.675754   0.23279265] (max=0.676)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.16851841 0.39932948 0.4321521 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 111532 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.2258077e-03 9.9556160e-01 2.1265313e-04]  (max=0.996)
#   -> D (LPIPS)   = [0.22933227 0.21720771 0.3162933 ]
#   -> p_lpips     = [0.40814072 0.5213079  0.07055135] (max=0.521)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.2258077e-03 9.9556160e-01 2.1265313e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112002 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.22635299 0.7713648  0.00228201]  (max=0.771)
#   -> D (LPIPS)   = [0.16711967 0.20757961 0.21978383]
#   -> p_lpips     = [0.74048716 0.15929878 0.10021403] (max=0.740)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.74048716 0.15929878 0.10021403]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 112074 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.35948604 0.61636615 0.02414777]  (max=0.616)
#   -> D (LPIPS)   = [0.27472258 0.2709287  0.29607812]
#   -> p_lpips     = [0.39445248 0.5333644  0.07218303] (max=0.533)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.37696928 0.5748653  0.0481654 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112648 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.33364874 0.36624894 0.3001023 ]  (max=0.366)
#   -> D (LPIPS)   = [0.26186928 0.2675184  0.27186048]
#   -> p_lpips     = [0.6858221  0.22136195 0.09281593] (max=0.686)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.50973547 0.29380545 0.19645911]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 112649 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.02238857 0.26246938 0.7151421 ]  (max=0.715)
#   -> D (LPIPS)   = [0.2194502 0.2480512 0.1720453]
#   -> p_lpips     = [0.20192139 0.0951333  0.70294535] (max=0.703)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.20192139 0.0951333  0.70294535]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112746 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.08850734 0.30659813 0.6048944 ]  (max=0.605)
#   -> D (LPIPS)   = [0.20396423 0.23402615 0.17605478]
#   -> p_lpips     = [0.25165626 0.08920476 0.659139  ] (max=0.659)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.1700818  0.19790144 0.63201666]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112847 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.07239352 0.19039695 0.7372095 ]  (max=0.737)
#   -> D (LPIPS)   = [0.22041889 0.24420954 0.18326087]
#   -> p_lpips     = [0.20648421 0.0945894  0.6989264 ] (max=0.699)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.13943887 0.14249317 0.71806794]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 113098 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.33919898 0.47807127 0.18272975]  (max=0.478)
#   -> D (LPIPS)   = [0.30760655 0.29772678 0.318211  ]
#   -> p_lpips     = [0.25132632 0.65942955 0.08924408] (max=0.659)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.29526263 0.5687504  0.13598692]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113435 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.10803793 0.8907935  0.00116822]  (max=0.891)
#   -> D (LPIPS)   = [0.14211139 0.17203842 0.213938  ]
#   -> p_lpips     = [0.63696605 0.2768299  0.08620398] (max=0.637)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10803793 0.8907935  0.00116822]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113971 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.7089136  0.22436565 0.06672071]  (max=0.709)
#   -> D (LPIPS)   = [0.3432268  0.35863593 0.3386359 ]
#   -> p_lpips     = [0.35754928 0.07658201 0.56586874] (max=0.566)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.53323144 0.15047383 0.31629473]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 114361 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.34884113 0.07546204 0.57569677]  (max=0.576)
#   -> D (LPIPS)   = [0.19548994 0.25332606 0.15859587]
#   -> p_lpips     = [0.28784826 0.08489057 0.62726116] (max=0.627)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.3183447  0.0801763  0.60147893]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 114417 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.4924211  0.3359895  0.17158943]  (max=0.492)
#   -> D (LPIPS)   = [0.314883   0.31114486 0.33463204]
#   -> p_lpips     = [0.3904929  0.53685206 0.07265502] (max=0.537)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.44145697 0.4364208  0.12212223]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 92897 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.16419213 0.83419687 0.00161139]  (max=0.834)
#   -> D (LPIPS)   = [0.25733694 0.2359557  0.28257185]
#   -> p_lpips     = [0.26032886 0.65150017 0.08817096] (max=0.652)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.16419213 0.83419687 0.00161139]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 96587 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.845288   0.14853801 0.00617365]  (max=0.845)
#   -> D (LPIPS)   = [0.30060983 0.307852   0.33504796]
#   -> p_lpips     = [0.55803746 0.36644033 0.07552216] (max=0.558)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.845288   0.14853801 0.00617365]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 97599 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10306366 0.3041661  0.5927701 ]  (max=0.593)
#   -> D (LPIPS)   = [0.2519526  0.25932083 0.23658295]
#   -> p_lpips     = [0.1856049  0.09707828 0.71731687] (max=0.717)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.1856049  0.09707828 0.71731687]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 97607 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.08155376 0.9172364  0.00120963]  (max=0.917)
#   -> D (LPIPS)   = [0.23922041 0.21735957 0.31632447]
#   -> p_lpips     = [0.36153275 0.56236005 0.07610716] (max=0.562)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.08155376 0.9172364  0.00120963]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 97737 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [2.2141216e-02 9.7707045e-01 7.8825332e-04]  (max=0.977)
#   -> D (LPIPS)   = [0.21736886 0.20908682 0.29609329]
#   -> p_lpips     = [0.42133257 0.50968856 0.06897885] (max=0.510)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [2.2141216e-02 9.7707045e-01 7.8825332e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 97875 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.17550947 0.7824895  0.04200106]  (max=0.782)
#   -> D (LPIPS)   = [0.18236364 0.20490997 0.20126675]
#   -> p_lpips     = [0.7562568  0.10234823 0.14139494] (max=0.756)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.7562568  0.10234823 0.14139494]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 98871 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10312297 0.16586047 0.7310164 ]  (max=0.731)
#   -> D (LPIPS)   = [0.23050596 0.26097953 0.18209258]
#   -> p_lpips     = [0.20516182 0.09474703 0.7000911 ] (max=0.700)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.20516182 0.09474703 0.7000911 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 98874 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.07654356 0.25246713 0.67098933]  (max=0.671)
#   -> D (LPIPS)   = [0.21957436 0.2537513  0.18299371]
#   -> p_lpips     = [0.23850396 0.09077255 0.67072344] (max=0.671)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.15752377 0.17161983 0.67085636]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 99308 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [2.192017e-02 9.771047e-01 9.751084e-04]  (max=0.977)
#   -> D (LPIPS)   = [0.2199096  0.23275429 0.29560438]
#   -> p_lpips     = [0.54125845 0.38549012 0.07325137] (max=0.541)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [2.192017e-02 9.771047e-01 9.751084e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR024780B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.7297992  0.26850277 0.00169805]  (max=0.730)
#   -> D (LPIPS)   = [0.13226439 0.20134297 0.21094906]
#   -> p_lpips     = [0.7644684  0.13207203 0.10345954] (max=0.764)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.7644684  0.13207203 0.10345954]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR024780G | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.65585154 0.20971972 0.13442864]  (max=0.656)
#   -> D (LPIPS)   = [0.23597622 0.26252756 0.2344429 ]
#   -> p_lpips     = [0.44124264 0.06660551 0.49215183] (max=0.492)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5485471  0.13816261 0.31329024]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR031409B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.8840053  0.1026183  0.01337642]  (max=0.884)
#   -> D (LPIPS)   = [0.26896662 0.27617294 0.28484544]
#   -> p_lpips     = [0.6498567  0.26219478 0.08794854] (max=0.650)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.8840053  0.1026183  0.01337642]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR036496B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.58999443 0.40922812 0.00077758]  (max=0.590)
#   -> D (LPIPS)   = [0.18170275 0.22407638 0.24754521]
#   -> p_lpips     = [0.70851654 0.19559611 0.09588729] (max=0.709)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.70851654 0.19559611 0.09588729]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR037458B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.2978003  0.7011191  0.00108058]  (max=0.701)
#   -> D (LPIPS)   = [0.13715166 0.18861699 0.20028342]
#   -> p_lpips     = [0.7512107  0.14712404 0.10166531] (max=0.751)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.7512107  0.14712404 0.10166531]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR038469 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.79540104 0.16524713 0.03935165]  (max=0.795)
#   -> D (LPIPS)   = [0.22010162 0.2408998  0.23112395]
#   -> p_lpips     = [0.67484826 0.09133077 0.23382095] (max=0.675)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.73512465 0.12828895 0.1365863 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR039473 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.85671794 0.11562434 0.02765777]  (max=0.857)
#   -> D (LPIPS)   = [0.1703344  0.20819996 0.19044729]
#   -> p_lpips     = [0.6752265  0.09138197 0.23339142] (max=0.675)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.85671794 0.11562434 0.02765777]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048297 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9968177  0.00213349 0.00104845]  (max=0.997)
#   -> D (LPIPS)   = [0.14016105 0.20681444 0.18337467]
#   -> p_lpips     = [0.7098355  0.0960658  0.19409862] (max=0.710)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9968177  0.00213349 0.00104845]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048621B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.5534439  0.21775487 0.22880119]  (max=0.553)
#   -> D (LPIPS)   = [0.1708873  0.2254057  0.17204969]
#   -> p_lpips     = [0.4776485  0.06464269 0.45770887] (max=0.478)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5155462  0.14119878 0.34325504]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048944B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.99300873 0.00497102 0.00202005]  (max=0.993)
#   -> D (LPIPS)   = [0.1612704  0.2209547  0.18976083]
#   -> p_lpips     = [0.6577817  0.08902107 0.2531972 ] (max=0.658)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.99300873 0.00497102 0.00202005]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048994B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.94369763 0.05454416 0.00175795]  (max=0.944)
#   -> D (LPIPS)   = [0.13309753 0.1942185  0.20206581]
#   -> p_lpips     = [0.7661346  0.13018034 0.10368504] (max=0.766)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.94369763 0.05454416 0.00175795]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049019C | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.5680885  0.43046796 0.0014436 ]  (max=0.568)
#   -> D (LPIPS)   = [0.18266171 0.20706445 0.2567409 ]
#   -> p_lpips     = [0.6050366  0.31308058 0.0818828 ] (max=0.605)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5865625  0.37177426 0.0416632 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049358 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9935545  0.0036735  0.00277196]  (max=0.994)
#   -> D (LPIPS)   = [0.16081448 0.21564677 0.17561236]
#   -> p_lpips     = [0.5819946  0.07876441 0.33924094] (max=0.582)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9935545  0.0036735  0.00277196]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049453 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9916212  0.00684992 0.00152889]  (max=0.992)
#   -> D (LPIPS)   = [0.14162986 0.200911   0.17195854]
#   -> p_lpips     = [0.668998   0.09053903 0.24046294] (max=0.669)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9916212  0.00684992 0.00152889]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051461B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.31320512 0.684222   0.0025727 ]  (max=0.684)
#   -> D (LPIPS)   = [0.17852709 0.15339813 0.21820994]
#   -> p_lpips     = [0.2885633  0.6266313  0.08480532] (max=0.627)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.30088422 0.6554266  0.04368901]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051586 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [9.942805e-01 4.751296e-03 9.685940e-04]  (max=0.994)
#   -> D (LPIPS)   = [0.14189303 0.20004368 0.18573119]
#   -> p_lpips     = [0.73705864 0.09975003 0.16319127] (max=0.737)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.942805e-01 4.751296e-03 9.685940e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.68040144 0.20172563 0.11787304]  (max=0.680)
#   -> D (LPIPS)   = [0.23958269 0.27136877 0.2716853 ]
#   -> p_lpips     = [0.7853203  0.10839821 0.10628154] (max=0.785)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.7853203  0.10839821 0.10628154]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644C | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.4244308  0.55408615 0.02148315]  (max=0.554)
#   -> D (LPIPS)   = [0.20020701 0.23940039 0.21843742]
#   -> p_lpips     = [0.6536894  0.08846723 0.25784335] (max=0.654)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5390601  0.3212767  0.13966325]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051651 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.15458207 0.84431756 0.00110047]  (max=0.844)
#   -> D (LPIPS)   = [0.13449219 0.17277074 0.21265173]
#   -> p_lpips     = [0.6618857  0.24853781 0.08957648] (max=0.662)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.15458207 0.84431756 0.00110047]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051796 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [9.848100e-01 1.434851e-02 8.411982e-04]  (max=0.985)
#   -> D (LPIPS)   = [0.12266909 0.18673922 0.20666221]
#   -> p_lpips     = [0.739194   0.160767   0.10003902] (max=0.739)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.848100e-01 1.434851e-02 8.411982e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051796B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.63141143 0.03344614 0.3351424 ]  (max=0.631)
#   -> D (LPIPS)   = [0.32475153 0.32544655 0.32321095]
#   -> p_lpips     = [0.18165858 0.09754869 0.7207928 ] (max=0.721)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.18165858 0.09754869 0.7207928 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] MR052585B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.6877391  0.3059271  0.00633362]  (max=0.688)
#   -> D (LPIPS)   = [0.19555716 0.24275619 0.2091806 ]
#   -> p_lpips     = [0.5893582  0.07976096 0.33088082] (max=0.589)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.6385486  0.19284403 0.16860722]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054683 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.4420122  0.3188584  0.23912925]  (max=0.442)
#   -> D (LPIPS)   = [0.21087693 0.24610288 0.20146033]
#   -> p_lpips     = [0.36614415 0.07555746 0.55829835] (max=0.558)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.4040782  0.19720794 0.3987138 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054875 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9440492  0.02880679 0.02714384]  (max=0.944)
#   -> D (LPIPS)   = [0.21247628 0.23687646 0.21361636]
#   -> p_lpips     = [0.48872975 0.06614237 0.44512793] (max=0.489)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9440492  0.02880679 0.02714384]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [INFO] Saved patient-level GATED ENSEMBLE results to: /content/drive/MyDrive/TESIS/xai_batch_testset/grid_ensemble_lpipsnorm/results_a0p50_tc0p80_tl0p70_T0p50.csv
#
# [METRICS] CNN (prob-based aggregation):
#   Accuracy: 0.8382
#   F1-macro: 0.8515
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.9130    0.7241    0.8077        29
#   meningioma     0.6786    0.9048    0.7755        21
#    pituitary     1.0000    0.9444    0.9714        18
#
#     accuracy                         0.8382        68
#    macro avg     0.8639    0.8578    0.8515        68
# weighted avg     0.8637    0.8382    0.8411        68
#
#   Confusion matrix:
# [[21  8  0]
#  [ 2 19  0]
#  [ 0  1 17]]
#
# [METRICS] LPIPS (inference by generation, normalized):
#   Accuracy: 0.7647
#   F1-macro: 0.7566
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7222    0.6190    0.6667        21
#    pituitary     0.7500    0.8333    0.7895        18
#
#     accuracy                         0.7647        68
#    macro avg     0.7574    0.7600    0.7566        68
# weighted avg     0.7627    0.7647    0.7618        68
#
#   Confusion matrix:
# [[24  2  3]
#  [ 6 13  2]
#  [ 0  3 15]]
#
# [METRICS] GATED ENSEMBLE (alpha_cnn = 0.50, tau_cnn = 0.80, tau_lpips = 0.70, lpips_temp = 0.50):
#   Accuracy: 0.7941
#   F1-macro: 0.7951
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7000    0.6667    0.6829        21
#    pituitary     0.8889    0.8889    0.8889        18
#
#     accuracy                         0.7941        68
#    macro avg     0.7963    0.7944    0.7951        68
# weighted avg     0.7926    0.7941    0.7932        68
#
#   Confusion matrix:
# [[24  4  1]
#  [ 6 14  1]
#  [ 0  2 16]]
#
# ======================================================================
# [GRID] Config 2/81 | alpha_cnn=0.50, tau_cnn=0.80, tau_lpips=0.70, lpips_temp=0.70
# [INFO] Using device (ensemble gated): cuda
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [INFO] frame_weights (ensemble) = {1: 2, 2: 0.3, 3: 1}
# [INFO] class_weights (ensemble) = {'glioma': 400, 'meningioma': 0.3, 'pituitary': 1.0}
# [INFO] Found 68 patient folders in /content/localdata/class/classification
#
# [PATIENT] 101029 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.05880123 0.04282852 0.89837   ]  (max=0.898)
#   -> D (LPIPS)   = [0.26241094 0.28325713 0.21245256]
#   -> p_lpips     = [0.2274435  0.14935167 0.6232048 ] (max=0.623)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05880123 0.04282852 0.89837   ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101082 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.01764533 0.9271509  0.05520365]  (max=0.927)
#   -> D (LPIPS)   = [0.27446947 0.2708344  0.29261586]
#   -> p_lpips     = [0.38859022 0.49321124 0.11819858] (max=0.493)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01764533 0.9271509  0.05520365]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 101724 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10999078 0.19776064 0.6922485 ]  (max=0.692)
#   -> D (LPIPS)   = [0.22606193 0.23705442 0.1835412 ]
#   -> p_lpips     = [0.20587866 0.15352061 0.6406007 ] (max=0.641)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.15793473 0.17564063 0.66642463]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101797 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.2725743  0.7262002  0.00122545]  (max=0.726)
#   -> D (LPIPS)   = [0.15931454 0.1999399  0.22137481]
#   -> p_lpips     = [0.61267966 0.24049106 0.1468293 ] (max=0.613)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.44262698 0.48334563 0.07402737]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102075 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.22499348 0.7095861  0.06542044]  (max=0.710)
#   -> D (LPIPS)   = [0.22106811 0.22819519 0.23189758]
#   -> p_lpips     = [0.613417   0.23957701 0.14700602] (max=0.613)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.41920525 0.47458154 0.10621323]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102420 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.9200412e-02 9.5016962e-01 6.3025148e-04]  (max=0.950)
#   -> D (LPIPS)   = [0.21633242 0.18679282 0.25658804]
#   -> p_lpips     = [0.30588093 0.55993104 0.13418804] (max=0.560)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.9200412e-02 9.5016962e-01 6.3025148e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102714 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [1.0695639e-02 9.8859143e-01 7.1317330e-04]  (max=0.989)
#   -> D (LPIPS)   = [0.20514031 0.17160968 0.25475118]
#   -> p_lpips     = [0.3119611  0.55502623 0.13301261] (max=0.555)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [1.0695639e-02 9.8859143e-01 7.1317330e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102818 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.3887455  0.50333583 0.10791877]  (max=0.503)
#   -> D (LPIPS)   = [0.2838913  0.263191   0.29081172]
#   -> p_lpips     = [0.21662062 0.6319354  0.15144397] (max=0.632)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.30268306 0.56763566 0.12968138]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102985 | y_true = meningioma | #generated images = 18
#   -> p_cnn       = [0.20268539 0.77666515 0.02064927]  (max=0.777)
#   -> D (LPIPS)   = [0.33997402 0.32388234 0.32761768]
#   -> p_lpips     = [0.12243229 0.51087743 0.36669037] (max=0.511)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.16255884 0.6437713  0.19366983]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 103046 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.01402741 0.00740414 0.97856814]  (max=0.979)
#   -> D (LPIPS)   = [0.28607473 0.29963562 0.2358825 ]
#   -> p_lpips     = [0.20758724 0.15319031 0.63922244] (max=0.639)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01402741 0.00740414 0.97856814]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 103731 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.09332734 0.02401109 0.8826613 ]  (max=0.883)
#   -> D (LPIPS)   = [0.23927592 0.26269922 0.2077677 ]
#   -> p_lpips     = [0.26226184 0.14262055 0.5951176 ] (max=0.595)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.09332734 0.02401109 0.8826613 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 104684 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.04114664 0.00396847 0.9548845 ]  (max=0.955)
#   -> D (LPIPS)   = [0.29366422 0.30793333 0.2533874 ]
#   -> p_lpips     = [0.21931034 0.15092398 0.6297656 ] (max=0.630)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.04114664 0.00396847 0.9548845 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 105936 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.27415067 0.05945286 0.6663964 ]  (max=0.666)
#   -> D (LPIPS)   = [0.38576433 0.38960946 0.37033376]
#   -> p_lpips     = [0.20449571 0.15378797 0.6417163 ] (max=0.642)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.2393232  0.10662042 0.6540563 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 106494 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.3131546  0.6851171  0.00172825]  (max=0.685)
#   -> D (LPIPS)   = [0.17481415 0.23241411 0.19456731]
#   -> p_lpips     = [0.53985983 0.12937796 0.33076218] (max=0.540)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.42650723 0.40724754 0.1662452 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 107190 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.10218839 0.8923044  0.00550694]  (max=0.892)
#   -> D (LPIPS)   = [0.3086259  0.2916909  0.33951348]
#   -> p_lpips     = [0.3272349  0.54270524 0.13005987] (max=0.543)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10218839 0.8923044  0.00550694]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107248 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.1821512  0.8138684  0.00398028]  (max=0.814)
#   -> D (LPIPS)   = [0.2806108  0.26920402 0.28919795]
#   -> p_lpips     = [0.26311374 0.59443045 0.14245586] (max=0.594)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.1821512  0.8138684  0.00398028]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107429 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.3704647  0.05234618 0.577189  ]  (max=0.577)
#   -> D (LPIPS)   = [0.37784588 0.37551624 0.36966488]
#   -> p_lpips     = [0.14981848 0.22502887 0.62515265] (max=0.625)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.2601416  0.13868752 0.60117084]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107494 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.12992649 0.60647446 0.26359883]  (max=0.606)
#   -> D (LPIPS)   = [0.21099102 0.23249143 0.20343024]
#   -> p_lpips     = [0.3574387  0.12422083 0.51834047] (max=0.518)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.2436826  0.36534765 0.39096963]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107747 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.05872681 0.9389876  0.00228564]  (max=0.939)
#   -> D (LPIPS)   = [0.1422056  0.1639802  0.21555595]
#   -> p_lpips     = [0.5279772  0.34549254 0.12653029] (max=0.528)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05872681 0.9389876  0.00228564]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 108858 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.08102877 0.23464216 0.6843289 ]  (max=0.684)
#   -> D (LPIPS)   = [0.22146118 0.22632821 0.21675205]
#   -> p_lpips     = [0.28550076 0.13812797 0.5763713 ] (max=0.576)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.18326476 0.18638507 0.6303501 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 109350 | y_true = meningioma | #generated images = 18
#   -> p_cnn       = [0.29527646 0.7025341  0.00218939]  (max=0.703)
#   -> D (LPIPS)   = [0.3161229  0.31038043 0.32828218]
#   -> p_lpips     = [0.33780706 0.53417695 0.12801605] (max=0.534)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.31654176 0.6183555  0.06510272]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109471 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.2177707  0.37653035 0.4056989 ]  (max=0.406)
#   -> D (LPIPS)   = [0.27741235 0.24258201 0.28512684]
#   -> p_lpips     = [0.20030898 0.6450936  0.15459736] (max=0.645)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.20903984 0.510812   0.28014812]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109898 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.24558346 0.12290494 0.63151157]  (max=0.632)
#   -> D (LPIPS)   = [0.32553896 0.3138283  0.3200682 ]
#   -> p_lpips     = [0.14041317 0.5859068  0.27368012] (max=0.586)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.19299832 0.35440588 0.45259583]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 111532 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.2258077e-03 9.9556160e-01 2.1265313e-04]  (max=0.996)
#   -> D (LPIPS)   = [0.22933227 0.21720771 0.3162933 ]
#   -> p_lpips     = [0.40380487 0.48093787 0.11525726] (max=0.481)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.2258077e-03 9.9556160e-01 2.1265313e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112002 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.22635299 0.7713648  0.00228201]  (max=0.771)
#   -> D (LPIPS)   = [0.16711967 0.20757961 0.21978383]
#   -> p_lpips     = [0.6355869  0.21209402 0.15231904] (max=0.636)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.43096995 0.4917294  0.07730053]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112074 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.35948604 0.61636615 0.02414777]  (max=0.616)
#   -> D (LPIPS)   = [0.27472258 0.2709287  0.29607812]
#   -> p_lpips     = [0.3940465  0.48880976 0.11714376] (max=0.489)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.37676626 0.552588   0.07064576]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112648 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.33364874 0.36624894 0.3001023 ]  (max=0.366)
#   -> D (LPIPS)   = [0.26186928 0.2675184  0.27186048]
#   -> p_lpips     = [0.5932884  0.26452947 0.14218217] (max=0.593)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.46346858 0.31538922 0.22114223]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 112649 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.02238857 0.26246938 0.7151421 ]  (max=0.715)
#   -> D (LPIPS)   = [0.2194502 0.2480512 0.1720453]
#   -> p_lpips     = [0.24864906 0.14525218 0.6060988 ] (max=0.606)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.13551882 0.20386079 0.66062045]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112746 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.08850734 0.30659813 0.6048944 ]  (max=0.605)
#   -> D (LPIPS)   = [0.20396423 0.23402615 0.17605478]
#   -> p_lpips     = [0.28851765 0.13754474 0.5739376 ] (max=0.574)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.1885125  0.22207144 0.589416  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112847 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.07239352 0.19039695 0.7372095 ]  (max=0.737)
#   -> D (LPIPS)   = [0.22041889 0.24420954 0.18326087]
#   -> p_lpips     = [0.2524149  0.14452417 0.6030609 ] (max=0.603)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.16240421 0.16746056 0.6701352 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 113098 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.33919898 0.47807127 0.18272975]  (max=0.478)
#   -> D (LPIPS)   = [0.30760655 0.29772678 0.318211  ]
#   -> p_lpips     = [0.28826076 0.5741449  0.1375944 ] (max=0.574)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.31372988 0.5261081  0.16016208]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113435 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.10803793 0.8907935  0.00116822]  (max=0.891)
#   -> D (LPIPS)   = [0.14211139 0.17203842 0.213938  ]
#   -> p_lpips     = [0.55831915 0.30787906 0.13380176] (max=0.558)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10803793 0.8907935  0.00116822]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113971 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.7089136  0.22436565 0.06672071]  (max=0.709)
#   -> D (LPIPS)   = [0.3432268  0.35863593 0.3386359 ]
#   -> p_lpips     = [0.36754796 0.12226649 0.5101856 ] (max=0.510)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5382308  0.17331608 0.28845316]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 114361 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.34884113 0.07546204 0.57569677]  (max=0.576)
#   -> D (LPIPS)   = [0.19548994 0.25332606 0.15859587]
# ...
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR031409B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.8840053  0.1026183  0.01337642]  (max=0.884)
#   -> D (LPIPS)   = [0.26896662 0.27617294 0.28484544]
#   -> p_lpips     = [0.56735384 0.29667923 0.13596693] (max=0.567)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.85234016 0.12202439 0.02563547]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR036496B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.58999443 0.40922812 0.00077758]  (max=0.590)
#   -> D (LPIPS)   = [0.18170275 0.22407638 0.24754521]
#   -> p_lpips     = [0.61034405 0.2433864  0.14626959] (max=0.610)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.59202933 0.39264393 0.01532678]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR037458B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.2978003  0.7011191  0.00108058]  (max=0.701)
#   -> D (LPIPS)   = [0.13715166 0.18861699 0.20028342]
#   -> p_lpips     = [0.64445233 0.20110402 0.15444367] (max=0.644)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.3324655  0.6511176  0.01641689]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR038469 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.79540104 0.16524713 0.03935165]  (max=0.795)
#   -> D (LPIPS)   = [0.22010162 0.2408998  0.23112395]
#   -> p_lpips     = [0.5852477  0.14025521 0.27449712] (max=0.585)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.7743857  0.16274793 0.0628662 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR039473 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.85671794 0.11562434 0.02765777]  (max=0.857)
#   -> D (LPIPS)   = [0.1703344  0.20819996 0.19044729]
#   -> p_lpips     = [0.5855229  0.14032117 0.27415597] (max=0.586)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.82959837 0.11809402 0.05230759]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048297 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9968177  0.00213349 0.00104845]  (max=0.997)
#   -> D (LPIPS)   = [0.14016105 0.20681444 0.18337467]
#   -> p_lpips     = [0.6113551  0.14651188 0.24213304] (max=0.611)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9968177  0.00213349 0.00104845]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048621B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.5534439  0.21775487 0.22880119]  (max=0.553)
#   -> D (LPIPS)   = [0.1708873  0.2254057  0.17204969]
#   -> p_lpips     = [0.45256    0.10845647 0.43898356] (max=0.453)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5433555  0.20682502 0.24981943]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048944B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.99300873 0.00497102 0.00202005]  (max=0.993)
#   -> D (LPIPS)   = [0.1612704  0.2209547  0.18976083]
#   -> p_lpips     = [0.57297057 0.137313   0.28971642] (max=0.573)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.99300873 0.00497102 0.00202005]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048994B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.94369763 0.05454416 0.00175795]  (max=0.944)
#   -> D (LPIPS)   = [0.13309753 0.1942185  0.20206581]
#   -> p_lpips     = [0.65720266 0.18529809 0.15749928] (max=0.657)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.94369763 0.05454416 0.00175795]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049019C | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.5680885  0.43046796 0.0014436 ]  (max=0.568)
#   -> D (LPIPS)   = [0.18266171 0.20706445 0.2567409 ]
#   -> p_lpips     = [0.53639907 0.3350523  0.12854859] (max=0.536)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5649195 0.4209264 0.0141541]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049358 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9935545  0.0036735  0.00277196]  (max=0.994)
#   -> D (LPIPS)   = [0.16081448 0.21564677 0.17561236]
#   -> p_lpips     = [0.5209047  0.12483535 0.35426   ] (max=0.521)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9935545  0.0036735  0.00277196]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049453 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9916212  0.00684992 0.00152889]  (max=0.992)
#   -> D (LPIPS)   = [0.14162986 0.200911   0.17195854]
#   -> p_lpips     = [0.5810096  0.13923956 0.27975085] (max=0.581)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9916212  0.00684992 0.00152889]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051461B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.31320512 0.684222   0.0025727 ]  (max=0.684)
#   -> D (LPIPS)   = [0.17852709 0.15339813 0.21820994]
#   -> p_lpips     = [0.3167564  0.551158   0.13208558] (max=0.551)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.31356025 0.6709156  0.01552399]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051586 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [9.942805e-01 4.751296e-03 9.685940e-04]  (max=0.994)
#   -> D (LPIPS)   = [0.14189303 0.20004368 0.18573119]
#   -> p_lpips     = [0.63279915 0.15165097 0.21554995] (max=0.633)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.942805e-01 4.751296e-03 9.685940e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.68040144 0.20172563 0.11787304]  (max=0.680)
#   -> D (LPIPS)   = [0.23958269 0.27136877 0.2716853 ]
#   -> p_lpips     = [0.67444456 0.16392411 0.16163133] (max=0.674)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.67980576 0.19794548 0.12224887]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644C | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.4244308  0.55408615 0.02148315]  (max=0.554)
#   -> D (LPIPS)   = [0.20020701 0.23940039 0.21843742]
#   -> p_lpips     = [0.570064   0.13661642 0.2933196 ] (max=0.570)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.43899408 0.5123392  0.0486668 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051651 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.15458207 0.84431756 0.00110047]  (max=0.844)
#   -> D (LPIPS)   = [0.13449219 0.17277074 0.21265173]
#   -> p_lpips     = [0.57589936 0.28608578 0.13801488] (max=0.576)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.19671379 0.78849435 0.01479191]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051796 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [9.848100e-01 1.434851e-02 8.411982e-04]  (max=0.985)
#   -> D (LPIPS)   = [0.12266909 0.18673922 0.20666221]
#   -> p_lpips     = [0.63453287 0.2134007  0.15206644] (max=0.635)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.848100e-01 1.434851e-02 8.411982e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051796B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.63141143 0.03344614 0.3351424 ]  (max=0.631)
#   -> D (LPIPS)   = [0.32475153 0.32544655 0.32321095]
#   -> p_lpips     = [0.23160426 0.14854732 0.61984843] (max=0.620)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.59143066 0.04495626 0.36361298]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR052585B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.6877391  0.3059271  0.00633362]  (max=0.688)
#   -> D (LPIPS)   = [0.19555716 0.24275619 0.2091806 ]
#   -> p_lpips     = [0.52583146 0.12601605 0.34815255] (max=0.526)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.6715483  0.287936   0.04051551]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054683 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.4420122  0.3188584  0.23912925]  (max=0.442)
#   -> D (LPIPS)   = [0.21087693 0.24610288 0.20146033]
#   -> p_lpips     = [0.37374988 0.12106752 0.5051826 ] (max=0.505)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.43518597 0.2990793  0.26573458]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054875 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9440492  0.02880679 0.02714384]  (max=0.944)
#   -> D (LPIPS)   = [0.21247628 0.23687646 0.21361636]
#   -> p_lpips     = [0.45975295 0.11018027 0.43006688] (max=0.460)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9440492  0.02880679 0.02714384]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [INFO] Saved patient-level GATED ENSEMBLE results to: /content/drive/MyDrive/TESIS/xai_batch_testset/grid_ensemble_lpipsnorm/results_a0p90_tc0p90_tl0p80_T0p70.csv
#
# [METRICS] CNN (prob-based aggregation):
#   Accuracy: 0.8382
#   F1-macro: 0.8515
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.9130    0.7241    0.8077        29
#   meningioma     0.6786    0.9048    0.7755        21
#    pituitary     1.0000    0.9444    0.9714        18
#
#     accuracy                         0.8382        68
#    macro avg     0.8639    0.8578    0.8515        68
# weighted avg     0.8637    0.8382    0.8411        68
#
#   Confusion matrix:
# [[21  8  0]
#  [ 2 19  0]
#  [ 0  1 17]]
#
# [METRICS] LPIPS (inference by generation, normalized):
#   Accuracy: 0.7647
#   F1-macro: 0.7566
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7222    0.6190    0.6667        21
#    pituitary     0.7500    0.8333    0.7895        18
#
#     accuracy                         0.7647        68
#    macro avg     0.7574    0.7600    0.7566        68
# weighted avg     0.7627    0.7647    0.7618        68
#
#   Confusion matrix:
# [[24  2  3]
#  [ 6 13  2]
#  [ 0  3 15]]
#
# [METRICS] GATED ENSEMBLE (alpha_cnn = 0.90, tau_cnn = 0.90, tau_lpips = 0.80, lpips_temp = 0.70):
#   Accuracy: 0.8088
#   F1-macro: 0.8228
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.8750    0.7241    0.7925        29
#   meningioma     0.6429    0.8571    0.7347        21
#    pituitary     1.0000    0.8889    0.9412        18
#
#     accuracy                         0.8088        68
#    macro avg     0.8393    0.8234    0.8228        68
# weighted avg     0.8364    0.8088    0.8140        68
#
#   Confusion matrix:
# [[21  8  0]
#  [ 3 18  0]
#  [ 0  2 16]]
#
# ======================================================================
# [GRID] Config 69/81 | alpha_cnn=0.90, tau_cnn=0.90, tau_lpips=0.80, lpips_temp=0.90
# [INFO] Using device (ensemble gated): cuda
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [INFO] frame_weights (ensemble) = {1: 2, 2: 0.3, 3: 1}
# [INFO] class_weights (ensemble) = {'glioma': 400, 'meningioma': 0.3, 'pituitary': 1.0}
# [INFO] Found 68 patient folders in /content/localdata/class/classification
#
# [PATIENT] 101029 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.05880123 0.04282852 0.89837   ]  (max=0.898)
#   -> D (LPIPS)   = [0.26241094 0.28325713 0.21245256]
#   -> p_lpips     = [0.25567868 0.18434143 0.55997986] (max=0.560)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.07848898 0.05697981 0.864531  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101082 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.01764533 0.9271509  0.05520365]  (max=0.927)
#   -> D (LPIPS)   = [0.27446947 0.2708344  0.29261586]
#   -> p_lpips     = [0.38461536 0.46297613 0.15240848] (max=0.463)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01764533 0.9271509  0.05520365]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 101724 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10999078 0.19776064 0.6922485 ]  (max=0.692)
#   -> D (LPIPS)   = [0.22606193 0.23705442 0.1835412 ]
#   -> p_lpips     = [0.23731755 0.18888882 0.57379365] (max=0.574)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.12272345 0.19687344 0.680403  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101797 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.2725743  0.7262002  0.00122545]  (max=0.726)
#   -> D (LPIPS)   = [0.15931454 0.1999399  0.22137481]
#   -> p_lpips     = [0.5517599  0.26660466 0.18163547] (max=0.552)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.30049285 0.68024063 0.01926645]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102075 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.22499348 0.7095861  0.06542044]  (max=0.710)
#   -> D (LPIPS)   = [0.22106811 0.22819519 0.23189758]
#   -> p_lpips     = [0.55233264 0.2658433  0.18182403] (max=0.552)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.25772738 0.6652118  0.0770608 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102420 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.9200412e-02 9.5016962e-01 6.3025148e-04]  (max=0.950)
#   -> D (LPIPS)   = [0.21633242 0.18679282 0.25658804]
#   -> p_lpips     = [0.31976974 0.51176184 0.1684684 ] (max=0.512)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.9200412e-02 9.5016962e-01 6.3025148e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102714 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [1.0695639e-02 9.8859143e-01 7.1317330e-04]  (max=0.989)
#   -> D (LPIPS)   = [0.20514031 0.17160968 0.25475118]
#   -> p_lpips     = [0.32460722 0.50812244 0.16727033] (max=0.508)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [1.0695639e-02 9.8859143e-01 7.1317330e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102818 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.3887455  0.50333583 0.10791877]  (max=0.503)
#   -> D (LPIPS)   = [0.2838913  0.263191   0.29081172]
#   -> p_lpips     = [0.24651396 0.5668748  0.18661119] (max=0.567)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.37452233 0.50968975 0.11578801]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102985 | y_true = meningioma | #generated images = 18

# %%
from pathlib import Path
import torch
import torch.nn as nn
from torchvision import models


# === Rutas ===
classification_root = Path("/content/localdata/class/classification")
ckpt_path = "/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/inge1.3fold/full_train/final_full.ckpt"
out_csv = Path("/content/drive/MyDrive/TESIS/xai_batch_testset/results_ensemble_gated_lpipsnorm.csv")

# === Clases ===
class_names = ["glioma", "meningioma", "pituitary"]

# === Modelo CNN ===
def build_model(num_classes: int, pretrained: bool = False) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m

checkpoint = torch.load(ckpt_path, map_location="cuda")
model = build_model(num_classes=len(class_names), pretrained=False)
if "model" in checkpoint:
    model.load_state_dict(checkpoint["model"])
else:
    model.load_state_dict(checkpoint)

frame_weights = {
    1: 2,
    2: 0.3,
    3: 1,
}

class_weights = {
    "glioma": 400,
    "meningioma": 0.3,
    "pituitary": 1.0,
}


results = ensemble_cnn_lpips_patient_gated(
    classification_root=classification_root,
    model=model,
    class_names=class_names,
    out_csv=out_csv,
    device=None,             # "cuda" si quieres forzar GPU
    image_size=256,
    frame_weights=frame_weights,
    class_weights=class_weights,
    alpha_cnn=0.9,           # p_ens = 0.2 * p_cnn + 0.8 * p_lpips cuando gate_mode="mixed"
    tau_cnn=0.8,
    tau_lpips=0.8,
    lpips_temp=0.7,          # más bajo -> LPIPS más "picudo"
)

print("Final ensemble results:", results)
# Out:
# [INFO] Using device (ensemble gated): cuda
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [INFO] frame_weights (ensemble) = {1: 2, 2: 0.3, 3: 1}
# [INFO] class_weights (ensemble) = {'glioma': 400, 'meningioma': 0.3, 'pituitary': 1.0}
# [INFO] Found 68 patient folders in /content/localdata/class/classification
#
# [PATIENT] 101029 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.05766637 0.04251871 0.8998147 ]  (max=0.900)
#   -> D (LPIPS)   = [0.26238975 0.28323698 0.21243775]
#   -> p_lpips     = [0.22745277 0.14934988 0.6231974 ] (max=0.623)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05766637 0.04251871 0.8998147 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101082 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.01784439 0.9266646  0.05549082]  (max=0.927)
#   -> D (LPIPS)   = [0.27448702 0.27085114 0.292629  ]
#   -> p_lpips     = [0.38856828 0.49322888 0.11820281] (max=0.493)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01784439 0.9266646  0.05549082]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 101724 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10923654 0.19802076 0.6927426 ]  (max=0.693)
#   -> D (LPIPS)   = [0.22608358 0.2370655  0.18354918]
#   -> p_lpips     = [0.20582972 0.15353008 0.6406402 ] (max=0.641)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.11889586 0.19357169 0.68753237]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101797 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.27210206 0.72666675 0.0012312 ]  (max=0.727)
#   -> D (LPIPS)   = [0.15928522 0.19991313 0.2213675 ]
#   -> p_lpips     = [0.6126394  0.2405409  0.14681967] (max=0.613)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.3061558  0.67805415 0.01579004]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102075 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.22482    0.70862484 0.06655518]  (max=0.709)
#   -> D (LPIPS)   = [0.22106464 0.22819433 0.23190139]
#   -> p_lpips     = [0.6133746  0.2396295  0.14699586] (max=0.613)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.26367545 0.66172534 0.07459925]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102420 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.9134977e-02 9.5023125e-01 6.3370721e-04]  (max=0.950)
#   -> D (LPIPS)   = [0.21632397 0.18678877 0.2565738 ]
#   -> p_lpips     = [0.3058813  0.55993074 0.13418798] (max=0.560)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.9134977e-02 9.5023125e-01 6.3370721e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102714 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [1.0813505e-02 9.8845792e-01 7.2851847e-04]  (max=0.988)
#   -> D (LPIPS)   = [0.20516741 0.17164566 0.2547739 ]
#   -> p_lpips     = [0.3119741  0.55501574 0.13301009] (max=0.555)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [1.0813505e-02 9.8845792e-01 7.2851847e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102818 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.38803726 0.5034381  0.10852441]  (max=0.503)
#   -> D (LPIPS)   = [0.28390715 0.26321188 0.2908199 ]
#   -> p_lpips     = [0.21658124 0.63196725 0.1514516 ] (max=0.632)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.37089166 0.516291   0.11281713]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102985 | y_true = meningioma | #generated images = 18
#   -> p_cnn       = [0.20249605 0.7764296  0.02107423]  (max=0.776)
#   -> D (LPIPS)   = [0.33999154 0.32390612 0.3276336 ]
#   -> p_lpips     = [0.12240671 0.5107706  0.36682263] (max=0.511)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.19448712 0.7498637  0.05564907]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 103046 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.01375963 0.00737478 0.97886527]  (max=0.979)
#   -> D (LPIPS)   = [0.28605548 0.299614   0.23586717]
#   -> p_lpips     = [0.20758347 0.15319103 0.6392254 ] (max=0.639)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01375963 0.00737478 0.97886527]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 103731 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.09187519 0.0238815  0.88424295]  (max=0.884)
#   -> D (LPIPS)   = [0.23930353 0.26272467 0.20776749]
#   -> p_lpips     = [0.26219594 0.14263327 0.59517074] (max=0.595)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.09187519 0.0238815  0.88424295]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 104684 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.03999297 0.00391499 0.95609176]  (max=0.956)
#   -> D (LPIPS)   = [0.29364434 0.3079137  0.25336635]
#   -> p_lpips     = [0.21930978 0.15092409 0.6297661 ] (max=0.630)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.03999297 0.00391499 0.95609176]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 105936 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.27404156 0.05936218 0.66659623]  (max=0.667)
#   -> D (LPIPS)   = [0.38573018 0.38957167 0.37030903]
#   -> p_lpips     = [0.20448327 0.15379037 0.6417263 ] (max=0.642)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.26708573 0.06880499 0.66410923]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 106494 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.312736   0.6855172  0.00174688]  (max=0.686)
#   -> D (LPIPS)   = [0.17484139 0.23243196 0.1945847 ]
#   -> p_lpips     = [0.5398305  0.12937094 0.3307986 ] (max=0.540)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.33544546 0.62990254 0.03465205]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107190 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.10207777 0.8923639  0.00555817]  (max=0.892)
#   -> D (LPIPS)   = [0.30860287 0.2916694  0.33949026]
#   -> p_lpips     = [0.32724103 0.54270023 0.13005868] (max=0.543)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10207777 0.8923639  0.00555817]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107248 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.1820838  0.8139149  0.00400111]  (max=0.814)
#   -> D (LPIPS)   = [0.28062838 0.2692147  0.28921464]
#   -> p_lpips     = [0.26306555 0.59446925 0.14246516] (max=0.594)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.1820838  0.8139149  0.00400111]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107429 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.36978546 0.05207306 0.57814133]  (max=0.578)
#   -> D (LPIPS)   = [0.3778778 0.3755408 0.3697041]
#   -> p_lpips     = [0.14976282 0.22531672 0.6249205 ] (max=0.625)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.3477832  0.06939742 0.5828193 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107494 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.12928776 0.6060231  0.26468894]  (max=0.606)
#   -> D (LPIPS)   = [0.21099421 0.23249376 0.20343569]
#   -> p_lpips     = [0.35745507 0.12421765 0.51832724] (max=0.518)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.1521045  0.55784255 0.29005277]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107747 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.05862444 0.9390802  0.00229571]  (max=0.939)
#   -> D (LPIPS)   = [0.14219947 0.16397175 0.21554877]
#   -> p_lpips     = [0.5279701  0.34550136 0.12652856] (max=0.528)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05862444 0.9390802  0.00229571]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 108858 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.0812484  0.234508   0.68424356]  (max=0.684)
#   -> D (LPIPS)   = [0.22138788 0.2262646  0.21670163]
#   -> p_lpips     = [0.2860004  0.13803136 0.5759682 ] (max=0.576)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.1017236  0.22486033 0.673416  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 109350 | y_true = meningioma | #generated images = 18
#   -> p_cnn       = [0.2952452  0.7025489  0.00220567]  (max=0.703)
#   -> D (LPIPS)   = [0.31621608 0.3104587  0.3283612 ]
#   -> p_lpips     = [0.33754504 0.53438824 0.1280667 ] (max=0.534)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.29947516 0.68573284 0.01479177]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109471 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.21850713 0.37456375 0.40692896]  (max=0.407)
#   -> D (LPIPS)   = [0.27736428 0.24253441 0.28508115]
#   -> p_lpips     = [0.20031995 0.6450848  0.15459524] (max=0.645)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.2166884  0.40161586 0.3816956 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109898 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.2454158  0.12305611 0.63152796]  (max=0.632)
#   -> D (LPIPS)   = [0.32546458 0.31375656 0.32000017]
#   -> p_lpips     = [0.14043711 0.5860067  0.27355623] (max=0.586)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.23491794 0.16935116 0.5957308 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 111532 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [4.1923849e-03 9.9559349e-01 2.1423149e-04]  (max=0.996)
#   -> D (LPIPS)   = [0.22934116 0.21721612 0.31629997]
#   -> p_lpips     = [0.4038024  0.48093987 0.11525773] (max=0.481)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.1923849e-03 9.9559349e-01 2.1423149e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112002 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.2256941  0.771998   0.00230781]  (max=0.772)
#   -> D (LPIPS)   = [0.16710047 0.20756572 0.21976265]
#   -> p_lpips     = [0.63561195 0.21206309 0.15232505] (max=0.636)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.26668587 0.7160045  0.01730954]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112074 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.35897404 0.6163922  0.02463367]  (max=0.616)
#   -> D (LPIPS)   = [0.27469775 0.2709033  0.29605854]
#   -> p_lpips     = [0.39405036 0.48880664 0.11714301] (max=0.489)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.36248168 0.6036336  0.0338846 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112648 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.3319544  0.36618003 0.30186558]  (max=0.366)
#   -> D (LPIPS)   = [0.26189673 0.26754844 0.27188635]
#   -> p_lpips     = [0.5933666  0.2644325  0.14220092] (max=0.593)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.35809562 0.35600525 0.2858991 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 112649 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.02221601 0.2623971  0.7153869 ]  (max=0.715)
#   -> D (LPIPS)   = [0.21948506 0.2480772  0.17206773]
#   -> p_lpips     = [0.24861327 0.14525911 0.6061277 ] (max=0.606)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.04485574 0.2506833  0.704461  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112746 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.08819675 0.3058894  0.6059136 ]  (max=0.606)
#   -> D (LPIPS)   = [0.20396382 0.23401637 0.17605595]
#   -> p_lpips     = [0.28849906 0.13754833 0.5739526 ] (max=0.574)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.10822698 0.2890553  0.60271746]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112847 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.07142761 0.19000894 0.7385634 ]  (max=0.739)
#   -> D (LPIPS)   = [0.22043484 0.24422342 0.18326999]
#   -> p_lpips     = [0.2523975  0.14452752 0.60307497] (max=0.603)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.0895246  0.18546079 0.72501457]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 113098 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.33891124 0.47731394 0.18377472]  (max=0.477)
#   -> D (LPIPS)   = [0.3076048  0.29773524 0.31821403]
#   -> p_lpips     = [0.28836963 0.57405704 0.13757335] (max=0.574)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.33385706 0.48698825 0.17915457]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113435 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.10711592 0.8917118  0.00117234]  (max=0.892)
#   -> D (LPIPS)   = [0.14209391 0.17202727 0.21391623]
#   -> p_lpips     = [0.5583469  0.30784467 0.13380842] (max=0.558)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10711592 0.8917118  0.00117234]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113971 | y_true = meningioma | #generated images = 27
#   -> p_cnn       = [0.70804477 0.22447632 0.06747895]  (max=0.708)
#   -> D (LPIPS)   = [0.34327826 0.3586909  0.33868372]
#   -> p_lpips     = [0.36751473 0.12227291 0.5102123 ] (max=0.510)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.67399174 0.21425599 0.11175228]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 114361 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.34807548 0.07556416 0.5763603 ]  (max=0.576)
#   -> D (LPIPS)   = [0.19548911 0.2533207  0.15859658]
#   -> p_lpips     = [0.31621513 0.13219021 0.5515946 ] (max=0.552)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.34488943 0.08122677 0.5738837 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 114417 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.49227673 0.33504507 0.17267816]  (max=0.492)
#   -> D (LPIPS)   = [0.31492153 0.31118158 0.33466703]
#   -> p_lpips     = [0.3911875  0.49111605 0.11769646] (max=0.491)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.48216778 0.35065216 0.16717999]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 92897 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.1641348  0.8342402  0.00162501]  (max=0.834)
#   -> D (LPIPS)   = [0.2573287  0.23596598 0.2825623 ]
#   -> p_lpips     = [0.29530054 0.56846607 0.13623348] (max=0.568)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.1641348  0.8342402  0.00162501]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 96587 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.84545565 0.14827754 0.00626637]  (max=0.845)
#   -> D (LPIPS)   = [0.30067107 0.30792233 0.3351059 ]
#   -> p_lpips     = [0.5050872  0.37386823 0.12104466] (max=0.505)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.84545565 0.14827754 0.00626637]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 97599 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.1027393  0.3030602  0.59420043]  (max=0.594)
#   -> D (LPIPS)   = [0.25197327 0.25933066 0.23660176]
#   -> p_lpips     = [0.23487781 0.14791447 0.61720777] (max=0.617)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.11595315 0.28754562 0.5965012 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 97607 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.08104195 0.9177436  0.00121417]  (max=0.918)
#   -> D (LPIPS)   = [0.23921664 0.21735296 0.31629863]
#   -> p_lpips     = [0.37040114 0.50788397 0.12171492] (max=0.508)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.08104195 0.9177436  0.00121417]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 97737 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [2.1914195e-02 9.7729409e-01 7.9164450e-04]  (max=0.977)
#   -> D (LPIPS)   = [0.21739782 0.2091019  0.2960918 ]
#   -> p_lpips     = [0.41312352 0.4734207  0.11345576] (max=0.473)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [2.1914195e-02 9.7729409e-01 7.9164450e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 97875 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.17516594 0.78242064 0.0424131 ]  (max=0.782)
#   -> D (LPIPS)   = [0.18236372 0.20491353 0.2012683 ]
#   -> p_lpips     = [0.6486948  0.15546037 0.19584483] (max=0.649)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.22251883 0.7197246  0.05775627]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 98871 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.10248093 0.16626114 0.7312579 ]  (max=0.731)
#   -> D (LPIPS)   = [0.23051557 0.26098654 0.18209964]
#   -> p_lpips     = [0.25131726 0.14473636 0.6039464 ] (max=0.604)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.11736456 0.16410865 0.7185268 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 98874 | y_true = pituitary | #generated images = 36
#   -> p_cnn       = [0.07618883 0.25219357 0.67161775]  (max=0.672)
#   -> D (LPIPS)   = [0.21956332 0.25374457 0.18297532]
#   -> p_lpips     = [0.2782001  0.13953933 0.58226055] (max=0.582)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.09638995 0.24092814 0.662682  ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 99308 | y_true = meningioma | #generated images = 36
#   -> p_cnn       = [0.02177406 0.97724617 0.00097983]  (max=0.977)
#   -> D (LPIPS)   = [0.21989034 0.2327359  0.29557475]
#   -> p_lpips     = [0.4939876  0.3876278  0.11838464] (max=0.494)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.02177406 0.97724617 0.00097983]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR024780B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.72813743 0.27014962 0.00171281]  (max=0.728)
#   -> D (LPIPS)   = [0.13223362 0.20131318 0.21092215]
#   -> p_lpips     = [0.6557476  0.18710183 0.15715058] (max=0.656)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.72089845 0.26184484 0.01725659]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR024780G | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.65282154 0.21047124 0.13670705]  (max=0.653)
#   -> D (LPIPS)   = [0.23597203 0.26251316 0.23444296]
#   -> p_lpips     = [0.4273556  0.1107044  0.46194002] (max=0.462)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.63027495 0.20049456 0.16923034]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR031409B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.88358516 0.102957   0.01345786]  (max=0.884)
#   -> D (LPIPS)   = [0.26897573 0.27617517 0.28484428]
#   -> p_lpips     = [0.5673202  0.29672092 0.13595888] (max=0.567)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.88358516 0.102957   0.01345786]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR036496B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.5880565  0.41116256 0.00078104]  (max=0.588)
#   -> D (LPIPS)   = [0.18166664 0.22404593 0.247506  ]
#   -> p_lpips     = [0.6103688  0.24335574 0.1462755 ] (max=0.610)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.59028774 0.39438185 0.01533049]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR037458B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.29738256 0.70153177 0.00108563]  (max=0.702)
#   -> D (LPIPS)   = [0.13713594 0.18860793 0.20027056]
#   -> p_lpips     = [0.644465   0.20108828 0.1544467 ] (max=0.644)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.3320908  0.6514874  0.01642174]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR038469 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.7935951  0.166296   0.04010879]  (max=0.794)
#   -> D (LPIPS)   = [0.22007605 0.24087144 0.23111166]
#   -> p_lpips     = [0.5854105  0.14029422 0.2742953 ] (max=0.585)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.7727766  0.16369583 0.06352744]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR039473 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.8550491  0.1166835  0.02826731]  (max=0.855)
#   -> D (LPIPS)   = [0.17028922 0.2081531  0.19039881]
#   -> p_lpips     = [0.5855084  0.14031768 0.27417397] (max=0.586)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.8550491  0.1166835  0.02826731]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048297 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9967898  0.0021577  0.00105247]  (max=0.997)
#   -> D (LPIPS)   = [0.14014976 0.20679547 0.18337132]
#   -> p_lpips     = [0.61139613 0.1465217  0.24208224] (max=0.611)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9967898  0.0021577  0.00105247]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048621B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.5519807  0.21761826 0.23040113]  (max=0.552)
#   -> D (LPIPS)   = [0.17084664 0.22536235 0.17203139]
#   -> p_lpips     = [0.45267674 0.10848445 0.43883887] (max=0.453)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5420503  0.20670487 0.2512449 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048944B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9929116  0.00503989 0.00204854]  (max=0.993)
#   -> D (LPIPS)   = [0.16125882 0.22093703 0.18975268]
#   -> p_lpips     = [0.5729958  0.13731903 0.28968522] (max=0.573)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9929116  0.00503989 0.00204854]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048994B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.94287044 0.05535591 0.0017738 ]  (max=0.943)
#   -> D (LPIPS)   = [0.13307063 0.19419478 0.20204292]
#   -> p_lpips     = [0.6572017  0.18529929 0.15749906] (max=0.657)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.94287044 0.05535591 0.0017738 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049019C | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.56712896 0.43141657 0.00145438]  (max=0.567)
#   -> D (LPIPS)   = [0.18263958 0.20703825 0.25671896]
#   -> p_lpips     = [0.53638476 0.33507007 0.12854515] (max=0.536)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5640545  0.42178193 0.01416346]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049358 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9934504  0.00371903 0.0028304 ]  (max=0.993)
#   -> D (LPIPS)   = [0.16079518 0.21562372 0.17559384]
#   -> p_lpips     = [0.5209133  0.12483741 0.35424933] (max=0.521)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9934504  0.00371903 0.0028304 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049453 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.9914903  0.0069668  0.00154265]  (max=0.991)
#   -> D (LPIPS)   = [0.14161383 0.20089445 0.17194235]
#   -> p_lpips     = [0.5810101  0.13923967 0.2797503 ] (max=0.581)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9914903  0.0069668  0.00154265]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051461B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.3128172  0.6845649  0.00261789]  (max=0.685)
#   -> D (LPIPS)   = [0.1785175  0.15339062 0.21819328]
#   -> p_lpips     = [0.31674936 0.55116373 0.13208695] (max=0.551)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.31321037 0.6712247  0.0155648 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051586 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [9.9423593e-01 4.7932644e-03 9.7099750e-04]  (max=0.994)
#   -> D (LPIPS)   = [0.14187504 0.20002984 0.18572588]
#   -> p_lpips     = [0.6328311  0.15165862 0.21551026] (max=0.633)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.9423593e-01 4.7932644e-03 9.7099750e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.6798316  0.20181642 0.11835207]  (max=0.680)
#   -> D (LPIPS)   = [0.23956768 0.27134556 0.27166075]
#   -> p_lpips     = [0.67445064 0.16391651 0.16163279] (max=0.674)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.6792935  0.19802643 0.12268014]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644C | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.42341718 0.5547306  0.02185233]  (max=0.555)
#   -> D (LPIPS)   = [0.20017888 0.23937012 0.21841733]
#   -> p_lpips     = [0.5701191  0.13662963 0.2932513 ] (max=0.570)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.43808734 0.5129205  0.04899223]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051651 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.15399416 0.8449008  0.00110492]  (max=0.845)
#   -> D (LPIPS)   = [0.13448513 0.1727529  0.21264012]
#   -> p_lpips     = [0.5758736  0.28611767 0.1380087 ] (max=0.576)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.15399416 0.8449008  0.00110492]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051796 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [9.8453492e-01 1.4621858e-02 8.4313442e-04]  (max=0.985)
#   -> D (LPIPS)   = [0.12262448 0.18670703 0.2066157 ]
#   -> p_lpips     = [0.6345648  0.21336111 0.15207411] (max=0.635)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.8453492e-01 1.4621858e-02 8.4313442e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051796B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.6311309  0.03366093 0.33520812]  (max=0.631)
#   -> D (LPIPS)   = [0.32478908 0.32547584 0.32323027]
#   -> p_lpips     = [0.2303207  0.14879546 0.6208839 ] (max=0.621)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.59104985 0.04517438 0.3637757 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR052585B | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.6865047  0.3070262  0.00646882]  (max=0.687)
#   -> D (LPIPS)   = [0.19553319 0.24272817 0.20917316]
#   -> p_lpips     = [0.5259296  0.12603956 0.34803095] (max=0.526)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.6704472  0.28892756 0.04062504]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054683 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.43882164 0.31896463 0.24221359]  (max=0.439)
#   -> D (LPIPS)   = [0.2108604  0.2460652  0.20142889]
#   -> p_lpips     = [0.37362826 0.12109103 0.5052807 ] (max=0.505)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.4323023  0.29917726 0.2685203 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054875 | y_true = glioma | #generated images = 36
#   -> p_cnn       = [0.94267213 0.02921605 0.02811141]  (max=0.943)
#   -> D (LPIPS)   = [0.21243814 0.23683423 0.21358284]
#   -> p_lpips     = [0.4598088  0.11019365 0.4299976 ] (max=0.460)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.94267213 0.02921605 0.02811141]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [INFO] Saved patient-level GATED ENSEMBLE results to: /content/drive/MyDrive/TESIS/xai_batch_testset/results_ensemble_gated_lpipsnorm.csv
#
# [METRICS] CNN (prob-based aggregation):
#   Accuracy: 0.8382
#   F1-macro: 0.8515
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.9130    0.7241    0.8077        29
#   meningioma     0.6786    0.9048    0.7755        21
#    pituitary     1.0000    0.9444    0.9714        18
#
#     accuracy                         0.8382        68
#    macro avg     0.8639    0.8578    0.8515        68
# weighted avg     0.8637    0.8382    0.8411        68
#
#   Confusion matrix:
# [[21  8  0]
#  [ 2 19  0]
#  [ 0  1 17]]
#
# [METRICS] LPIPS (inference by generation, normalized):
#   Accuracy: 0.7647
#   F1-macro: 0.7566
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7222    0.6190    0.6667        21
#    pituitary     0.7500    0.8333    0.7895        18
#
#     accuracy                         0.7647        68
#    macro avg     0.7574    0.7600    0.7566        68
# weighted avg     0.7627    0.7647    0.7618        68
#
#   Confusion matrix:
# [[24  2  3]
#  [ 6 13  2]
#  [ 0  3 15]]
#
# [METRICS] GATED ENSEMBLE (alpha_cnn = 0.90, tau_cnn = 0.80, tau_lpips = 0.80, lpips_temp = 0.70):
#   Accuracy: 0.8088
#   F1-macro: 0.8228
#   Classification report:
#               precision    recall  f1-score   support
#
#       glioma     0.8750    0.7241    0.7925        29
#   meningioma     0.6429    0.8571    0.7347        21
#    pituitary     1.0000    0.8889    0.9412        18
#
#     accuracy                         0.8088        68
#    macro avg     0.8393    0.8234    0.8228        68
# weighted avg     0.8364    0.8088    0.8140        68
#
#   Confusion matrix:
# [[21  8  0]
#  [ 3 18  0]
#  [ 0  2 16]]
# Final ensemble results: {'cnn': {'accuracy': 0.8382352941176471, 'f1_macro': 0.8515436944008372}, 'lpips': {'accuracy': 0.7647058823529411, 'f1_macro': 0.7565665576370305}, 'ensemble_gated': {'accuracy': 0.8088235294117647, 'f1_macro': 0.8227743927759784}, 'n_patients': 68}

# %%
# fusion_cnn_lpips_all.py
# -*- coding: utf-8 -*-
"""
Single script that:
- Loads a ResNet50 CNN checkpoint.
- Scans classification_root for patients with real_*.png and cf_to_*.png.
- Computes patient-level CNN and LPIPS probabilities.
- Builds a gated ensemble (CNN+LPIPS).
- Applies several decision-level fusion strategies:
    * Majority vote
    * Weighted majority
    * Bayes-style log-linear fusion
    * KL-based log-linear fusion
    * Joint posterior fusion
    * Dempster–Shafer (singleton case)

For each method, it reports:
- Global ACC and macro-F1
- Per-class precision/recall/F1
- Confusion matrix

All hyperparameters are grouped in a CONFIG section for easy editing.
"""

from pathlib import Path
from typing import List, Dict, Optional
import csv
import re

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models, transforms

from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
)

import lpips  # pip install lpips


# ============================================================
# CONFIGURACIÓN GENERAL
# ============================================================

# Rutas que tú definiste
CLASSIFICATION_ROOT = Path("/content/localdata/class/classification")
CKPT_PATH = "/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/inge1.3fold/full_train/final_full.ckpt"
OUT_CSV = Path("/content/drive/MyDrive/TESIS/xai_batch_testset/results_fusion_all.csv")

# Clases (orden consistente en todo el script)
CLASS_NAMES = ["glioma", "meningioma", "pituitary"]


# ============================================================
# HIPERPARÁMETROS (EDITABLES FÁCILMENTE)
# ============================================================

# Pesos internos de agregación (mismo criterio que ya usabas)
FRAME_WEIGHTS = {
    1: 2.0,
    2: 0.3,
    3: 1.0,
}

CLASS_WEIGHTS = {
    "glioma": 400.0,
    "meningioma": 0.3,
    "pituitary": 1.0,
}

# Conversión de LPIPS → probabilidades (temperatura)
LPIPS_TEMP = 0.2

# Ensamble "gated" CNN+LPIPS
ALPHA_CNN_GATED = 0.5   # mezcla cuando ambos están por debajo de sus umbrales
TAU_CNN = 0.80          # umbral de confianza del CNN
TAU_LPIPS = 0.70        # umbral de confianza del LPIPS

# FUSIÓN A NIVEL DECISIÓN (CNN vs LPIPS)

# Weighted majority: pesos fijos para CNN y LPIPS (en desacuerdos)
WEIGHT_CNN_MAJ = 0.7
WEIGHT_LPIPS_MAJ = 0.3

# Bayes-style fusion (log-linear, α=0.5 es simétrico)
ALPHA_BAYES = 0.5

# KL-based fusion (otro α, típicamente más sesgado al CNN)
ALPHA_KL = 0.7

# Joint posterior (otro α, similar a KL pero conceptualmente distinto)
ALPHA_JOINT = 0.7


# ============================================================
# UTILIDADES DE MODELO / PREPROCESAMIENTO
# ============================================================

def build_model(num_classes: int, pretrained: bool = False) -> nn.Module:
    """
    Construye un ResNet50 y reemplaza la última capa fully connected.
    """
    m = models.resnet50(
        weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None
    )
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m


def lpips_distances_to_probs(
    D: np.ndarray,
    temp: float = 0.2,
) -> np.ndarray:
    """
    Convierte distancias LPIPS por clase D[c] a probabilidades.
    Pasos:
      1) Min-max normalización en [0,1] (invirtiendo sentido: menor dist -> mejor).
      2) Softmax(-D_norm/temp).
    """
    D = np.asarray(D, dtype=np.float32)
    C = D.shape[0]

    finite_mask = np.isfinite(D)
    if not finite_mask.any():
        return np.ones(C, dtype=np.float32) / float(C)

    D_finite = D[finite_mask]
    d_min = float(D_finite.min())
    d_max = float(D_finite.max())

    D_norm = np.zeros_like(D, dtype=np.float32)
    if d_max > d_min:
        D_norm = (D - d_min) / (d_max - d_min)
    else:
        return np.ones(C, dtype=np.float32) / float(C)

    D_norm[~finite_mask] = 1.0

    logits = -D_norm / max(temp, 1e-6)
    logits = logits - logits.max()
    e = np.exp(logits)
    p = e / e.sum()

    return p.astype(np.float32)


# ============================================================
# FUSIÓN A NIVEL DECISIÓN
# ============================================================

def majority_vote(labels_list: List[np.ndarray]) -> np.ndarray:
    """
    Majority vote no ponderado.
    labels_list: lista de arrays [N] (uno por modelo).
    """
    labels_arr = np.stack(labels_list, axis=1)  # [N, M]
    N = labels_arr.shape[0]
    C = labels_arr.max() + 1
    y_pred = np.zeros(N, dtype=int)

    for i in range(N):
        votes = np.bincount(labels_arr[i], minlength=C)
        y_pred[i] = votes.argmax()
    return y_pred


def weighted_majority_vote(labels_list: List[np.ndarray], weights: List[float]) -> np.ndarray:
    """
    Majority vote ponderado entre modelos.
    """
    labels_arr = np.stack(labels_list, axis=1)  # [N, M]
    weights_arr = np.array(weights, dtype=float)

    N = labels_arr.shape[0]
    C = labels_arr.max() + 1
    y_pred = np.zeros(N, dtype=int)

    for i in range(N):
        scores = np.zeros(C, dtype=float)
        for label, w in zip(labels_arr[i], weights_arr):
            scores[int(label)] += w
        y_pred[i] = scores.argmax()

    return y_pred


def fuse_loglinear(
    probs_cnn: np.ndarray,
    probs_lpips: np.ndarray,
    alpha_cnn: float,
    eps: float = 1e-8,
) -> np.ndarray:
    """
    Fusión log-lineal / product-of-experts:
        p_fused ∝ (p_cnn)^α * (p_lpips)^(1-α)
    Esto representa:
      - Bayes-style fusion (α moderado)
      - KL-based fusion (mínimo de suma de KL)
      - Joint posterior (interpretación generativa)
    """
    assert 0.0 <= alpha_cnn <= 1.0
    pc = np.clip(probs_cnn, eps, 1.0)
    pl = np.clip(probs_lpips, eps, 1.0)

    log_pc = np.log(pc)
    log_pl = np.log(pl)

    log_pf = alpha_cnn * log_pc + (1.0 - alpha_cnn) * log_pl

    max_log = np.max(log_pf, axis=1, keepdims=True)
    exp_log = np.exp(log_pf - max_log)
    fused = exp_log / np.sum(exp_log, axis=1, keepdims=True)
    return fused


def fuse_dempster_shafer_singleton(
    probs_cnn: np.ndarray,
    probs_lpips: np.ndarray,
    eps: float = 1e-8,
) -> np.ndarray:
    """
    Fusión Dempster–Shafer en el caso sencillo donde cada fuente solo
    asigna masa a hipótesis singleton (sin masa explícita de ignorancia).
    Se reduce a un producto elemento a elemento y normalización.
    """
    pc = np.clip(probs_cnn, eps, 1.0)
    pl = np.clip(probs_lpips, eps, 1.0)

    m12 = pc * pl
    norm = np.sum(m12, axis=1, keepdims=True)
    fused = m12 / norm
    return fused


def print_metrics(name: str, y_true: np.ndarray, y_pred: np.ndarray) -> Dict[str, float]:
    """
    Imprime ACC y macro-F1.
    """
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="macro")
    print(f"{name:25s} ACC = {acc:.4f} | F1_macro = {f1:.4f}")
    return {"accuracy": float(acc), "f1_macro": float(f1)}


def print_class_metrics(name: str, y_true: np.ndarray, y_pred: np.ndarray, class_names: List[str]):
    """
    Imprime métricas por clase (precision/recall/F1) y matriz de confusión.
    """
    print(f"\n----- {name}: per-class metrics -----")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    cm = confusion_matrix(y_true, y_pred)
    print(f"Confusion matrix ({name}):")
    print(cm)
    print("--------------------------------------\n")


# ============================================================
# PIPELINE PRINCIPAL: CNN + LPIPS + FUSIONES
# ============================================================

def run_ensemble_and_fusions(
    classification_root: Path,
    ckpt_path: str,
    out_csv: Path,
    class_names: List[str],
    frame_weights: Optional[Dict[int, float]] = None,
    class_weights: Optional[Dict[str, float]] = None,
    alpha_cnn_gated: float = ALPHA_CNN_GATED,
    tau_cnn: float = TAU_CNN,
    tau_lpips: float = TAU_LPIPS,
    lpips_temp: float = LPIPS_TEMP,
):
    """
    - Carga CNN y LPIPS.
    - Para cada paciente:
        * Obtiene probabilidades CNN y LPIPS por clase.
        * Calcula ensamble gated.
    - Luego aplica fusiones:
        * Majority vote
        * Weighted majority
        * Bayes
        * KL-based
        * Joint posterior
        * Dempster–Shafer
    - Guarda CSV por paciente y muestra métricas globales y por clase.
    """

    classification_root = Path(classification_root)
    out_csv = Path(out_csv)

    # ---- Device ----
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"[INFO] Using device: {device}")

    # ---- CNN ----
    num_classes = len(class_names)
    print("[INFO] Loading CNN checkpoint...")
    model = build_model(num_classes=num_classes, pretrained=False)
    checkpoint = torch.load(ckpt_path, map_location=device)
    if "model" in checkpoint:
        model.load_state_dict(checkpoint["model"])
    else:
        model.load_state_dict(checkpoint)
    model = model.to(device)
    model.eval()
    print("[INFO] CNN loaded.")

    # ---- LPIPS ----
    print("[INFO] Loading LPIPS (alex)...")
    lpips_fn = lpips.LPIPS(net='alex').to(device)
    lpips_fn.eval()
    print("[INFO] LPIPS ready.")

    class_to_idx = {c: i for i, c in enumerate(class_names)}
    idx_to_class = {i: c for c, i in class_to_idx.items()}

    # ---- Pesos de agregación ----
    if frame_weights is None:
        frame_weights = FRAME_WEIGHTS
    if class_weights is None:
        class_weights = CLASS_WEIGHTS

    print(f"[INFO] frame_weights = {frame_weights}")
    print(f"[INFO] class_weights = {class_weights}")

    # ---- Transforms ----
    resize_tf = transforms.Resize((256, 256))
    to_tensor = transforms.ToTensor()
    norm_cnn = transforms.Normalize(mean=[0.5, 0.5, 0.5],
                                    std=[0.5, 0.5, 0.5])

    def preprocess_cnn(pil_img: Image.Image) -> torch.Tensor:
        img = pil_img.convert("L")
        img = resize_tf(img)
        t = to_tensor(img)         # [1,H,W]
        t = t.repeat(3, 1, 1)      # [3,H,W]
        t = norm_cnn(t)
        return t

    def preprocess_lpips(pil_img: Image.Image) -> torch.Tensor:
        img = pil_img.convert("L")
        img = resize_tf(img)
        t = to_tensor(img)         # [1,H,W] in [0,1]
        t = t.repeat(3, 1, 1)      # [3,H,W]
        t = t * 2.0 - 1.0          # [-1,1]
        return t.unsqueeze(0)      # [1,3,H,W]

    # ---- Pacientes ----
    patient_dirs = [d for d in classification_root.iterdir() if d.is_dir()]
    patient_dirs = sorted(patient_dirs, key=lambda p: p.name)

    print(f"[INFO] Found {len(patient_dirs)} patient folders in {classification_root}")

    real_pattern = re.compile(r"^real_([^_]+)(?:_i(\d+))?$")
    cf_pattern = re.compile(r"^cf_to_([a-zA-Z0-9]+)(?:_i(\d+))?_f(\d+)$")

    all_rows = []

    y_true_all = []
    y_pred_cnn_all = []
    y_pred_lpips_all = []
    y_pred_ens_all = []

    p_cnn_all = []
    p_lpips_all = []

    for patient_dir in patient_dirs:
        patient_id = patient_dir.name

        # ===== Real images =====
        real_files = list(patient_dir.glob("real_*.png"))
        if not real_files:
            print(f"[WARN] No real_*.png for patient {patient_id}, skipping.")
            continue

        real_by_idx: Dict[int, Path] = {}
        true_cls = None

        for rf in real_files:
            m_real = real_pattern.match(rf.stem)
            if not m_real:
                continue
            cls = m_real.group(1)
            idx_str = m_real.group(2)

            if true_cls is None:
                true_cls = cls
            elif cls != true_cls:
                print(f"[WARN] Multiple real classes for patient {patient_id}, skipping.")
                true_cls = None
                break

            idx_img = int(idx_str) if idx_str is not None else 0
            real_by_idx[idx_img] = rf

        if true_cls is None or true_cls not in class_to_idx:
            print(f"[WARN] Could not determine valid true class for patient {patient_id}, skipping.")
            continue

        true_idx = class_to_idx[true_cls]
        real_tensor_cache: Dict[int, torch.Tensor] = {}

        # ===== Generated images =====
        cf_files = sorted(patient_dir.glob("cf_to_*.png"))
        if not cf_files:
            print(f"[WARN] No cf_to_*.png for patient {patient_id}, skipping.")
            continue

        print(f"\n[PATIENT] {patient_id} | y_true = {true_cls} | #generated = {len(cf_files)}")

        sum_probs_cnn = torch.zeros(num_classes, device=device)
        sum_w_cnn = 0.0

        sum_d_per_target = {c_idx: 0.0 for c_idx in range(num_classes)}
        sum_w_per_target = {c_idx: 0.0 for c_idx in range(num_classes)}
        count_imgs_per_target = {c_idx: 0 for c_idx in range(num_classes)}

        for img_path in cf_files:
            m_cf = cf_pattern.match(img_path.stem)
            if not m_cf:
                print(f"[WARN] Filename {img_path.name} does not match cf pattern, skipping.")
                continue

            target_cls = m_cf.group(1)
            idx_str = m_cf.group(2)
            frame_str = m_cf.group(3)

            if target_cls not in class_to_idx:
                print(f"[WARN] target_cls '{target_cls}' not in class_names, skipping {img_path.name}.")
                continue

            target_idx = class_to_idx[target_cls]
            img_idx = int(idx_str) if idx_str is not None else 0

            try:
                frame_idx = int(frame_str)
            except Exception:
                frame_idx = None

            w_frame = frame_weights.get(frame_idx, 1.0)
            w_cls = class_weights.get(target_cls, 1.0)
            w_total = w_cls * w_frame

            # ----- CNN -----
            pil_cf = Image.open(img_path)
            x_cnn = preprocess_cnn(pil_cf).unsqueeze(0).to(device)
            with torch.no_grad():
                logits = model(x_cnn)
                probs = F.softmax(logits, dim=1)[0]
            sum_probs_cnn += w_total * probs
            sum_w_cnn += w_total

            # ----- LPIPS -----
            real_path = real_by_idx.get(img_idx, real_files[0])
            if img_idx not in real_tensor_cache:
                real_pil = Image.open(real_path)
                real_t = preprocess_lpips(real_pil).to(device)
                real_tensor_cache[img_idx] = real_t
            else:
                real_t = real_tensor_cache[img_idx]

            cf_t = preprocess_lpips(pil_cf).to(device)
            with torch.no_grad():
                d_lpips = lpips_fn(real_t, cf_t).item()

            sum_d_per_target[target_idx] += w_total * d_lpips
            sum_w_per_target[target_idx] += w_total
            count_imgs_per_target[target_idx] += 1

        if sum_w_cnn == 0.0:
            print(f"[WARN] sum_w_cnn == 0 for patient {patient_id}, skipping.")
            continue

        # CNN patient-level
        p_cnn = (sum_probs_cnn / sum_w_cnn).detach().cpu().numpy()
        pred_idx_cnn = int(p_cnn.argmax())
        pred_cls_cnn = idx_to_class[pred_idx_cnn]
        max_p_cnn = float(p_cnn.max())

        # LPIPS -> D -> p_lpips
        D = np.zeros(num_classes, dtype=np.float32)
        for c_idx in range(num_classes):
            if sum_w_per_target[c_idx] > 0:
                D[c_idx] = float(sum_d_per_target[c_idx] / sum_w_per_target[c_idx])
            else:
                D[c_idx] = np.inf

        p_lpips = lpips_distances_to_probs(D, temp=lpips_temp)
        pred_idx_lpips = int(p_lpips.argmax())
        pred_cls_lpips = idx_to_class[pred_idx_lpips]
        max_p_lpips = float(p_lpips.max())

        # Ensamble gated
        if max_p_cnn >= tau_cnn:
            p_ens = p_cnn.copy()
            gate_mode = "cnn_only"
        elif max_p_lpips >= tau_lpips:
            p_ens = p_lpips.copy()
            gate_mode = "lpips_only"
        else:
            p_ens = alpha_cnn_gated * p_cnn + (1.0 - alpha_cnn_gated) * p_lpips
            gate_mode = "mixed"

        pred_idx_ens = int(p_ens.argmax())
        pred_cls_ens = idx_to_class[pred_idx_ens]

        print(f"  -> p_cnn       = {p_cnn} (max={max_p_cnn:.3f})")
        print(f"  -> D (LPIPS)   = {D}")
        print(f"  -> p_lpips     = {p_lpips} (max={max_p_lpips:.3f})")
        print(f"  -> gate_mode   = {gate_mode}")
        print(f"  -> p_ensemble  = {p_ens}")
        print(f"  -> y_pred_cnn      = {pred_cls_cnn}")
        print(f"  -> y_pred_lpips    = {pred_cls_lpips}")
        print(f"  -> y_pred_ensemble = {pred_cls_ens}")

        # Acumular global
        y_true_all.append(true_idx)
        y_pred_cnn_all.append(pred_idx_cnn)
        y_pred_lpips_all.append(pred_idx_lpips)
        y_pred_ens_all.append(pred_idx_ens)
        p_cnn_all.append(p_cnn)
        p_lpips_all.append(p_lpips)

        # Fila CSV
        row = {
            "patient_id": patient_id,
            "y_true": true_cls,
            "y_pred_cnn": pred_cls_cnn,
            "y_pred_lpips": pred_cls_lpips,
            "y_pred_ensemble_gated": pred_cls_ens,
            "gate_mode": gate_mode,
            "max_p_cnn": max_p_cnn,
            "max_p_lpips": max_p_lpips,
        }
        for i, c in enumerate(class_names):
            row[f"p_cnn_{c}"] = float(p_cnn[i])
            row[f"D_{c}"] = float(D[i]) if np.isfinite(D[i]) else float("inf")
            row[f"p_lpips_{c}"] = float(p_lpips[i])
            row[f"p_ens_gated_{c}"] = float(p_ens[i])
            row[f"n_imgs_{c}"] = int(count_imgs_per_target[i])
            row[f"sum_w_{c}"] = float(sum_w_per_target[i])

        all_rows.append(row)

    # Guardar CSV
    out_csv.parent.mkdir(parents=True, exist_ok=True)
    fieldnames = (
        ["patient_id", "y_true", "y_pred_cnn", "y_pred_lpips", "y_pred_ensemble_gated",
         "gate_mode", "max_p_cnn", "max_p_lpips"]
        + [f"p_cnn_{c}" for c in class_names]
        + [f"D_{c}" for c in class_names]
        + [f"p_lpips_{c}" for c in class_names]
        + [f"p_ens_gated_{c}" for c in class_names]
        + [f"n_imgs_{c}" for c in class_names]
        + [f"sum_w_{c}" for c in class_names]
    )

    with out_csv.open("w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        for r in all_rows:
            writer.writerow(r)

    print(f"\n[INFO] Saved patient-level results to: {out_csv}")

    if len(y_true_all) == 0:
        print("[WARN] No patients evaluated. Check your classification_root.")
        return

    # Convertir a arrays
    y_true_all = np.array(y_true_all, dtype=int)
    y_pred_cnn_all = np.array(y_pred_cnn_all, dtype=int)
    y_pred_lpips_all = np.array(y_pred_lpips_all, dtype=int)
    y_pred_ens_all = np.array(y_pred_ens_all, dtype=int)
    p_cnn_all = np.vstack(p_cnn_all)
    p_lpips_all = np.vstack(p_lpips_all)

    print("\n================ METRICS ==================")

    # --- CNN baseline ---
    metrics_cnn = print_metrics("CNN baseline", y_true_all, y_pred_cnn_all)
    print_class_metrics("CNN baseline", y_true_all, y_pred_cnn_all, class_names)

    # --- LPIPS baseline ---
    metrics_lpips = print_metrics("LPIPS baseline", y_true_all, y_pred_lpips_all)
    print_class_metrics("LPIPS baseline", y_true_all, y_pred_lpips_all, class_names)

    # --- Gated ensemble ---
    metrics_gated = print_metrics("Gated ensemble", y_true_all, y_pred_ens_all)
    print_class_metrics("Gated ensemble", y_true_all, y_pred_ens_all, class_names)

    # --- Majority vote ---
    y_mv = majority_vote([y_pred_cnn_all, y_pred_lpips_all])
    metrics_mv = print_metrics("Majority vote", y_true_all, y_mv)
    print_class_metrics("Majority vote", y_true_all, y_mv, class_names)

    # --- Weighted majority ---
    y_wmv = weighted_majority_vote(
        [y_pred_cnn_all, y_pred_lpips_all],
        weights=[WEIGHT_CNN_MAJ, WEIGHT_LPIPS_MAJ],
    )
    metrics_wmv = print_metrics("Weighted majority", y_true_all, y_wmv)
    print_class_metrics("Weighted majority", y_true_all, y_wmv, class_names)

    # --- Bayes fusion (log-linear con ALPHA_BAYES) ---
    probs_bayes = fuse_loglinear(p_cnn_all, p_lpips_all, alpha_cnn=ALPHA_BAYES)
    y_bayes = probs_bayes.argmax(axis=1)
    metrics_bayes = print_metrics("Bayes fusion", y_true_all, y_bayes)
    print_class_metrics("Bayes fusion", y_true_all, y_bayes, class_names)

    # --- KL-based fusion (log-linear con ALPHA_KL) ---
    probs_kl = fuse_loglinear(p_cnn_all, p_lpips_all, alpha_cnn=ALPHA_KL)
    y_kl = probs_kl.argmax(axis=1)
    metrics_kl = print_metrics("KL-based fusion", y_true_all, y_kl)
    print_class_metrics("KL-based fusion", y_true_all, y_kl, class_names)

    # --- Joint posterior (log-linear con ALPHA_JOINT) ---
    probs_joint = fuse_loglinear(p_cnn_all, p_lpips_all, alpha_cnn=ALPHA_JOINT)
    y_joint = probs_joint.argmax(axis=1)
    metrics_joint = print_metrics("Joint posterior", y_true_all, y_joint)
    print_class_metrics("Joint posterior", y_true_all, y_joint, class_names)

    # --- Dempster–Shafer ---
    probs_ds = fuse_dempster_shafer_singleton(p_cnn_all, p_lpips_all)
    y_ds = probs_ds.argmax(axis=1)
    metrics_ds = print_metrics("Dempster–Shafer", y_true_all, y_ds)
    print_class_metrics("Dempster–Shafer", y_true_all, y_ds, class_names)

    print("\n[INFO] Done. Metrics computed for:")
    print("  - CNN baseline")
    print("  - LPIPS baseline")
    print("  - Gated ensemble")
    print("  - Majority vote")
    print("  - Weighted majority")
    print("  - Bayes fusion")
    print("  - KL-based fusion")
    print("  - Joint posterior fusion")
    print("  - Dempster–Shafer fusion")


# ============================================================
# MAIN
# ============================================================

if __name__ == "__main__":
    run_ensemble_and_fusions(
        classification_root=CLASSIFICATION_ROOT,
        ckpt_path=CKPT_PATH,
        out_csv=OUT_CSV,
        class_names=CLASS_NAMES,
        frame_weights=FRAME_WEIGHTS,
        class_weights=CLASS_WEIGHTS,
        alpha_cnn_gated=ALPHA_CNN_GATED,
        tau_cnn=TAU_CNN,
        tau_lpips=TAU_LPIPS,
        lpips_temp=LPIPS_TEMP,
    )
# Out:
# [INFO] Using device: cuda
# [INFO] Loading CNN checkpoint...
# [INFO] CNN loaded.
# [INFO] Loading LPIPS (alex)...
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [INFO] LPIPS ready.
# [INFO] frame_weights = {1: 2.0, 2: 0.3, 3: 1.0}
# [INFO] class_weights = {'glioma': 400.0, 'meningioma': 0.3, 'pituitary': 1.0}
# [INFO] Found 68 patient folders in /content/localdata/class/classification
#
# [PATIENT] 101029 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.05766637 0.04251871 0.8998147 ] (max=0.900)
#   -> D (LPIPS)   = [0.26238975 0.28323698 0.21243775]
#   -> p_lpips     = [0.02834811 0.00650312 0.9651488 ] (max=0.965)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05766637 0.04251871 0.8998147 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101082 | y_true = meningioma | #generated = 27
#   -> p_cnn       = [0.01784439 0.9266646  0.05549082] (max=0.927)
#   -> D (LPIPS)   = [0.27448702 0.27085114 0.292629  ]
#   -> p_lpips     = [0.30122295 0.6941002  0.00467681] (max=0.694)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01784439 0.9266646  0.05549082]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 101724 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.10923654 0.19802076 0.6927426 ] (max=0.693)
#   -> D (LPIPS)   = [0.22608358 0.2370655  0.18354918]
#   -> p_lpips     = [0.01833064 0.00657017 0.9750992 ] (max=0.975)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.01833064 0.00657017 0.9750992 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 101797 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.27210206 0.72666675 0.0012312 ] (max=0.727)
#   -> D (LPIPS)   = [0.15928522 0.19991313 0.2213675 ]
#   -> p_lpips     = [0.957245   0.03630507 0.00644987] (max=0.957)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.957245   0.03630507 0.00644987]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 102075 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.22482    0.70862484 0.06655518] (max=0.709)
#   -> D (LPIPS)   = [0.22106464 0.22819433 0.23190139]
#   -> p_lpips     = [0.95784783 0.03569829 0.00645393] (max=0.958)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.95784783 0.03569829 0.00645393]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 102420 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [4.9134977e-02 9.5023125e-01 6.3370721e-04] (max=0.950)
#   -> D (LPIPS)   = [0.21632397 0.18678877 0.2565738 ]
#   -> p_lpips     = [0.10689363 0.88712895 0.00597743] (max=0.887)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.9134977e-02 9.5023125e-01 6.3370721e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102714 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [1.0813505e-02 9.8845792e-01 7.2851847e-04] (max=0.988)
#   -> D (LPIPS)   = [0.20516741 0.17164566 0.2547739 ]
#   -> p_lpips     = [0.11681096 0.87727803 0.00591105] (max=0.877)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [1.0813505e-02 9.8845792e-01 7.2851847e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102818 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.38803726 0.5034381  0.10852441] (max=0.503)
#   -> D (LPIPS)   = [0.28390715 0.26321188 0.2908199 ]
#   -> p_lpips     = [0.0228706  0.97058964 0.00653978] (max=0.971)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.0228706  0.97058964 0.00653978]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 102985 | y_true = meningioma | #generated = 18
#   -> p_cnn       = [0.20249605 0.7764296  0.02107423] (max=0.776)
#   -> D (LPIPS)   = [0.33999154 0.32390612 0.3276336 ]
#   -> p_lpips     = [0.005102   0.7572038  0.23769419] (max=0.757)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.005102   0.7572038  0.23769419]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 103046 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.01375963 0.00737478 0.97886527] (max=0.979)
#   -> D (LPIPS)   = [0.28605548 0.299614   0.23586717]
#   -> p_lpips     = [0.01901651 0.00656558 0.9744179 ] (max=0.974)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.01375963 0.00737478 0.97886527]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 103731 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.09187519 0.0238815  0.88424295] (max=0.884)
#   -> D (LPIPS)   = [0.23930353 0.26272467 0.20776749]
#   -> p_lpips     = [0.05335976 0.00633572 0.9403045 ] (max=0.940)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.09187519 0.0238815  0.88424295]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 104684 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.03999297 0.00391499 0.95609176] (max=0.956)
#   -> D (LPIPS)   = [0.29364434 0.3079137  0.25336635]
#   -> p_lpips     = [0.02415678 0.00653117 0.9693121 ] (max=0.969)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.03999297 0.00391499 0.95609176]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 105936 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.27404156 0.05936218 0.66659623] (max=0.667)
#   -> D (LPIPS)   = [0.38573018 0.38957167 0.37030903]
#   -> p_lpips     = [0.01781777 0.0065736  0.97560865] (max=0.976)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.01781777 0.0065736  0.97560865]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 106494 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.312736   0.6855172  0.00174688] (max=0.686)
#   -> D (LPIPS)   = [0.17484139 0.23243196 0.1945847 ]
#   -> p_lpips     = [0.84255797 0.00567711 0.15176497] (max=0.843)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.84255797 0.00567711 0.15176497]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 107190 | y_true = meningioma | #generated = 27
#   -> p_cnn       = [0.10207777 0.8923639  0.00555817] (max=0.892)
#   -> D (LPIPS)   = [0.30860287 0.2916694  0.33949026]
#   -> p_lpips     = [0.14464602 0.8496293  0.00572476] (max=0.850)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10207777 0.8923639  0.00555817]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107248 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.1820838  0.8139149  0.00400111] (max=0.814)
#   -> D (LPIPS)   = [0.28062838 0.2692147  0.28921464]
#   -> p_lpips     = [0.05415924 0.93951035 0.00633037] (max=0.940)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.1820838  0.8139149  0.00400111]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 107429 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.36978546 0.05207306 0.57814133] (max=0.578)
#   -> D (LPIPS)   = [0.3778778 0.3755408 0.3697041]
#   -> p_lpips     = [0.00651083 0.02719566 0.96629345] (max=0.966)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.00651083 0.02719566 0.96629345]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107494 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.12928776 0.6060231  0.26468894] (max=0.606)
#   -> D (LPIPS)   = [0.21099421 0.23249376 0.20343569]
#   -> p_lpips     = [0.21293819 0.00526769 0.78179413] (max=0.782)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.21293819 0.00526769 0.78179413]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 107747 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.05862444 0.9390802  0.00229571] (max=0.939)
#   -> D (LPIPS)   = [0.14219947 0.16397175 0.21554877]
#   -> p_lpips     = [0.8107454  0.1837918  0.00546276] (max=0.811)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.05862444 0.9390802  0.00229571]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 108858 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.0812484  0.234508   0.68424356] (max=0.684)
#   -> D (LPIPS)   = [0.22138788 0.2262646  0.21670163]
#   -> p_lpips     = [0.07893379 0.00616456 0.9149017 ] (max=0.915)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.07893379 0.00616456 0.9149017 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 109350 | y_true = meningioma | #generated = 18
#   -> p_cnn       = [0.2952452  0.7025489  0.00220567] (max=0.703)
#   -> D (LPIPS)   = [0.31621608 0.3104587  0.3283612 ]
#   -> p_lpips     = [0.1659373  0.8284804  0.00558226] (max=0.828)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.1659373  0.8284804  0.00558226]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109471 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.21850713 0.37456375 0.40692896] (max=0.407)
#   -> D (LPIPS)   = [0.27736428 0.24253441 0.28508115]
#   -> p_lpips     = [0.01630497 0.9771113  0.00658372] (max=0.977)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.01630497 0.9771113  0.00658372]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 109898 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.2454158  0.12305611 0.63152796] (max=0.632)
#   -> D (LPIPS)   = [0.32546458 0.31375656 0.32000017]
#   -> p_lpips     = [0.00626063 0.9291599  0.06457949] (max=0.929)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.00626063 0.9291599  0.06457949]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 111532 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [4.1923849e-03 9.9559349e-01 2.1423149e-04] (max=0.996)
#   -> D (LPIPS)   = [0.22934116 0.21721612 0.31629997]
#   -> p_lpips     = [0.35010606 0.6455443  0.00434964] (max=0.646)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [4.1923849e-03 9.9559349e-01 2.1423149e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112002 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.2256941  0.771998   0.00230781] (max=0.772)
#   -> D (LPIPS)   = [0.16710047 0.20756572 0.21976265]
#   -> p_lpips     = [0.97258353 0.02086328 0.00655322] (max=0.973)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.97258353 0.02086328 0.00655322]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 112074 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.35897404 0.6163922  0.02463367] (max=0.616)
#   -> D (LPIPS)   = [0.27469775 0.2709033  0.29605854]
#   -> p_lpips     = [0.31844565 0.6769928  0.00456154] (max=0.677)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.33870983 0.6466925  0.0145976 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 112648 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.3319544  0.36618003 0.30186558] (max=0.366)
#   -> D (LPIPS)   = [0.26189673 0.26754844 0.27188635]
#   -> p_lpips     = [0.93824285 0.05543528 0.00632183] (max=0.938)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.93824285 0.05543528 0.00632183]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 112649 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.02221601 0.2623971  0.7153869 ] (max=0.715)
#   -> D (LPIPS)   = [0.21948506 0.2480772  0.17206773]
#   -> p_lpips     = [0.04205195 0.0064114  0.95153666] (max=0.952)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.04205195 0.0064114  0.95153666]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112746 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.08819675 0.3058894  0.6059136 ] (max=0.606)
#   -> D (LPIPS)   = [0.20396382 0.23401637 0.17605595]
#   -> p_lpips     = [0.08209563 0.0061434  0.91176105] (max=0.912)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.08209563 0.0061434  0.91176105]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 112847 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.07142761 0.19000894 0.7385634 ] (max=0.739)
#   -> D (LPIPS)   = [0.22043484 0.24422342 0.18326999]
#   -> p_lpips     = [0.04498738 0.00639176 0.94862086] (max=0.949)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.04498738 0.00639176 0.94862086]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 113098 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.33891124 0.47731394 0.18377472] (max=0.477)
#   -> D (LPIPS)   = [0.3076048  0.29773524 0.31821403]
#   -> p_lpips     = [0.08192949 0.91192603 0.00614451] (max=0.912)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.08192949 0.91192603 0.00614451]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113435 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.10711592 0.8917118  0.00117234] (max=0.892)
#   -> D (LPIPS)   = [0.14209391 0.17202727 0.21391623]
#   -> p_lpips     = [0.8840261  0.11001736 0.00595652] (max=0.884)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.10711592 0.8917118  0.00117234]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 113971 | y_true = meningioma | #generated = 27
#   -> p_cnn       = [0.70804477 0.22447632 0.06747895] (max=0.708)
#   -> D (LPIPS)   = [0.34327826 0.3586909  0.33868372]
#   -> p_lpips     = [0.23958835 0.00508932 0.7553223 ] (max=0.755)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.23958835 0.00508932 0.7553223 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 114361 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.34807548 0.07556416 0.5763603 ] (max=0.576)
#   -> D (LPIPS)   = [0.19548911 0.2533207  0.15859658]
#   -> p_lpips     = [0.12410885 0.00586221 0.8700289 ] (max=0.870)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.12410885 0.00586221 0.8700289 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 114417 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.49227673 0.33504507 0.17267816] (max=0.492)
#   -> D (LPIPS)   = [0.31492153 0.31118158 0.33466703]
#   -> p_lpips     = [0.30939636 0.6859816  0.00462211] (max=0.686)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.40083653 0.5105133  0.08865013]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 92897 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.1641348  0.8342402  0.00162501] (max=0.834)
#   -> D (LPIPS)   = [0.2573287  0.23596598 0.2825623 ]
#   -> p_lpips     = [0.09120309 0.9027145  0.00608244] (max=0.903)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.1641348  0.8342402  0.00162501]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 96587 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.84545565 0.14827754 0.00626637] (max=0.845)
#   -> D (LPIPS)   = [0.30067107 0.30792233 0.3351059 ]
#   -> p_lpips     = [0.73764616 0.2573836  0.00497022] (max=0.738)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.84545565 0.14827754 0.00626637]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 97599 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.1027393  0.3030602  0.59420043] (max=0.594)
#   -> D (LPIPS)   = [0.25197327 0.25933066 0.23660176]
#   -> p_lpips     = [0.03266609 0.00647422 0.9608597 ] (max=0.961)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.03266609 0.00647422 0.9608597 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 97607 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.08104195 0.9177436  0.00121417] (max=0.918)
#   -> D (LPIPS)   = [0.23921664 0.21735296 0.31629863]
#   -> p_lpips     = [0.24758239 0.7473818  0.00503582] (max=0.747)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.08104195 0.9177436  0.00121417]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 97737 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [2.1914195e-02 9.7729409e-01 7.9164450e-04] (max=0.977)
#   -> D (LPIPS)   = [0.21739782 0.2091019  0.2960918 ]
#   -> p_lpips     = [0.38141468 0.61444527 0.0041401 ] (max=0.614)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [2.1914195e-02 9.7729409e-01 7.9164450e-04]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] 97875 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.17516594 0.78242064 0.0424131 ] (max=0.782)
#   -> D (LPIPS)   = [0.18236372 0.20491353 0.2012683 ]
#   -> p_lpips     = [0.9786097  0.00659382 0.01479655] (max=0.979)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.9786097  0.00659382 0.01479655]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] 98871 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.10248093 0.16626114 0.7312579 ] (max=0.731)
#   -> D (LPIPS)   = [0.23051557 0.26098654 0.18209964]
#   -> p_lpips     = [0.04413313 0.00639747 0.94946945] (max=0.949)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.04413313 0.00639747 0.94946945]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 98874 | y_true = pituitary | #generated = 36
#   -> p_cnn       = [0.07618883 0.25219357 0.67161775] (max=0.672)
#   -> D (LPIPS)   = [0.21956332 0.25374457 0.18297532]
#   -> p_lpips     = [0.06967215 0.00622655 0.9241013 ] (max=0.924)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.06967215 0.00622655 0.9241013 ]
#   -> y_pred_cnn      = pituitary
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] 99308 | y_true = meningioma | #generated = 36
#   -> p_cnn       = [0.02177406 0.97724617 0.00097983] (max=0.977)
#   -> D (LPIPS)   = [0.21989034 0.2327359  0.29557475]
#   -> p_lpips     = [0.69699025 0.29831347 0.00469628] (max=0.697)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.02177406 0.97724617 0.00097983]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR024780B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.72813743 0.27014962 0.00171281] (max=0.728)
#   -> D (LPIPS)   = [0.13223362 0.20131318 0.21092215]
#   -> p_lpips     = [0.9812139  0.01217471 0.00661137] (max=0.981)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.9812139  0.01217471 0.00661137]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR024780G | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.65282154 0.21047124 0.13670705] (max=0.653)
#   -> D (LPIPS)   = [0.23597203 0.26251316 0.23444296]
#   -> p_lpips     = [0.43067926 0.00381038 0.5655104 ] (max=0.566)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.54175043 0.10714081 0.35110873]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR031409B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.88358516 0.102957   0.01345786] (max=0.884)
#   -> D (LPIPS)   = [0.26897573 0.27617517 0.28484428]
#   -> p_lpips     = [0.90073115 0.09319978 0.00606908] (max=0.901)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.88358516 0.102957   0.01345786]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR036496B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.5880565  0.41116256 0.00078104] (max=0.588)
#   -> D (LPIPS)   = [0.18166664 0.22404593 0.247506  ]
#   -> p_lpips     = [0.955331   0.03823196 0.00643697] (max=0.955)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.955331   0.03823196 0.00643697]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR037458B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.29738256 0.70153177 0.00108563] (max=0.702)
#   -> D (LPIPS)   = [0.13713594 0.18860793 0.20027056]
#   -> p_lpips     = [0.9768421  0.01657602 0.00658191] (max=0.977)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.9768421  0.01657602 0.00658191]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR038469 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.7935951  0.166296   0.04010879] (max=0.794)
#   -> D (LPIPS)   = [0.22007605 0.24087144 0.23111166]
#   -> p_lpips     = [0.928375   0.00625534 0.06536963] (max=0.928)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.928375   0.00625534 0.06536963]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR039473 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.8550491  0.1166835  0.02826731] (max=0.855)
#   -> D (LPIPS)   = [0.17028922 0.2081531  0.19039881]
#   -> p_lpips     = [0.92850435 0.00625621 0.06523941] (max=0.929)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.8550491  0.1166835  0.02826731]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048297 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.9967898  0.0021577  0.00105247] (max=0.997)
#   -> D (LPIPS)   = [0.14014976 0.20679547 0.18337132]
#   -> p_lpips     = [0.956207   0.00644287 0.03735018] (max=0.956)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9967898  0.0021577  0.00105247]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048621B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.5519807  0.21761826 0.23040113] (max=0.552)
#   -> D (LPIPS)   = [0.17084664 0.22536235 0.17203139]
#   -> p_lpips     = [0.5252729  0.00353926 0.47118786] (max=0.525)
#   -> gate_mode   = mixed
#   -> p_ensemble  = [0.5386268  0.11057876 0.3507945 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048944B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.9929116  0.00503989 0.00204854] (max=0.993)
#   -> D (LPIPS)   = [0.16125882 0.22093703 0.18975268]
#   -> p_lpips     = [0.91023606 0.00613312 0.0836308 ] (max=0.910)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9929116  0.00503989 0.00204854]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR048994B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.94287044 0.05535591 0.0017738 ] (max=0.943)
#   -> D (LPIPS)   = [0.13307063 0.19419478 0.20204292]
#   -> p_lpips     = [0.98170125 0.01168402 0.00661465] (max=0.982)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.94287044 0.05535591 0.0017738 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049019C | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.56712896 0.43141657 0.00145438] (max=0.567)
#   -> D (LPIPS)   = [0.18263958 0.20703825 0.25671896]
#   -> p_lpips     = [0.83374685 0.16063544 0.00561774] (max=0.834)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.83374685 0.16063544 0.00561774]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049358 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.9934504  0.00371903 0.0028304 ] (max=0.993)
#   -> D (LPIPS)   = [0.16079518 0.21562372 0.17559384]
#   -> p_lpips     = [0.7898285  0.00532182 0.20484968] (max=0.790)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9934504  0.00371903 0.0028304 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR049453 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.9914903  0.0069668  0.00154265] (max=0.991)
#   -> D (LPIPS)   = [0.14161383 0.20089445 0.17194235]
#   -> p_lpips     = [0.9223443  0.00621471 0.07144094] (max=0.922)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.9914903  0.0069668  0.00154265]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051461B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.3128172  0.6845649  0.00261789] (max=0.685)
#   -> D (LPIPS)   = [0.1785175  0.15339062 0.21819328]
#   -> p_lpips     = [0.12505156 0.8690925  0.0058559 ] (max=0.869)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.12505156 0.8690925  0.0058559 ]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = meningioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051586 | y_true = glioma | #generated = 36
#   -> p_cnn       = [9.9423593e-01 4.7932644e-03 9.7099750e-04] (max=0.994)
#   -> D (LPIPS)   = [0.14187504 0.20002984 0.18572588]
#   -> p_lpips     = [0.9710758  0.00654306 0.02238121] (max=0.971)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.9423593e-01 4.7932644e-03 9.7099750e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.6798316  0.20181642 0.11835207] (max=0.680)
#   -> D (LPIPS)   = [0.23956768 0.27134556 0.27166075]
#   -> p_lpips     = [0.9863732  0.00698064 0.00664613] (max=0.986)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.9863732  0.00698064 0.00664613]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051644C | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.42341718 0.5547306  0.02185233] (max=0.555)
#   -> D (LPIPS)   = [0.20017888 0.23937012 0.21841733]
#   -> p_lpips     = [0.905518   0.00610133 0.08838074] (max=0.906)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.905518   0.00610133 0.08838074]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051651 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.15399416 0.8449008  0.00110492] (max=0.845)
#   -> D (LPIPS)   = [0.13448513 0.1727529  0.21264012]
#   -> p_lpips     = [0.9147564  0.07908002 0.00616358] (max=0.915)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.15399416 0.8449008  0.00110492]
#   -> y_pred_cnn      = meningioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = meningioma
#
# [PATIENT] MR051796 | y_true = glioma | #generated = 36
#   -> p_cnn       = [9.8453492e-01 1.4621858e-02 8.4313442e-04] (max=0.985)
#   -> D (LPIPS)   = [0.12262448 0.18670703 0.2066157 ]
#   -> p_lpips     = [0.9720258  0.02142473 0.00654946] (max=0.972)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [9.8453492e-01 1.4621858e-02 8.4313442e-04]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR051796B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.6311309  0.03366093 0.33520812] (max=0.631)
#   -> D (LPIPS)   = [0.32478908 0.32547584 0.32323027]
#   -> p_lpips     = [0.02995738 0.00649235 0.96355027] (max=0.964)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.02995738 0.00649235 0.96355027]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] MR052585B | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.6865047  0.3070262  0.00646882] (max=0.687)
#   -> D (LPIPS)   = [0.19553319 0.24272817 0.20917316]
#   -> p_lpips     = [0.8048494  0.00542303 0.1897276 ] (max=0.805)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.8048494  0.00542303 0.1897276 ]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [PATIENT] MR054683 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.43882164 0.31896463 0.24221359] (max=0.439)
#   -> D (LPIPS)   = [0.2108604  0.2460652  0.20142889]
#   -> p_lpips     = [0.2566985  0.00497481 0.73832667] (max=0.738)
#   -> gate_mode   = lpips_only
#   -> p_ensemble  = [0.2566985  0.00497481 0.73832667]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = pituitary
#   -> y_pred_ensemble = pituitary
#
# [PATIENT] MR054875 | y_true = glioma | #generated = 36
#   -> p_cnn       = [0.94267213 0.02921605 0.02811141] (max=0.943)
#   -> D (LPIPS)   = [0.21243814 0.23683423 0.21358284]
#   -> p_lpips     = [0.55629164 0.00374826 0.43996003] (max=0.556)
#   -> gate_mode   = cnn_only
#   -> p_ensemble  = [0.94267213 0.02921605 0.02811141]
#   -> y_pred_cnn      = glioma
#   -> y_pred_lpips    = glioma
#   -> y_pred_ensemble = glioma
#
# [INFO] Saved patient-level results to: /content/drive/MyDrive/TESIS/xai_batch_testset/results_fusion_all.csv
#
# ================ METRICS ==================
# CNN baseline              ACC = 0.8382 | F1_macro = 0.8515
#
# ----- CNN baseline: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.9130    0.7241    0.8077        29
#   meningioma     0.6786    0.9048    0.7755        21
#    pituitary     1.0000    0.9444    0.9714        18
#
#     accuracy                         0.8382        68
#    macro avg     0.8639    0.8578    0.8515        68
# weighted avg     0.8637    0.8382    0.8411        68
#
# Confusion matrix (CNN baseline):
# [[21  8  0]
#  [ 2 19  0]
#  [ 0  1 17]]
# --------------------------------------
#
# LPIPS baseline            ACC = 0.7647 | F1_macro = 0.7566
#
# ----- LPIPS baseline: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7222    0.6190    0.6667        21
#    pituitary     0.7500    0.8333    0.7895        18
#
#     accuracy                         0.7647        68
#    macro avg     0.7574    0.7600    0.7566        68
# weighted avg     0.7627    0.7647    0.7618        68
#
# Confusion matrix (LPIPS baseline):
# [[24  2  3]
#  [ 6 13  2]
#  [ 0  3 15]]
# --------------------------------------
#
# Gated ensemble            ACC = 0.7794 | F1_macro = 0.7766
#
# ----- Gated ensemble: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.8519    0.7931    0.8214        29
#   meningioma     0.6818    0.7143    0.6977        21
#    pituitary     0.7895    0.8333    0.8108        18
#
#     accuracy                         0.7794        68
#    macro avg     0.7744    0.7802    0.7766        68
# weighted avg     0.7828    0.7794    0.7804        68
#
# Confusion matrix (Gated ensemble):
# [[23  4  2]
#  [ 4 15  2]
#  [ 0  3 15]]
# --------------------------------------
#
# Majority vote             ACC = 0.8088 | F1_macro = 0.8065
#
# ----- Majority vote: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.7714    0.9310    0.8438        29
#   meningioma     0.7222    0.6190    0.6667        21
#    pituitary     1.0000    0.8333    0.9091        18
#
#     accuracy                         0.8088        68
#    macro avg     0.8312    0.7945    0.8065        68
# weighted avg     0.8167    0.8088    0.8064        68
#
# Confusion matrix (Majority vote):
# [[27  2  0]
#  [ 8 13  0]
#  [ 0  3 15]]
# --------------------------------------
#
# Weighted majority         ACC = 0.8382 | F1_macro = 0.8515
#
# ----- Weighted majority: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.9130    0.7241    0.8077        29
#   meningioma     0.6786    0.9048    0.7755        21
#    pituitary     1.0000    0.9444    0.9714        18
#
#     accuracy                         0.8382        68
#    macro avg     0.8639    0.8578    0.8515        68
# weighted avg     0.8637    0.8382    0.8411        68
#
# Confusion matrix (Weighted majority):
# [[21  8  0]
#  [ 2 19  0]
#  [ 0  1 17]]
# --------------------------------------
#
# Bayes fusion              ACC = 0.7941 | F1_macro = 0.7917
#
# ----- Bayes fusion: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.8276    0.8276    0.8276        29
#   meningioma     0.7143    0.7143    0.7143        21
#    pituitary     0.8333    0.8333    0.8333        18
#
#     accuracy                         0.7941        68
#    macro avg     0.7917    0.7917    0.7917        68
# weighted avg     0.7941    0.7941    0.7941        68
#
# Confusion matrix (Bayes fusion):
# [[24  3  2]
#  [ 5 15  1]
#  [ 0  3 15]]
# --------------------------------------
#
# KL-based fusion           ACC = 0.7941 | F1_macro = 0.7951
#
# ----- KL-based fusion: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7000    0.6667    0.6829        21
#    pituitary     0.8889    0.8889    0.8889        18
#
#     accuracy                         0.7941        68
#    macro avg     0.7963    0.7944    0.7951        68
# weighted avg     0.7926    0.7941    0.7932        68
#
# Confusion matrix (KL-based fusion):
# [[24  4  1]
#  [ 6 14  1]
#  [ 0  2 16]]
# --------------------------------------
#
# Joint posterior           ACC = 0.7941 | F1_macro = 0.7951
#
# ----- Joint posterior: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.8000    0.8276    0.8136        29
#   meningioma     0.7000    0.6667    0.6829        21
#    pituitary     0.8889    0.8889    0.8889        18
#
#     accuracy                         0.7941        68
#    macro avg     0.7963    0.7944    0.7951        68
# weighted avg     0.7926    0.7941    0.7932        68
#
# Confusion matrix (Joint posterior):
# [[24  4  1]
#  [ 6 14  1]
#  [ 0  2 16]]
# --------------------------------------
#
# Dempster–Shafer           ACC = 0.7941 | F1_macro = 0.7917
#
# ----- Dempster–Shafer: per-class metrics -----
#               precision    recall  f1-score   support
#
#       glioma     0.8276    0.8276    0.8276        29
#   meningioma     0.7143    0.7143    0.7143        21
#    pituitary     0.8333    0.8333    0.8333        18
#
#     accuracy                         0.7941        68
#    macro avg     0.7917    0.7917    0.7917        68
# weighted avg     0.7941    0.7941    0.7941        68
#
# Confusion matrix (Dempster–Shafer):
# [[24  3  2]
#  [ 5 15  1]
#  [ 0  3 15]]
# --------------------------------------
#
#
# [INFO] Done. Metrics computed for:
#   - CNN baseline
#   - LPIPS baseline
#   - Gated ensemble
#   - Majority vote
#   - Weighted majority
#   - Bayes fusion
#   - KL-based fusion
#   - Joint posterior fusion
#   - Dempster–Shafer fusion

# %%
# ============================================================
# HIPERPARÁMETROS (EDITABLES FÁCILMENTE)
# ============================================================

FRAME_WEIGHTS = {...}
CLASS_WEIGHTS = {...}
LPIPS_TEMP = 0.2
ALPHA_CNN_GATED = 0.5
TAU_CNN = 0.80
TAU_LPIPS = 0.70
WEIGHT_CNN_MAJ = 0.5
WEIGHT_LPIPS_MAJ = 0.5
ALPHA_BAYES = 0.5
ALPHA_KL = 0.7
ALPHA_JOINT = 0.7

# %%
# meta_fusion_classifier.py
# -*- coding: utf-8 -*-
"""
Meta-classifier for decision-level fusion between CNN and LPIPS.

This script:
- Loads patient-level predictions from results_fusion_all.csv
  (produced by the fusion_cnn_lpips_all.py script).
- Builds feature vectors combining:
    * CNN probabilities
    * LPIPS probabilities
    * Max probabilities
    * Entropies
    * Absolute differences |p_cnn - p_lpips|
    * Disagreement indicator between CNN and LPIPS
- Trains a multinomial Logistic Regression meta-classifier
  using StratifiedKFold cross-validation at patient level.
- Reports:
    * Fold-wise accuracy and macro-F1
    * Mean accuracy and macro-F1
    * Per-class precision/recall/F1 (classification_report)
    * Confusion matrix for cross-validated predictions
"""

from pathlib import Path
from typing import List, Tuple, Dict

import numpy as np
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
)

# ============================================================
# CONFIG
# ============================================================

# Path to the CSV generated by your fusion script
INPUT_CSV = Path(
    "/content/drive/MyDrive/TESIS/xai_batch_testset/results_fusion_all.csv"
)

# Class names (same order as your main pipeline)
CLASS_NAMES = ["glioma", "meningioma", "pituitary"]


# ============================================================
# FEATURE ENGINEERING
# ============================================================

def compute_entropy(probs: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    """
    Compute entropy H(p) = -sum_c p_c log p_c for each sample.
    probs: array [N, C]
    Returns: array [N]
    """
    p = np.clip(probs, eps, 1.0)
    return -np.sum(p * np.log(p), axis=1)


def build_features(
    df: pd.DataFrame,
    class_names: List[str],
) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Build feature matrix X and label vector y from the patient-level CSV.

    Features per patient (row):
        - p_cnn_c for each class
        - p_lpips_c for each class
        - max_p_cnn
        - max_p_lpips
        - entropy_cnn
        - entropy_lpips
        - |p_cnn_c - p_lpips_c| for each class
        - disagreement_flag (1 if argmax differs, 0 otherwise)

    Returns:
        X: [N, D] float32
        y: [N] int labels
        patient_ids: [N] object array (for reference)
    """
    class_to_idx = {c: i for i, c in enumerate(class_names)}

    # Ground truth as integer labels
    y_col = df["y_true"]
    y = np.array([class_to_idx[str(v)] for v in y_col], dtype=int)

    # CNN and LPIPS probabilities
    p_cnn_list = []
    p_lpips_list = []
    for c in class_names:
        p_cnn_list.append(df[f"p_cnn_{c}"].astype(float).values)
        p_lpips_list.append(df[f"p_lpips_{c}"].astype(float).values)

    p_cnn = np.stack(p_cnn_list, axis=1)     # [N, C]
    p_lpips = np.stack(p_lpips_list, axis=1) # [N, C]

    # Max probabilities and argmax
    max_p_cnn = p_cnn.max(axis=1)            # [N]
    max_p_lpips = p_lpips.max(axis=1)        # [N]
    argmax_cnn = p_cnn.argmax(axis=1)        # [N]
    argmax_lpips = p_lpips.argmax(axis=1)    # [N]

    # Entropies
    H_cnn = compute_entropy(p_cnn)           # [N]
    H_lpips = compute_entropy(p_lpips)       # [N]

    # Absolute differences |p_cnn - p_lpips|
    abs_diff = np.abs(p_cnn - p_lpips)       # [N, C]

    # Disagreement flag
    disagree_flag = (argmax_cnn != argmax_lpips).astype(float)  # [N]

    # Stack all features
    # Order:
    #   [p_cnn (3), p_lpips (3), max_p_cnn, max_p_lpips,
    #    H_cnn, H_lpips, abs_diff (3), disagree_flag]
    features = [
        p_cnn,
        p_lpips,
        max_p_cnn[:, None],
        max_p_lpips[:, None],
        H_cnn[:, None],
        H_lpips[:, None],
        abs_diff,
        disagree_flag[:, None],
    ]
    X = np.concatenate(features, axis=1).astype(np.float32)  # [N, D]

    patient_ids = df["patient_id"].values

    return X, y, patient_ids


# ============================================================
# META-CLASSIFIER TRAINING (CROSS-VALIDATION)
# ============================================================

def run_meta_classifier(
    X: np.ndarray,
    y: np.ndarray,
    class_names: List[str],
    n_splits: int = 5,
    random_state: int = 42,
):
    """
    Train and evaluate a meta-classifier using StratifiedKFold.

    - Uses LogisticRegression (multinomial).
    - Reports fold-wise ACC and macro-F1.
    - Reports overall classification_report and confusion_matrix for
      cross-validated predictions.
    """
    skf = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=random_state,
    )

    all_y_true = []
    all_y_pred = []

    fold_metrics = []

    print(f"[INFO] Starting StratifiedKFold with {n_splits} splits...")
    fold_idx = 0

    for train_idx, test_idx in skf.split(X, y):
        fold_idx += 1
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        clf = LogisticRegression(
            multi_class="multinomial",
            solver="lbfgs",
            max_iter=1000,
        )
        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)

        acc = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average="macro")

        fold_metrics.append((acc, f1))

        all_y_true.append(y_test)
        all_y_pred.append(y_pred)

        print(f"[FOLD {fold_idx}] ACC = {acc:.4f} | F1_macro = {f1:.4f}")

    # Concatenate all folds
    all_y_true = np.concatenate(all_y_true, axis=0)
    all_y_pred = np.concatenate(all_y_pred, axis=0)

    # Global metrics
    mean_acc = np.mean([m[0] for m in fold_metrics])
    mean_f1 = np.mean([m[1] for m in fold_metrics])

    print("\n========== META-CLASSIFIER (LogReg) ==========")
    print(f"Mean ACC over folds      = {mean_acc:.4f}")
    print(f"Mean F1_macro over folds = {mean_f1:.4f}")

    print("\nPer-class metrics (cross-validated predictions):")
    print(classification_report(all_y_true, all_y_pred,
                                target_names=class_names,
                                digits=4))

    print("Confusion matrix (all folds):")
    print(confusion_matrix(all_y_true, all_y_pred))


# ============================================================
# MAIN
# ============================================================

def main():
    print(f"[INFO] Loading CSV from: {INPUT_CSV}")
    df = pd.read_csv(INPUT_CSV)

    print(f"[INFO] Number of patients: {len(df)}")

    # Build features and labels
    X, y, patient_ids = build_features(df, CLASS_NAMES)
    print(f"[INFO] Feature matrix shape: {X.shape}")
    print(f"[INFO] Labels shape: {y.shape}")

    # Train and evaluate meta-classifier
    run_meta_classifier(X, y, CLASS_NAMES, n_splits=5, random_state=42)


if __name__ == "__main__":
    main()
# Out:
# [INFO] Loading CSV from: /content/drive/MyDrive/TESIS/xai_batch_testset/results_fusion_all.csv
# [INFO] Number of patients: 68
# [INFO] Feature matrix shape: (68, 14)
# [INFO] Labels shape: (68,)
# [INFO] Starting StratifiedKFold with 5 splits...
# [FOLD 1] ACC = 0.7143 | F1_macro = 0.7281
# [FOLD 2] ACC = 0.8571 | F1_macro = 0.8667
# [FOLD 3] ACC = 0.8571 | F1_macro = 0.8222
# [FOLD 4] ACC = 0.6154 | F1_macro = 0.6223
# [FOLD 5] ACC = 0.8462 | F1_macro = 0.8611
#
# ========== META-CLASSIFIER (LogReg) ==========
# Mean ACC over folds      = 0.7780
# Mean F1_macro over folds = 0.7801
#
# Per-class metrics (cross-validated predictions):
#               precision    recall  f1-score   support
#
#       glioma     0.8148    0.7586    0.7857        29
#   meningioma     0.6667    0.7619    0.7111        21
#    pituitary     0.8824    0.8333    0.8571        18
#
#     accuracy                         0.7794        68
#    macro avg     0.7879    0.7846    0.7847        68
# weighted avg     0.7869    0.7794    0.7816        68
#
# Confusion matrix (all folds):
# [[22  5  2]
#  [ 5 16  0]
#  [ 0  3 15]]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
