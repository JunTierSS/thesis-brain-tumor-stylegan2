# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# !pip install gdown --upgrade

if os.path.isdir("/content/drive/MyDrive/colab-sg2-ada-pytorch"):
    # %cd "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/JunTierSS/stylegan2-ada
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/JunTierSS/stylegan2-ada
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/splits/by_patient_30test1/train.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/trainori_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/trainori.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/trainori.zip" -d "/content/localdata/trainori_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/trainori_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/trainori_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/trainori.zip
# Contenido de /content/localdata/trainori_unzipped
# total 120K
# drwxr-xr-x 5 root root 4.0K Dec 13 04:15 .
# drwxr-xr-x 3 root root 4.0K Dec 13 04:15 ..
# drwxr-xr-x 2 root root  48K Dec 13 04:15 glioma
# drwxr-xr-x 2 root root  28K Dec 13 04:15 meningioma
# drwxr-xr-x 2 root root  36K Dec 13 04:15 pituitary

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/splits/by_patient_30test1/test.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/testori_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/testori.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/testori.zip" -d "/content/localdata/testori_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/testori_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/testori_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/testori.zip
# Contenido de /content/localdata/testori_unzipped
# total 68K
# drwxr-xr-x 5 root root 4.0K Dec 13 04:15 .
# drwxr-xr-x 4 root root 4.0K Dec 13 04:15 ..
# drwxr-xr-x 2 root root  28K Dec 13 04:15 glioma
# drwxr-xr-x 2 root root  12K Dec 13 04:15 meningioma
# drwxr-xr-x 2 root root  20K Dec 13 04:15 pituitary

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/datasetinge/testreducido.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/test_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/test.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/test.zip" -d "/content/localdata/test_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/test_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/test_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/test.zip
# Contenido de /content/localdata/test_unzipped
# total 12K
# drwxr-xr-x 3 root root 4.0K Dec 13 04:15 .
# drwxr-xr-x 5 root root 4.0K Dec 13 04:15 ..
# drwxrwxrwx 5 root root 4.0K Nov 10 21:19 testreducido

# %%
# (2) Rutas
ZIP ="/content/drive/MyDrive/TESIS/datasetinge/trainreducido.zip"
DEST = "/content/localdata"                 # carpeta base local
UNZIP_DIR = f"{DEST}/train_unzipped"        # donde se extraerá el zip

import os, shutil, pathlib, subprocess

# (3) Crear carpeta destino y copiar el ZIP localmente (I/O mucho más rápido)
os.makedirs(DEST, exist_ok=True)
local_zip = f"{DEST}/train.zip"
shutil.copy2(ZIP, local_zip)
print("ZIP copiado a:", local_zip)

# (4) Descomprimir (silencioso, sobrescribe si ya existe)
os.makedirs(UNZIP_DIR, exist_ok=True)
# !unzip -q -o "/content/localdata/train.zip" -d "/content/localdata/train_unzipped"

# (5) (Opcional) eliminar carpeta __MACOSX si existe
# !find "/content/localdata/train_unzipped" -type d -name "__MACOSX" -prune -exec rm -rf {} +

# (6) Mostrar estructura principal para que ubiques DATA_ROOT / TEST_ROOT
print("Contenido de", UNZIP_DIR)
# !ls -lah "/content/localdata/train_unzipped" | head -n 50
# Out:
# ZIP copiado a: /content/localdata/train.zip
# Contenido de /content/localdata/train_unzipped
# total 12K
# drwxr-xr-x 3 root root 4.0K Dec 13 04:15 .
# drwxr-xr-x 6 root root 4.0K Dec 13 04:15 ..
# drwxrwxrwx 5 root root 4.0K Nov 10 21:19 trainreducido

# %%
pip install ninja
# Out:
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.13.0

# %%
pip install opensimplex
# Out:
# Collecting opensimplex
#   Downloading opensimplex-0.4.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from opensimplex) (2.0.2)
# Downloading opensimplex-0.4.5.1-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.4.5.1

# %%
import os, re, io, json, time, argparse, random, csv, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional

import numpy as np
from PIL import Image, ImageOps

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms, models
import torchvision.transforms.functional as TF
import torchvision

from sklearn.model_selection import StratifiedShuffleSplit

# %%
# -*- coding: utf-8 -*-
"""
K-Fold training (by patient) for brain tumor classification (ResNet50)
- No-leak by patient_id (groups)
- StratifiedGroupKFold if available; fallback to GroupKFold
- Optional StyleGAN2-ADA augmentation:
    * Real-only run (no GAN)
    * GAN-balanced run: para cada fold se agrega GAN hasta igualar la clase mayor (por nº de imágenes REALES)
- Per-fold metrics + CV summary
- OOF (out-of-fold) predictions & metrics (one row per pool sample, predicted by a model that didn't see it)
- External TEST evaluation per fold + K-fold ensemble (avg probs across folds)
- Full INTTEST metrics per fold + INTTEST ensemble, and CV summary with mean±std for VAL/INTTEST/TEST
- Optional final fine-tuning epochs using only REAL images (no GAN) per fold and in full-train

Author: Jun + ChatGPT
"""

import os, re, io, json, time, random, csv, math, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional
from dataclasses import dataclass, asdict

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support,
    classification_report, confusion_matrix
)

# ====== Splitters ======
try:
    from sklearn.model_selection import StratifiedGroupKFold
    HAS_SGTK = True
except Exception:
    HAS_SGTK = False
    from sklearn.model_selection import GroupKFold

# ====== Utils ======

def set_seed(seed: int = 42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
    try:
        torch.set_float32_matmul_precision("high")
    except Exception:
        pass

def timestamp() -> str:
    return time.strftime("%Y%m%d-%H%M%S")

def extract_patient_id(p: Path) -> str:
    stem = p.stem
    token = stem.split("_")[0]
    return token.strip().lower()

IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}

# ====== Config ======

@dataclass
class Config:
    data_root: str
    out_dir: str
    test_root: str = ""
    gan_pkl: str = ""
    images_per_class: int = 0        # sólo se usa si balance_gan_to_max=False
    truncation: float = 1.0
    internal_test_ratio: float = 0.0   # optional: holdout before CV
    image_size: int = 256
    batch_size: int = 32
    epochs: int = 15
    lr: float = 1e-3
    weight_decay: float = 1e-4
    num_workers: int = 4
    seed: int = 42
    kfolds: int = 5
    amp: bool = True
    pretrained: bool = True
    train_full_after_cv: bool = False   # optional: retrain on full pool at end

    # Fine-tuning final sólo con reales
    fine_tune_real_epochs: int = 0      # 0 = desactivado

    # NUEVO: balancear clases con GAN hasta la clase mayor de REALES
    balance_gan_to_max: bool = False

# ====== Dataset ======

class MRIDataset(Dataset):
    def __init__(self, items: List[Tuple[Path, int, str]], image_size: int = 256, aug: bool = False):
        self.items = items
        self.image_size = image_size
        self.aug = aug
        mean = [0.5, 0.5, 0.5]; std = [0.5, 0.5, 0.5]
        if aug:
            self.tf = transforms.Compose([
                transforms.RandomResizedCrop(image_size, scale=(0.9, 1.0), ratio=(0.95, 1.05)),
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.RandomRotation(10),
                transforms.ToTensor(),
            ])
        else:
            self.tf = transforms.Compose([
                transforms.Resize((image_size, image_size)),
                transforms.ToTensor(),
            ])
        self.norm = transforms.Normalize(mean=mean, std=std)

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        path, y, pid = self.items[idx]
        img = Image.open(path).convert("L")
        img = self.tf(img)           # [1,H,W]
        img = img.repeat(3, 1, 1)    # [3,H,W]
        img = self.norm(img)
        return img, y, str(path), pid

# ====== Scan & Helpers ======

def scan_folder(root: Path) -> Tuple[List[Tuple[Path,int,str]], List[str]]:
    assert root.is_dir(), f"Not a directory: {root}"
    class_names = sorted([d.name for d in root.iterdir() if d.is_dir()])
    items: List[Tuple[Path,int,str]] = []
    for ci, cname in enumerate(class_names):
        cdir = root / cname
        for p in cdir.rglob("*"):
            if p.suffix.lower() in IMG_EXTS:
                pid = extract_patient_id(p)
                items.append((p, ci, pid))
    return items, class_names

def ensure_no_overlap(ids_a: List[str], ids_b: List[str]) -> Tuple[int, List[str]]:
    a = set(ids_a); b = set(ids_b)
    inter = sorted(a.intersection(b))
    return len(inter), inter

def summarize_id_counts(items: List[Tuple[Path,int,str]], class_names: List[str], split_name: str, out_dir: Path):
    from collections import defaultdict
    ids_by_class = defaultdict(set); imgs_by_class = defaultdict(int); all_ids = set()
    for p, ci, pid in items:
        ids_by_class[ci].add(pid)
        imgs_by_class[ci] += 1
        all_ids.add(pid)

    print(f"[ID-STATS] {split_name}: unique patient IDs total = {len(all_ids)} | images = {len(items)}")
    for ci, cname in enumerate(class_names):
        print(f"  - {cname}: ids={len(ids_by_class[ci])} images={imgs_by_class[ci]}")

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"id_counts_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["class", "n_unique_ids", "n_images"])
        for ci, cname in enumerate(class_names):
            w.writerow([cname, len(ids_by_class[ci]), imgs_by_class[ci]])
        w.writerow(["__TOTAL__", len(all_ids), len(items)])

# ====== Model ======

def build_model(num_classes: int, pretrained: bool = True) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m

# ====== Eval (writes artifacts) ======

@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, device: torch.device, class_names: List[str], split_name: str, out_dir: Path):
    model.eval()
    all_probs, all_preds, all_labels = [], [], []
    all_paths, all_pids = [], []

    for imgs, ys, paths, pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        all_paths.extend(list(paths))
        all_pids.extend(list(pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, len(class_names)))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)

    acc = float(accuracy_score(labels, preds)) if len(labels) else 0.0
    prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)
    prec_weighted, rec_weighted, f1_weighted, _ = precision_recall_fscore_support(labels, preds, average='weighted', zero_division=0)
    per_class = classification_report(labels, preds, target_names=class_names, output_dict=True, zero_division=0)
    cm = confusion_matrix(labels, preds, labels=list(range(len(class_names))))

    metrics = {
        "overall": {
            "accuracy": acc,
            "precision_macro": prec_macro,
            "recall_macro": rec_macro,
            "f1_macro": f1_macro,
            "precision_weighted": prec_weighted,
            "recall_weighted": rec_weighted,
            "f1_weighted": f1_weighted,
            "num_samples": len(labels),
        },
        "per_class": per_class,
    }

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"metrics_{split_name}.json", 'w', encoding='utf-8') as f:
        json.dump(metrics, f, indent=2)

    with open(out_dir / f"metrics_overall_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro","precision_weighted","recall_weighted","f1_weighted","num_samples"])
        o = metrics['overall']
        w.writerow([split_name, o['accuracy'], o['precision_macro'], o['recall_macro'], o['f1_macro'],
                    o['precision_weighted'], o['recall_weighted'], o['f1_weighted'], o['num_samples']])

    with open(out_dir / f"per_class_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["class", "precision", "recall", "f1", "support"])
        for cname in class_names:
            row = per_class.get(cname, {"precision":0, "recall":0, "f1-score":0, "support":0})
            w.writerow([cname, row.get("precision",0), row.get("recall",0),
                        row.get("f1-score",0), row.get("support",0)])

    with open(out_dir / f"confusion_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["true\\pred"] + class_names)
        for i, cname in enumerate(class_names):
            w.writerow([cname] + list(cm[i]))

    with open(out_dir / f"predictions_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
        for i in range(len(labels)):
            w.writerow([all_paths[i], all_pids[i], class_names[labels[i]],
                        class_names[preds[i]]] + list(map(float, probs[i].tolist())))

    return metrics, cm

# Helper: fast inference to collect arrays (for OOF & ensemble)
@torch.no_grad()
def infer_loader(model: nn.Module, loader: DataLoader, device: torch.device):
    model.eval()
    paths, pids = [], []
    all_probs, all_preds, all_labels = [], [], []
    for imgs, ys, batch_paths, batch_pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        paths.extend(list(batch_paths))
        pids.extend(list(batch_pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, 0))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)
    return {"probs": probs, "preds": preds, "labels": labels, "paths": paths, "pids": pids}

# ====== Optional GAN loader (TRAIN only) ======

@torch.no_grad()
def _load_stylegan2_ada_G(gan_pkl: str, device: torch.device):
    try:
        import dnnlib
        from training import network as _dummy
        from legacy import load_network_pkl
    except Exception:
        try:
            from torch_utils import misc as _m  # noqa
            from torch_utils import training_stats as _ts  # noqa
            from legacy import load_network_pkl
        except Exception:
            return None
    try:
        with open(gan_pkl, 'rb') as f:
            data = load_network_pkl(f)
        G_ema = data.get('G_ema', None) or data.get('G', None)
        if G_ema is None:
            return None
        G_ema = G_ema.to(device)
        G_ema.eval()
        return G_ema
    except Exception:
        return None

@torch.no_grad()
def maybe_generate_gan_images(gan_pkl: str,
                              class_names: List[str],
                              n_per_class: int,
                              truncation: float,
                              out_dir: Path,
                              device: torch.device,
                              seed: int = 42) -> Optional[Path]:
    if (not gan_pkl) or n_per_class <= 0:
        return None
    G = _load_stylegan2_ada_G(gan_pkl, device)
    if G is None:
        print("[GAN] Could not load StyleGAN2-ADA G_ema. Skipping GAN augmentation.")
        return None
    if getattr(G, 'c_dim', 0) <= 0:
        print("[GAN] Generator is not conditional (c_dim=0). Skipping.")
        return None

    rng = np.random.RandomState(seed)
    synth_root = out_dir / "gan_synth"
    for cname in class_names:
        (synth_root / cname).mkdir(parents=True, exist_ok=True)

    batch = 16
    for ci, cname in enumerate(class_names):
        saved = 0
        while saved < n_per_class:
            bs = min(batch, n_per_class - saved)
            z = torch.from_numpy(rng.randn(bs, G.z_dim)).to(device)
            c = torch.zeros(bs, G.c_dim, device=device); c[:, ci] = 1.0
            try:
                img = G(z, c, truncation_psi=float(truncation), noise_mode='const')
            except TypeError:
                img = G(z, c, truncation_psi=float(truncation))
            img = (img * 127.5 + 128).clamp(0,255).to(torch.uint8).cpu()
            for k in range(bs):
                x = img[k]
                if x.shape[0] == 1:
                    arr = x[0].numpy()
                    pil = Image.fromarray(arr).convert('L')
                else:
                    arr = x.permute(1,2,0).numpy()
                    pil = Image.fromarray(arr).convert('L')
                fname = synth_root / cname / f"gan_{cname}_{saved+k:05d}.png"
                pil.save(fname)
            saved += bs
        print(f"[GAN] Saved {saved} images for class '{cname}'")
    return synth_root

def collate_fn(batch):
    imgs, ys, paths, pids = zip(*batch)
    return torch.stack(imgs, dim=0), torch.tensor(ys, dtype=torch.long), list(paths), list(pids)

# ====== Helper: construir subset balanceado real + GAN ======

def build_balanced_train_subset(real_train_subset: List[Tuple[Path,int,str]],
                                synth_items: List[Tuple[Path,int,str]],
                                num_classes: int,
                                seed: int) -> List[Tuple[Path,int,str]]:
    """
    Toma:
      - real_train_subset: sólo imágenes reales de ese fold
      - synth_items: TODAS las sintéticas (escaneadas desde gan_synth/)
    Devuelve:
      - lista con reales + suficientes GAN por clase para igualar la clase mayor (en REALES).
    """
    from collections import defaultdict

    # Reales por clase
    real_by_class: Dict[int, List[Tuple[Path,int,str]]] = defaultdict(list)
    for item in real_train_subset:
        _, ci, _ = item
        real_by_class[ci].append(item)

    # GAN por clase
    synth_by_class: Dict[int, List[Tuple[Path,int,str]]] = defaultdict(list)
    for item in synth_items:
        _, ci, _ = item
        synth_by_class[ci].append(item)

    # Target = tamaño de la clase mayor (sólo contando REALES)
    counts_real = [len(real_by_class[c]) for c in range(num_classes)]
    target = max(counts_real) if counts_real else 0
    print(f"[BAL] Real class counts (fold): {counts_real} -> target={target}")

    rng = random.Random(seed)
    balanced: List[Tuple[Path,int,str]] = list(real_train_subset)

    for ci in range(num_classes):
        need = target - len(real_by_class[ci])
        if need <= 0:
            continue
        pool = synth_by_class[ci]
        if not pool:
            print(f"[BAL] WARNING: no GAN images for class {ci}, cannot fully balance.")
            continue
        # muestramos con reemplazo si need > len(pool)
        for _ in range(need):
            balanced.append(rng.choice(pool))

    return balanced

# ====== K-Fold Train (CV + OOF + TEST + INTTEST ensemble) ======

def train_kfold(cfg: Config):
    if cfg.fine_tune_real_epochs < 0 or cfg.fine_tune_real_epochs > cfg.epochs:
        raise ValueError("fine_tune_real_epochs must be between 0 and cfg.epochs")

    base_run = Path(cfg.out_dir) / f"kfold_{cfg.kfolds}f_run_{timestamp()}"
    base_run.mkdir(parents=True, exist_ok=True)
    with open(base_run / 'config.json', 'w', encoding='utf-8') as f:
        json.dump(asdict(cfg), f, indent=2)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"[Device] Using {device}")

    # Scan pool
    all_items, class_names = scan_folder(Path(cfg.data_root))
    print(f"[Scan] Pool images: {len(all_items)} | Classes: {class_names}")

    # Optional internal-test holdout (by patient)
    inttest_subset: List[Tuple[Path,int,str]] = []
    if cfg.internal_test_ratio and cfg.internal_test_ratio > 0:
        from sklearn.model_selection import GroupShuffleSplit
        X_all = np.arange(len(all_items))
        y_all = np.array([lbl for _, lbl, _ in all_items])
        g_all = np.array([pid for _, _, pid in all_items])
        gss = GroupShuffleSplit(n_splits=1, test_size=cfg.internal_test_ratio, random_state=cfg.seed)
        trval_idx, inttest_idx = next(gss.split(X_all, y_all, g_all))
        base_pool = [all_items[i] for i in trval_idx]
        inttest_subset = [all_items[i] for i in inttest_idx]
        print(f"[Split] Internal test: {len(inttest_subset)} images ({cfg.internal_test_ratio*100:.1f}%)")
    else:
        base_pool = all_items

    # External test (leak-sanitized vs pool & internal test)
    ext_subset: List[Tuple[Path,int,str]] = []
    if cfg.test_root and len(cfg.test_root.strip()) > 0 and Path(cfg.test_root).exists():
        ext_items, _ = scan_folder(Path(cfg.test_root))
        ids_pool = set(pid for _,_,pid in base_pool)
        if len(inttest_subset) > 0:
            ids_pool |= set(pid for _,_,pid in inttest_subset)
        for it in ext_items:
            if it[2] not in ids_pool:
                ext_subset.append(it)
        removed = len(ext_items) - len(ext_subset)
        if removed > 0:
            print(f"[LEAK-FIX] Removed {removed} overlapping ext-test images by patient ID.")
        print(f"[Scan] External test images (sanitized): {len(ext_subset)}")

    # Build folds grouped by patient (SOLO con REALES)
    X = np.arange(len(base_pool))
    y = np.array([lbl for _, lbl, _ in base_pool])
    groups = np.array([pid for _, _, pid in base_pool])

    if cfg.kfolds < 2:
        raise ValueError("kfolds must be >= 2")

    if HAS_SGTK:
        splitter = StratifiedGroupKFold(n_splits=cfg.kfolds, shuffle=True, random_state=cfg.seed)
        folds_iter = list(splitter.split(X, y, groups))
        print("[Split] Using StratifiedGroupKFold")
    else:
        splitter = GroupKFold(n_splits=cfg.kfolds)
        folds_iter = list(splitter.split(X, groups=groups))
        print("[Split] Using GroupKFold (no stratification)")

    # ===== Pre-generate GAN synth una sola vez =====
    synth_items: List[Tuple[Path,int,str]] = []
    synth_root: Optional[Path] = None
    if cfg.gan_pkl and cfg.gan_pkl.strip():
        # si queremos balancear, ignoramos images_per_class y usamos el máximo global de REALES
        if cfg.balance_gan_to_max:
            from collections import defaultdict
            real_counts_global = defaultdict(int)
            for _, ci, _ in base_pool:
                real_counts_global[ci] += 1
            # Vector ordenado por índice de clase
            counts_vec = [real_counts_global[ci] for ci in range(len(class_names))]
            n_per_class = max(counts_vec) if counts_vec else 0
            print(f"[GAN] balance_gan_to_max=True -> global real counts per class = {counts_vec}, using n_per_class={n_per_class}")
        else:
            n_per_class = cfg.images_per_class

        if n_per_class > 0:
            synth_root = maybe_generate_gan_images(
                gan_pkl=cfg.gan_pkl,
                class_names=class_names,
                n_per_class=n_per_class,
                truncation=cfg.truncation,
                out_dir=base_run,
                device=device,
                seed=cfg.seed,
            )
            if synth_root is not None:
                synth_items, _ = scan_folder(synth_root)
                print(f"[GAN] Synth images generated (global): {len(synth_items)}")
        else:
            print("[GAN] n_per_class <= 0 -> no synthetic images will be generated.")
    else:
        print("[GAN] gan_pkl empty -> NO GAN will be used.")

    # Prepare fixed loaders for ensembles (TEST e INTTEST)
    test_loader_fixed: Optional[DataLoader] = None
    test_ref_paths = test_ref_pids = test_ref_labels = None
    if len(ext_subset) > 0:
        test_ds_fixed = MRIDataset(ext_subset, image_size=cfg.image_size, aug=False)
        test_loader_fixed = DataLoader(test_ds_fixed, batch_size=cfg.batch_size, shuffle=False,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        # Se rellenan luego con infer_loader

    inttest_loader_fixed: Optional[DataLoader] = None
    int_ref_paths = int_ref_pids = int_ref_labels = None
    if len(inttest_subset) > 0:
        int_ds_fixed = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
        inttest_loader_fixed = DataLoader(int_ds_fixed, batch_size=cfg.batch_size, shuffle=False,
                                          num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

    # ===== OOF buffers =====
    n_pool = len(base_pool)
    n_cls = len(class_names)
    oof_probs = np.full((n_pool, n_cls), np.nan, dtype=np.float32)
    oof_pred  = np.full((n_pool,), -1, dtype=np.int64)
    oof_true  = np.full((n_pool,), -1, dtype=np.int64)
    oof_path  = [""] * n_pool
    oof_pid   = [""] * n_pool

    # For ensembles
    test_probs_folds: List[np.ndarray] = []
    inttest_probs_folds: List[np.ndarray] = []

    # Per-fold training
    cv_rows = []
    for fold_id, (tr_idx, va_idx) in enumerate(folds_iter, start=1):
        print(f"\n===== FOLD {fold_id}/{cfg.kfolds} =====")
        set_seed(cfg.seed + fold_id)

        fold_dir = base_run / f"fold_{fold_id:02d}"
        fold_dir.mkdir(parents=True, exist_ok=True)

        # REAL train subset and VAL subset
        real_train_subset = [base_pool[i] for i in tr_idx]
        val_subset        = [base_pool[i] for i in va_idx]

        # Leak checks (sólo reales)
        ids_train = [pid for _,_,pid in real_train_subset]
        ids_val   = [pid for _,_,pid in val_subset]
        inter_n, inter_ids = ensure_no_overlap(ids_train, ids_val)
        if inter_n > 0:
            raise RuntimeError(f"[LEAK ERROR] Train↔Val share {inter_n} patient IDs (fold {fold_id}): {inter_ids[:10]}")

        if len(inttest_subset) > 0:
            ids_int = [pid for _,_,pid in inttest_subset]
            n1,_ = ensure_no_overlap(ids_train, ids_int)
            n2,_ = ensure_no_overlap(ids_val, ids_int)
            if n1>0 or n2>0:
                raise RuntimeError("[LEAK ERROR] Fold and INTTEST share patients")

        # ===== construir train_subset =====
        if cfg.balance_gan_to_max and len(synth_items) > 0:
            train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + fold_id,
            )
            print(f"[BAL] Fold {fold_id}: real={len(real_train_subset)} | train_balanced(real+GAN)={len(train_subset)}")
        else:
            # sin balanceo: opcionalmente append de todo synth_items
            train_subset = list(real_train_subset)
            if len(synth_items) > 0:
                train_subset = train_subset + synth_items
                print(f"[TRAIN] Fold {fold_id}: real={len(real_train_subset)} + synth={len(synth_items)} -> {len(train_subset)}")
            else:
                print(f"[TRAIN] Fold {fold_id}: only real images, n={len(real_train_subset)}")

        # Stats CSV
        summarize_id_counts(train_subset, class_names, f'fold{fold_id}_train', fold_dir)
        summarize_id_counts(val_subset,   class_names, f'fold{fold_id}_val',   fold_dir)
        if len(inttest_subset) > 0:
            summarize_id_counts(inttest_subset, class_names, f'fold{fold_id}_inttest', fold_dir)
        if len(ext_subset) > 0:
            summarize_id_counts(ext_subset,     class_names, f'fold{fold_id}_test',    fold_dir)

        # Loaders
        train_ds       = MRIDataset(train_subset,       image_size=cfg.image_size, aug=True)
        real_train_ds  = MRIDataset(real_train_subset,  image_size=cfg.image_size, aug=True)
        val_ds         = MRIDataset(val_subset,         image_size=cfg.image_size, aug=False)

        train_loader      = DataLoader(train_ds,      batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        real_train_loader = DataLoader(real_train_ds, batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        val_loader        = DataLoader(val_ds,        batch_size=cfg.batch_size, shuffle=False,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        inttest_loader = None
        if len(inttest_subset) > 0:
            int_ds = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
            inttest_loader = DataLoader(int_ds, batch_size=cfg.batch_size, shuffle=False,
                                        num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        # Para TEST por fold usamos loader fijo
        test_loader = test_loader_fixed

        # Model/optim
        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()

        amp_enabled = (cfg.amp and device.type == 'cuda')
        scaler = torch.amp.GradScaler('cuda', enabled=amp_enabled)

        best_f1 = -1.0

        # Epoch split: main (train_subset) + fine-tuning (real only)
        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft   = cfg.fine_tune_real_epochs

        # ----- Phase 1: train con train_subset (real + GAN o sólo real) -----
        for epoch in range(1, epochs_main + 1):
            model.train()
            running_loss = 0.0; n_seen = 0
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(model, val_loader, device, class_names,
                                split_name='val', out_dir=fold_dir)
            f1_macro = m_val['overall']['f1_macro']
            acc_val  = m_val['overall']['accuracy']
            print(f"[Fold {fold_id} | Epoch {epoch:03d}] "
                  f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}")

            torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                       fold_dir / 'last.ckpt')

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                           fold_dir / 'best.ckpt')
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved.")

        # ----- Phase 2: fine-tuning sólo con REALES -----
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            running_loss = 0.0; n_seen = 0
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(model, val_loader, device, class_names,
                                split_name='val', out_dir=fold_dir)
            f1_macro = m_val['overall']['f1_macro']
            acc_val  = m_val['overall']['accuracy']
            print(f"[Fold {fold_id} | FT Epoch {epoch:03d}] "
                  f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}")

            torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                       fold_dir / 'last.ckpt')

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                           fold_dir / 'best.ckpt')
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved (fine-tune).")

        # Re-eval BEST and collect OOF for this fold
        best = torch.load(fold_dir / 'best.ckpt', map_location=device)
        model.load_state_dict(best['model'])

        print(f"[Fold {fold_id}] Re-evaluating BEST on VAL (and collecting OOF)...")
        m_val_best, _ = evaluate(model, val_loader, device, class_names,
                                 split_name='val_best', out_dir=fold_dir)

        # Collect arrays for OOF
        val_inf = infer_loader(model, val_loader, device)  # same order as val_subset (shuffle=False)
        for j, base_i in enumerate(va_idx):
            oof_probs[base_i] = val_inf["probs"][j]
            oof_pred[base_i]  = int(val_inf["preds"][j])
            oof_true[base_i]  = int(val_inf["labels"][j])
            oof_path[base_i]  = val_inf["paths"][j]
            oof_pid[base_i]   = val_inf["pids"][j]

        # Row base with full VAL metrics
        row = {
            "fold": fold_id,
            "val_acc": m_val_best["overall"]["accuracy"],
            "val_precision_macro": m_val_best["overall"]["precision_macro"],
            "val_recall_macro": m_val_best["overall"]["recall_macro"],
            "val_f1_macro": m_val_best["overall"]["f1_macro"],
            "val_precision_weighted": m_val_best["overall"]["precision_weighted"],
            "val_recall_weighted": m_val_best["overall"]["recall_weighted"],
            "val_f1_weighted": m_val_best["overall"]["f1_weighted"],
            "val_n": m_val_best["overall"]["num_samples"],
        }

        # INTERNAL TEST per fold + probs for ensemble
        if inttest_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on INTERNAL TEST...")
            m_int, _ = evaluate(model, inttest_loader, device, class_names,
                                split_name='inttest', out_dir=fold_dir)
            row.update({
                "int_acc": m_int["overall"]["accuracy"],
                "int_precision_macro": m_int["overall"]["precision_macro"],
                "int_recall_macro": m_int["overall"]["recall_macro"],
                "int_f1_macro": m_int["overall"]["f1_macro"],
                "int_precision_weighted": m_int["overall"]["precision_weighted"],
                "int_recall_weighted": m_int["overall"]["recall_weighted"],
                "int_f1_weighted": m_int["overall"]["f1_weighted"],
                "int_n": m_int["overall"]["num_samples"],
            })
            t_int = infer_loader(model, inttest_loader, device)
            inttest_probs_folds.append(t_int["probs"])
            if int_ref_paths is None:
                int_ref_paths  = t_int["paths"]
                int_ref_pids   = t_int["pids"]
                int_ref_labels = t_int["labels"]

        # EXTERNAL TEST per fold + probs for ensemble
        if test_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on EXTERNAL TEST...")
            m_ext, _ = evaluate(model, test_loader, device, class_names,
                                split_name='test', out_dir=fold_dir)
            row.update({
                "test_acc": m_ext["overall"]["accuracy"],
                "test_precision_macro": m_ext["overall"]["precision_macro"],
                "test_recall_macro": m_ext["overall"]["recall_macro"],
                "test_f1_macro": m_ext["overall"]["f1_macro"],
                "test_precision_weighted": m_ext["overall"]["precision_weighted"],
                "test_recall_weighted": m_ext["overall"]["recall_weighted"],
                "test_f1_weighted": m_ext["overall"]["f1_weighted"],
                "test_n": m_ext["overall"]["num_samples"],
            })
            t_inf = infer_loader(model, test_loader, device)
            test_probs_folds.append(t_inf["probs"])
            if test_ref_paths is None:
                test_ref_paths  = t_inf["paths"]
                test_ref_pids   = t_inf["pids"]
                test_ref_labels = t_inf["labels"]

        cv_rows.append(row)

    # === CV summary (mean ± std) ===
    summary_csv = base_run / "cv_summary.csv"
    keys = sorted(set().union(*[r.keys() for r in cv_rows]))
    with open(summary_csv, 'w', newline='', encoding='utf-8') as f:
        w = csv.DictWriter(f, fieldnames=keys)
        w.writeheader()
        for r in cv_rows:
            w.writerow(r)

    def _agg_for(prefix: str) -> Dict[str, Tuple[Optional[float], Optional[float]]]:
        metrics = ["acc","precision_macro","recall_macro","f1_macro",
                   "precision_weighted","recall_weighted","f1_weighted"]
        out: Dict[str, Tuple[Optional[float], Optional[float]]] = {}
        for m in metrics:
            col = f"{prefix}_{m}"
            vals = [float(r[col]) for r in cv_rows if col in r]
            if len(vals) == 0:
                out[m] = (None, None)
            else:
                out[m] = (float(np.mean(vals)), float(np.std(vals)))
        return out

    cv_stats_full = {
        "kfolds": cfg.kfolds,
        "val":     _agg_for("val"),
        "inttest": _agg_for("int") if any(("int_acc" in r) for r in cv_rows) else {},
        "test":    _agg_for("test") if any(("test_acc" in r) for r in cv_rows) else {},
    }
    with open(base_run / "cv_summary_full.json", 'w', encoding='utf-8') as f:
        json.dump(cv_stats_full, f, indent=2)

    with open(base_run / "cv_summary_full.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["split","metric","mean","std","k"])
        for split in ["val","inttest","test"]:
            if split not in cv_stats_full or not cv_stats_full[split]:
                continue
            for metric, (mu, sd) in cv_stats_full[split].items():
                if mu is None:
                    continue
                w.writerow([split, metric, mu, sd, cfg.kfolds])

    print("[CV] Summary (mean±std) written to cv_summary_full.{json,csv}")

    # === OOF metrics & artifacts ===
    valid_mask = (~np.isnan(oof_probs).any(axis=1)) & (oof_true != -1)
    oof_probs_v = oof_probs[valid_mask]
    oof_pred_v  = oof_pred[valid_mask]
    oof_true_v  = oof_true[valid_mask]
    oof_path_v  = [oof_path[i] for i, ok in enumerate(valid_mask) if ok]
    oof_pid_v   = [oof_pid[i]  for i, ok in enumerate(valid_mask) if ok]

    if len(oof_true_v) > 0:
        acc = float(accuracy_score(oof_true_v, oof_pred_v))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average='weighted', zero_division=0)
        per_class = classification_report(
            oof_true_v, oof_pred_v, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(oof_true_v, oof_pred_v, labels=list(range(len(class_names))))

        oof_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(oof_true_v)),
            },
            "per_class": per_class,
        }
        with open(base_run / "oof_metrics.json", 'w', encoding='utf-8') as f:
            json.dump(oof_metrics, f, indent=2)

        with open(base_run / "metrics_overall_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = oof_metrics['overall']
            w.writerow(["oof", o['accuracy'], o['precision_macro'], o['recall_macro'],
                        o['f1_macro'], o['precision_weighted'], o['recall_weighted'],
                        o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "oof_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(oof_true_v)):
                w.writerow([oof_path_v[i], oof_pid_v[i],
                            class_names[oof_true_v[i]],
                            class_names[oof_pred_v[i]]] +
                           list(map(float, oof_probs_v[i].tolist())))

    # === TEST ensemble (avg across folds) ===
    if test_loader_fixed is not None and len(test_probs_folds) > 0:
        probs_stack = np.stack(test_probs_folds, axis=0)     # [K, N_test, C]
        probs_mean  = probs_stack.mean(axis=0)               # [N_test, C]
        preds_ens   = probs_mean.argmax(axis=1)

        acc = float(accuracy_score(test_ref_labels, preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average='weighted', zero_division=0)
        per_class = classification_report(
            test_ref_labels, preds_ens, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(test_ref_labels, preds_ens, labels=list(range(len(class_names))))

        test_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(test_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_test_ensemble.json", 'w', encoding='utf-8') as f:
            json.dump(test_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = test_ens_metrics['overall']
            w.writerow(["test_ensemble", o['accuracy'], o['precision_macro'],
                        o['recall_macro'], o['f1_macro'], o['precision_weighted'],
                        o['recall_weighted'], o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "test_ensemble_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(test_ref_labels)):
                w.writerow([test_ref_paths[i], test_ref_pids[i],
                            class_names[int(test_ref_labels[i])],
                            class_names[int(preds_ens[i])]] +
                           list(map(float, probs_mean[i].tolist())))

    # === INTTEST ensemble (avg across folds) ===
    if inttest_loader_fixed is not None and len(inttest_probs_folds) > 0:
        int_probs_stack = np.stack(inttest_probs_folds, axis=0)  # [K, N_int, C]
        int_probs_mean  = int_probs_stack.mean(axis=0)           # [N_int, C]
        int_preds_ens   = int_probs_mean.argmax(axis=1)

        acc = float(accuracy_score(int_ref_labels, int_preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average='weighted', zero_division=0)
        per_class = classification_report(
            int_ref_labels, int_preds_ens, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(int_ref_labels, int_preds_ens, labels=list(range(len(class_names))))

        int_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(int_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_inttest_ensemble.json", 'w', encoding='utf-8') as f:
            json.dump(int_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = int_ens_metrics['overall']
            w.writerow(["inttest_ensemble", o['accuracy'], o['precision_macro'],
                        o['recall_macro'], o['f1_macro'], o['precision_weighted'],
                        o['recall_weighted'], o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "inttest_ensemble_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(int_ref_labels)):
                w.writerow([int_ref_paths[i], int_ref_pids[i],
                            class_names[int(int_ref_labels[i])],
                            class_names[int(int_preds_ens[i])]] +
                           list(map(float, int_probs_mean[i].tolist())))

    # (Optional) train on FULL pool and evaluate test once
    if cfg.train_full_after_cv:
        print("\n[Full Train] Training with full pool (no internal test)...")
        run_full = base_run / "full_train"
        run_full.mkdir(parents=True, exist_ok=True)

        real_train_subset = list(base_pool)

        if cfg.balance_gan_to_max and len(synth_items) > 0:
            full_train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + 999,
            )
            print(f"[Full Train] real={len(real_train_subset)} | train_balanced(real+GAN)={len(full_train_subset)}")
        else:
            full_train_subset = real_train_subset + (synth_items if len(synth_items) > 0 else [])
            print(f"[Full Train] real={len(real_train_subset)} + synth={len(synth_items)} -> {len(full_train_subset)}")

        train_ds      = MRIDataset(full_train_subset, image_size=cfg.image_size, aug=False)
        real_train_ds = MRIDataset(real_train_subset, image_size=cfg.image_size, aug=False)

        train_loader      = DataLoader(train_ds,      batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        real_train_loader = DataLoader(real_train_ds, batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()
        amp_enabled = (cfg.amp and device.type == 'cuda')
        scaler = torch.amp.GradScaler('cuda', enabled=amp_enabled)

        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft   = cfg.fine_tune_real_epochs

        # Full-train Phase 1: full_train_subset (real + synth balanceado o no)
        for epoch in range(1, epochs_main + 1):
            model.train()
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        # Full-train Phase 2: sólo reales
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        torch.save({'model': model.state_dict(), 'class_names': class_names},
                   run_full / 'final_full.ckpt')

        if test_loader_fixed is not None:
            print("[Full Train] Evaluating on TEST ...")
            evaluate(model, test_loader_fixed, device, class_names,
                     split_name='test_full', out_dir=run_full)

    print(f"\n[Artifacts] Saved at: {base_run}")
    return base_run

# %% [markdown]
# #data leakage example

# %%
    def run_real_only():
        cfg_real = Config(
    data_root="/content/localdata/testori_unzipped",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1leak",
            balance_gan_to_max=False,   # ignorado porque no hay gan_pkl
            fine_tune_real_epochs=0,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds=5)
        return train_kfold(cfg_real)



    resultado = run_real_only()
    print("Run finished, artifacts at:", resultado)
# Out:
# [Device] Using cuda
# [Scan] Pool images: 911 | Classes: ['glioma', 'meningioma', 'pituitary']
# [LEAK-FIX] Removed 702 overlapping ext-test images by patient ID.
# [Scan] External test images (sanitized): 0
# [Split] Using StratifiedGroupKFold
# [GAN] gan_pkl empty -> NO GAN will be used.
#
# ===== FOLD 1/5 =====
# [TRAIN] Fold 1: only real images, n=673
# [ID-STATS] fold1_train: unique patient IDs total = 55 | images = 673
#   - glioma: ids=24 images=336
#   - meningioma: ids=18 images=143
#   - pituitary: ids=13 images=194
# [ID-STATS] fold1_val: unique patient IDs total = 15 | images = 238
#   - glioma: ids=6 images=110
#   - meningioma: ids=4 images=51
#   - pituitary: ids=5 images=77
# [Fold 1 | Epoch 001] train_loss=0.4829 | val_acc=0.7521 | val_f1_macro=0.6870
# [Fold 1] New best (F1_macro=0.6870) saved.
# [Fold 1 | Epoch 002] train_loss=0.1576 | val_acc=0.8866 | val_f1_macro=0.8684
# [Fold 1] New best (F1_macro=0.8684) saved.
# [Fold 1 | Epoch 003] train_loss=0.0920 | val_acc=0.8824 | val_f1_macro=0.8436
# [Fold 1 | Epoch 004] train_loss=0.0847 | val_acc=0.8782 | val_f1_macro=0.8283
# [Fold 1 | Epoch 005] train_loss=0.0874 | val_acc=0.8697 | val_f1_macro=0.8488
# [Fold 1 | Epoch 006] train_loss=0.0442 | val_acc=0.8866 | val_f1_macro=0.8567
# [Fold 1 | Epoch 007] train_loss=0.0260 | val_acc=0.8908 | val_f1_macro=0.8508
# [Fold 1 | Epoch 008] train_loss=0.0214 | val_acc=0.8571 | val_f1_macro=0.8068
# [Fold 1 | Epoch 009] train_loss=0.0074 | val_acc=0.8739 | val_f1_macro=0.8287
# [Fold 1 | Epoch 010] train_loss=0.0189 | val_acc=0.8697 | val_f1_macro=0.8272
# [Fold 1 | Epoch 011] train_loss=0.0267 | val_acc=0.8824 | val_f1_macro=0.8402
# [Fold 1 | Epoch 012] train_loss=0.0138 | val_acc=0.8950 | val_f1_macro=0.8607
# [Fold 1 | Epoch 013] train_loss=0.0089 | val_acc=0.8782 | val_f1_macro=0.8424
# [Fold 1 | Epoch 014] train_loss=0.0065 | val_acc=0.8908 | val_f1_macro=0.8594
# [Fold 1 | Epoch 015] train_loss=0.0071 | val_acc=0.8950 | val_f1_macro=0.8594
# [Fold 1 | Epoch 016] train_loss=0.0048 | val_acc=0.8992 | val_f1_macro=0.8626
# [Fold 1 | Epoch 017] train_loss=0.0081 | val_acc=0.8908 | val_f1_macro=0.8506
# [Fold 1 | Epoch 018] train_loss=0.0087 | val_acc=0.8866 | val_f1_macro=0.8515
# [Fold 1 | Epoch 019] train_loss=0.0046 | val_acc=0.8908 | val_f1_macro=0.8561
# [Fold 1 | Epoch 020] train_loss=0.0056 | val_acc=0.8739 | val_f1_macro=0.8358
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 2/5 =====
# [TRAIN] Fold 2: only real images, n=795
# [ID-STATS] fold2_train: unique patient IDs total = 57 | images = 795
#   - glioma: ids=23 images=366
#   - meningioma: ids=17 images=169
#   - pituitary: ids=17 images=260
# [ID-STATS] fold2_val: unique patient IDs total = 13 | images = 116
#   - glioma: ids=7 images=80
#   - meningioma: ids=5 images=25
#   - pituitary: ids=1 images=11
# [Fold 2 | Epoch 001] train_loss=0.4382 | val_acc=0.8448 | val_f1_macro=0.7935
# [Fold 2] New best (F1_macro=0.7935) saved.
# [Fold 2 | Epoch 002] train_loss=0.1074 | val_acc=0.9052 | val_f1_macro=0.9050
# [Fold 2] New best (F1_macro=0.9050) saved.
# [Fold 2 | Epoch 003] train_loss=0.0740 | val_acc=0.8879 | val_f1_macro=0.8810
# [Fold 2 | Epoch 004] train_loss=0.1022 | val_acc=0.8879 | val_f1_macro=0.8733
# [Fold 2 | Epoch 005] train_loss=0.0502 | val_acc=0.8793 | val_f1_macro=0.8436
# [Fold 2 | Epoch 006] train_loss=0.0234 | val_acc=0.8879 | val_f1_macro=0.8648
# [Fold 2 | Epoch 007] train_loss=0.0252 | val_acc=0.8362 | val_f1_macro=0.7790
# [Fold 2 | Epoch 008] train_loss=0.0236 | val_acc=0.8879 | val_f1_macro=0.8699
# [Fold 2 | Epoch 009] train_loss=0.0141 | val_acc=0.8793 | val_f1_macro=0.8576
# [Fold 2 | Epoch 010] train_loss=0.0154 | val_acc=0.8621 | val_f1_macro=0.8433
# [Fold 2 | Epoch 011] train_loss=0.0163 | val_acc=0.8362 | val_f1_macro=0.8130
# [Fold 2 | Epoch 012] train_loss=0.0095 | val_acc=0.8621 | val_f1_macro=0.8604
# [Fold 2 | Epoch 013] train_loss=0.0066 | val_acc=0.8793 | val_f1_macro=0.8888
# [Fold 2 | Epoch 014] train_loss=0.0073 | val_acc=0.9052 | val_f1_macro=0.9117
# [Fold 2] New best (F1_macro=0.9117) saved.
# [Fold 2 | Epoch 015] train_loss=0.0071 | val_acc=0.9052 | val_f1_macro=0.9117
# [Fold 2 | Epoch 016] train_loss=0.0064 | val_acc=0.8966 | val_f1_macro=0.9003
# [Fold 2 | Epoch 017] train_loss=0.0030 | val_acc=0.8966 | val_f1_macro=0.9003
# [Fold 2 | Epoch 018] train_loss=0.0026 | val_acc=0.8966 | val_f1_macro=0.9003
# [Fold 2 | Epoch 019] train_loss=0.0046 | val_acc=0.8966 | val_f1_macro=0.9026
# [Fold 2 | Epoch 020] train_loss=0.0031 | val_acc=0.8966 | val_f1_macro=0.9026
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 3/5 =====
# [TRAIN] Fold 3: only real images, n=703
# [ID-STATS] fold3_train: unique patient IDs total = 55 | images = 703
#   - glioma: ids=22 images=340
#   - meningioma: ids=18 images=136
#   - pituitary: ids=15 images=227
# [ID-STATS] fold3_val: unique patient IDs total = 15 | images = 208
#   - glioma: ids=8 images=106
#   - meningioma: ids=4 images=58
#   - pituitary: ids=3 images=44
# [Fold 3 | Epoch 001] train_loss=0.4346 | val_acc=0.7115 | val_f1_macro=0.6338
# [Fold 3] New best (F1_macro=0.6338) saved.
# [Fold 3 | Epoch 002] train_loss=0.2365 | val_acc=0.7788 | val_f1_macro=0.7291
# [Fold 3] New best (F1_macro=0.7291) saved.
# [Fold 3 | Epoch 003] train_loss=0.1290 | val_acc=0.9231 | val_f1_macro=0.9274
# [Fold 3] New best (F1_macro=0.9274) saved.
# [Fold 3 | Epoch 004] train_loss=0.0701 | val_acc=0.8990 | val_f1_macro=0.9034
# [Fold 3 | Epoch 005] train_loss=0.0564 | val_acc=0.8942 | val_f1_macro=0.8997
# [Fold 3 | Epoch 006] train_loss=0.0658 | val_acc=0.9231 | val_f1_macro=0.9265
# [Fold 3 | Epoch 007] train_loss=0.0383 | val_acc=0.9471 | val_f1_macro=0.9508
# [Fold 3] New best (F1_macro=0.9508) saved.
# [Fold 3 | Epoch 008] train_loss=0.0246 | val_acc=0.9279 | val_f1_macro=0.9330
# [Fold 3 | Epoch 009] train_loss=0.0123 | val_acc=0.9327 | val_f1_macro=0.9382
# [Fold 3 | Epoch 010] train_loss=0.0126 | val_acc=0.9279 | val_f1_macro=0.9328
# [Fold 3 | Epoch 011] train_loss=0.0145 | val_acc=0.9423 | val_f1_macro=0.9458
# [Fold 3 | Epoch 012] train_loss=0.0096 | val_acc=0.9375 | val_f1_macro=0.9420
# [Fold 3 | Epoch 013] train_loss=0.0073 | val_acc=0.9423 | val_f1_macro=0.9474
# [Fold 3 | Epoch 014] train_loss=0.0149 | val_acc=0.9519 | val_f1_macro=0.9547
# [Fold 3] New best (F1_macro=0.9547) saved.
# [Fold 3 | Epoch 015] train_loss=0.0066 | val_acc=0.9471 | val_f1_macro=0.9505
# [Fold 3 | Epoch 016] train_loss=0.0032 | val_acc=0.9471 | val_f1_macro=0.9505
# [Fold 3 | Epoch 017] train_loss=0.0039 | val_acc=0.9471 | val_f1_macro=0.9505
# [Fold 3 | Epoch 018] train_loss=0.0070 | val_acc=0.9423 | val_f1_macro=0.9462
# [Fold 3 | Epoch 019] train_loss=0.0100 | val_acc=0.9423 | val_f1_macro=0.9471
# [Fold 3 | Epoch 020] train_loss=0.0039 | val_acc=0.9423 | val_f1_macro=0.9466
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 4/5 =====
# [TRAIN] Fold 4: only real images, n=737
# [ID-STATS] fold4_train: unique patient IDs total = 56 | images = 737
#   - glioma: ids=24 images=331
#   - meningioma: ids=17 images=171
#   - pituitary: ids=15 images=235
# [ID-STATS] fold4_val: unique patient IDs total = 14 | images = 174
#   - glioma: ids=6 images=115
#   - meningioma: ids=5 images=23
#   - pituitary: ids=3 images=36
# [Fold 4 | Epoch 001] train_loss=0.4531 | val_acc=0.9195 | val_f1_macro=0.8930
# [Fold 4] New best (F1_macro=0.8930) saved.
# [Fold 4 | Epoch 002] train_loss=0.1529 | val_acc=0.9310 | val_f1_macro=0.8739
# [Fold 4 | Epoch 003] train_loss=0.1081 | val_acc=0.8908 | val_f1_macro=0.8246
# [Fold 4 | Epoch 004] train_loss=0.0719 | val_acc=0.9483 | val_f1_macro=0.9290
# [Fold 4] New best (F1_macro=0.9290) saved.
# [Fold 4 | Epoch 005] train_loss=0.0575 | val_acc=0.8736 | val_f1_macro=0.7685
# [Fold 4 | Epoch 006] train_loss=0.0601 | val_acc=0.9310 | val_f1_macro=0.8800
# [Fold 4 | Epoch 007] train_loss=0.0354 | val_acc=0.9195 | val_f1_macro=0.8718
# [Fold 4 | Epoch 008] train_loss=0.0261 | val_acc=0.9483 | val_f1_macro=0.9163
# [Fold 4 | Epoch 009] train_loss=0.0211 | val_acc=0.9483 | val_f1_macro=0.9085
# [Fold 4 | Epoch 010] train_loss=0.0171 | val_acc=0.9310 | val_f1_macro=0.8870
# [Fold 4 | Epoch 011] train_loss=0.0161 | val_acc=0.9655 | val_f1_macro=0.9511
# [Fold 4] New best (F1_macro=0.9511) saved.
# [Fold 4 | Epoch 012] train_loss=0.0113 | val_acc=0.9655 | val_f1_macro=0.9382
# [Fold 4 | Epoch 013] train_loss=0.0107 | val_acc=0.9770 | val_f1_macro=0.9614
# [Fold 4] New best (F1_macro=0.9614) saved.
# [Fold 4 | Epoch 014] train_loss=0.0083 | val_acc=0.9598 | val_f1_macro=0.9314
# [Fold 4 | Epoch 015] train_loss=0.0094 | val_acc=0.9310 | val_f1_macro=0.8815
# [Fold 4 | Epoch 016] train_loss=0.0192 | val_acc=0.9713 | val_f1_macro=0.9497
# [Fold 4 | Epoch 017] train_loss=0.0062 | val_acc=0.9483 | val_f1_macro=0.9126
# [Fold 4 | Epoch 018] train_loss=0.0061 | val_acc=0.9713 | val_f1_macro=0.9497
# [Fold 4 | Epoch 019] train_loss=0.0056 | val_acc=0.9713 | val_f1_macro=0.9497
# [Fold 4 | Epoch 020] train_loss=0.0053 | val_acc=0.9655 | val_f1_macro=0.9431
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 5/5 =====
# [TRAIN] Fold 5: only real images, n=736
# [ID-STATS] fold5_train: unique patient IDs total = 57 | images = 736
#   - glioma: ids=27 images=411
#   - meningioma: ids=18 images=157
#   - pituitary: ids=12 images=168
# [ID-STATS] fold5_val: unique patient IDs total = 13 | images = 175
#   - glioma: ids=3 images=35
#   - meningioma: ids=4 images=37
#   - pituitary: ids=6 images=103
# [Fold 5 | Epoch 001] train_loss=0.4729 | val_acc=0.8571 | val_f1_macro=0.7671
# [Fold 5] New best (F1_macro=0.7671) saved.
# [Fold 5 | Epoch 002] train_loss=0.1902 | val_acc=0.8686 | val_f1_macro=0.7813
# [Fold 5] New best (F1_macro=0.7813) saved.
# [Fold 5 | Epoch 003] train_loss=0.1190 | val_acc=0.7771 | val_f1_macro=0.7069
# [Fold 5 | Epoch 004] train_loss=0.0835 | val_acc=0.8914 | val_f1_macro=0.8252
# [Fold 5] New best (F1_macro=0.8252) saved.
# [Fold 5 | Epoch 005] train_loss=0.0717 | val_acc=0.8914 | val_f1_macro=0.8232
# [Fold 5 | Epoch 006] train_loss=0.0528 | val_acc=0.8800 | val_f1_macro=0.8009
# [Fold 5 | Epoch 007] train_loss=0.0523 | val_acc=0.8743 | val_f1_macro=0.7949
# [Fold 5 | Epoch 008] train_loss=0.0260 | val_acc=0.8857 | val_f1_macro=0.8125
# [Fold 5 | Epoch 009] train_loss=0.0129 | val_acc=0.8743 | val_f1_macro=0.7883
# [Fold 5 | Epoch 010] train_loss=0.0139 | val_acc=0.8857 | val_f1_macro=0.8075
# [Fold 5 | Epoch 011] train_loss=0.0089 | val_acc=0.8800 | val_f1_macro=0.8037
# [Fold 5 | Epoch 012] train_loss=0.0072 | val_acc=0.8629 | val_f1_macro=0.7714
# [Fold 5 | Epoch 013] train_loss=0.0098 | val_acc=0.8800 | val_f1_macro=0.8044
# [Fold 5 | Epoch 014] train_loss=0.0080 | val_acc=0.8971 | val_f1_macro=0.8322
# [Fold 5] New best (F1_macro=0.8322) saved.
# [Fold 5 | Epoch 015] train_loss=0.0045 | val_acc=0.8914 | val_f1_macro=0.8245
# [Fold 5 | Epoch 016] train_loss=0.0036 | val_acc=0.8800 | val_f1_macro=0.8011
# [Fold 5 | Epoch 017] train_loss=0.0052 | val_acc=0.8800 | val_f1_macro=0.7989
# [Fold 5 | Epoch 018] train_loss=0.0027 | val_acc=0.8800 | val_f1_macro=0.7989
# [Fold 5 | Epoch 019] train_loss=0.0042 | val_acc=0.8800 | val_f1_macro=0.7989
# [Fold 5 | Epoch 020] train_loss=0.0110 | val_acc=0.8800 | val_f1_macro=0.7989
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [Full Train] real=911 + synth=0 -> 911
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1leak/kfold_5f_run_20251129-044948
# Run finished, artifacts at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1leak/kfold_5f_run_20251129-044948

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/testori_unzipped",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Models/00003-finalnuevo-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000900.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1leak",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=0.8,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 911 | Classes: ['glioma', 'meningioma', 'pituitary']
# [LEAK-FIX] Removed 702 overlapping ext-test images by patient ID.
# [Scan] External test images (sanitized): 0
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [446, 194, 271], using n_per_class=446
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
# ...
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 1681, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2164, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py", line 2632, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 813, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1293, in create_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py312_cu126/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# [GAN] Saved 446 images for class 'pituitary'
# [GAN] Synth images generated (global): 1338
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [336, 143, 194] -> target=336
# [BAL] Fold 1: real=673 | train_balanced(real+GAN)=1008
# [ID-STATS] fold1_train: unique patient IDs total = 56 | images = 1008
#   - glioma: ids=24 images=336
#   - meningioma: ids=19 images=336
#   - pituitary: ids=14 images=336
# [ID-STATS] fold1_val: unique patient IDs total = 15 | images = 238
#   - glioma: ids=6 images=110
#   - meningioma: ids=4 images=51
#   - pituitary: ids=5 images=77
# [Fold 1 | Epoch 001] train_loss=0.4086 | val_acc=0.7689 | val_f1_macro=0.7089
# [Fold 1] New best (F1_macro=0.7089) saved.
# [Fold 1 | Epoch 002] train_loss=0.1291 | val_acc=0.8361 | val_f1_macro=0.7925
# [Fold 1] New best (F1_macro=0.7925) saved.
# [Fold 1 | Epoch 003] train_loss=0.0831 | val_acc=0.8571 | val_f1_macro=0.8119
# [Fold 1] New best (F1_macro=0.8119) saved.
# [Fold 1 | Epoch 004] train_loss=0.0519 | val_acc=0.9454 | val_f1_macro=0.9370
# [Fold 1] New best (F1_macro=0.9370) saved.
# [Fold 1 | Epoch 005] train_loss=0.0545 | val_acc=0.8908 | val_f1_macro=0.8762
# [Fold 1 | Epoch 006] train_loss=0.0592 | val_acc=0.8950 | val_f1_macro=0.8774
# [Fold 1 | Epoch 007] train_loss=0.0313 | val_acc=0.8487 | val_f1_macro=0.7762
# [Fold 1 | Epoch 008] train_loss=0.0206 | val_acc=0.9118 | val_f1_macro=0.8989
# [Fold 1 | Epoch 009] train_loss=0.0216 | val_acc=0.9328 | val_f1_macro=0.9196
# [Fold 1 | Epoch 010] train_loss=0.0102 | val_acc=0.9034 | val_f1_macro=0.8758
# [Fold 1 | Epoch 011] train_loss=0.0154 | val_acc=0.8739 | val_f1_macro=0.8309
# [Fold 1 | Epoch 012] train_loss=0.0147 | val_acc=0.8866 | val_f1_macro=0.8477
# [Fold 1 | Epoch 013] train_loss=0.0108 | val_acc=0.8992 | val_f1_macro=0.8754
# [Fold 1 | Epoch 014] train_loss=0.0155 | val_acc=0.8908 | val_f1_macro=0.8664
# [Fold 1 | Epoch 015] train_loss=0.0052 | val_acc=0.8908 | val_f1_macro=0.8732
# [Fold 1 | FT Epoch 016] train_loss=0.0323 | val_acc=0.9034 | val_f1_macro=0.8870
# [Fold 1 | FT Epoch 017] train_loss=0.0106 | val_acc=0.9034 | val_f1_macro=0.8876
# [Fold 1 | FT Epoch 018] train_loss=0.0161 | val_acc=0.9160 | val_f1_macro=0.9022
# [Fold 1 | FT Epoch 019] train_loss=0.0128 | val_acc=0.9160 | val_f1_macro=0.9038
# [Fold 1 | FT Epoch 020] train_loss=0.0067 | val_acc=0.9118 | val_f1_macro=0.8969
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [366, 169, 260] -> target=366
# [BAL] Fold 2: real=795 | train_balanced(real+GAN)=1098
# [ID-STATS] fold2_train: unique patient IDs total = 58 | images = 1098
#   - glioma: ids=23 images=366
#   - meningioma: ids=18 images=366
#   - pituitary: ids=18 images=366
# [ID-STATS] fold2_val: unique patient IDs total = 13 | images = 116
#   - glioma: ids=7 images=80
#   - meningioma: ids=5 images=25
#   - pituitary: ids=1 images=11
# [Fold 2 | Epoch 001] train_loss=0.4021 | val_acc=0.7931 | val_f1_macro=0.6574
# [Fold 2] New best (F1_macro=0.6574) saved.
# [Fold 2 | Epoch 002] train_loss=0.1678 | val_acc=0.8448 | val_f1_macro=0.8203
# [Fold 2] New best (F1_macro=0.8203) saved.
# [Fold 2 | Epoch 003] train_loss=0.0990 | val_acc=0.8879 | val_f1_macro=0.8878
# [Fold 2] New best (F1_macro=0.8878) saved.
# [Fold 2 | Epoch 004] train_loss=0.0759 | val_acc=0.8879 | val_f1_macro=0.8566
# [Fold 2 | Epoch 005] train_loss=0.1018 | val_acc=0.8448 | val_f1_macro=0.7965
# [Fold 2 | Epoch 006] train_loss=0.0373 | val_acc=0.8534 | val_f1_macro=0.8228
# [Fold 2 | Epoch 007] train_loss=0.0235 | val_acc=0.8276 | val_f1_macro=0.7941
# [Fold 2 | Epoch 008] train_loss=0.0269 | val_acc=0.8879 | val_f1_macro=0.8719
# [Fold 2 | Epoch 009] train_loss=0.0377 | val_acc=0.8879 | val_f1_macro=0.8781
# [Fold 2 | Epoch 010] train_loss=0.0290 | val_acc=0.8448 | val_f1_macro=0.8414
# [Fold 2 | Epoch 011] train_loss=0.0174 | val_acc=0.8879 | val_f1_macro=0.8999
# [Fold 2] New best (F1_macro=0.8999) saved.
# [Fold 2 | Epoch 012] train_loss=0.0105 | val_acc=0.8707 | val_f1_macro=0.8530
# [Fold 2 | Epoch 013] train_loss=0.0170 | val_acc=0.8966 | val_f1_macro=0.9047
# [Fold 2] New best (F1_macro=0.9047) saved.
# [Fold 2 | Epoch 014] train_loss=0.0156 | val_acc=0.9052 | val_f1_macro=0.9117
# [Fold 2] New best (F1_macro=0.9117) saved.
# [Fold 2 | Epoch 015] train_loss=0.0119 | val_acc=0.8966 | val_f1_macro=0.9003
# [Fold 2 | FT Epoch 016] train_loss=0.0112 | val_acc=0.9052 | val_f1_macro=0.9136
# [Fold 2] New best (F1_macro=0.9136) saved (fine-tune).
# [Fold 2 | FT Epoch 017] train_loss=0.0079 | val_acc=0.9052 | val_f1_macro=0.9117
# [Fold 2 | FT Epoch 018] train_loss=0.0053 | val_acc=0.9052 | val_f1_macro=0.9136
# [Fold 2 | FT Epoch 019] train_loss=0.0066 | val_acc=0.9052 | val_f1_macro=0.9136
# [Fold 2 | FT Epoch 020] train_loss=0.0049 | val_acc=0.9052 | val_f1_macro=0.9136
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [340, 136, 227] -> target=340
# [BAL] Fold 3: real=703 | train_balanced(real+GAN)=1020
# [ID-STATS] fold3_train: unique patient IDs total = 56 | images = 1020
#   - glioma: ids=22 images=340
#   - meningioma: ids=19 images=340
#   - pituitary: ids=16 images=340
# [ID-STATS] fold3_val: unique patient IDs total = 15 | images = 208
#   - glioma: ids=8 images=106
#   - meningioma: ids=4 images=58
#   - pituitary: ids=3 images=44
# [Fold 3 | Epoch 001] train_loss=0.4202 | val_acc=0.7933 | val_f1_macro=0.7688
# [Fold 3] New best (F1_macro=0.7688) saved.
# [Fold 3 | Epoch 002] train_loss=0.1689 | val_acc=0.7740 | val_f1_macro=0.7234
# [Fold 3 | Epoch 003] train_loss=0.0863 | val_acc=0.8606 | val_f1_macro=0.8554
# [Fold 3] New best (F1_macro=0.8554) saved.
# [Fold 3 | Epoch 004] train_loss=0.0901 | val_acc=0.9135 | val_f1_macro=0.9152
# [Fold 3] New best (F1_macro=0.9152) saved.
# [Fold 3 | Epoch 005] train_loss=0.0764 | val_acc=0.9135 | val_f1_macro=0.9167
# [Fold 3] New best (F1_macro=0.9167) saved.
# [Fold 3 | Epoch 006] train_loss=0.0466 | val_acc=0.8606 | val_f1_macro=0.8557
# [Fold 3 | Epoch 007] train_loss=0.0391 | val_acc=0.8269 | val_f1_macro=0.8122
# [Fold 3 | Epoch 008] train_loss=0.0186 | val_acc=0.8750 | val_f1_macro=0.8710
# [Fold 3 | Epoch 009] train_loss=0.0243 | val_acc=0.9135 | val_f1_macro=0.9157
# [Fold 3 | Epoch 010] train_loss=0.0116 | val_acc=0.8942 | val_f1_macro=0.8924
# [Fold 3 | Epoch 011] train_loss=0.0178 | val_acc=0.9279 | val_f1_macro=0.9306
# [Fold 3] New best (F1_macro=0.9306) saved.
# [Fold 3 | Epoch 012] train_loss=0.0187 | val_acc=0.8942 | val_f1_macro=0.8933
# [Fold 3 | Epoch 013] train_loss=0.0094 | val_acc=0.8894 | val_f1_macro=0.8879
# [Fold 3 | Epoch 014] train_loss=0.0102 | val_acc=0.9038 | val_f1_macro=0.9036
# [Fold 3 | Epoch 015] train_loss=0.0083 | val_acc=0.9038 | val_f1_macro=0.9041
# [Fold 3 | FT Epoch 016] train_loss=0.0192 | val_acc=0.9087 | val_f1_macro=0.9102
# [Fold 3 | FT Epoch 017] train_loss=0.0046 | val_acc=0.9135 | val_f1_macro=0.9153
# [Fold 3 | FT Epoch 018] train_loss=0.0131 | val_acc=0.9135 | val_f1_macro=0.9153
# [Fold 3 | FT Epoch 019] train_loss=0.0108 | val_acc=0.9327 | val_f1_macro=0.9351
# [Fold 3] New best (F1_macro=0.9351) saved (fine-tune).
# [Fold 3 | FT Epoch 020] train_loss=0.0098 | val_acc=0.9231 | val_f1_macro=0.9253
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [331, 171, 235] -> target=331
# [BAL] Fold 4: real=737 | train_balanced(real+GAN)=993
# [ID-STATS] fold4_train: unique patient IDs total = 57 | images = 993
#   - glioma: ids=24 images=331
#   - meningioma: ids=18 images=331
#   - pituitary: ids=16 images=331
# [ID-STATS] fold4_val: unique patient IDs total = 14 | images = 174
#   - glioma: ids=6 images=115
#   - meningioma: ids=5 images=23
#   - pituitary: ids=3 images=36
# [Fold 4 | Epoch 001] train_loss=0.4359 | val_acc=0.9368 | val_f1_macro=0.9011
# [Fold 4] New best (F1_macro=0.9011) saved.
# [Fold 4 | Epoch 002] train_loss=0.1397 | val_acc=0.9080 | val_f1_macro=0.8636
# [Fold 4 | Epoch 003] train_loss=0.1052 | val_acc=0.9253 | val_f1_macro=0.8665
# [Fold 4 | Epoch 004] train_loss=0.0709 | val_acc=0.9023 | val_f1_macro=0.8251
# [Fold 4 | Epoch 005] train_loss=0.0665 | val_acc=0.9253 | val_f1_macro=0.8819
# [Fold 4 | Epoch 006] train_loss=0.0462 | val_acc=0.9138 | val_f1_macro=0.8735
# [Fold 4 | Epoch 007] train_loss=0.0244 | val_acc=0.9138 | val_f1_macro=0.8644
# [Fold 4 | Epoch 008] train_loss=0.0289 | val_acc=0.9080 | val_f1_macro=0.8522
# [Fold 4 | Epoch 009] train_loss=0.0182 | val_acc=0.9195 | val_f1_macro=0.8699
# [Fold 4 | Epoch 010] train_loss=0.0180 | val_acc=0.9310 | val_f1_macro=0.8847
# [Fold 4 | Epoch 011] train_loss=0.0179 | val_acc=0.9368 | val_f1_macro=0.8920
# [Fold 4 | Epoch 012] train_loss=0.0120 | val_acc=0.9253 | val_f1_macro=0.8866
# [Fold 4 | Epoch 013] train_loss=0.0196 | val_acc=0.9080 | val_f1_macro=0.8543
# [Fold 4 | Epoch 014] train_loss=0.0092 | val_acc=0.9368 | val_f1_macro=0.8963
# [Fold 4 | Epoch 015] train_loss=0.0112 | val_acc=0.9368 | val_f1_macro=0.8963
# Exception in thread Thread-852 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/pin_memory.py", line 61, in _pin_memory_loop
#     do_one_step()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/pin_memory.py", line 37, in do_one_step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2578054253.py in <cell line: 0>()
#      17          kfolds =5       )
#      18      return train_kfold(cfg_bal)
# ---> 19 resultado = run_gan_balanced()
#
# /tmp/ipython-input-2578054253.py in run_gan_balanced()
#      16          seed = 122,
#      17          kfolds =5       )
# ---> 18      return train_kfold(cfg_bal)
#      19 resultado = run_gan_balanced()
#
# /tmp/ipython-input-2092564287.py in train_kfold(cfg)
#     686             train_loss = running_loss / max(1, n_seen)
#     687
# --> 688             m_val, _ = evaluate(model, val_loader, device, class_names,
#     689                                 split_name='val', out_dir=fold_dir)
#     690             f1_macro = m_val['overall']['f1_macro']
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /tmp/ipython-input-2092564287.py in evaluate(model, loader, device, class_names, split_name, out_dir)
#     183     all_paths, all_pids = [], []
#     184
# --> 185     for imgs, ys, paths, pids in loader:
#     186         imgs = imgs.to(device, non_blocking=True)
#     187         ys = ys.to(device, non_blocking=True)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     732                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733                 self._reset()  # type: ignore[call-arg]
# --> 734             data = self._next_data()
#     735             self._num_yielded += 1
#     736             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1490
#    1491             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1492             idx, data = self._get_data()
#    1493             self._tasks_outstanding -= 1
#    1494             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1442         elif self._pin_memory:
#    1443             while self._pin_memory_thread.is_alive():
# -> 1444                 success, data = self._try_get_data()
#    1445                 if success:
#    1446                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1283         #   (bool: whether successfully get data, any: data if successful else None)
#    1284         try:
# -> 1285             data = self._data_queue.get(timeout=timeout)
#    1286             return (True, data)
#    1287         except Exception as e:
#
# /usr/lib/python3.12/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     357             else:
#     358                 if timeout > 0:
# --> 359                     gotit = waiter.acquire(True, timeout)
#     360                 else:
#     361                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 519, in Client

# %% [markdown]
# #normal

# %%
    def run_real_only():
        cfg_real = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            balance_gan_to_max=False,   # ignorado porque no hay gan_pkl
            fine_tune_real_epochs=0,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds=5)
        return train_kfold(cfg_real)



    resultado = run_real_only()
    print("Run finished, artifacts at:", resultado)
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] gan_pkl empty -> NO GAN will be used.
#
# ===== FOLD 1/5 =====
# [TRAIN] Fold 1: only real images, n=1294
# [ID-STATS] fold1_train: unique patient IDs total = 125 | images = 1294
#   - glioma: ids=41 images=499
#   - meningioma: ids=46 images=304
#   - pituitary: ids=38 images=491
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 221MB/s]
# [Fold 1 | Epoch 001] train_loss=0.4076 | val_acc=0.9218 | val_f1_macro=0.9261
# [Fold 1] New best (F1_macro=0.9261) saved.
# [Fold 1 | Epoch 002] train_loss=0.1489 | val_acc=0.9251 | val_f1_macro=0.9267
# [Fold 1] New best (F1_macro=0.9267) saved.
# [Fold 1 | Epoch 003] train_loss=0.0881 | val_acc=0.9674 | val_f1_macro=0.9695
# [Fold 1] New best (F1_macro=0.9695) saved.
# [Fold 1 | Epoch 004] train_loss=0.0731 | val_acc=0.9316 | val_f1_macro=0.9321
# [Fold 1 | Epoch 005] train_loss=0.0581 | val_acc=0.9609 | val_f1_macro=0.9576
# [Fold 1 | Epoch 006] train_loss=0.0593 | val_acc=0.9283 | val_f1_macro=0.9312
# [Fold 1 | Epoch 007] train_loss=0.0482 | val_acc=0.9544 | val_f1_macro=0.9567
# [Fold 1 | Epoch 008] train_loss=0.0396 | val_acc=0.9381 | val_f1_macro=0.9393
# [Fold 1 | Epoch 009] train_loss=0.0149 | val_acc=0.9381 | val_f1_macro=0.9369
# [Fold 1 | Epoch 010] train_loss=0.0135 | val_acc=0.9707 | val_f1_macro=0.9732
# [Fold 1] New best (F1_macro=0.9732) saved.
# [Fold 1 | Epoch 011] train_loss=0.0154 | val_acc=0.9349 | val_f1_macro=0.9353
# [Fold 1 | Epoch 012] train_loss=0.0112 | val_acc=0.9316 | val_f1_macro=0.9387
# [Fold 1 | Epoch 013] train_loss=0.0067 | val_acc=0.9577 | val_f1_macro=0.9608
# [Fold 1 | Epoch 014] train_loss=0.0064 | val_acc=0.9544 | val_f1_macro=0.9580
# [Fold 1 | Epoch 015] train_loss=0.0068 | val_acc=0.9544 | val_f1_macro=0.9582
# [Fold 1 | Epoch 016] train_loss=0.0095 | val_acc=0.9479 | val_f1_macro=0.9526
# [Fold 1 | Epoch 017] train_loss=0.0084 | val_acc=0.9544 | val_f1_macro=0.9569
# [Fold 1 | Epoch 018] train_loss=0.0117 | val_acc=0.9544 | val_f1_macro=0.9569
# [Fold 1 | Epoch 019] train_loss=0.0060 | val_acc=0.9544 | val_f1_macro=0.9569
# [Fold 1 | Epoch 020] train_loss=0.0037 | val_acc=0.9544 | val_f1_macro=0.9569
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [TRAIN] Fold 2: only real images, n=1288
# [ID-STATS] fold2_train: unique patient IDs total = 124 | images = 1288
#   - glioma: ids=44 images=524
#   - meningioma: ids=47 images=342
#   - pituitary: ids=33 images=422
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3882 | val_acc=0.8882 | val_f1_macro=0.8579
# [Fold 2] New best (F1_macro=0.8579) saved.
# [Fold 2 | Epoch 002] train_loss=0.1276 | val_acc=0.8914 | val_f1_macro=0.8699
# [Fold 2] New best (F1_macro=0.8699) saved.
# [Fold 2 | Epoch 003] train_loss=0.0762 | val_acc=0.8658 | val_f1_macro=0.8007
# [Fold 2 | Epoch 004] train_loss=0.0902 | val_acc=0.9073 | val_f1_macro=0.8742
# [Fold 2] New best (F1_macro=0.8742) saved.
# [Fold 2 | Epoch 005] train_loss=0.0832 | val_acc=0.9297 | val_f1_macro=0.9081
# [Fold 2] New best (F1_macro=0.9081) saved.
# [Fold 2 | Epoch 006] train_loss=0.0616 | val_acc=0.9137 | val_f1_macro=0.8907
# [Fold 2 | Epoch 007] train_loss=0.0288 | val_acc=0.9233 | val_f1_macro=0.8990
# [Fold 2 | Epoch 008] train_loss=0.0133 | val_acc=0.8850 | val_f1_macro=0.8405
# [Fold 2 | Epoch 009] train_loss=0.0229 | val_acc=0.9073 | val_f1_macro=0.8714
# [Fold 2 | Epoch 010] train_loss=0.0295 | val_acc=0.9073 | val_f1_macro=0.8727
# [Fold 2 | Epoch 011] train_loss=0.0234 | val_acc=0.9169 | val_f1_macro=0.8891
# [Fold 2 | Epoch 012] train_loss=0.0252 | val_acc=0.9073 | val_f1_macro=0.8750
# [Fold 2 | Epoch 013] train_loss=0.0113 | val_acc=0.9169 | val_f1_macro=0.8902
# [Fold 2 | Epoch 014] train_loss=0.0138 | val_acc=0.9169 | val_f1_macro=0.8900
# [Fold 2 | Epoch 015] train_loss=0.0071 | val_acc=0.9233 | val_f1_macro=0.8993
# [Fold 2 | Epoch 016] train_loss=0.0059 | val_acc=0.9233 | val_f1_macro=0.8993
# [Fold 2 | Epoch 017] train_loss=0.0062 | val_acc=0.9201 | val_f1_macro=0.8936
# [Fold 2 | Epoch 018] train_loss=0.0077 | val_acc=0.9297 | val_f1_macro=0.9079
# [Fold 2 | Epoch 019] train_loss=0.0040 | val_acc=0.9201 | val_f1_macro=0.8936
# [Fold 2 | Epoch 020] train_loss=0.0050 | val_acc=0.9201 | val_f1_macro=0.8936
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [TRAIN] Fold 3: only real images, n=1257
# [ID-STATS] fold3_train: unique patient IDs total = 125 | images = 1257
#   - glioma: ids=44 images=506
#   - meningioma: ids=46 images=301
#   - pituitary: ids=35 images=450
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3691 | val_acc=0.8517 | val_f1_macro=0.8468
# [Fold 3] New best (F1_macro=0.8468) saved.
# [Fold 3 | Epoch 002] train_loss=0.1165 | val_acc=0.9012 | val_f1_macro=0.8952
# [Fold 3] New best (F1_macro=0.8952) saved.
# [Fold 3 | Epoch 003] train_loss=0.0891 | val_acc=0.9041 | val_f1_macro=0.8972
# [Fold 3] New best (F1_macro=0.8972) saved.
# [Fold 3 | Epoch 004] train_loss=0.0740 | val_acc=0.8953 | val_f1_macro=0.8902
# [Fold 3 | Epoch 005] train_loss=0.0481 | val_acc=0.9041 | val_f1_macro=0.8994
# [Fold 3] New best (F1_macro=0.8994) saved.
# [Fold 3 | Epoch 006] train_loss=0.0274 | val_acc=0.9041 | val_f1_macro=0.8993
# [Fold 3 | Epoch 007] train_loss=0.0193 | val_acc=0.9099 | val_f1_macro=0.9040
# [Fold 3] New best (F1_macro=0.9040) saved.
# [Fold 3 | Epoch 008] train_loss=0.0229 | val_acc=0.8866 | val_f1_macro=0.8818
# [Fold 3 | Epoch 009] train_loss=0.0194 | val_acc=0.9070 | val_f1_macro=0.9022
# [Fold 3 | Epoch 010] train_loss=0.0193 | val_acc=0.9128 | val_f1_macro=0.9070
# [Fold 3] New best (F1_macro=0.9070) saved.
# [Fold 3 | Epoch 011] train_loss=0.0071 | val_acc=0.9186 | val_f1_macro=0.9141
# [Fold 3] New best (F1_macro=0.9141) saved.
# [Fold 3 | Epoch 012] train_loss=0.0067 | val_acc=0.9041 | val_f1_macro=0.8999
# [Fold 3 | Epoch 013] train_loss=0.0041 | val_acc=0.9012 | val_f1_macro=0.8974
# [Fold 3 | Epoch 014] train_loss=0.0022 | val_acc=0.9099 | val_f1_macro=0.9056
# [Fold 3 | Epoch 015] train_loss=0.0113 | val_acc=0.9186 | val_f1_macro=0.9139
# [Fold 3 | Epoch 016] train_loss=0.0043 | val_acc=0.9215 | val_f1_macro=0.9167
# [Fold 3] New best (F1_macro=0.9167) saved.
# [Fold 3 | Epoch 017] train_loss=0.0053 | val_acc=0.9215 | val_f1_macro=0.9167
# [Fold 3 | Epoch 018] train_loss=0.0027 | val_acc=0.9186 | val_f1_macro=0.9137
# [Fold 3 | Epoch 019] train_loss=0.0043 | val_acc=0.9215 | val_f1_macro=0.9164
# [Fold 3 | Epoch 020] train_loss=0.0091 | val_acc=0.9186 | val_f1_macro=0.9137
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [TRAIN] Fold 4: only real images, n=1244
# [ID-STATS] fold4_train: unique patient IDs total = 125 | images = 1244
#   - glioma: ids=40 images=450
#   - meningioma: ids=51 images=370
#   - pituitary: ids=34 images=424
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.3898 | val_acc=0.9776 | val_f1_macro=0.9592
# [Fold 4] New best (F1_macro=0.9592) saved.
# [Fold 4 | Epoch 002] train_loss=0.1442 | val_acc=0.9692 | val_f1_macro=0.9455
# [Fold 4 | Epoch 003] train_loss=0.1004 | val_acc=0.9636 | val_f1_macro=0.9454
# [Fold 4 | Epoch 004] train_loss=0.0907 | val_acc=0.9804 | val_f1_macro=0.9675
# [Fold 4] New best (F1_macro=0.9675) saved.
# [Fold 4 | Epoch 005] train_loss=0.0755 | val_acc=0.9776 | val_f1_macro=0.9619
# [Fold 4 | Epoch 006] train_loss=0.0397 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4] New best (F1_macro=0.9841) saved.
# [Fold 4 | Epoch 007] train_loss=0.0169 | val_acc=0.9776 | val_f1_macro=0.9599
# [Fold 4 | Epoch 008] train_loss=0.0341 | val_acc=0.9916 | val_f1_macro=0.9865
# [Fold 4] New best (F1_macro=0.9865) saved.
# [Fold 4 | Epoch 009] train_loss=0.0292 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | Epoch 010] train_loss=0.0438 | val_acc=0.9860 | val_f1_macro=0.9777
# [Fold 4 | Epoch 011] train_loss=0.0182 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] New best (F1_macro=0.9899) saved.
# [Fold 4 | Epoch 012] train_loss=0.0090 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 013] train_loss=0.0088 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | Epoch 014] train_loss=0.0087 | val_acc=0.9860 | val_f1_macro=0.9783
# [Fold 4 | Epoch 015] train_loss=0.0044 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 016] train_loss=0.0039 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 017] train_loss=0.0037 | val_acc=0.9888 | val_f1_macro=0.9808
# [Fold 4 | Epoch 018] train_loss=0.0049 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 019] train_loss=0.0043 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 020] train_loss=0.0094 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [TRAIN] Fold 5: only real images, n=1321
# [ID-STATS] fold5_train: unique patient IDs total = 125 | images = 1321
#   - glioma: ids=47 images=557
#   - meningioma: ids=42 images=307
#   - pituitary: ids=36 images=457
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3822 | val_acc=0.7071 | val_f1_macro=0.6974
# [Fold 5] New best (F1_macro=0.6974) saved.
# [Fold 5 | Epoch 002] train_loss=0.1525 | val_acc=0.7464 | val_f1_macro=0.7415
# [Fold 5] New best (F1_macro=0.7415) saved.
# [Fold 5 | Epoch 003] train_loss=0.0972 | val_acc=0.9143 | val_f1_macro=0.9133
# [Fold 5] New best (F1_macro=0.9133) saved.
# [Fold 5 | Epoch 004] train_loss=0.0736 | val_acc=0.8429 | val_f1_macro=0.8437
# [Fold 5 | Epoch 005] train_loss=0.0742 | val_acc=0.9143 | val_f1_macro=0.9135
# [Fold 5] New best (F1_macro=0.9135) saved.
# [Fold 5 | Epoch 006] train_loss=0.0705 | val_acc=0.8857 | val_f1_macro=0.8847
# [Fold 5 | Epoch 007] train_loss=0.0314 | val_acc=0.8893 | val_f1_macro=0.8887
# [Fold 5 | Epoch 008] train_loss=0.0264 | val_acc=0.8821 | val_f1_macro=0.8820
# [Fold 5 | Epoch 009] train_loss=0.0139 | val_acc=0.8750 | val_f1_macro=0.8748
# [Fold 5 | Epoch 010] train_loss=0.0161 | val_acc=0.9071 | val_f1_macro=0.9064
# [Fold 5 | Epoch 011] train_loss=0.0112 | val_acc=0.8893 | val_f1_macro=0.8882
# [Fold 5 | Epoch 012] train_loss=0.0182 | val_acc=0.9071 | val_f1_macro=0.9067
# [Fold 5 | Epoch 013] train_loss=0.0259 | val_acc=0.9179 | val_f1_macro=0.9168
# [Fold 5] New best (F1_macro=0.9168) saved.
# [Fold 5 | Epoch 014] train_loss=0.0079 | val_acc=0.9179 | val_f1_macro=0.9169
# [Fold 5] New best (F1_macro=0.9169) saved.
# [Fold 5 | Epoch 015] train_loss=0.0057 | val_acc=0.9143 | val_f1_macro=0.9134
# [Fold 5 | Epoch 016] train_loss=0.0063 | val_acc=0.9250 | val_f1_macro=0.9241
# [Fold 5] New best (F1_macro=0.9241) saved.
# [Fold 5 | Epoch 017] train_loss=0.0060 | val_acc=0.9179 | val_f1_macro=0.9175
# [Fold 5 | Epoch 018] train_loss=0.0132 | val_acc=0.9214 | val_f1_macro=0.9211
# [Fold 5 | Epoch 019] train_loss=0.0049 | val_acc=0.9071 | val_f1_macro=0.9067
# [Fold 5 | Epoch 020] train_loss=0.0067 | val_acc=0.9179 | val_f1_macro=0.9171
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [Full Train] real=1601 + synth=0 -> 1601
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-013459
# Run finished, artifacts at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-013459

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=0.8,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [634, 406, 561], using n_per_class=634
# Setting up PyTorch plugin "bias_act_plugin"...
# W1112 01:42:37.353000 332 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1112 01:42:37.353000 332 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"...
# W1112 01:43:01.794000 332 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1112 01:43:01.794000 332 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# Done.
# [GAN] Saved 634 images for class 'glioma'
# [GAN] Saved 634 images for class 'meningioma'
# [GAN] Saved 634 images for class 'pituitary'
# [GAN] Synth images generated (global): 1902
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [499, 304, 491] -> target=499
# [BAL] Fold 1: real=1294 | train_balanced(real+GAN)=1497
# [ID-STATS] fold1_train: unique patient IDs total = 126 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=47 images=499
#   - pituitary: ids=39 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.3747 | val_acc=0.9349 | val_f1_macro=0.9410
# [Fold 1] New best (F1_macro=0.9410) saved.
# [Fold 1 | Epoch 002] train_loss=0.1274 | val_acc=0.9186 | val_f1_macro=0.9237
# [Fold 1 | Epoch 003] train_loss=0.1018 | val_acc=0.9511 | val_f1_macro=0.9479
# [Fold 1] New best (F1_macro=0.9479) saved.
# [Fold 1 | Epoch 004] train_loss=0.0542 | val_acc=0.9023 | val_f1_macro=0.9030
# [Fold 1 | Epoch 005] train_loss=0.0623 | val_acc=0.9544 | val_f1_macro=0.9522
# [Fold 1] New best (F1_macro=0.9522) saved.
# [Fold 1 | Epoch 006] train_loss=0.0377 | val_acc=0.9349 | val_f1_macro=0.9340
# [Fold 1 | Epoch 007] train_loss=0.0168 | val_acc=0.9577 | val_f1_macro=0.9536
# [Fold 1] New best (F1_macro=0.9536) saved.
# [Fold 1 | Epoch 008] train_loss=0.0279 | val_acc=0.9511 | val_f1_macro=0.9507
# [Fold 1 | Epoch 009] train_loss=0.0446 | val_acc=0.8958 | val_f1_macro=0.8946
# [Fold 1 | Epoch 010] train_loss=0.0342 | val_acc=0.9316 | val_f1_macro=0.9297
# [Fold 1 | Epoch 011] train_loss=0.0180 | val_acc=0.9609 | val_f1_macro=0.9572
# [Fold 1] New best (F1_macro=0.9572) saved.
# [Fold 1 | Epoch 012] train_loss=0.0118 | val_acc=0.9544 | val_f1_macro=0.9519
# [Fold 1 | Epoch 013] train_loss=0.0066 | val_acc=0.9446 | val_f1_macro=0.9433
# [Fold 1 | Epoch 014] train_loss=0.0053 | val_acc=0.9577 | val_f1_macro=0.9557
# [Fold 1 | Epoch 015] train_loss=0.0100 | val_acc=0.9414 | val_f1_macro=0.9381
# [Fold 1 | FT Epoch 016] train_loss=0.0095 | val_acc=0.9707 | val_f1_macro=0.9685
# [Fold 1] New best (F1_macro=0.9685) saved (fine-tune).
# [Fold 1 | FT Epoch 017] train_loss=0.0051 | val_acc=0.9642 | val_f1_macro=0.9626
# [Fold 1 | FT Epoch 018] train_loss=0.0081 | val_acc=0.9609 | val_f1_macro=0.9584
# [Fold 1 | FT Epoch 019] train_loss=0.0040 | val_acc=0.9577 | val_f1_macro=0.9544
# [Fold 1 | FT Epoch 020] train_loss=0.0045 | val_acc=0.9609 | val_f1_macro=0.9574
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [524, 342, 422] -> target=524
# [BAL] Fold 2: real=1288 | train_balanced(real+GAN)=1572
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=48 images=524
#   - pituitary: ids=34 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3584 | val_acc=0.8946 | val_f1_macro=0.8552
# [Fold 2] New best (F1_macro=0.8552) saved.
# [Fold 2 | Epoch 002] train_loss=0.1167 | val_acc=0.8946 | val_f1_macro=0.8638
# [Fold 2] New best (F1_macro=0.8638) saved.
# [Fold 2 | Epoch 003] train_loss=0.0803 | val_acc=0.9010 | val_f1_macro=0.8702
# [Fold 2] New best (F1_macro=0.8702) saved.
# [Fold 2 | Epoch 004] train_loss=0.0768 | val_acc=0.8946 | val_f1_macro=0.8537
# [Fold 2 | Epoch 005] train_loss=0.0526 | val_acc=0.9137 | val_f1_macro=0.8950
# [Fold 2] New best (F1_macro=0.8950) saved.
# [Fold 2 | Epoch 006] train_loss=0.1104 | val_acc=0.9297 | val_f1_macro=0.9086
# [Fold 2] New best (F1_macro=0.9086) saved.
# [Fold 2 | Epoch 007] train_loss=0.0635 | val_acc=0.9329 | val_f1_macro=0.9157
# [Fold 2] New best (F1_macro=0.9157) saved.
# [Fold 2 | Epoch 008] train_loss=0.0392 | val_acc=0.9073 | val_f1_macro=0.8756
# [Fold 2 | Epoch 009] train_loss=0.0190 | val_acc=0.9137 | val_f1_macro=0.8834
# [Fold 2 | Epoch 010] train_loss=0.0296 | val_acc=0.9042 | val_f1_macro=0.8738
# [Fold 2 | Epoch 011] train_loss=0.0231 | val_acc=0.9201 | val_f1_macro=0.8938
# [Fold 2 | Epoch 012] train_loss=0.0163 | val_acc=0.9169 | val_f1_macro=0.8890
# [Fold 2 | Epoch 013] train_loss=0.0094 | val_acc=0.9010 | val_f1_macro=0.8631
# [Fold 2 | Epoch 014] train_loss=0.0140 | val_acc=0.9233 | val_f1_macro=0.8974
# [Fold 2 | Epoch 015] train_loss=0.0102 | val_acc=0.9361 | val_f1_macro=0.9161
# [Fold 2] New best (F1_macro=0.9161) saved.
# [Fold 2 | FT Epoch 016] train_loss=0.0100 | val_acc=0.9233 | val_f1_macro=0.8986
# [Fold 2 | FT Epoch 017] train_loss=0.0048 | val_acc=0.9233 | val_f1_macro=0.8977
# [Fold 2 | FT Epoch 018] train_loss=0.0074 | val_acc=0.9265 | val_f1_macro=0.9022
# [Fold 2 | FT Epoch 019] train_loss=0.0040 | val_acc=0.9201 | val_f1_macro=0.8920
# [Fold 2 | FT Epoch 020] train_loss=0.0068 | val_acc=0.9265 | val_f1_macro=0.9022
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [506, 301, 450] -> target=506
# [BAL] Fold 3: real=1257 | train_balanced(real+GAN)=1518
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=47 images=506
#   - pituitary: ids=36 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3087 | val_acc=0.8634 | val_f1_macro=0.8603
# [Fold 3] New best (F1_macro=0.8603) saved.
# [Fold 3 | Epoch 002] train_loss=0.1257 | val_acc=0.8895 | val_f1_macro=0.8823
# [Fold 3] New best (F1_macro=0.8823) saved.
# [Fold 3 | Epoch 003] train_loss=0.0805 | val_acc=0.8808 | val_f1_macro=0.8755
# [Fold 3 | Epoch 004] train_loss=0.0533 | val_acc=0.8866 | val_f1_macro=0.8835
# [Fold 3] New best (F1_macro=0.8835) saved.
# [Fold 3 | Epoch 005] train_loss=0.0691 | val_acc=0.9012 | val_f1_macro=0.8978
# [Fold 3] New best (F1_macro=0.8978) saved.
# [Fold 3 | Epoch 006] train_loss=0.0278 | val_acc=0.9128 | val_f1_macro=0.9086
# [Fold 3] New best (F1_macro=0.9086) saved.
# [Fold 3 | Epoch 007] train_loss=0.0205 | val_acc=0.9128 | val_f1_macro=0.9088
# [Fold 3] New best (F1_macro=0.9088) saved.
# [Fold 3 | Epoch 008] train_loss=0.0164 | val_acc=0.8895 | val_f1_macro=0.8851
# [Fold 3 | Epoch 009] train_loss=0.0413 | val_acc=0.8983 | val_f1_macro=0.8923
# [Fold 3 | Epoch 010] train_loss=0.0154 | val_acc=0.8983 | val_f1_macro=0.8942
# [Fold 3 | Epoch 011] train_loss=0.0129 | val_acc=0.9041 | val_f1_macro=0.8992
# [Fold 3 | Epoch 012] train_loss=0.0117 | val_acc=0.9099 | val_f1_macro=0.9030
# [Fold 3 | Epoch 013] train_loss=0.0104 | val_acc=0.9099 | val_f1_macro=0.9052
# [Fold 3 | Epoch 014] train_loss=0.0043 | val_acc=0.9041 | val_f1_macro=0.8988
# [Fold 3 | Epoch 015] train_loss=0.0039 | val_acc=0.9099 | val_f1_macro=0.9054
# [Fold 3 | FT Epoch 016] train_loss=0.0097 | val_acc=0.9099 | val_f1_macro=0.9058
# [Fold 3 | FT Epoch 017] train_loss=0.0034 | val_acc=0.9099 | val_f1_macro=0.9052
# [Fold 3 | FT Epoch 018] train_loss=0.0044 | val_acc=0.9128 | val_f1_macro=0.9084
# [Fold 3 | FT Epoch 019] train_loss=0.0035 | val_acc=0.9128 | val_f1_macro=0.9084
# [Fold 3 | FT Epoch 020] train_loss=0.0084 | val_acc=0.9128 | val_f1_macro=0.9088
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [450, 370, 424] -> target=450
# [BAL] Fold 4: real=1244 | train_balanced(real+GAN)=1350
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=52 images=450
#   - pituitary: ids=35 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.3993 | val_acc=0.9300 | val_f1_macro=0.8879
# [Fold 4] New best (F1_macro=0.8879) saved.
# [Fold 4 | Epoch 002] train_loss=0.1830 | val_acc=0.9636 | val_f1_macro=0.9552
# [Fold 4] New best (F1_macro=0.9552) saved.
# [Fold 4 | Epoch 003] train_loss=0.1276 | val_acc=0.9748 | val_f1_macro=0.9497
# [Fold 4 | Epoch 004] train_loss=0.0699 | val_acc=0.9748 | val_f1_macro=0.9605
# [Fold 4] New best (F1_macro=0.9605) saved.
# [Fold 4 | Epoch 005] train_loss=0.0561 | val_acc=0.9832 | val_f1_macro=0.9708
# [Fold 4] New best (F1_macro=0.9708) saved.
# [Fold 4 | Epoch 006] train_loss=0.0471 | val_acc=0.9384 | val_f1_macro=0.9202
# [Fold 4 | Epoch 007] train_loss=0.0369 | val_acc=0.9860 | val_f1_macro=0.9759
# [Fold 4] New best (F1_macro=0.9759) saved.
# [Fold 4 | Epoch 008] train_loss=0.0482 | val_acc=0.9916 | val_f1_macro=0.9865
# [Fold 4] New best (F1_macro=0.9865) saved.
# [Fold 4 | Epoch 009] train_loss=0.0323 | val_acc=0.9748 | val_f1_macro=0.9647
# [Fold 4 | Epoch 010] train_loss=0.0373 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] New best (F1_macro=0.9899) saved.
# [Fold 4 | Epoch 011] train_loss=0.0156 | val_acc=0.9860 | val_f1_macro=0.9759
# [Fold 4 | Epoch 012] train_loss=0.0153 | val_acc=0.9776 | val_f1_macro=0.9605
# [Fold 4 | Epoch 013] train_loss=0.0081 | val_acc=0.9832 | val_f1_macro=0.9708
# [Fold 4 | Epoch 014] train_loss=0.0122 | val_acc=0.9888 | val_f1_macro=0.9811
# [Fold 4 | Epoch 015] train_loss=0.0060 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 016] train_loss=0.0035 | val_acc=0.9888 | val_f1_macro=0.9811
# [Fold 4 | FT Epoch 017] train_loss=0.0072 | val_acc=0.9916 | val_f1_macro=0.9865
# [Fold 4 | FT Epoch 018] train_loss=0.0043 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 019] train_loss=0.0058 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 020] train_loss=0.0036 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [557, 307, 457] -> target=557
# [BAL] Fold 5: real=1321 | train_balanced(real+GAN)=1671
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=43 images=557
#   - pituitary: ids=37 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3417 | val_acc=0.7821 | val_f1_macro=0.7675
# [Fold 5] New best (F1_macro=0.7675) saved.
# [Fold 5 | Epoch 002] train_loss=0.1496 | val_acc=0.9179 | val_f1_macro=0.9158
# [Fold 5] New best (F1_macro=0.9158) saved.
# [Fold 5 | Epoch 003] train_loss=0.1018 | val_acc=0.9000 | val_f1_macro=0.8996
# [Fold 5 | Epoch 004] train_loss=0.0825 | val_acc=0.9571 | val_f1_macro=0.9569
# [Fold 5] New best (F1_macro=0.9569) saved.
# [Fold 5 | Epoch 005] train_loss=0.0680 | val_acc=0.9321 | val_f1_macro=0.9313
# [Fold 5 | Epoch 006] train_loss=0.0781 | val_acc=0.8429 | val_f1_macro=0.8365
# [Fold 5 | Epoch 007] train_loss=0.0514 | val_acc=0.8893 | val_f1_macro=0.8887
# [Fold 5 | Epoch 008] train_loss=0.0264 | val_acc=0.9250 | val_f1_macro=0.9248
# [Fold 5 | Epoch 009] train_loss=0.0262 | val_acc=0.9500 | val_f1_macro=0.9496
# [Fold 5 | Epoch 010] train_loss=0.0348 | val_acc=0.9429 | val_f1_macro=0.9413
# [Fold 5 | Epoch 011] train_loss=0.0186 | val_acc=0.9393 | val_f1_macro=0.9382
# [Fold 5 | Epoch 012] train_loss=0.0109 | val_acc=0.9571 | val_f1_macro=0.9564
# [Fold 5 | Epoch 013] train_loss=0.0137 | val_acc=0.9607 | val_f1_macro=0.9604
# [Fold 5] New best (F1_macro=0.9604) saved.
# [Fold 5 | Epoch 014] train_loss=0.0071 | val_acc=0.9536 | val_f1_macro=0.9530
# [Fold 5 | Epoch 015] train_loss=0.0073 | val_acc=0.9250 | val_f1_macro=0.9236
# [Fold 5 | FT Epoch 016] train_loss=0.0102 | val_acc=0.9679 | val_f1_macro=0.9672
# [Fold 5] New best (F1_macro=0.9672) saved (fine-tune).
# [Fold 5 | FT Epoch 017] train_loss=0.0068 | val_acc=0.9571 | val_f1_macro=0.9566
# [Fold 5 | FT Epoch 018] train_loss=0.0112 | val_acc=0.9643 | val_f1_macro=0.9639
# [Fold 5 | FT Epoch 019] train_loss=0.0048 | val_acc=0.9571 | val_f1_macro=0.9567
# [Fold 5 | FT Epoch 020] train_loss=0.0109 | val_acc=0.9571 | val_f1_macro=0.9567
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [BAL] Real class counts (fold): [634, 406, 561] -> target=634
# [Full Train] real=1601 | train_balanced(real+GAN)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-014212

# %% [markdown]
# #aa

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=1.0,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [634, 406, 561], using n_per_class=634
# Setting up PyTorch plugin "bias_act_plugin"...
# W1213 04:16:05.152000 233 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1213 04:16:05.152000 233 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"...
# W1213 04:16:42.733000 233 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1213 04:16:42.733000 233 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# Done.
# [GAN] Saved 634 images for class 'glioma'
# [GAN] Saved 634 images for class 'meningioma'
# [GAN] Saved 634 images for class 'pituitary'
# [GAN] Synth images generated (global): 1902
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [499, 304, 491] -> target=499
# [BAL] Fold 1: real=1294 | train_balanced(real+GAN)=1497
# [ID-STATS] fold1_train: unique patient IDs total = 126 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=47 images=499
#   - pituitary: ids=39 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 202MB/s]
# [Fold 1 | Epoch 001] train_loss=0.3674 | val_acc=0.9055 | val_f1_macro=0.9040
# [Fold 1] New best (F1_macro=0.9040) saved.
# [Fold 1 | Epoch 002] train_loss=0.1242 | val_acc=0.9544 | val_f1_macro=0.9524
# [Fold 1] New best (F1_macro=0.9524) saved.
# [Fold 1 | Epoch 003] train_loss=0.1061 | val_acc=0.9316 | val_f1_macro=0.9331
# [Fold 1 | Epoch 004] train_loss=0.0493 | val_acc=0.9251 | val_f1_macro=0.9331
# [Fold 1 | Epoch 005] train_loss=0.0422 | val_acc=0.9511 | val_f1_macro=0.9498
# [Fold 1 | Epoch 006] train_loss=0.0468 | val_acc=0.9446 | val_f1_macro=0.9470
# [Fold 1 | Epoch 007] train_loss=0.0337 | val_acc=0.9446 | val_f1_macro=0.9461
# [Fold 1 | Epoch 008] train_loss=0.0276 | val_acc=0.9121 | val_f1_macro=0.9077
# [Fold 1 | Epoch 009] train_loss=0.0619 | val_acc=0.9446 | val_f1_macro=0.9444
# [Fold 1 | Epoch 010] train_loss=0.0242 | val_acc=0.9414 | val_f1_macro=0.9439
# [Fold 1 | Epoch 011] train_loss=0.0138 | val_acc=0.9479 | val_f1_macro=0.9479
# [Fold 1 | Epoch 012] train_loss=0.0117 | val_acc=0.9446 | val_f1_macro=0.9423
# [Fold 1 | Epoch 013] train_loss=0.0085 | val_acc=0.9479 | val_f1_macro=0.9439
# [Fold 1 | Epoch 014] train_loss=0.0078 | val_acc=0.9511 | val_f1_macro=0.9517
# [Fold 1 | Epoch 015] train_loss=0.0100 | val_acc=0.9674 | val_f1_macro=0.9659
# [Fold 1] New best (F1_macro=0.9659) saved.
# [Fold 1 | FT Epoch 016] train_loss=0.0087 | val_acc=0.9609 | val_f1_macro=0.9590
# [Fold 1 | FT Epoch 017] train_loss=0.0048 | val_acc=0.9674 | val_f1_macro=0.9666
# [Fold 1] New best (F1_macro=0.9666) saved (fine-tune).
# [Fold 1 | FT Epoch 018] train_loss=0.0064 | val_acc=0.9642 | val_f1_macro=0.9626
# [Fold 1 | FT Epoch 019] train_loss=0.0054 | val_acc=0.9609 | val_f1_macro=0.9595
# [Fold 1 | FT Epoch 020] train_loss=0.0044 | val_acc=0.9609 | val_f1_macro=0.9591
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [524, 342, 422] -> target=524
# [BAL] Fold 2: real=1288 | train_balanced(real+GAN)=1572
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=48 images=524
#   - pituitary: ids=34 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3609 | val_acc=0.8339 | val_f1_macro=0.7765
# [Fold 2] New best (F1_macro=0.7765) saved.
# [Fold 2 | Epoch 002] train_loss=0.1227 | val_acc=0.8978 | val_f1_macro=0.8621
# [Fold 2] New best (F1_macro=0.8621) saved.
# [Fold 2 | Epoch 003] train_loss=0.0763 | val_acc=0.8882 | val_f1_macro=0.8399
# [Fold 2 | Epoch 004] train_loss=0.0906 | val_acc=0.8658 | val_f1_macro=0.8198
# [Fold 2 | Epoch 005] train_loss=0.0594 | val_acc=0.8850 | val_f1_macro=0.8524
# [Fold 2 | Epoch 006] train_loss=0.0690 | val_acc=0.9073 | val_f1_macro=0.8754
# [Fold 2] New best (F1_macro=0.8754) saved.
# [Fold 2 | Epoch 007] train_loss=0.0373 | val_acc=0.9233 | val_f1_macro=0.9050
# [Fold 2] New best (F1_macro=0.9050) saved.
# [Fold 2 | Epoch 008] train_loss=0.0324 | val_acc=0.9137 | val_f1_macro=0.8853
# [Fold 2 | Epoch 009] train_loss=0.0184 | val_acc=0.9265 | val_f1_macro=0.9022
# [Fold 2 | Epoch 010] train_loss=0.0395 | val_acc=0.9010 | val_f1_macro=0.8657
# [Fold 2 | Epoch 011] train_loss=0.0255 | val_acc=0.9105 | val_f1_macro=0.8846
# [Fold 2 | Epoch 012] train_loss=0.0132 | val_acc=0.9265 | val_f1_macro=0.9031
# [Fold 2 | Epoch 013] train_loss=0.0102 | val_acc=0.9105 | val_f1_macro=0.8806
# [Fold 2 | Epoch 014] train_loss=0.0084 | val_acc=0.9201 | val_f1_macro=0.8956
# [Fold 2 | Epoch 015] train_loss=0.0123 | val_acc=0.9233 | val_f1_macro=0.9003
# [Fold 2 | FT Epoch 016] train_loss=0.0061 | val_acc=0.9297 | val_f1_macro=0.9055
# [Fold 2] New best (F1_macro=0.9055) saved (fine-tune).
# [Fold 2 | FT Epoch 017] train_loss=0.0133 | val_acc=0.9265 | val_f1_macro=0.9006
# [Fold 2 | FT Epoch 018] train_loss=0.0071 | val_acc=0.9297 | val_f1_macro=0.9055
# [Fold 2 | FT Epoch 019] train_loss=0.0060 | val_acc=0.9265 | val_f1_macro=0.9006
# [Fold 2 | FT Epoch 020] train_loss=0.0063 | val_acc=0.9265 | val_f1_macro=0.9006
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [506, 301, 450] -> target=506
# [BAL] Fold 3: real=1257 | train_balanced(real+GAN)=1518
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=47 images=506
#   - pituitary: ids=36 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3027 | val_acc=0.8634 | val_f1_macro=0.8549
# [Fold 3] New best (F1_macro=0.8549) saved.
# [Fold 3 | Epoch 002] train_loss=0.1231 | val_acc=0.8779 | val_f1_macro=0.8720
# [Fold 3] New best (F1_macro=0.8720) saved.
# [Fold 3 | Epoch 003] train_loss=0.0982 | val_acc=0.8808 | val_f1_macro=0.8769
# [Fold 3] New best (F1_macro=0.8769) saved.
# [Fold 3 | Epoch 004] train_loss=0.0652 | val_acc=0.8953 | val_f1_macro=0.8924
# [Fold 3] New best (F1_macro=0.8924) saved.
# [Fold 3 | Epoch 005] train_loss=0.0460 | val_acc=0.8983 | val_f1_macro=0.8925
# [Fold 3] New best (F1_macro=0.8925) saved.
# [Fold 3 | Epoch 006] train_loss=0.0447 | val_acc=0.8924 | val_f1_macro=0.8889
# [Fold 3 | Epoch 007] train_loss=0.0180 | val_acc=0.8837 | val_f1_macro=0.8793
# [Fold 3 | Epoch 008] train_loss=0.0330 | val_acc=0.9186 | val_f1_macro=0.9137
# [Fold 3] New best (F1_macro=0.9137) saved.
# [Fold 3 | Epoch 009] train_loss=0.0296 | val_acc=0.8983 | val_f1_macro=0.8946
# [Fold 3 | Epoch 010] train_loss=0.0141 | val_acc=0.8866 | val_f1_macro=0.8838
# [Fold 3 | Epoch 011] train_loss=0.0069 | val_acc=0.8983 | val_f1_macro=0.8950
# [Fold 3 | Epoch 012] train_loss=0.0061 | val_acc=0.8983 | val_f1_macro=0.8946
# [Fold 3 | Epoch 013] train_loss=0.0049 | val_acc=0.8953 | val_f1_macro=0.8919
# [Fold 3 | Epoch 014] train_loss=0.0046 | val_acc=0.8983 | val_f1_macro=0.8946
# [Fold 3 | Epoch 015] train_loss=0.0031 | val_acc=0.8953 | val_f1_macro=0.8923
# [Fold 3 | FT Epoch 016] train_loss=0.0077 | val_acc=0.8953 | val_f1_macro=0.8921
# [Fold 3 | FT Epoch 017] train_loss=0.0048 | val_acc=0.8983 | val_f1_macro=0.8950
# [Fold 3 | FT Epoch 018] train_loss=0.0037 | val_acc=0.8924 | val_f1_macro=0.8892
# [Fold 3 | FT Epoch 019] train_loss=0.0035 | val_acc=0.9012 | val_f1_macro=0.8976
# [Fold 3 | FT Epoch 020] train_loss=0.0165 | val_acc=0.8895 | val_f1_macro=0.8863
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [450, 370, 424] -> target=450
# [BAL] Fold 4: real=1244 | train_balanced(real+GAN)=1350
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=52 images=450
#   - pituitary: ids=35 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.4048 | val_acc=0.9720 | val_f1_macro=0.9512
# [Fold 4] New best (F1_macro=0.9512) saved.
# [Fold 4 | Epoch 002] train_loss=0.1836 | val_acc=0.9720 | val_f1_macro=0.9518
# [Fold 4] New best (F1_macro=0.9518) saved.
# [Fold 4 | Epoch 003] train_loss=0.0984 | val_acc=0.9776 | val_f1_macro=0.9695
# [Fold 4] New best (F1_macro=0.9695) saved.
# [Fold 4 | Epoch 004] train_loss=0.0980 | val_acc=0.9720 | val_f1_macro=0.9685
# [Fold 4 | Epoch 005] train_loss=0.0546 | val_acc=0.9888 | val_f1_macro=0.9808
# [Fold 4] New best (F1_macro=0.9808) saved.
# [Fold 4 | Epoch 006] train_loss=0.0500 | val_acc=0.9776 | val_f1_macro=0.9691
# [Fold 4 | Epoch 007] train_loss=0.0355 | val_acc=0.9720 | val_f1_macro=0.9641
# [Fold 4 | Epoch 008] train_loss=0.0249 | val_acc=0.9860 | val_f1_macro=0.9823
# [Fold 4] New best (F1_macro=0.9823) saved.
# [Fold 4 | Epoch 009] train_loss=0.0266 | val_acc=0.9748 | val_f1_macro=0.9667
# [Fold 4 | Epoch 010] train_loss=0.0260 | val_acc=0.9832 | val_f1_macro=0.9796
# [Fold 4 | Epoch 011] train_loss=0.0463 | val_acc=0.9804 | val_f1_macro=0.9744
# [Fold 4 | Epoch 012] train_loss=0.0232 | val_acc=0.9832 | val_f1_macro=0.9799
# [Fold 4 | Epoch 013] train_loss=0.0170 | val_acc=0.9776 | val_f1_macro=0.9683
# [Fold 4 | Epoch 014] train_loss=0.0119 | val_acc=0.9860 | val_f1_macro=0.9783
# [Fold 4 | Epoch 015] train_loss=0.0080 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4] New best (F1_macro=0.9841) saved.
# [Fold 4 | FT Epoch 016] train_loss=0.0050 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | FT Epoch 017] train_loss=0.0072 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | FT Epoch 018] train_loss=0.0054 | val_acc=0.9860 | val_f1_macro=0.9820
# [Fold 4 | FT Epoch 019] train_loss=0.0092 | val_acc=0.9804 | val_f1_macro=0.9744
# [Fold 4 | FT Epoch 020] train_loss=0.0055 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [557, 307, 457] -> target=557
# [BAL] Fold 5: real=1321 | train_balanced(real+GAN)=1671
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=43 images=557
#   - pituitary: ids=37 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3419 | val_acc=0.7964 | val_f1_macro=0.7850
# [Fold 5] New best (F1_macro=0.7850) saved.
# [Fold 5 | Epoch 002] train_loss=0.1457 | val_acc=0.9179 | val_f1_macro=0.9170
# [Fold 5] New best (F1_macro=0.9170) saved.
# [Fold 5 | Epoch 003] train_loss=0.0775 | val_acc=0.8464 | val_f1_macro=0.8431
# [Fold 5 | Epoch 004] train_loss=0.0816 | val_acc=0.9071 | val_f1_macro=0.9039
# [Fold 5 | Epoch 005] train_loss=0.0592 | val_acc=0.9071 | val_f1_macro=0.9057
# [Fold 5 | Epoch 006] train_loss=0.0690 | val_acc=0.9143 | val_f1_macro=0.9137
# [Fold 5 | Epoch 007] train_loss=0.0529 | val_acc=0.9286 | val_f1_macro=0.9287
# [Fold 5] New best (F1_macro=0.9287) saved.
# [Fold 5 | Epoch 008] train_loss=0.0295 | val_acc=0.9000 | val_f1_macro=0.8995
# [Fold 5 | Epoch 009] train_loss=0.0253 | val_acc=0.9214 | val_f1_macro=0.9211
# [Fold 5 | Epoch 010] train_loss=0.0309 | val_acc=0.8893 | val_f1_macro=0.8884
# [Fold 5 | Epoch 011] train_loss=0.0222 | val_acc=0.9321 | val_f1_macro=0.9317
# [Fold 5] New best (F1_macro=0.9317) saved.
# [Fold 5 | Epoch 012] train_loss=0.0143 | val_acc=0.9250 | val_f1_macro=0.9244
# [Fold 5 | Epoch 013] train_loss=0.0110 | val_acc=0.9143 | val_f1_macro=0.9134
# [Fold 5 | Epoch 014] train_loss=0.0064 | val_acc=0.9179 | val_f1_macro=0.9173
# [Fold 5 | Epoch 015] train_loss=0.0073 | val_acc=0.9071 | val_f1_macro=0.9064
# [Fold 5 | FT Epoch 016] train_loss=0.0095 | val_acc=0.9429 | val_f1_macro=0.9424
# [Fold 5] New best (F1_macro=0.9424) saved (fine-tune).
# [Fold 5 | FT Epoch 017] train_loss=0.0050 | val_acc=0.9250 | val_f1_macro=0.9244
# [Fold 5 | FT Epoch 018] train_loss=0.0170 | val_acc=0.9286 | val_f1_macro=0.9280
# [Fold 5 | FT Epoch 019] train_loss=0.0033 | val_acc=0.9214 | val_f1_macro=0.9209
# [Fold 5 | FT Epoch 020] train_loss=0.0099 | val_acc=0.9250 | val_f1_macro=0.9244
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [BAL] Real class counts (fold): [634, 406, 561] -> target=634
# [Full Train] real=1601 | train_balanced(real+GAN)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251213-041553

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=1.1,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [634, 406, 561], using n_per_class=634
# [GAN] Saved 634 images for class 'glioma'
# [GAN] Saved 634 images for class 'meningioma'
# [GAN] Saved 634 images for class 'pituitary'
# [GAN] Synth images generated (global): 1902
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [499, 304, 491] -> target=499
# [BAL] Fold 1: real=1294 | train_balanced(real+GAN)=1497
# [ID-STATS] fold1_train: unique patient IDs total = 126 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=47 images=499
#   - pituitary: ids=39 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.3655 | val_acc=0.9381 | val_f1_macro=0.9437
# [Fold 1] New best (F1_macro=0.9437) saved.
# [Fold 1 | Epoch 002] train_loss=0.1297 | val_acc=0.8893 | val_f1_macro=0.8960
# [Fold 1 | Epoch 003] train_loss=0.0948 | val_acc=0.9153 | val_f1_macro=0.9184
# [Fold 1 | Epoch 004] train_loss=0.0570 | val_acc=0.9316 | val_f1_macro=0.9309
# [Fold 1 | Epoch 005] train_loss=0.0526 | val_acc=0.9446 | val_f1_macro=0.9444
# [Fold 1] New best (F1_macro=0.9444) saved.
# [Fold 1 | Epoch 006] train_loss=0.0410 | val_acc=0.9609 | val_f1_macro=0.9602
# [Fold 1] New best (F1_macro=0.9602) saved.
# [Fold 1 | Epoch 007] train_loss=0.0228 | val_acc=0.9218 | val_f1_macro=0.9279
# [Fold 1 | Epoch 008] train_loss=0.0311 | val_acc=0.9544 | val_f1_macro=0.9550
# [Fold 1 | Epoch 009] train_loss=0.0355 | val_acc=0.9479 | val_f1_macro=0.9464
# [Fold 1 | Epoch 010] train_loss=0.0210 | val_acc=0.9511 | val_f1_macro=0.9493
# [Fold 1 | Epoch 011] train_loss=0.0080 | val_acc=0.9446 | val_f1_macro=0.9441
# [Fold 1 | Epoch 012] train_loss=0.0106 | val_acc=0.9349 | val_f1_macro=0.9353
# [Fold 1 | Epoch 013] train_loss=0.0054 | val_acc=0.9511 | val_f1_macro=0.9494
# [Fold 1 | Epoch 014] train_loss=0.0041 | val_acc=0.9479 | val_f1_macro=0.9479
# [Fold 1 | Epoch 015] train_loss=0.0039 | val_acc=0.9511 | val_f1_macro=0.9507
# [Fold 1 | FT Epoch 016] train_loss=0.0106 | val_acc=0.9511 | val_f1_macro=0.9510
# [Fold 1 | FT Epoch 017] train_loss=0.0061 | val_acc=0.9511 | val_f1_macro=0.9496
# [Fold 1 | FT Epoch 018] train_loss=0.0082 | val_acc=0.9577 | val_f1_macro=0.9552
# [Fold 1 | FT Epoch 019] train_loss=0.0039 | val_acc=0.9609 | val_f1_macro=0.9591
# [Fold 1 | FT Epoch 020] train_loss=0.0036 | val_acc=0.9609 | val_f1_macro=0.9592
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [524, 342, 422] -> target=524
# [BAL] Fold 2: real=1288 | train_balanced(real+GAN)=1572
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=48 images=524
#   - pituitary: ids=34 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3573 | val_acc=0.8786 | val_f1_macro=0.8270
# [Fold 2] New best (F1_macro=0.8270) saved.
# [Fold 2 | Epoch 002] train_loss=0.1114 | val_acc=0.9073 | val_f1_macro=0.8858
# [Fold 2] New best (F1_macro=0.8858) saved.
# [Fold 2 | Epoch 003] train_loss=0.0660 | val_acc=0.8403 | val_f1_macro=0.7729
# [Fold 2 | Epoch 004] train_loss=0.1286 | val_acc=0.9137 | val_f1_macro=0.8856
# [Fold 2 | Epoch 005] train_loss=0.0491 | val_acc=0.9042 | val_f1_macro=0.8785
# [Fold 2 | Epoch 006] train_loss=0.0614 | val_acc=0.9233 | val_f1_macro=0.8956
# [Fold 2] New best (F1_macro=0.8956) saved.
# [Fold 2 | Epoch 007] train_loss=0.0382 | val_acc=0.9201 | val_f1_macro=0.8950
# [Fold 2 | Epoch 008] train_loss=0.0350 | val_acc=0.9073 | val_f1_macro=0.8701
# [Fold 2 | Epoch 009] train_loss=0.0146 | val_acc=0.9137 | val_f1_macro=0.8829
# [Fold 2 | Epoch 010] train_loss=0.0288 | val_acc=0.9169 | val_f1_macro=0.8900
# [Fold 2 | Epoch 011] train_loss=0.0234 | val_acc=0.9233 | val_f1_macro=0.8980
# [Fold 2] New best (F1_macro=0.8980) saved.
# [Fold 2 | Epoch 012] train_loss=0.0139 | val_acc=0.9233 | val_f1_macro=0.8984
# [Fold 2] New best (F1_macro=0.8984) saved.
# [Fold 2 | Epoch 013] train_loss=0.0188 | val_acc=0.9137 | val_f1_macro=0.8809
# [Fold 2 | Epoch 014] train_loss=0.0095 | val_acc=0.9105 | val_f1_macro=0.8759
# [Fold 2 | Epoch 015] train_loss=0.0083 | val_acc=0.9233 | val_f1_macro=0.8986
# [Fold 2] New best (F1_macro=0.8986) saved.
# [Fold 2 | FT Epoch 016] train_loss=0.0130 | val_acc=0.9137 | val_f1_macro=0.8850
# [Fold 2 | FT Epoch 017] train_loss=0.0076 | val_acc=0.9137 | val_f1_macro=0.8848
# [Fold 2 | FT Epoch 018] train_loss=0.0066 | val_acc=0.9169 | val_f1_macro=0.8892
# [Fold 2 | FT Epoch 019] train_loss=0.0058 | val_acc=0.9137 | val_f1_macro=0.8845
# [Fold 2 | FT Epoch 020] train_loss=0.0048 | val_acc=0.9137 | val_f1_macro=0.8845
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [506, 301, 450] -> target=506
# [BAL] Fold 3: real=1257 | train_balanced(real+GAN)=1518
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=47 images=506
#   - pituitary: ids=36 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3161 | val_acc=0.8401 | val_f1_macro=0.8324
# [Fold 3] New best (F1_macro=0.8324) saved.
# [Fold 3 | Epoch 002] train_loss=0.1174 | val_acc=0.8837 | val_f1_macro=0.8803
# [Fold 3] New best (F1_macro=0.8803) saved.
# [Fold 3 | Epoch 003] train_loss=0.0724 | val_acc=0.8983 | val_f1_macro=0.8949
# [Fold 3] New best (F1_macro=0.8949) saved.
# [Fold 3 | Epoch 004] train_loss=0.0521 | val_acc=0.8866 | val_f1_macro=0.8839
# [Fold 3 | Epoch 005] train_loss=0.0544 | val_acc=0.9012 | val_f1_macro=0.8968
# [Fold 3] New best (F1_macro=0.8968) saved.
# [Fold 3 | Epoch 006] train_loss=0.0270 | val_acc=0.9157 | val_f1_macro=0.9109
# [Fold 3] New best (F1_macro=0.9109) saved.
# [Fold 3 | Epoch 007] train_loss=0.0211 | val_acc=0.8983 | val_f1_macro=0.8950
# [Fold 3 | Epoch 008] train_loss=0.0243 | val_acc=0.9099 | val_f1_macro=0.9047
# [Fold 3 | Epoch 009] train_loss=0.0252 | val_acc=0.9041 | val_f1_macro=0.8974
# [Fold 3 | Epoch 010] train_loss=0.0118 | val_acc=0.9128 | val_f1_macro=0.9084
# [Fold 3 | Epoch 011] train_loss=0.0130 | val_acc=0.9215 | val_f1_macro=0.9165
# [Fold 3] New best (F1_macro=0.9165) saved.
# [Fold 3 | Epoch 012] train_loss=0.0071 | val_acc=0.9186 | val_f1_macro=0.9128
# [Fold 3 | Epoch 013] train_loss=0.0088 | val_acc=0.9215 | val_f1_macro=0.9161
# [Fold 3 | Epoch 014] train_loss=0.0042 | val_acc=0.9186 | val_f1_macro=0.9137
# [Fold 3 | Epoch 015] train_loss=0.0021 | val_acc=0.9157 | val_f1_macro=0.9111
# [Fold 3 | FT Epoch 016] train_loss=0.0097 | val_acc=0.9215 | val_f1_macro=0.9173
# [Fold 3] New best (F1_macro=0.9173) saved (fine-tune).
# [Fold 3 | FT Epoch 017] train_loss=0.0087 | val_acc=0.9244 | val_f1_macro=0.9197
# [Fold 3] New best (F1_macro=0.9197) saved (fine-tune).
# [Fold 3 | FT Epoch 018] train_loss=0.0051 | val_acc=0.9244 | val_f1_macro=0.9199
# [Fold 3] New best (F1_macro=0.9199) saved (fine-tune).
# [Fold 3 | FT Epoch 019] train_loss=0.0026 | val_acc=0.9244 | val_f1_macro=0.9199
# [Fold 3 | FT Epoch 020] train_loss=0.0125 | val_acc=0.9157 | val_f1_macro=0.9111
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [450, 370, 424] -> target=450
# [BAL] Fold 4: real=1244 | train_balanced(real+GAN)=1350
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=52 images=450
#   - pituitary: ids=35 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.3973 | val_acc=0.9412 | val_f1_macro=0.9067
# [Fold 4] New best (F1_macro=0.9067) saved.
# [Fold 4 | Epoch 002] train_loss=0.1948 | val_acc=0.9692 | val_f1_macro=0.9450
# [Fold 4] New best (F1_macro=0.9450) saved.
# [Fold 4 | Epoch 003] train_loss=0.1219 | val_acc=0.9860 | val_f1_macro=0.9759
# [Fold 4] New best (F1_macro=0.9759) saved.
# [Fold 4 | Epoch 004] train_loss=0.0810 | val_acc=0.9552 | val_f1_macro=0.9410
# [Fold 4 | Epoch 005] train_loss=0.0601 | val_acc=0.9776 | val_f1_macro=0.9726
# [Fold 4 | Epoch 006] train_loss=0.0707 | val_acc=0.9692 | val_f1_macro=0.9516
# [Fold 4 | Epoch 007] train_loss=0.0285 | val_acc=0.9776 | val_f1_macro=0.9619
# [Fold 4 | Epoch 008] train_loss=0.0446 | val_acc=0.9776 | val_f1_macro=0.9719
# [Fold 4 | Epoch 009] train_loss=0.0247 | val_acc=0.9776 | val_f1_macro=0.9695
# [Fold 4 | Epoch 010] train_loss=0.0168 | val_acc=0.9748 | val_f1_macro=0.9644
# [Fold 4 | Epoch 011] train_loss=0.0213 | val_acc=0.9888 | val_f1_macro=0.9844
# [Fold 4] New best (F1_macro=0.9844) saved.
# [Fold 4 | Epoch 012] train_loss=0.0128 | val_acc=0.9888 | val_f1_macro=0.9844
# [Fold 4 | Epoch 013] train_loss=0.0124 | val_acc=0.9860 | val_f1_macro=0.9823
# [Fold 4 | Epoch 014] train_loss=0.0134 | val_acc=0.9888 | val_f1_macro=0.9811
# [Fold 4 | Epoch 015] train_loss=0.0048 | val_acc=0.9860 | val_f1_macro=0.9787
# [Fold 4 | FT Epoch 016] train_loss=0.0043 | val_acc=0.9860 | val_f1_macro=0.9759
# [Fold 4 | FT Epoch 017] train_loss=0.0072 | val_acc=0.9832 | val_f1_macro=0.9702
# [Fold 4 | FT Epoch 018] train_loss=0.0058 | val_acc=0.9832 | val_f1_macro=0.9702
# [Fold 4 | FT Epoch 019] train_loss=0.0050 | val_acc=0.9860 | val_f1_macro=0.9759
# [Fold 4 | FT Epoch 020] train_loss=0.0077 | val_acc=0.9832 | val_f1_macro=0.9702
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [557, 307, 457] -> target=557
# [BAL] Fold 5: real=1321 | train_balanced(real+GAN)=1671
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=43 images=557
#   - pituitary: ids=37 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3330 | val_acc=0.7000 | val_f1_macro=0.6653
# [Fold 5] New best (F1_macro=0.6653) saved.
# [Fold 5 | Epoch 002] train_loss=0.1541 | val_acc=0.9036 | val_f1_macro=0.9030
# [Fold 5] New best (F1_macro=0.9030) saved.
# [Fold 5 | Epoch 003] train_loss=0.0926 | val_acc=0.8857 | val_f1_macro=0.8851
# [Fold 5 | Epoch 004] train_loss=0.0672 | val_acc=0.9250 | val_f1_macro=0.9243
# [Fold 5] New best (F1_macro=0.9243) saved.
# [Fold 5 | Epoch 005] train_loss=0.0513 | val_acc=0.9107 | val_f1_macro=0.9088
# [Fold 5 | Epoch 006] train_loss=0.0957 | val_acc=0.9321 | val_f1_macro=0.9313
# [Fold 5] New best (F1_macro=0.9313) saved.
# [Fold 5 | Epoch 007] train_loss=0.0382 | val_acc=0.9393 | val_f1_macro=0.9387
# [Fold 5] New best (F1_macro=0.9387) saved.
# [Fold 5 | Epoch 008] train_loss=0.0271 | val_acc=0.9393 | val_f1_macro=0.9381
# [Fold 5 | Epoch 009] train_loss=0.0236 | val_acc=0.9179 | val_f1_macro=0.9171
# [Fold 5 | Epoch 010] train_loss=0.0254 | val_acc=0.9607 | val_f1_macro=0.9603
# [Fold 5] New best (F1_macro=0.9603) saved.
# [Fold 5 | Epoch 011] train_loss=0.0084 | val_acc=0.9250 | val_f1_macro=0.9241
# [Fold 5 | Epoch 012] train_loss=0.0113 | val_acc=0.9571 | val_f1_macro=0.9563
# [Fold 5 | Epoch 013] train_loss=0.0083 | val_acc=0.9500 | val_f1_macro=0.9493
# [Fold 5 | Epoch 014] train_loss=0.0056 | val_acc=0.9393 | val_f1_macro=0.9387
# [Fold 5 | Epoch 015] train_loss=0.0051 | val_acc=0.9071 | val_f1_macro=0.9060
# [Fold 5 | FT Epoch 016] train_loss=0.0113 | val_acc=0.9500 | val_f1_macro=0.9489
# [Fold 5 | FT Epoch 017] train_loss=0.0072 | val_acc=0.9214 | val_f1_macro=0.9207
# [Fold 5 | FT Epoch 018] train_loss=0.0099 | val_acc=0.9286 | val_f1_macro=0.9278
# [Fold 5 | FT Epoch 019] train_loss=0.0039 | val_acc=0.9286 | val_f1_macro=0.9277
# [Fold 5 | FT Epoch 020] train_loss=0.0092 | val_acc=0.9214 | val_f1_macro=0.9206
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [BAL] Real class counts (fold): [634, 406, 561] -> target=634
# [Full Train] real=1601 | train_balanced(real+GAN)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-015123

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=1.2,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [634, 406, 561], using n_per_class=634
# Setting up PyTorch plugin "bias_act_plugin"...
# W1112 22:51:34.359000 6568 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1112 22:51:34.359000 6568 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"...
# W1112 22:52:00.948000 6568 torch/utils/cpp_extension.py:2425] TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# W1112 22:52:00.948000 6568 torch/utils/cpp_extension.py:2425] If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'] to specific architectures.
# Done.
# [GAN] Saved 634 images for class 'glioma'
# [GAN] Saved 634 images for class 'meningioma'
# [GAN] Saved 634 images for class 'pituitary'
# [GAN] Synth images generated (global): 1902
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [499, 304, 491] -> target=499
# [BAL] Fold 1: real=1294 | train_balanced(real+GAN)=1497
# [ID-STATS] fold1_train: unique patient IDs total = 126 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=47 images=499
#   - pituitary: ids=39 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 237MB/s]
# [Fold 1 | Epoch 001] train_loss=0.3711 | val_acc=0.8534 | val_f1_macro=0.8707
# [Fold 1] New best (F1_macro=0.8707) saved.
# [Fold 1 | Epoch 002] train_loss=0.1508 | val_acc=0.9414 | val_f1_macro=0.9402
# [Fold 1] New best (F1_macro=0.9402) saved.
# [Fold 1 | Epoch 003] train_loss=0.0958 | val_acc=0.9381 | val_f1_macro=0.9365
# [Fold 1 | Epoch 004] train_loss=0.0522 | val_acc=0.9349 | val_f1_macro=0.9315
# [Fold 1 | Epoch 005] train_loss=0.0528 | val_acc=0.9186 | val_f1_macro=0.9151
# [Fold 1 | Epoch 006] train_loss=0.0500 | val_acc=0.9479 | val_f1_macro=0.9476
# [Fold 1] New best (F1_macro=0.9476) saved.
# [Fold 1 | Epoch 007] train_loss=0.0374 | val_acc=0.9577 | val_f1_macro=0.9558
# [Fold 1] New best (F1_macro=0.9558) saved.
# [Fold 1 | Epoch 008] train_loss=0.0211 | val_acc=0.9544 | val_f1_macro=0.9509
# [Fold 1 | Epoch 009] train_loss=0.0405 | val_acc=0.9544 | val_f1_macro=0.9537
# [Fold 1 | Epoch 010] train_loss=0.0215 | val_acc=0.9577 | val_f1_macro=0.9549
# [Fold 1 | Epoch 011] train_loss=0.0137 | val_acc=0.9479 | val_f1_macro=0.9462
# [Fold 1 | Epoch 012] train_loss=0.0188 | val_acc=0.9283 | val_f1_macro=0.9271
# [Fold 1 | Epoch 013] train_loss=0.0115 | val_acc=0.9577 | val_f1_macro=0.9557
# [Fold 1 | Epoch 014] train_loss=0.0059 | val_acc=0.9609 | val_f1_macro=0.9572
# [Fold 1] New best (F1_macro=0.9572) saved.
# [Fold 1 | Epoch 015] train_loss=0.0068 | val_acc=0.9642 | val_f1_macro=0.9625
# [Fold 1] New best (F1_macro=0.9625) saved.
# [Fold 1 | FT Epoch 016] train_loss=0.0116 | val_acc=0.9642 | val_f1_macro=0.9637
# [Fold 1] New best (F1_macro=0.9637) saved (fine-tune).
# [Fold 1 | FT Epoch 017] train_loss=0.0041 | val_acc=0.9642 | val_f1_macro=0.9637
# [Fold 1 | FT Epoch 018] train_loss=0.0080 | val_acc=0.9674 | val_f1_macro=0.9653
# [Fold 1] New best (F1_macro=0.9653) saved (fine-tune).
# [Fold 1 | FT Epoch 019] train_loss=0.0038 | val_acc=0.9609 | val_f1_macro=0.9572
# [Fold 1 | FT Epoch 020] train_loss=0.0048 | val_acc=0.9609 | val_f1_macro=0.9572
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [524, 342, 422] -> target=524
# [BAL] Fold 2: real=1288 | train_balanced(real+GAN)=1572
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=48 images=524
#   - pituitary: ids=34 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3648 | val_acc=0.8498 | val_f1_macro=0.7996
# [Fold 2] New best (F1_macro=0.7996) saved.
# [Fold 2 | Epoch 002] train_loss=0.1128 | val_acc=0.9042 | val_f1_macro=0.8764
# [Fold 2] New best (F1_macro=0.8764) saved.
# [Fold 2 | Epoch 003] train_loss=0.0768 | val_acc=0.8818 | val_f1_macro=0.8292
# [Fold 2 | Epoch 004] train_loss=0.0865 | val_acc=0.9105 | val_f1_macro=0.8841
# [Fold 2] New best (F1_macro=0.8841) saved.
# [Fold 2 | Epoch 005] train_loss=0.0622 | val_acc=0.8658 | val_f1_macro=0.8336
# [Fold 2 | Epoch 006] train_loss=0.0887 | val_acc=0.9073 | val_f1_macro=0.8811
# [Fold 2 | Epoch 007] train_loss=0.0403 | val_acc=0.8914 | val_f1_macro=0.8650
# [Fold 2 | Epoch 008] train_loss=0.0427 | val_acc=0.9010 | val_f1_macro=0.8609
# [Fold 2 | Epoch 009] train_loss=0.0158 | val_acc=0.9201 | val_f1_macro=0.8948
# [Fold 2] New best (F1_macro=0.8948) saved.
# [Fold 2 | Epoch 010] train_loss=0.0484 | val_acc=0.8978 | val_f1_macro=0.8629
# [Fold 2 | Epoch 011] train_loss=0.0171 | val_acc=0.9042 | val_f1_macro=0.8701
# [Fold 2 | Epoch 012] train_loss=0.0138 | val_acc=0.9137 | val_f1_macro=0.8851
# [Fold 2 | Epoch 013] train_loss=0.0101 | val_acc=0.8978 | val_f1_macro=0.8566
# [Fold 2 | Epoch 014] train_loss=0.0175 | val_acc=0.9073 | val_f1_macro=0.8730
# [Fold 2 | Epoch 015] train_loss=0.0090 | val_acc=0.9265 | val_f1_macro=0.9020
# [Fold 2] New best (F1_macro=0.9020) saved.
# [Fold 2 | FT Epoch 016] train_loss=0.0182 | val_acc=0.9233 | val_f1_macro=0.8974
# [Fold 2 | FT Epoch 017] train_loss=0.0079 | val_acc=0.9137 | val_f1_macro=0.8831
# [Fold 2 | FT Epoch 018] train_loss=0.0083 | val_acc=0.9233 | val_f1_macro=0.8974
# [Fold 2 | FT Epoch 019] train_loss=0.0080 | val_acc=0.9169 | val_f1_macro=0.8879
# [Fold 2 | FT Epoch 020] train_loss=0.0107 | val_acc=0.9201 | val_f1_macro=0.8926
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [506, 301, 450] -> target=506
# [BAL] Fold 3: real=1257 | train_balanced(real+GAN)=1518
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=47 images=506
#   - pituitary: ids=36 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3102 | val_acc=0.8576 | val_f1_macro=0.8448
# [Fold 3] New best (F1_macro=0.8448) saved.
# [Fold 3 | Epoch 002] train_loss=0.1102 | val_acc=0.8576 | val_f1_macro=0.8561
# [Fold 3] New best (F1_macro=0.8561) saved.
# [Fold 3 | Epoch 003] train_loss=0.0818 | val_acc=0.9012 | val_f1_macro=0.8966
# [Fold 3] New best (F1_macro=0.8966) saved.
# [Fold 3 | Epoch 004] train_loss=0.0740 | val_acc=0.8721 | val_f1_macro=0.8685
# [Fold 3 | Epoch 005] train_loss=0.0452 | val_acc=0.8983 | val_f1_macro=0.8923
# [Fold 3 | Epoch 006] train_loss=0.0426 | val_acc=0.8808 | val_f1_macro=0.8781
# [Fold 3 | Epoch 007] train_loss=0.0145 | val_acc=0.9012 | val_f1_macro=0.8963
# [Fold 3 | Epoch 008] train_loss=0.0292 | val_acc=0.8779 | val_f1_macro=0.8752
# [Fold 3 | Epoch 009] train_loss=0.0245 | val_acc=0.9070 | val_f1_macro=0.9024
# [Fold 3] New best (F1_macro=0.9024) saved.
# [Fold 3 | Epoch 010] train_loss=0.0152 | val_acc=0.9128 | val_f1_macro=0.9086
# [Fold 3] New best (F1_macro=0.9086) saved.
# [Fold 3 | Epoch 011] train_loss=0.0185 | val_acc=0.9012 | val_f1_macro=0.8974
# [Fold 3 | Epoch 012] train_loss=0.0090 | val_acc=0.9099 | val_f1_macro=0.9057
# [Fold 3 | Epoch 013] train_loss=0.0036 | val_acc=0.9157 | val_f1_macro=0.9113
# [Fold 3] New best (F1_macro=0.9113) saved.
# [Fold 3 | Epoch 014] train_loss=0.0059 | val_acc=0.9128 | val_f1_macro=0.9088
# [Fold 3 | Epoch 015] train_loss=0.0036 | val_acc=0.9099 | val_f1_macro=0.9060
# [Fold 3 | FT Epoch 016] train_loss=0.0103 | val_acc=0.9070 | val_f1_macro=0.9029
# [Fold 3 | FT Epoch 017] train_loss=0.0074 | val_acc=0.9128 | val_f1_macro=0.9088
# [Fold 3 | FT Epoch 018] train_loss=0.0045 | val_acc=0.9099 | val_f1_macro=0.9060
# [Fold 3 | FT Epoch 019] train_loss=0.0024 | val_acc=0.9128 | val_f1_macro=0.9088
# [Fold 3 | FT Epoch 020] train_loss=0.0101 | val_acc=0.9099 | val_f1_macro=0.9058
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [450, 370, 424] -> target=450
# [BAL] Fold 4: real=1244 | train_balanced(real+GAN)=1350
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=52 images=450
#   - pituitary: ids=35 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.4193 | val_acc=0.9636 | val_f1_macro=0.9413
# [Fold 4] New best (F1_macro=0.9413) saved.
# [Fold 4 | Epoch 002] train_loss=0.1494 | val_acc=0.9692 | val_f1_macro=0.9494
# [Fold 4] New best (F1_macro=0.9494) saved.
# [Fold 4 | Epoch 003] train_loss=0.1183 | val_acc=0.9412 | val_f1_macro=0.9158
# [Fold 4 | Epoch 004] train_loss=0.0667 | val_acc=0.9804 | val_f1_macro=0.9741
# [Fold 4] New best (F1_macro=0.9741) saved.
# [Fold 4 | Epoch 005] train_loss=0.0695 | val_acc=0.9860 | val_f1_macro=0.9783
# [Fold 4] New best (F1_macro=0.9783) saved.
# [Fold 4 | Epoch 006] train_loss=0.0600 | val_acc=0.9720 | val_f1_macro=0.9584
# [Fold 4 | Epoch 007] train_loss=0.0327 | val_acc=0.9720 | val_f1_macro=0.9526
# [Fold 4 | Epoch 008] train_loss=0.0212 | val_acc=0.9888 | val_f1_macro=0.9844
# [Fold 4] New best (F1_macro=0.9844) saved.
# [Fold 4 | Epoch 009] train_loss=0.0165 | val_acc=0.9804 | val_f1_macro=0.9675
# [Fold 4 | Epoch 010] train_loss=0.0151 | val_acc=0.9748 | val_f1_macro=0.9557
# [Fold 4 | Epoch 011] train_loss=0.0246 | val_acc=0.9888 | val_f1_macro=0.9811
# [Fold 4 | Epoch 012] train_loss=0.0237 | val_acc=0.9860 | val_f1_macro=0.9823
# [Fold 4 | Epoch 013] train_loss=0.0137 | val_acc=0.9888 | val_f1_macro=0.9877
# [Fold 4] New best (F1_macro=0.9877) saved.
# [Fold 4 | Epoch 014] train_loss=0.0085 | val_acc=0.9888 | val_f1_macro=0.9849
# [Fold 4 | Epoch 015] train_loss=0.0077 | val_acc=0.9944 | val_f1_macro=0.9920
# [Fold 4] New best (F1_macro=0.9920) saved.
# [Fold 4 | FT Epoch 016] train_loss=0.0066 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 017] train_loss=0.0094 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | FT Epoch 018] train_loss=0.0044 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | FT Epoch 019] train_loss=0.0067 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 020] train_loss=0.0063 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [557, 307, 457] -> target=557
# [BAL] Fold 5: real=1321 | train_balanced(real+GAN)=1671
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=43 images=557
#   - pituitary: ids=37 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3333 | val_acc=0.8179 | val_f1_macro=0.8098
# [Fold 5] New best (F1_macro=0.8098) saved.
# [Fold 5 | Epoch 002] train_loss=0.1485 | val_acc=0.9036 | val_f1_macro=0.9044
# [Fold 5] New best (F1_macro=0.9044) saved.
# [Fold 5 | Epoch 003] train_loss=0.0887 | val_acc=0.8607 | val_f1_macro=0.8586
# [Fold 5 | Epoch 004] train_loss=0.0815 | val_acc=0.8393 | val_f1_macro=0.8361
# [Fold 5 | Epoch 005] train_loss=0.0509 | val_acc=0.9107 | val_f1_macro=0.9095
# [Fold 5] New best (F1_macro=0.9095) saved.
# [Fold 5 | Epoch 006] train_loss=0.0766 | val_acc=0.9143 | val_f1_macro=0.9136
# [Fold 5] New best (F1_macro=0.9136) saved.
# [Fold 5 | Epoch 007] train_loss=0.0469 | val_acc=0.8571 | val_f1_macro=0.8563
# [Fold 5 | Epoch 008] train_loss=0.0383 | val_acc=0.9464 | val_f1_macro=0.9459
# [Fold 5] New best (F1_macro=0.9459) saved.
# [Fold 5 | Epoch 009] train_loss=0.0334 | val_acc=0.9571 | val_f1_macro=0.9568
# [Fold 5] New best (F1_macro=0.9568) saved.
# [Fold 5 | Epoch 010] train_loss=0.0616 | val_acc=0.7786 | val_f1_macro=0.7638
# [Fold 5 | Epoch 011] train_loss=0.0238 | val_acc=0.8929 | val_f1_macro=0.8917
# [Fold 5 | Epoch 012] train_loss=0.0128 | val_acc=0.9321 | val_f1_macro=0.9315
# [Fold 5 | Epoch 013] train_loss=0.0117 | val_acc=0.9250 | val_f1_macro=0.9238
# [Fold 5 | Epoch 014] train_loss=0.0061 | val_acc=0.9000 | val_f1_macro=0.8989
# [Fold 5 | Epoch 015] train_loss=0.0102 | val_acc=0.9071 | val_f1_macro=0.9066
# [Fold 5 | FT Epoch 016] train_loss=0.0217 | val_acc=0.9571 | val_f1_macro=0.9568
# [Fold 5] New best (F1_macro=0.9568) saved (fine-tune).
# [Fold 5 | FT Epoch 017] train_loss=0.0058 | val_acc=0.9250 | val_f1_macro=0.9240
# [Fold 5 | FT Epoch 018] train_loss=0.0141 | val_acc=0.9429 | val_f1_macro=0.9427
# [Fold 5 | FT Epoch 019] train_loss=0.0045 | val_acc=0.9286 | val_f1_macro=0.9277
# [Fold 5 | FT Epoch 020] train_loss=0.0113 | val_acc=0.9357 | val_f1_macro=0.9350
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [BAL] Real class counts (fold): [634, 406, 561] -> target=634
# [Full Train] real=1601 | train_balanced(real+GAN)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-225111

# %%
import os
from pathlib import Path
from collections import defaultdict
from typing import List, Tuple, Dict

# Assuming scan_folder and extract_patient_id are already defined in the environment
# from cell jV1_XG1syq7x

def get_data_summary(data_root_path: str) -> Dict:
    """
    Scans a directory to count images and unique patient IDs per class.

    Args:
        data_root_path (str): The path to the root directory containing class subfolders.

    Returns:
        Dict: A dictionary containing summary statistics:
              - 'total_images': total number of images found.
              - 'total_patients': total number of unique patients found.
              - 'class_names': List of class names.
              - 'class_stats': a dictionary with stats per class, e.g.,
                {'glioma': {'images': 100, 'patients': 10}, ...}
    """
    root_path_obj = Path(data_root_path)
    if not root_path_obj.is_dir():
        print(f"Error: Path '{data_root_path}' is not a valid directory.")
        return {"error": f"Path '{data_root_path}' is not a valid directory."}

    items, class_names = scan_folder(root_path_obj)

    ids_by_class = defaultdict(set)
    imgs_by_class = defaultdict(int)
    all_unique_patients = set()

    for _, class_idx, patient_id in items:
        ids_by_class[class_idx].add(patient_id)
        imgs_by_class[class_idx] += 1
        all_unique_patients.add(patient_id)

    summary = {
        "total_images": len(items),
        "total_patients": len(all_unique_patients),
        "class_names": class_names,
        "class_stats": {}
    }

    print(f"Summary for: {data_root_path}")
    print(f"  Total images: {len(items)}")
    print(f"  Total unique patients: {len(all_unique_patients)}")
    print("  Per-class statistics:")

    for i, cname in enumerate(class_names):
        num_images = imgs_by_class[i]
        num_patients = len(ids_by_class[i])
        summary["class_stats"][cname] = {
            "images": num_images,
            "patients": num_patients
        }
        print(f"    - Class '{cname}': {num_images} images, {num_patients} patients")

    return summary

# %%
# Example usage:
# Use one of the previously unzipped directories, for instance, the training data
train_data_path = "/content/localdata/test_unzipped/testreducido"

# Get and print the summary
summary_results = get_data_summary(train_data_path)

# You can also access the dictionary directly
print("\nFull summary dictionary:")
print(summary_results)
# Out:
# Summary for: /content/localdata/test_unzipped/testreducido
#   Total images: 702
#   Total unique patients: 68
#   Per-class statistics:
#     - Class 'glioma': 312 images, 29 patients
#     - Class 'meningioma': 141 images, 21 patients
#     - Class 'pituitary': 249 images, 18 patients
#
# Full summary dictionary:
# {'total_images': 702, 'total_patients': 68, 'class_names': ['glioma', 'meningioma', 'pituitary'], 'class_stats': {'glioma': {'images': 312, 'patients': 29}, 'meningioma': {'images': 141, 'patients': 21}, 'pituitary': {'images': 249, 'patients': 18}}}

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=1.3,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [634, 406, 561], using n_per_class=634
# [GAN] Saved 634 images for class 'glioma'
# [GAN] Saved 634 images for class 'meningioma'
# [GAN] Saved 634 images for class 'pituitary'
# [GAN] Synth images generated (global): 1902
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [499, 304, 491] -> target=499
# [BAL] Fold 1: real=1294 | train_balanced(real+GAN)=1497
# [ID-STATS] fold1_train: unique patient IDs total = 126 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=47 images=499
#   - pituitary: ids=39 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.3540 | val_acc=0.9251 | val_f1_macro=0.9288
# [Fold 1] New best (F1_macro=0.9288) saved.
# [Fold 1 | Epoch 002] train_loss=0.1324 | val_acc=0.9121 | val_f1_macro=0.9152
# [Fold 1 | Epoch 003] train_loss=0.0853 | val_acc=0.9381 | val_f1_macro=0.9379
# [Fold 1] New best (F1_macro=0.9379) saved.
# [Fold 1 | Epoch 004] train_loss=0.0453 | val_acc=0.9414 | val_f1_macro=0.9440
# [Fold 1] New best (F1_macro=0.9440) saved.
# [Fold 1 | Epoch 005] train_loss=0.0654 | val_acc=0.9055 | val_f1_macro=0.9088
# [Fold 1 | Epoch 006] train_loss=0.0443 | val_acc=0.9511 | val_f1_macro=0.9517
# [Fold 1] New best (F1_macro=0.9517) saved.
# [Fold 1 | Epoch 007] train_loss=0.0168 | val_acc=0.9544 | val_f1_macro=0.9550
# [Fold 1] New best (F1_macro=0.9550) saved.
# [Fold 1 | Epoch 008] train_loss=0.0286 | val_acc=0.9251 | val_f1_macro=0.9276
# [Fold 1 | Epoch 009] train_loss=0.0550 | val_acc=0.9121 | val_f1_macro=0.9164
# [Fold 1 | Epoch 010] train_loss=0.0253 | val_acc=0.9479 | val_f1_macro=0.9481
# [Fold 1 | Epoch 011] train_loss=0.0093 | val_acc=0.9511 | val_f1_macro=0.9531
# [Fold 1 | Epoch 012] train_loss=0.0079 | val_acc=0.9414 | val_f1_macro=0.9401
# [Fold 1 | Epoch 013] train_loss=0.0048 | val_acc=0.9446 | val_f1_macro=0.9455
# [Fold 1 | Epoch 014] train_loss=0.0045 | val_acc=0.9511 | val_f1_macro=0.9507
# [Fold 1 | Epoch 015] train_loss=0.0076 | val_acc=0.9609 | val_f1_macro=0.9592
# [Fold 1] New best (F1_macro=0.9592) saved.
# [Fold 1 | FT Epoch 016] train_loss=0.0084 | val_acc=0.9739 | val_f1_macro=0.9717
# [Fold 1] New best (F1_macro=0.9717) saved (fine-tune).
# [Fold 1 | FT Epoch 017] train_loss=0.0052 | val_acc=0.9707 | val_f1_macro=0.9687
# [Fold 1 | FT Epoch 018] train_loss=0.0053 | val_acc=0.9739 | val_f1_macro=0.9717
# [Fold 1 | FT Epoch 019] train_loss=0.0057 | val_acc=0.9674 | val_f1_macro=0.9647
# [Fold 1 | FT Epoch 020] train_loss=0.0031 | val_acc=0.9707 | val_f1_macro=0.9678
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [524, 342, 422] -> target=524
# [BAL] Fold 2: real=1288 | train_balanced(real+GAN)=1572
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=48 images=524
#   - pituitary: ids=34 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3565 | val_acc=0.8435 | val_f1_macro=0.7657
# [Fold 2] New best (F1_macro=0.7657) saved.
# [Fold 2 | Epoch 002] train_loss=0.1240 | val_acc=0.8914 | val_f1_macro=0.8510
# [Fold 2] New best (F1_macro=0.8510) saved.
# [Fold 2 | Epoch 003] train_loss=0.0862 | val_acc=0.9169 | val_f1_macro=0.8897
# [Fold 2] New best (F1_macro=0.8897) saved.
# [Fold 2 | Epoch 004] train_loss=0.0907 | val_acc=0.9169 | val_f1_macro=0.8929
# [Fold 2] New best (F1_macro=0.8929) saved.
# [Fold 2 | Epoch 005] train_loss=0.0760 | val_acc=0.9233 | val_f1_macro=0.9059
# [Fold 2] New best (F1_macro=0.9059) saved.
# [Fold 2 | Epoch 006] train_loss=0.0620 | val_acc=0.8818 | val_f1_macro=0.8198
# [Fold 2 | Epoch 007] train_loss=0.0469 | val_acc=0.9361 | val_f1_macro=0.9146
# [Fold 2] New best (F1_macro=0.9146) saved.
# [Fold 2 | Epoch 008] train_loss=0.0313 | val_acc=0.9233 | val_f1_macro=0.8990
# [Fold 2 | Epoch 009] train_loss=0.0097 | val_acc=0.9073 | val_f1_macro=0.8748
# [Fold 2 | Epoch 010] train_loss=0.0412 | val_acc=0.9042 | val_f1_macro=0.8721
# [Fold 2 | Epoch 011] train_loss=0.0265 | val_acc=0.9010 | val_f1_macro=0.8598
# [Fold 2 | Epoch 012] train_loss=0.0170 | val_acc=0.9233 | val_f1_macro=0.8989
# [Fold 2 | Epoch 013] train_loss=0.0080 | val_acc=0.9137 | val_f1_macro=0.8811
# [Fold 2 | Epoch 014] train_loss=0.0097 | val_acc=0.9233 | val_f1_macro=0.8971
# [Fold 2 | Epoch 015] train_loss=0.0140 | val_acc=0.9233 | val_f1_macro=0.8991
# [Fold 2 | FT Epoch 016] train_loss=0.0105 | val_acc=0.9073 | val_f1_macro=0.8755
# [Fold 2 | FT Epoch 017] train_loss=0.0079 | val_acc=0.9169 | val_f1_macro=0.8897
# [Fold 2 | FT Epoch 018] train_loss=0.0048 | val_acc=0.9201 | val_f1_macro=0.8940
# [Fold 2 | FT Epoch 019] train_loss=0.0070 | val_acc=0.9201 | val_f1_macro=0.8933
# [Fold 2 | FT Epoch 020] train_loss=0.0077 | val_acc=0.9233 | val_f1_macro=0.8979
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [506, 301, 450] -> target=506
# [BAL] Fold 3: real=1257 | train_balanced(real+GAN)=1518
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=47 images=506
#   - pituitary: ids=36 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3124 | val_acc=0.8459 | val_f1_macro=0.8416
# [Fold 3] New best (F1_macro=0.8416) saved.
# [Fold 3 | Epoch 002] train_loss=0.1118 | val_acc=0.8866 | val_f1_macro=0.8847
# [Fold 3] New best (F1_macro=0.8847) saved.
# [Fold 3 | Epoch 003] train_loss=0.0767 | val_acc=0.8866 | val_f1_macro=0.8794
# [Fold 3 | Epoch 004] train_loss=0.0514 | val_acc=0.8953 | val_f1_macro=0.8928
# [Fold 3] New best (F1_macro=0.8928) saved.
# [Fold 3 | Epoch 005] train_loss=0.0628 | val_acc=0.9099 | val_f1_macro=0.9050
# [Fold 3] New best (F1_macro=0.9050) saved.
# [Fold 3 | Epoch 006] train_loss=0.0469 | val_acc=0.9157 | val_f1_macro=0.9113
# [Fold 3] New best (F1_macro=0.9113) saved.
# [Fold 3 | Epoch 007] train_loss=0.0190 | val_acc=0.9099 | val_f1_macro=0.9054
# [Fold 3 | Epoch 008] train_loss=0.0152 | val_acc=0.9099 | val_f1_macro=0.9056
# [Fold 3 | Epoch 009] train_loss=0.0145 | val_acc=0.8895 | val_f1_macro=0.8834
# [Fold 3 | Epoch 010] train_loss=0.0136 | val_acc=0.9041 | val_f1_macro=0.8989
# [Fold 3 | Epoch 011] train_loss=0.0083 | val_acc=0.9041 | val_f1_macro=0.8999
# [Fold 3 | Epoch 012] train_loss=0.0136 | val_acc=0.9041 | val_f1_macro=0.8972
# [Fold 3 | Epoch 013] train_loss=0.0097 | val_acc=0.9157 | val_f1_macro=0.9111
# [Fold 3 | Epoch 014] train_loss=0.0054 | val_acc=0.9186 | val_f1_macro=0.9129
# [Fold 3] New best (F1_macro=0.9129) saved.
# [Fold 3 | Epoch 015] train_loss=0.0029 | val_acc=0.9244 | val_f1_macro=0.9193
# [Fold 3] New best (F1_macro=0.9193) saved.
# [Fold 3 | FT Epoch 016] train_loss=0.0077 | val_acc=0.9215 | val_f1_macro=0.9163
# [Fold 3 | FT Epoch 017] train_loss=0.0049 | val_acc=0.9215 | val_f1_macro=0.9161
# [Fold 3 | FT Epoch 018] train_loss=0.0073 | val_acc=0.9215 | val_f1_macro=0.9163
# [Fold 3 | FT Epoch 019] train_loss=0.0030 | val_acc=0.9244 | val_f1_macro=0.9193
# [Fold 3 | FT Epoch 020] train_loss=0.0060 | val_acc=0.9157 | val_f1_macro=0.9102
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [450, 370, 424] -> target=450
# [BAL] Fold 4: real=1244 | train_balanced(real+GAN)=1350
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=52 images=450
#   - pituitary: ids=35 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.3973 | val_acc=0.9524 | val_f1_macro=0.9168
# [Fold 4] New best (F1_macro=0.9168) saved.
# [Fold 4 | Epoch 002] train_loss=0.1755 | val_acc=0.9804 | val_f1_macro=0.9744
# [Fold 4] New best (F1_macro=0.9744) saved.
# [Fold 4 | Epoch 003] train_loss=0.1154 | val_acc=0.9804 | val_f1_macro=0.9775
# [Fold 4] New best (F1_macro=0.9775) saved.
# [Fold 4 | Epoch 004] train_loss=0.0671 | val_acc=0.9832 | val_f1_macro=0.9759
# [Fold 4 | Epoch 005] train_loss=0.0620 | val_acc=0.9860 | val_f1_macro=0.9856
# [Fold 4] New best (F1_macro=0.9856) saved.
# [Fold 4 | Epoch 006] train_loss=0.0508 | val_acc=0.9776 | val_f1_macro=0.9764
# [Fold 4 | Epoch 007] train_loss=0.0352 | val_acc=0.9860 | val_f1_macro=0.9794
# [Fold 4 | Epoch 008] train_loss=0.0326 | val_acc=0.9804 | val_f1_macro=0.9740
# [Fold 4 | Epoch 009] train_loss=0.0159 | val_acc=0.9888 | val_f1_macro=0.9844
# [Fold 4 | Epoch 010] train_loss=0.0077 | val_acc=0.9860 | val_f1_macro=0.9823
# [Fold 4 | Epoch 011] train_loss=0.0107 | val_acc=0.9860 | val_f1_macro=0.9819
# [Fold 4 | Epoch 012] train_loss=0.0113 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] New best (F1_macro=0.9899) saved.
# [Fold 4 | Epoch 013] train_loss=0.0106 | val_acc=0.9860 | val_f1_macro=0.9787
# [Fold 4 | Epoch 014] train_loss=0.0134 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 015] train_loss=0.0039 | val_acc=0.9888 | val_f1_macro=0.9841
# [Fold 4 | FT Epoch 016] train_loss=0.0036 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 017] train_loss=0.0105 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 018] train_loss=0.0049 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 019] train_loss=0.0061 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 020] train_loss=0.0049 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [557, 307, 457] -> target=557
# [BAL] Fold 5: real=1321 | train_balanced(real+GAN)=1671
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=43 images=557
#   - pituitary: ids=37 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3459 | val_acc=0.6571 | val_f1_macro=0.5820
# [Fold 5] New best (F1_macro=0.5820) saved.
# [Fold 5 | Epoch 002] train_loss=0.1500 | val_acc=0.9321 | val_f1_macro=0.9300
# [Fold 5] New best (F1_macro=0.9300) saved.
# [Fold 5 | Epoch 003] train_loss=0.1006 | val_acc=0.9071 | val_f1_macro=0.9065
# [Fold 5 | Epoch 004] train_loss=0.0762 | val_acc=0.9179 | val_f1_macro=0.9166
# [Fold 5 | Epoch 005] train_loss=0.0591 | val_acc=0.9071 | val_f1_macro=0.9043
# [Fold 5 | Epoch 006] train_loss=0.0807 | val_acc=0.9464 | val_f1_macro=0.9453
# [Fold 5] New best (F1_macro=0.9453) saved.
# [Fold 5 | Epoch 007] train_loss=0.0260 | val_acc=0.9321 | val_f1_macro=0.9316
# [Fold 5 | Epoch 008] train_loss=0.0254 | val_acc=0.9357 | val_f1_macro=0.9348
# [Fold 5 | Epoch 009] train_loss=0.0217 | val_acc=0.9464 | val_f1_macro=0.9439
# [Fold 5 | Epoch 010] train_loss=0.0381 | val_acc=0.9321 | val_f1_macro=0.9316
# [Fold 5 | Epoch 011] train_loss=0.0166 | val_acc=0.8964 | val_f1_macro=0.8950
# [Fold 5 | Epoch 012] train_loss=0.0168 | val_acc=0.9464 | val_f1_macro=0.9455
# [Fold 5] New best (F1_macro=0.9455) saved.
# [Fold 5 | Epoch 013] train_loss=0.0076 | val_acc=0.9464 | val_f1_macro=0.9458
# [Fold 5] New best (F1_macro=0.9458) saved.
# [Fold 5 | Epoch 014] train_loss=0.0069 | val_acc=0.9357 | val_f1_macro=0.9354
# [Fold 5 | Epoch 015] train_loss=0.0068 | val_acc=0.9000 | val_f1_macro=0.8977
# [Fold 5 | FT Epoch 016] train_loss=0.0094 | val_acc=0.9607 | val_f1_macro=0.9602
# [Fold 5] New best (F1_macro=0.9602) saved (fine-tune).
# [Fold 5 | FT Epoch 017] train_loss=0.0062 | val_acc=0.9500 | val_f1_macro=0.9491
# [Fold 5 | FT Epoch 018] train_loss=0.0118 | val_acc=0.9500 | val_f1_macro=0.9494
# [Fold 5 | FT Epoch 019] train_loss=0.0036 | val_acc=0.9464 | val_f1_macro=0.9455
# [Fold 5 | FT Epoch 020] train_loss=0.0075 | val_acc=0.9464 | val_f1_macro=0.9455
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [BAL] Real class counts (fold): [634, 406, 561] -> target=634
# [Full Train] real=1601 | train_balanced(real+GAN)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-020604

# %%
   def run_gan_balanced():
        cfg_bal = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1",
            # images_per_class se IGNORA cuando balance_gan_to_max=True
            images_per_class=0,
            truncation=1.4,
            balance_gan_to_max=True,   # aquí se activa el balanceo automático al máximo
            fine_tune_real_epochs=5,
            train_full_after_cv=True,
            lr = 1e-4,
            weight_decay = 1e-4,
            epochs = 20,
            seed = 122,
            kfolds =5       )
        return train_kfold(cfg_bal)
   resultado = run_gan_balanced()
# Out:
# [Device] Using cuda
# [Scan] Pool images: 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [Scan] External test images (sanitized): 702
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [634, 406, 561], using n_per_class=634
# [GAN] Saved 634 images for class 'glioma'
# [GAN] Saved 634 images for class 'meningioma'
# [GAN] Saved 634 images for class 'pituitary'
# [GAN] Synth images generated (global): 1902
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [499, 304, 491] -> target=499
# [BAL] Fold 1: real=1294 | train_balanced(real+GAN)=1497
# [ID-STATS] fold1_train: unique patient IDs total = 126 | images = 1497
#   - glioma: ids=41 images=499
#   - meningioma: ids=47 images=499
#   - pituitary: ids=39 images=499
# [ID-STATS] fold1_val: unique patient IDs total = 31 | images = 307
#   - glioma: ids=13 images=135
#   - meningioma: ids=12 images=102
#   - pituitary: ids=6 images=70
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 1 | Epoch 001] train_loss=0.3718 | val_acc=0.9218 | val_f1_macro=0.9302
# [Fold 1] New best (F1_macro=0.9302) saved.
# [Fold 1 | Epoch 002] train_loss=0.1255 | val_acc=0.9121 | val_f1_macro=0.9144
# [Fold 1 | Epoch 003] train_loss=0.0891 | val_acc=0.9121 | val_f1_macro=0.9143
# [Fold 1 | Epoch 004] train_loss=0.0522 | val_acc=0.9218 | val_f1_macro=0.9217
# [Fold 1 | Epoch 005] train_loss=0.0613 | val_acc=0.9088 | val_f1_macro=0.9101
# [Fold 1 | Epoch 006] train_loss=0.0402 | val_acc=0.9186 | val_f1_macro=0.9206
# [Fold 1 | Epoch 007] train_loss=0.0316 | val_acc=0.9511 | val_f1_macro=0.9510
# [Fold 1] New best (F1_macro=0.9510) saved.
# [Fold 1 | Epoch 008] train_loss=0.0280 | val_acc=0.9283 | val_f1_macro=0.9303
# [Fold 1 | Epoch 009] train_loss=0.0502 | val_acc=0.8795 | val_f1_macro=0.8787
# [Fold 1 | Epoch 010] train_loss=0.0305 | val_acc=0.9153 | val_f1_macro=0.9177
# [Fold 1 | Epoch 011] train_loss=0.0153 | val_acc=0.9446 | val_f1_macro=0.9461
# [Fold 1 | Epoch 012] train_loss=0.0119 | val_acc=0.9381 | val_f1_macro=0.9393
# [Fold 1 | Epoch 013] train_loss=0.0059 | val_acc=0.9446 | val_f1_macro=0.9455
# [Fold 1 | Epoch 014] train_loss=0.0054 | val_acc=0.9609 | val_f1_macro=0.9612
# [Fold 1] New best (F1_macro=0.9612) saved.
# [Fold 1 | Epoch 015] train_loss=0.0037 | val_acc=0.9544 | val_f1_macro=0.9544
# [Fold 1 | FT Epoch 016] train_loss=0.0094 | val_acc=0.9511 | val_f1_macro=0.9516
# [Fold 1 | FT Epoch 017] train_loss=0.0050 | val_acc=0.9577 | val_f1_macro=0.9583
# [Fold 1 | FT Epoch 018] train_loss=0.0120 | val_acc=0.9609 | val_f1_macro=0.9610
# [Fold 1 | FT Epoch 019] train_loss=0.0053 | val_acc=0.9544 | val_f1_macro=0.9550
# [Fold 1 | FT Epoch 020] train_loss=0.0044 | val_acc=0.9511 | val_f1_macro=0.9525
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [524, 342, 422] -> target=524
# [BAL] Fold 2: real=1288 | train_balanced(real+GAN)=1572
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 1572
#   - glioma: ids=44 images=524
#   - meningioma: ids=48 images=524
#   - pituitary: ids=34 images=524
# [ID-STATS] fold2_val: unique patient IDs total = 32 | images = 313
#   - glioma: ids=10 images=110
#   - meningioma: ids=11 images=64
#   - pituitary: ids=11 images=139
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 2 | Epoch 001] train_loss=0.3614 | val_acc=0.8722 | val_f1_macro=0.8129
# [Fold 2] New best (F1_macro=0.8129) saved.
# [Fold 2 | Epoch 002] train_loss=0.1158 | val_acc=0.9042 | val_f1_macro=0.8711
# [Fold 2] New best (F1_macro=0.8711) saved.
# [Fold 2 | Epoch 003] train_loss=0.0716 | val_acc=0.9105 | val_f1_macro=0.8871
# [Fold 2] New best (F1_macro=0.8871) saved.
# [Fold 2 | Epoch 004] train_loss=0.1034 | val_acc=0.9010 | val_f1_macro=0.8704
# [Fold 2 | Epoch 005] train_loss=0.0593 | val_acc=0.9201 | val_f1_macro=0.8984
# [Fold 2] New best (F1_macro=0.8984) saved.
# [Fold 2 | Epoch 006] train_loss=0.0847 | val_acc=0.9137 | val_f1_macro=0.8819
# [Fold 2 | Epoch 007] train_loss=0.0482 | val_acc=0.9265 | val_f1_macro=0.9044
# [Fold 2] New best (F1_macro=0.9044) saved.
# [Fold 2 | Epoch 008] train_loss=0.0369 | val_acc=0.9265 | val_f1_macro=0.9006
# [Fold 2 | Epoch 009] train_loss=0.0144 | val_acc=0.9169 | val_f1_macro=0.8890
# [Fold 2 | Epoch 010] train_loss=0.0291 | val_acc=0.9042 | val_f1_macro=0.8699
# [Fold 2 | Epoch 011] train_loss=0.0221 | val_acc=0.9169 | val_f1_macro=0.8892
# [Fold 2 | Epoch 012] train_loss=0.0167 | val_acc=0.9201 | val_f1_macro=0.8916
# [Fold 2 | Epoch 013] train_loss=0.0069 | val_acc=0.9233 | val_f1_macro=0.8956
# [Fold 2 | Epoch 014] train_loss=0.0055 | val_acc=0.9265 | val_f1_macro=0.9029
# [Fold 2 | Epoch 015] train_loss=0.0116 | val_acc=0.9265 | val_f1_macro=0.9029
# [Fold 2 | FT Epoch 016] train_loss=0.0068 | val_acc=0.9233 | val_f1_macro=0.8977
# [Fold 2 | FT Epoch 017] train_loss=0.0077 | val_acc=0.9233 | val_f1_macro=0.8977
# [Fold 2 | FT Epoch 018] train_loss=0.0047 | val_acc=0.9233 | val_f1_macro=0.8984
# [Fold 2 | FT Epoch 019] train_loss=0.0055 | val_acc=0.9233 | val_f1_macro=0.8977
# [Fold 2 | FT Epoch 020] train_loss=0.0062 | val_acc=0.9233 | val_f1_macro=0.8977
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [506, 301, 450] -> target=506
# [BAL] Fold 3: real=1257 | train_balanced(real+GAN)=1518
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 1518
#   - glioma: ids=44 images=506
#   - meningioma: ids=47 images=506
#   - pituitary: ids=36 images=506
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 344
#   - glioma: ids=10 images=128
#   - meningioma: ids=12 images=105
#   - pituitary: ids=9 images=111
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 3 | Epoch 001] train_loss=0.3152 | val_acc=0.8663 | val_f1_macro=0.8627
# [Fold 3] New best (F1_macro=0.8627) saved.
# [Fold 3 | Epoch 002] train_loss=0.1277 | val_acc=0.8837 | val_f1_macro=0.8812
# [Fold 3] New best (F1_macro=0.8812) saved.
# [Fold 3 | Epoch 003] train_loss=0.0765 | val_acc=0.9215 | val_f1_macro=0.9178
# [Fold 3] New best (F1_macro=0.9178) saved.
# [Fold 3 | Epoch 004] train_loss=0.0649 | val_acc=0.8866 | val_f1_macro=0.8834
# [Fold 3 | Epoch 005] train_loss=0.0562 | val_acc=0.8953 | val_f1_macro=0.8919
# [Fold 3 | Epoch 006] train_loss=0.0394 | val_acc=0.8983 | val_f1_macro=0.8939
# [Fold 3 | Epoch 007] train_loss=0.0206 | val_acc=0.8895 | val_f1_macro=0.8858
# [Fold 3 | Epoch 008] train_loss=0.0197 | val_acc=0.8866 | val_f1_macro=0.8827
# [Fold 3 | Epoch 009] train_loss=0.0139 | val_acc=0.8924 | val_f1_macro=0.8878
# [Fold 3 | Epoch 010] train_loss=0.0067 | val_acc=0.9099 | val_f1_macro=0.9060
# [Fold 3 | Epoch 011] train_loss=0.0102 | val_acc=0.8983 | val_f1_macro=0.8937
# [Fold 3 | Epoch 012] train_loss=0.0199 | val_acc=0.9157 | val_f1_macro=0.9098
# [Fold 3 | Epoch 013] train_loss=0.0076 | val_acc=0.9186 | val_f1_macro=0.9132
# [Fold 3 | Epoch 014] train_loss=0.0050 | val_acc=0.9186 | val_f1_macro=0.9132
# [Fold 3 | Epoch 015] train_loss=0.0044 | val_acc=0.9099 | val_f1_macro=0.9056
# [Fold 3 | FT Epoch 016] train_loss=0.0120 | val_acc=0.9128 | val_f1_macro=0.9086
# [Fold 3 | FT Epoch 017] train_loss=0.0045 | val_acc=0.9186 | val_f1_macro=0.9139
# [Fold 3 | FT Epoch 018] train_loss=0.0050 | val_acc=0.9215 | val_f1_macro=0.9168
# [Fold 3 | FT Epoch 019] train_loss=0.0023 | val_acc=0.9215 | val_f1_macro=0.9168
# [Fold 3 | FT Epoch 020] train_loss=0.0076 | val_acc=0.9186 | val_f1_macro=0.9141
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [450, 370, 424] -> target=450
# [BAL] Fold 4: real=1244 | train_balanced(real+GAN)=1350
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 1350
#   - glioma: ids=40 images=450
#   - meningioma: ids=52 images=450
#   - pituitary: ids=35 images=450
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 357
#   - glioma: ids=14 images=184
#   - meningioma: ids=7 images=36
#   - pituitary: ids=10 images=137
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 4 | Epoch 001] train_loss=0.4023 | val_acc=0.9608 | val_f1_macro=0.9273
# [Fold 4] New best (F1_macro=0.9273) saved.
# [Fold 4 | Epoch 002] train_loss=0.1826 | val_acc=0.9804 | val_f1_macro=0.9655
# [Fold 4] New best (F1_macro=0.9655) saved.
# [Fold 4 | Epoch 003] train_loss=0.1237 | val_acc=0.9860 | val_f1_macro=0.9787
# [Fold 4] New best (F1_macro=0.9787) saved.
# [Fold 4 | Epoch 004] train_loss=0.0775 | val_acc=0.9636 | val_f1_macro=0.9514
# [Fold 4 | Epoch 005] train_loss=0.0559 | val_acc=0.9720 | val_f1_macro=0.9563
# [Fold 4 | Epoch 006] train_loss=0.0442 | val_acc=0.9944 | val_f1_macro=0.9958
# [Fold 4] New best (F1_macro=0.9958) saved.
# [Fold 4 | Epoch 007] train_loss=0.0221 | val_acc=0.9916 | val_f1_macro=0.9865
# [Fold 4 | Epoch 008] train_loss=0.0358 | val_acc=0.9804 | val_f1_macro=0.9686
# [Fold 4 | Epoch 009] train_loss=0.0266 | val_acc=0.9832 | val_f1_macro=0.9802
# [Fold 4 | Epoch 010] train_loss=0.0173 | val_acc=0.9860 | val_f1_macro=0.9823
# [Fold 4 | Epoch 011] train_loss=0.0186 | val_acc=0.9888 | val_f1_macro=0.9877
# [Fold 4 | Epoch 012] train_loss=0.0090 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 013] train_loss=0.0141 | val_acc=0.9944 | val_f1_macro=0.9958
# [Fold 4 | Epoch 014] train_loss=0.0181 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | Epoch 015] train_loss=0.0045 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 016] train_loss=0.0041 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 017] train_loss=0.0082 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 018] train_loss=0.0042 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 019] train_loss=0.0066 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4 | FT Epoch 020] train_loss=0.0034 | val_acc=0.9916 | val_f1_macro=0.9899
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [557, 307, 457] -> target=557
# [BAL] Fold 5: real=1321 | train_balanced(real+GAN)=1671
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 1671
#   - glioma: ids=47 images=557
#   - meningioma: ids=43 images=557
#   - pituitary: ids=37 images=557
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 280
#   - glioma: ids=7 images=77
#   - meningioma: ids=16 images=99
#   - pituitary: ids=8 images=104
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 702
#   - glioma: ids=29 images=312
#   - meningioma: ids=21 images=141
#   - pituitary: ids=18 images=249
# [Fold 5 | Epoch 001] train_loss=0.3414 | val_acc=0.7286 | val_f1_macro=0.7013
# [Fold 5] New best (F1_macro=0.7013) saved.
# [Fold 5 | Epoch 002] train_loss=0.1521 | val_acc=0.9321 | val_f1_macro=0.9317
# [Fold 5] New best (F1_macro=0.9317) saved.
# [Fold 5 | Epoch 003] train_loss=0.0903 | val_acc=0.9107 | val_f1_macro=0.9096
# [Fold 5 | Epoch 004] train_loss=0.0654 | val_acc=0.8857 | val_f1_macro=0.8837
# [Fold 5 | Epoch 005] train_loss=0.0561 | val_acc=0.8929 | val_f1_macro=0.8909
# [Fold 5 | Epoch 006] train_loss=0.0749 | val_acc=0.9107 | val_f1_macro=0.9077
# [Fold 5 | Epoch 007] train_loss=0.0618 | val_acc=0.8929 | val_f1_macro=0.8923
# [Fold 5 | Epoch 008] train_loss=0.0256 | val_acc=0.9036 | val_f1_macro=0.9024
# [Fold 5 | Epoch 009] train_loss=0.0290 | val_acc=0.9071 | val_f1_macro=0.9059
# [Fold 5 | Epoch 010] train_loss=0.0415 | val_acc=0.9179 | val_f1_macro=0.9169
# [Fold 5 | Epoch 011] train_loss=0.0242 | val_acc=0.9143 | val_f1_macro=0.9132
# [Fold 5 | Epoch 012] train_loss=0.0127 | val_acc=0.9536 | val_f1_macro=0.9527
# [Fold 5] New best (F1_macro=0.9527) saved.
# [Fold 5 | Epoch 013] train_loss=0.0092 | val_acc=0.9643 | val_f1_macro=0.9637
# [Fold 5] New best (F1_macro=0.9637) saved.
# [Fold 5 | Epoch 014] train_loss=0.0089 | val_acc=0.9286 | val_f1_macro=0.9273
# [Fold 5 | Epoch 015] train_loss=0.0073 | val_acc=0.9214 | val_f1_macro=0.9199
# [Fold 5 | FT Epoch 016] train_loss=0.0140 | val_acc=0.9643 | val_f1_macro=0.9633
# [Fold 5 | FT Epoch 017] train_loss=0.0059 | val_acc=0.9357 | val_f1_macro=0.9346
# [Fold 5 | FT Epoch 018] train_loss=0.0117 | val_acc=0.9393 | val_f1_macro=0.9381
# [Fold 5 | FT Epoch 019] train_loss=0.0058 | val_acc=0.9321 | val_f1_macro=0.9309
# [Fold 5 | FT Epoch 020] train_loss=0.0098 | val_acc=0.9321 | val_f1_macro=0.9309
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Full Train] Training with full pool (no internal test)...
# [BAL] Real class counts (fold): [634, 406, 561] -> target=634
# [Full Train] real=1601 | train_balanced(real+GAN)=1902
# [Full Train] Evaluating on TEST ...
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/CNNResnet50kfoldinge1/kfold_5f_run_20251112-021329

# %%
# -*- coding: utf-8 -*-
"""
K-Fold training (by patient) for brain tumor classification (ResNet50)
- No-leak by patient_id (groups)
- StratifiedGroupKFold if available; fallback to GroupKFold
- Optional StyleGAN2-ADA augmentation:
    * Real-only run (no GAN)
    * GAN-balanced run: for each fold, add GAN images up to the largest REAL class
- Per-fold metrics + CV summary
- OOF (out-of-fold) predictions & metrics (one row per pool sample, predicted by a model that didn't see it)
- External TEST evaluation per fold + K-fold ensemble (avg probs across folds)
- Full INTTEST metrics per fold + INTTEST ensemble, and CV summary with mean±std for VAL/INTTEST/TEST
- Optional final fine-tuning epochs using only REAL images (no GAN) per fold and in full-train

Author: Jun + ChatGPT
"""

import os, re, io, json, time, random, csv, math, shutil, pickle
from pathlib import Path
from typing import List, Tuple, Dict, Optional
from dataclasses import dataclass, asdict

import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support,
    classification_report, confusion_matrix
)

# ====== Splitters ======
try:
    from sklearn.model_selection import StratifiedGroupKFold
    HAS_SGTK = True
except Exception:
    HAS_SGTK = False
    from sklearn.model_selection import GroupKFold

# ====== Utils ======

def set_seed(seed: int = 42):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True
    try:
        torch.set_float32_matmul_precision("high")
    except Exception:
        pass

def timestamp() -> str:
    return time.strftime("%Y%m%d-%H%M%S")

def extract_patient_id(p: Path) -> str:
    stem = p.stem
    token = stem.split("_")[0]
    return token.strip().lower()

IMG_EXTS = {".png", ".jpg", ".jpeg", ".bmp", ".tif", ".tiff"}

# ====== Config ======

@dataclass
class Config:
    data_root: str
    out_dir: str
    test_root: str = ""
    gan_pkl: str = ""
    images_per_class: int = 0        # only used if balance_gan_to_max=False
    truncation: float = 1.0
    internal_test_ratio: float = 0.0   # optional: holdout before CV
    image_size: int = 256
    batch_size: int = 32
    epochs: int = 15
    lr: float = 1e-3
    weight_decay: float = 1e-4
    num_workers: int = 4
    seed: int = 42
    kfolds: int = 5
    amp: bool = True
    pretrained: bool = True
    train_full_after_cv: bool = False   # optional: retrain on full pool at end

    # Fine-tuning final only with REAL images
    fine_tune_real_epochs: int = 0      # 0 = disabled

    # Balance classes with GAN up to the largest REAL class
    balance_gan_to_max: bool = False

    # NEW: use exactly one image per patient (real data)
    one_image_per_patient: bool = True
    one_image_strategy: str = "first"   # "first", "last", "random"

# ====== Dataset & Scanning ======

class MRIDataset(Dataset):
    def __init__(self, items: List[Tuple[Path, int, str]], image_size: int = 256, aug: bool = False):
        self.items = items
        self.image_size = image_size
        self.aug = aug
        mean = [0.5, 0.5, 0.5]; std = [0.5, 0.5, 0.5]
        if aug:
            self.tf = transforms.Compose([
                transforms.RandomResizedCrop(image_size, scale=(0.9, 1.0), ratio=(0.95, 1.05)),
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.RandomRotation(10),
                transforms.ToTensor(),
            ])
        else:
            self.tf = transforms.Compose([
                transforms.Resize((image_size, image_size)),
                transforms.ToTensor(),
            ])
        self.norm = transforms.Normalize(mean=mean, std=std)

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        path, y, pid = self.items[idx]
        img = Image.open(path).convert("L")
        img = self.tf(img)           # [1,H,W]
        img = img.repeat(3, 1, 1)    # [3,H,W]
        img = self.norm(img)
        return img, y, str(path), pid

def scan_folder(root: Path) -> Tuple[List[Tuple[Path,int,str]], List[str]]:
    assert root.is_dir(), f"Not a directory: {root}"
    class_names = sorted([d.name for d in root.iterdir() if d.is_dir()])
    items: List[Tuple[Path,int,str]] = []
    for ci, cname in enumerate(class_names):
        cdir = root / cname
        for p in cdir.rglob("*"):
            if p.suffix.lower() in IMG_EXTS:
                pid = extract_patient_id(p)
                items.append((p, ci, pid))
    return items, class_names

def select_one_image_per_patient(
    items: List[Tuple[Path, int, str]],
    strategy: str = "first",
    seed: int = 42,
) -> List[Tuple[Path, int, str]]:
    """
    Reduce a list of (path, class_idx, patient_id) so that there is exactly
    one image per patient_id. The chosen image can be:
      - "first": first occurrence in the list (default)
      - "last": last occurrence in the list
      - "random": random choice per patient (using 'seed' for reproducibility)
    """
    from collections import defaultdict

    by_pid: Dict[str, List[Tuple[Path, int, str]]] = defaultdict(list)
    for p, ci, pid in items:
        by_pid[pid].append((p, ci, pid))

    rng = random.Random(seed)
    selected: List[Tuple[Path, int, str]] = []
    for pid, lst in by_pid.items():
        if strategy == "random":
            chosen = rng.choice(lst)
        elif strategy == "last":
            chosen = lst[-1]
        else:  # "first" or anything else
            chosen = lst[0]
        selected.append(chosen)
    return selected

def ensure_no_overlap(ids_a: List[str], ids_b: List[str]) -> Tuple[int, List[str]]:
    a = set(ids_a); b = set(ids_b)
    inter = sorted(a.intersection(b))
    return len(inter), inter

def summarize_id_counts(items: List[Tuple[Path,int,str]], class_names: List[str], split_name: str, out_dir: Path):
    from collections import defaultdict
    ids_by_class = defaultdict(set); imgs_by_class = defaultdict(int); all_ids = set()
    for p, ci, pid in items:
        ids_by_class[ci].add(pid)
        imgs_by_class[ci] += 1
        all_ids.add(pid)

    print(f"[ID-STATS] {split_name}: unique patient IDs total = {len(all_ids)} | images = {len(items)}")
    for ci, cname in enumerate(class_names):
        print(f"  - {cname}: ids={len(ids_by_class[ci])} images={imgs_by_class[ci]}")

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"id_counts_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["class", "n_unique_ids", "n_images"])
        for ci, cname in enumerate(class_names):
            w.writerow([cname, len(ids_by_class[ci]), imgs_by_class[ci]])
        w.writerow(["__TOTAL__", len(all_ids), len(items)])

# ====== Model ======

def build_model(num_classes: int, pretrained: bool = True) -> nn.Module:
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1 if pretrained else None)
    in_features = m.fc.in_features
    m.fc = nn.Linear(in_features, num_classes)
    return m

# ====== Eval (writes artifacts) ======

@torch.no_grad()
def evaluate(model: nn.Module, loader: DataLoader, device: torch.device, class_names: List[str], split_name: str, out_dir: Path):
    model.eval()
    all_probs, all_preds, all_labels = [], [], []
    all_paths, all_pids = [], []

    for imgs, ys, paths, pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        all_paths.extend(list(paths))
        all_pids.extend(list(pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, len(class_names)))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)

    acc = float(accuracy_score(labels, preds)) if len(labels) else 0.0
    prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)
    prec_weighted, rec_weighted, f1_weighted, _ = precision_recall_fscore_support(labels, preds, average='weighted', zero_division=0)
    per_class = classification_report(labels, preds, target_names=class_names, output_dict=True, zero_division=0)
    cm = confusion_matrix(labels, preds, labels=list(range(len(class_names))))

    metrics = {
        "overall": {
            "accuracy": acc,
            "precision_macro": prec_macro,
            "recall_macro": rec_macro,
            "f1_macro": f1_macro,
            "precision_weighted": prec_weighted,
            "recall_weighted": rec_weighted,
            "f1_weighted": f1_weighted,
            "num_samples": len(labels),
        },
        "per_class": per_class,
    }

    out_dir.mkdir(parents=True, exist_ok=True)
    with open(out_dir / f"metrics_{split_name}.json", 'w', encoding='utf-8') as f:
        json.dump(metrics, f, indent=2)

    with open(out_dir / f"metrics_overall_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro","precision_weighted","recall_weighted","f1_weighted","num_samples"])
        o = metrics['overall']
        w.writerow([split_name, o['accuracy'], o['precision_macro'], o['recall_macro'], o['f1_macro'],
                    o['precision_weighted'], o['recall_weighted'], o['f1_weighted'], o['num_samples']])

    with open(out_dir / f"per_class_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["class", "precision", "recall", "f1", "support"])
        for cname in class_names:
            row = per_class.get(cname, {"precision":0, "recall":0, "f1-score":0, "support":0})
            w.writerow([cname, row.get("precision",0), row.get("recall",0),
                        row.get("f1-score",0), row.get("support",0)])

    with open(out_dir / f"confusion_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["true\\pred"] + class_names)
        for i, cname in enumerate(class_names):
            w.writerow([cname] + list(cm[i]))

    with open(out_dir / f"predictions_{split_name}.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["path", "patient_id", "true", "pred"] + [f"p_{c}" for c in class_names])
        for i in range(len(labels)):
            w.writerow([all_paths[i], all_pids[i], class_names[labels[i]],
                        class_names[preds[i]]] + list(map(float, probs[i].tolist())))

    return metrics, cm

# Helper: fast inference to collect arrays (for OOF & ensemble)
@torch.no_grad()
def infer_loader(model: nn.Module, loader: DataLoader, device: torch.device):
    model.eval()
    paths, pids = [], []
    all_probs, all_preds, all_labels = [], [], []
    for imgs, ys, batch_paths, batch_pids in loader:
        imgs = imgs.to(device, non_blocking=True)
        ys = ys.to(device, non_blocking=True)
        logits = model(imgs)
        probs = F.softmax(logits, dim=1)
        preds = probs.argmax(dim=1)

        all_probs.append(probs.cpu().numpy())
        all_preds.append(preds.cpu().numpy())
        all_labels.append(ys.cpu().numpy())
        paths.extend(list(batch_paths))
        pids.extend(list(batch_pids))

    probs = np.concatenate(all_probs, axis=0) if all_probs else np.zeros((0, 0))
    preds = np.concatenate(all_preds, axis=0) if all_preds else np.zeros((0,), dtype=np.int64)
    labels = np.concatenate(all_labels, axis=0) if all_labels else np.zeros((0,), dtype=np.int64)
    return {"probs": probs, "preds": preds, "labels": labels, "paths": paths, "pids": pids}

# ====== Optional GAN loader (TRAIN only) ======

@torch.no_grad()
def _load_stylegan2_ada_G(gan_pkl: str, device: torch.device):
    try:
        import dnnlib
        from training import network as _dummy
        from legacy import load_network_pkl
    except Exception:
        try:
            from torch_utils import misc as _m  # noqa
            from torch_utils import training_stats as _ts  # noqa
            from legacy import load_network_pkl
        except Exception:
            return None
    try:
        with open(gan_pkl, 'rb') as f:
            data = load_network_pkl(f)
        G_ema = data.get('G_ema', None) or data.get('G', None)
        if G_ema is None:
            return None
        G_ema = G_ema.to(device)
        G_ema.eval()
        return G_ema
    except Exception:
        return None

@torch.no_grad()
def maybe_generate_gan_images(gan_pkl: str,
                              class_names: List[str],
                              n_per_class: int,
                              truncation: float,
                              out_dir: Path,
                              device: torch.device,
                              seed: int = 42) -> Optional[Path]:
    if (not gan_pkl) or n_per_class <= 0:
        return None
    G = _load_stylegan2_ada_G(gan_pkl, device)
    if G is None:
        print("[GAN] Could not load StyleGAN2-ADA G_ema. Skipping GAN augmentation.")
        return None
    if getattr(G, 'c_dim', 0) <= 0:
        print("[GAN] Generator is not conditional (c_dim=0). Skipping.")
        return None

    rng = np.random.RandomState(seed)
    synth_root = out_dir / "gan_synth"
    for cname in class_names:
        (synth_root / cname).mkdir(parents=True, exist_ok=True)

    batch = 16
    for ci, cname in enumerate(class_names):
        saved = 0
        while saved < n_per_class:
            bs = min(batch, n_per_class - saved)
            z = torch.from_numpy(rng.randn(bs, G.z_dim)).to(device)
            c = torch.zeros(bs, G.c_dim, device=device); c[:, ci] = 1.0
            try:
                img = G(z, c, truncation_psi=float(truncation), noise_mode='const')
            except TypeError:
                img = G(z, c, truncation_psi=float(truncation))
            img = (img * 127.5 + 128).clamp(0,255).to(torch.uint8).cpu()
            for k in range(bs):
                x = img[k]
                if x.shape[0] == 1:
                    arr = x[0].numpy()
                    pil = Image.fromarray(arr).convert('L')
                else:
                    arr = x.permute(1,2,0).numpy()
                    pil = Image.fromarray(arr).convert('L')
                fname = synth_root / cname / f"gan_{cname}_{saved+k:05d}.png"
                pil.save(fname)
            saved += bs
        print(f"[GAN] Saved {saved} images for class '{cname}'")
    return synth_root

def collate_fn(batch):
    imgs, ys, paths, pids = zip(*batch)
    return torch.stack(imgs, dim=0), torch.tensor(ys, dtype=torch.long), list(paths), list(pids)

# ====== Helper: build balanced real + GAN subset ======

def build_balanced_train_subset(real_train_subset: List[Tuple[Path,int,str]],
                                synth_items: List[Tuple[Path,int,str]],
                                num_classes: int,
                                seed: int) -> List[Tuple[Path,int,str]]:
    """
    Inputs:
      - real_train_subset: only REAL images for that fold
      - synth_items: ALL synthetic images (scanned from gan_synth/)
    Returns:
      - list with real + enough GAN per class to match the max real-class size (per fold).
    """
    from collections import defaultdict

    # Real per class
    real_by_class: Dict[int, List[Tuple[Path,int,str]]] = defaultdict(list)
    for item in real_train_subset:
        _, ci, _ = item
        real_by_class[ci].append(item)

    # GAN per class
    synth_by_class: Dict[int, List[Tuple[Path,int,str]]] = defaultdict(list)
    for item in synth_items:
        _, ci, _ = item
        synth_by_class[ci].append(item)

    # Target = largest REAL class in this fold
    counts_real = [len(real_by_class[c]) for c in range(num_classes)]
    target = max(counts_real) if counts_real else 0
    print(f"[BAL] Real class counts (fold): {counts_real} -> target={target}")

    rng = random.Random(seed)
    balanced: List[Tuple[Path,int,str]] = list(real_train_subset)

    for ci in range(num_classes):
        need = target - len(real_by_class[ci])
        if need <= 0:
            continue
        pool = synth_by_class[ci]
        if not pool:
            print(f"[BAL] WARNING: no GAN images for class {ci}, cannot fully balance.")
            continue
        # sample with replacement if need > len(pool)
        for _ in range(need):
            balanced.append(rng.choice(pool))

    return balanced

# ====== K-Fold Train (CV + OOF + TEST + INTTEST ensemble) ======

def train_kfold(cfg: Config):
    if cfg.fine_tune_real_epochs < 0 or cfg.fine_tune_real_epochs > cfg.epochs:
        raise ValueError("fine_tune_real_epochs must be between 0 and cfg.epochs")

    base_run = Path(cfg.out_dir) / f"kfold_{cfg.kfolds}f_run_{timestamp()}"
    base_run.mkdir(parents=True, exist_ok=True)
    with open(base_run / 'config.json', 'w', encoding='utf-8') as f:
        json.dump(asdict(cfg), f, indent=2)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"[Device] Using {device}")

    # Scan pool (REAL images)
    all_items, class_names = scan_folder(Path(cfg.data_root))
    print(f"[Scan] Pool images (raw): {len(all_items)} | Classes: {class_names}")

    # Collapse to one image per patient in the pool (if enabled)
    if cfg.one_image_per_patient:
        before = len(all_items)
        all_items = select_one_image_per_patient(
            all_items,
            strategy=cfg.one_image_strategy,
            seed=cfg.seed,
        )
        print(f"[OneImage] Pool collapsed to 1 image/patient: {before} -> {len(all_items)}")

    # Optional internal-test holdout (by patient)
    inttest_subset: List[Tuple[Path,int,str]] = []
    if cfg.internal_test_ratio and cfg.internal_test_ratio > 0:
        from sklearn.model_selection import GroupShuffleSplit
        X_all = np.arange(len(all_items))
        y_all = np.array([lbl for _, lbl, _ in all_items])
        g_all = np.array([pid for _, _, pid in all_items])
        gss = GroupShuffleSplit(n_splits=1, test_size=cfg.internal_test_ratio, random_state=cfg.seed)
        trval_idx, inttest_idx = next(gss.split(X_all, y_all, g_all))
        base_pool = [all_items[i] for i in trval_idx]
        inttest_subset = [all_items[i] for i in inttest_idx]
        print(f"[Split] Internal test: {len(inttest_subset)} images ({cfg.internal_test_ratio*100:.1f}%)")
    else:
        base_pool = all_items

    # External test (sanitized vs pool & internal test)
    ext_subset: List[Tuple[Path,int,str]] = []
    if cfg.test_root and len(cfg.test_root.strip()) > 0 and Path(cfg.test_root).exists():
        ext_items, _ = scan_folder(Path(cfg.test_root))
        print(f"[Scan] External test images (raw): {len(ext_items)}")

        # Optional collapse to 1 image per patient in external test
        if cfg.one_image_per_patient and len(ext_items) > 0:
            before_ext = len(ext_items)
            ext_items = select_one_image_per_patient(
                ext_items,
                strategy=cfg.one_image_strategy,
                seed=cfg.seed + 1000,
            )
            print(f"[OneImage] External test collapsed to 1 image/patient: {before_ext} -> {len(ext_items)}")

        ids_pool = set(pid for _,_,pid in base_pool)
        if len(inttest_subset) > 0:
            ids_pool |= set(pid for _,_,pid in inttest_subset)

        for it in ext_items:
            if it[2] not in ids_pool:
                ext_subset.append(it)

        removed = len(ext_items) - len(ext_subset)
        if removed > 0:
            print(f"[LEAK-FIX] Removed {removed} overlapping ext-test images by patient ID.")
        print(f"[Scan] External test images (sanitized): {len(ext_subset)}")

    # Build folds grouped by patient (REAL pool only)
    X = np.arange(len(base_pool))
    y = np.array([lbl for _, lbl, _ in base_pool])
    groups = np.array([pid for _, _, pid in base_pool])

    if cfg.kfolds < 2:
        raise ValueError("kfolds must be >= 2")

    if HAS_SGTK:
        splitter = StratifiedGroupKFold(n_splits=cfg.kfolds, shuffle=True, random_state=cfg.seed)
        folds_iter = list(splitter.split(X, y, groups))
        print("[Split] Using StratifiedGroupKFold")
    else:
        splitter = GroupKFold(n_splits=cfg.kfolds)
        folds_iter = list(splitter.split(X, groups=groups))
        print("[Split] Using GroupKFold (no stratification)")

    # ===== Pre-generate GAN synth once =====
    synth_items: List[Tuple[Path,int,str]] = []
    synth_root: Optional[Path] = None
    if cfg.gan_pkl and cfg.gan_pkl.strip():
        # If we want to balance, ignore images_per_class and use global max of REAL images
        if cfg.balance_gan_to_max:
            from collections import defaultdict
            real_counts_global = defaultdict(int)
            for _, ci, _ in base_pool:
                real_counts_global[ci] += 1
            counts_vec = [real_counts_global[ci] for ci in range(len(class_names))]
            n_per_class = max(counts_vec) if counts_vec else 0
            print(f"[GAN] balance_gan_to_max=True -> global real counts per class = {counts_vec}, using n_per_class={n_per_class}")
        else:
            n_per_class = cfg.images_per_class

        if n_per_class > 0:
            synth_root = maybe_generate_gan_images(
                gan_pkl=cfg.gan_pkl,
                class_names=class_names,
                n_per_class=n_per_class,
                truncation=cfg.truncation,
                out_dir=base_run,
                device=device,
                seed=cfg.seed,
            )
            if synth_root is not None:
                synth_items, _ = scan_folder(synth_root)
                print(f"[GAN] Synth images generated (global): {len(synth_items)}")
        else:
            print("[GAN] n_per_class <= 0 -> no synthetic images will be generated.")
    else:
        print("[GAN] gan_pkl empty -> NO GAN will be used.")

    # Prepare fixed loaders for ensembles (TEST & INTTEST)
    test_loader_fixed: Optional[DataLoader] = None
    test_ref_paths = test_ref_pids = test_ref_labels = None
    if len(ext_subset) > 0:
        test_ds_fixed = MRIDataset(ext_subset, image_size=cfg.image_size, aug=False)
        test_loader_fixed = DataLoader(test_ds_fixed, batch_size=cfg.batch_size, shuffle=False,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

    inttest_loader_fixed: Optional[DataLoader] = None
    int_ref_paths = int_ref_pids = int_ref_labels = None
    if len(inttest_subset) > 0:
        int_ds_fixed = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
        inttest_loader_fixed = DataLoader(int_ds_fixed, batch_size=cfg.batch_size, shuffle=False,
                                          num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

    # ===== OOF buffers =====
    n_pool = len(base_pool)
    n_cls = len(class_names)
    oof_probs = np.full((n_pool, n_cls), np.nan, dtype=np.float32)
    oof_pred  = np.full((n_pool,), -1, dtype=np.int64)
    oof_true  = np.full((n_pool,), -1, dtype=np.int64)
    oof_path  = [""] * n_pool
    oof_pid   = [""] * n_pool

    # For ensembles
    test_probs_folds: List[np.ndarray] = []
    inttest_probs_folds: List[np.ndarray] = []

    # Per-fold training
    cv_rows = []
    for fold_id, (tr_idx, va_idx) in enumerate(folds_iter, start=1):
        print(f"\n===== FOLD {fold_id}/{cfg.kfolds} =====")
        set_seed(cfg.seed + fold_id)

        fold_dir = base_run / f"fold_{fold_id:02d}"
        fold_dir.mkdir(parents=True, exist_ok=True)

        # REAL train subset and VAL subset
        real_train_subset = [base_pool[i] for i in tr_idx]
        val_subset        = [base_pool[i] for i in va_idx]

        # Leak checks (REAL only)
        ids_train = [pid for _,_,pid in real_train_subset]
        ids_val   = [pid for _,_,pid in val_subset]
        inter_n, inter_ids = ensure_no_overlap(ids_train, ids_val)
        if inter_n > 0:
            raise RuntimeError(f"[LEAK ERROR] Train↔Val share {inter_n} patient IDs (fold {fold_id}): {inter_ids[:10]}")

        if len(inttest_subset) > 0:
            ids_int = [pid for _,_,pid in inttest_subset]
            n1,_ = ensure_no_overlap(ids_train, ids_int)
            n2,_ = ensure_no_overlap(ids_val, ids_int)
            if n1>0 or n2>0:
                raise RuntimeError("[LEAK ERROR] Fold and INTTEST share patients")

        # ===== build train_subset =====
        if cfg.balance_gan_to_max and len(synth_items) > 0:
            train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + fold_id,
            )
            print(f"[BAL] Fold {fold_id}: real={len(real_train_subset)} | train_balanced(real+GAN)={len(train_subset)}")
        else:
            # no balancing: optionally append all synth_items
            train_subset = list(real_train_subset)
            if len(synth_items) > 0:
                train_subset = train_subset + synth_items
                print(f"[TRAIN] Fold {fold_id}: real={len(real_train_subset)} + synth={len(synth_items)} -> {len(train_subset)}")
            else:
                print(f"[TRAIN] Fold {fold_id}: only real images, n={len(real_train_subset)}")

        # Stats CSV
        summarize_id_counts(train_subset, class_names, f'fold{fold_id}_train', fold_dir)
        summarize_id_counts(val_subset,   class_names, f'fold{fold_id}_val',   fold_dir)
        if len(inttest_subset) > 0:
            summarize_id_counts(inttest_subset, class_names, f'fold{fold_id}_inttest', fold_dir)
        if len(ext_subset) > 0:
            summarize_id_counts(ext_subset,     class_names, f'fold{fold_id}_test',    fold_dir)

        # Loaders
        train_ds       = MRIDataset(train_subset,       image_size=cfg.image_size, aug=True)
        real_train_ds  = MRIDataset(real_train_subset,  image_size=cfg.image_size, aug=True)
        val_ds         = MRIDataset(val_subset,         image_size=cfg.image_size, aug=False)

        train_loader      = DataLoader(train_ds,      batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        real_train_loader = DataLoader(real_train_ds, batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        val_loader        = DataLoader(val_ds,        batch_size=cfg.batch_size, shuffle=False,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        inttest_loader = None
        if len(inttest_subset) > 0:
            int_ds = MRIDataset(inttest_subset, image_size=cfg.image_size, aug=False)
            inttest_loader = DataLoader(int_ds, batch_size=cfg.batch_size, shuffle=False,
                                        num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        # TEST per fold uses fixed loader
        test_loader = test_loader_fixed

        # Model/optim
        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()

        amp_enabled = (cfg.amp and device.type == 'cuda')
        scaler = torch.amp.GradScaler('cuda', enabled=amp_enabled)

        best_f1 = -1.0

        # Epoch split: main (train_subset) + fine-tuning (real only)
        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft   = cfg.fine_tune_real_epochs

        # ----- Phase 1: train with train_subset (real + GAN or real only) -----
        for epoch in range(1, epochs_main + 1):
            model.train()
            running_loss = 0.0; n_seen = 0
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(model, val_loader, device, class_names,
                                split_name='val', out_dir=fold_dir)
            f1_macro = m_val['overall']['f1_macro']
            acc_val  = m_val['overall']['accuracy']
            print(f"[Fold {fold_id} | Epoch {epoch:03d}] "
                  f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}")

            torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                       fold_dir / 'last.ckpt')

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                           fold_dir / 'best.ckpt')
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved.")

        # ----- Phase 2: fine-tuning only with REAL images -----
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            running_loss = 0.0; n_seen = 0
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)

                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    logits = model(imgs)
                    loss = criterion(logits, ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

                running_loss += float(loss.item()) * imgs.size(0)
                n_seen += imgs.size(0)

            scheduler.step()
            train_loss = running_loss / max(1, n_seen)

            m_val, _ = evaluate(model, val_loader, device, class_names,
                                split_name='val', out_dir=fold_dir)
            f1_macro = m_val['overall']['f1_macro']
            acc_val  = m_val['overall']['accuracy']
            print(f"[Fold {fold_id} | FT Epoch {epoch:03d}] "
                  f"train_loss={train_loss:.4f} | val_acc={acc_val:.4f} | val_f1_macro={f1_macro:.4f}")

            torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                       fold_dir / 'last.ckpt')

            if f1_macro > best_f1:
                best_f1 = f1_macro
                torch.save({'model': model.state_dict(), 'epoch': epoch, 'class_names': class_names},
                           fold_dir / 'best.ckpt')
                print(f"[Fold {fold_id}] New best (F1_macro={best_f1:.4f}) saved (fine-tune).")

        # Re-eval BEST and collect OOF for this fold
        best = torch.load(fold_dir / 'best.ckpt', map_location=device)
        model.load_state_dict(best['model'])

        print(f"[Fold {fold_id}] Re-evaluating BEST on VAL (and collecting OOF)...")
        m_val_best, _ = evaluate(model, val_loader, device, class_names,
                                 split_name='val_best', out_dir=fold_dir)

        # Collect arrays for OOF
        val_inf = infer_loader(model, val_loader, device)  # same order as val_subset (shuffle=False)
        for j, base_i in enumerate(va_idx):
            oof_probs[base_i] = val_inf["probs"][j]
            oof_pred[base_i]  = int(val_inf["preds"][j])
            oof_true[base_i]  = int(val_inf["labels"][j])
            oof_path[base_i]  = val_inf["paths"][j]
            oof_pid[base_i]   = val_inf["pids"][j]

        # Row base with full VAL metrics
        row = {
            "fold": fold_id,
            "val_acc": m_val_best["overall"]["accuracy"],
            "val_precision_macro": m_val_best["overall"]["precision_macro"],
            "val_recall_macro": m_val_best["overall"]["recall_macro"],
            "val_f1_macro": m_val_best["overall"]["f1_macro"],
            "val_precision_weighted": m_val_best["overall"]["precision_weighted"],
            "val_recall_weighted": m_val_best["overall"]["recall_weighted"],
            "val_f1_weighted": m_val_best["overall"]["f1_weighted"],
            "val_n": m_val_best["overall"]["num_samples"],
        }

        # INTERNAL TEST per fold + probs for ensemble
        if inttest_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on INTERNAL TEST...")
            m_int, _ = evaluate(model, inttest_loader, device, class_names,
                                split_name='inttest', out_dir=fold_dir)
            row.update({
                "int_acc": m_int["overall"]["accuracy"],
                "int_precision_macro": m_int["overall"]["precision_macro"],
                "int_recall_macro": m_int["overall"]["recall_macro"],
                "int_f1_macro": m_int["overall"]["f1_macro"],
                "int_precision_weighted": m_int["overall"]["precision_weighted"],
                "int_recall_weighted": m_int["overall"]["recall_weighted"],
                "int_f1_weighted": m_int["overall"]["f1_weighted"],
                "int_n": m_int["overall"]["num_samples"],
            })
            t_int = infer_loader(model, inttest_loader, device)
            inttest_probs_folds.append(t_int["probs"])
            if int_ref_paths is None:
                int_ref_paths  = t_int["paths"]
                int_ref_pids   = t_int["pids"]
                int_ref_labels = t_int["labels"]

        # EXTERNAL TEST per fold + probs for ensemble
        if test_loader is not None:
            print(f"[Fold {fold_id}] Evaluating on EXTERNAL TEST...")
            m_ext, _ = evaluate(model, test_loader, device, class_names,
                                split_name='test', out_dir=fold_dir)
            row.update({
                "test_acc": m_ext["overall"]["accuracy"],
                "test_precision_macro": m_ext["overall"]["precision_macro"],
                "test_recall_macro": m_ext["overall"]["recall_macro"],
                "test_f1_macro": m_ext["overall"]["f1_macro"],
                "test_precision_weighted": m_ext["overall"]["precision_weighted"],
                "test_recall_weighted": m_ext["overall"]["recall_weighted"],
                "test_f1_weighted": m_ext["overall"]["f1_weighted"],
                "test_n": m_ext["overall"]["num_samples"],
            })
            t_inf = infer_loader(model, test_loader, device)
            test_probs_folds.append(t_inf["probs"])
            if test_ref_paths is None:
                test_ref_paths  = t_inf["paths"]
                test_ref_pids   = t_inf["pids"]
                test_ref_labels = t_inf["labels"]

        cv_rows.append(row)

    # === CV summary (mean ± std) ===
    summary_csv = base_run / "cv_summary.csv"
    keys = sorted(set().union(*[r.keys() for r in cv_rows]))
    with open(summary_csv, 'w', newline='', encoding='utf-8') as f:
        w = csv.DictWriter(f, fieldnames=keys)
        w.writeheader()
        for r in cv_rows:
            w.writerow(r)

    def _agg_for(prefix: str) -> Dict[str, Tuple[Optional[float], Optional[float]]]:
        metrics = ["acc","precision_macro","recall_macro","f1_macro",
                   "precision_weighted","recall_weighted","f1_weighted"]
        out: Dict[str, Tuple[Optional[float], Optional[float]]] = {}
        for m in metrics:
            col = f"{prefix}_{m}"
            vals = [float(r[col]) for r in cv_rows if col in r]
            if len(vals) == 0:
                out[m] = (None, None)
            else:
                out[m] = (float(np.mean(vals)), float(np.std(vals)))
        return out

    cv_stats_full = {
        "kfolds": cfg.kfolds,
        "val":     _agg_for("val"),
        "inttest": _agg_for("int") if any(("int_acc" in r) for r in cv_rows) else {},
        "test":    _agg_for("test") if any(("test_acc" in r) for r in cv_rows) else {},
    }
    with open(base_run / "cv_summary_full.json", 'w', encoding='utf-8') as f:
        json.dump(cv_stats_full, f, indent=2)

    with open(base_run / "cv_summary_full.csv", 'w', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(["split","metric","mean","std","k"])
        for split in ["val","inttest","test"]:
            if split not in cv_stats_full or not cv_stats_full[split]:
                continue
            for metric, (mu, sd) in cv_stats_full[split].items():
                if mu is None:
                    continue
                w.writerow([split, metric, mu, sd, cfg.kfolds])

    print("[CV] Summary (mean±std) written to cv_summary_full.{json,csv}")

    # === OOF metrics & artifacts ===
    valid_mask = (~np.isnan(oof_probs).any(axis=1)) & (oof_true != -1)
    oof_probs_v = oof_probs[valid_mask]
    oof_pred_v  = oof_pred[valid_mask]
    oof_true_v  = oof_true[valid_mask]
    oof_path_v  = [oof_path[i] for i, ok in enumerate(valid_mask) if ok]
    oof_pid_v   = [oof_pid[i]  for i, ok in enumerate(valid_mask) if ok]

    if len(oof_true_v) > 0:
        acc = float(accuracy_score(oof_true_v, oof_pred_v))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            oof_true_v, oof_pred_v, average='weighted', zero_division=0)
        per_class = classification_report(
            oof_true_v, oof_pred_v, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(oof_true_v, oof_pred_v, labels=list(range(len(class_names))))

        oof_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(oof_true_v)),
            },
            "per_class": per_class,
        }
        with open(base_run / "oof_metrics.json", 'w', encoding='utf-8') as f:
            json.dump(oof_metrics, f, indent=2)

        with open(base_run / "metrics_overall_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = oof_metrics['overall']
            w.writerow(["oof", o['accuracy'], o['precision_macro'], o['recall_macro'],
                        o['f1_macro'], o['precision_weighted'], o['recall_weighted'],
                        o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_oof.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "oof_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(oof_true_v)):
                w.writerow([oof_path_v[i], oof_pid_v[i],
                            class_names[oof_true_v[i]],
                            class_names[oof_pred_v[i]]] +
                           list(map(float, oof_probs_v[i].tolist())))

    # === TEST ensemble (avg across folds) ===
    if test_loader_fixed is not None and len(test_probs_folds) > 0:
        probs_stack = np.stack(test_probs_folds, axis=0)     # [K, N_test, C]
        probs_mean  = probs_stack.mean(axis=0)               # [N_test, C]
        preds_ens   = probs_mean.argmax(axis=1)

        acc = float(accuracy_score(test_ref_labels, preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            test_ref_labels, preds_ens, average='weighted', zero_division=0)
        per_class = classification_report(
            test_ref_labels, preds_ens, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(test_ref_labels, preds_ens, labels=list(range(len(class_names))))

        test_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(test_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_test_ensemble.json", 'w', encoding='utf-8') as f:
            json.dump(test_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = test_ens_metrics['overall']
            w.writerow(["test_ensemble", o['accuracy'], o['precision_macro'],
                        o['recall_macro'], o['f1_macro'], o['precision_weighted'],
                        o['recall_weighted'], o['f1_weighted'], o['num_samples']])

        with open(base_run / "per_class_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_test_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "test_ensemble_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(test_ref_labels)):
                w.writerow([test_ref_paths[i], test_ref_pids[i],
                            class_names[int(test_ref_labels[i])],
                            class_names[int(preds_ens[i])]] +
                           list(map(float, probs_mean[i].tolist())))

    # === INTTEST ensemble (avg across folds) ===
    if inttest_loader_fixed is not None and len(inttest_probs_folds) > 0:
        int_probs_stack = np.stack(inttest_probs_folds, axis=0)  # [K, N_int, C]
        int_probs_mean  = int_probs_stack.mean(axis=0)           # [N_int, C]
        int_preds_ens   = int_probs_mean.argmax(axis=1)

        acc = float(accuracy_score(int_ref_labels, int_preds_ens))
        prec_m, rec_m, f1_m, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average='macro', zero_division=0)
        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
            int_ref_labels, int_preds_ens, average='weighted', zero_division=0)
        per_class = classification_report(
            int_ref_labels, int_preds_ens, target_names=class_names,
            output_dict=True, zero_division=0)
        cm = confusion_matrix(int_ref_labels, int_preds_ens, labels=list(range(len(class_names))))

        int_ens_metrics = {
            "overall": {
                "accuracy": acc,
                "precision_macro": prec_m,
                "recall_macro": rec_m,
                "f1_macro": f1_m,
                "precision_weighted": prec_w,
                "recall_weighted": rec_w,
                "f1_weighted": f1_w,
                "num_samples": int(len(int_ref_labels)),
            },
            "per_class": per_class,
        }
        with open(base_run / "metrics_inttest_ensemble.json", 'w', encoding='utf-8') as f:
            json.dump(int_ens_metrics, f, indent=2)

        with open(base_run / "metrics_overall_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["split","accuracy","precision_macro","recall_macro","f1_macro",
                        "precision_weighted","recall_weighted","f1_weighted","num_samples"])
            o = int_ens_metrics["overall"]
            w.writerow(["inttest_ensemble", o["accuracy"], o["precision_macro"],
                        o["recall_macro"], o["f1_macro"], o["precision_weighted"],
                        o["recall_weighted"], o["f1_weighted"], o["num_samples"]])

        with open(base_run / "per_class_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["class","precision","recall","f1","support"])
            for cname in class_names:
                row = per_class.get(cname, {"precision":0, "recall":0,
                                            "f1-score":0, "support":0})
                w.writerow([cname, row.get("precision",0), row.get("recall",0),
                            row.get("f1-score",0), row.get("support",0)])

        with open(base_run / "confusion_inttest_ensemble.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["true\\pred"] + class_names)
            for i, cname in enumerate(class_names):
                w.writerow([cname] + list(cm[i]))

        with open(base_run / "inttest_ensemble_predictions.csv", 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow(["path","patient_id","true","pred"] +
                       [f"p_{c}" for c in class_names])
            for i in range(len(int_ref_labels)):
                w.writerow([int_ref_paths[i], int_ref_pids[i],
                            class_names[int(int_ref_labels[i])],
                            class_names[int(int_preds_ens[i])]] +
                           list(map(float, int_probs_mean[i].tolist())))

    # (Optional) train on FULL pool and evaluate test once
    if cfg.train_full_after_cv:
        print("\n[Full Train] Training with full pool (no internal test)...")
        run_full = base_run / "full_train"
        run_full.mkdir(parents=True, exist_ok=True)

        real_train_subset = list(base_pool)

        if cfg.balance_gan_to_max and len(synth_items) > 0:
            full_train_subset = build_balanced_train_subset(
                real_train_subset=real_train_subset,
                synth_items=synth_items,
                num_classes=len(class_names),
                seed=cfg.seed + 999,
            )
            print(f"[Full Train] real={len(real_train_subset)} | train_balanced(real+GAN)={len(full_train_subset)}")
        else:
            full_train_subset = real_train_subset + (synth_items if len(synth_items) > 0 else [])
            print(f"[Full Train] real={len(real_train_subset)} + synth={len(synth_items)} -> {len(full_train_subset)}")

        train_ds      = MRIDataset(full_train_subset, image_size=cfg.image_size, aug=False)
        real_train_ds = MRIDataset(real_train_subset, image_size=cfg.image_size, aug=False)

        train_loader      = DataLoader(train_ds,      batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)
        real_train_loader = DataLoader(real_train_ds, batch_size=cfg.batch_size, shuffle=True,
                                       num_workers=cfg.num_workers, pin_memory=True, collate_fn=collate_fn)

        model = build_model(num_classes=len(class_names), pretrained=cfg.pretrained).to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=cfg.epochs)
        criterion = nn.CrossEntropyLoss()
        amp_enabled = (cfg.amp and device.type == 'cuda')
        scaler = torch.amp.GradScaler('cuda', enabled=amp_enabled)

        epochs_main = cfg.epochs - cfg.fine_tune_real_epochs
        epochs_ft   = cfg.fine_tune_real_epochs

        # Full-train Phase 1: full_train_subset (real + synth balanced or not)
        for epoch in range(1, epochs_main + 1):
            model.train()
            for imgs, ys, _, _ in train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        # Full-train Phase 2: REAL only
        for ft_idx in range(1, epochs_ft + 1):
            epoch = epochs_main + ft_idx
            model.train()
            for imgs, ys, _, _ in real_train_loader:
                imgs = imgs.to(device, non_blocking=True)
                ys = ys.to(device, non_blocking=True)
                optimizer.zero_grad(set_to_none=True)
                with torch.amp.autocast('cuda', enabled=amp_enabled):
                    loss = criterion(model(imgs), ys)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            scheduler.step()

        torch.save({'model': model.state_dict(), 'class_names': class_names},
                   run_full / 'final_full.ckpt')

        if test_loader_fixed is not None:
            print("[Full Train] Evaluating on TEST ...")
            evaluate(model, test_loader_fixed, device, class_names,
                     split_name='test_full', out_dir=run_full)

    print(f"\n[Artifacts] Saved at: {base_run}")
    return base_run

# %%
from pathlib import Path

cfg = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/5kcnn_oneimg",
    gan_pkl="",                  # o tu .pkl si quieres GAN
    internal_test_ratio=0,
    kfolds=5,
    epochs=20,
    batch_size=32,
    pretrained=True,
    balance_gan_to_max=False,
    one_image_per_patient=True,   # <- clave
    one_image_strategy="random",   # o "random" si quieres samplear por paciente
)

run_dir = train_kfold(cfg)
print("Saved in:", run_dir)
# Out:
# [Device] Using cuda
# [Scan] Pool images (raw): 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [OneImage] Pool collapsed to 1 image/patient: 1601 -> 156
# [Scan] External test images (raw): 702
# [OneImage] External test collapsed to 1 image/patient: 702 -> 68
# [Scan] External test images (sanitized): 68
# [Split] Using StratifiedGroupKFold
# [GAN] gan_pkl empty -> NO GAN will be used.
#
# ===== FOLD 1/5 =====
# [TRAIN] Fold 1: only real images, n=124
# [ID-STATS] fold1_train: unique patient IDs total = 124 | images = 124
#   - glioma: ids=42 images=42
#   - meningioma: ids=45 images=45
#   - pituitary: ids=37 images=37
# [ID-STATS] fold1_val: unique patient IDs total = 32 | images = 32
#   - glioma: ids=12 images=12
#   - meningioma: ids=13 images=13
#   - pituitary: ids=7 images=7
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 1 | Epoch 001] train_loss=1.0264 | val_acc=0.4375 | val_f1_macro=0.3158
# [Fold 1] New best (F1_macro=0.3158) saved.
# [Fold 1 | Epoch 002] train_loss=0.8793 | val_acc=0.8125 | val_f1_macro=0.7996
# [Fold 1] New best (F1_macro=0.7996) saved.
# [Fold 1 | Epoch 003] train_loss=0.7037 | val_acc=0.5000 | val_f1_macro=0.4274
# [Fold 1 | Epoch 004] train_loss=0.4221 | val_acc=0.7812 | val_f1_macro=0.7672
# [Fold 1 | Epoch 005] train_loss=0.4468 | val_acc=0.6250 | val_f1_macro=0.5374
# [Fold 1 | Epoch 006] train_loss=0.3683 | val_acc=0.5938 | val_f1_macro=0.6201
# [Fold 1 | Epoch 007] train_loss=0.2428 | val_acc=0.5625 | val_f1_macro=0.5662
# [Fold 1 | Epoch 008] train_loss=0.2944 | val_acc=0.7500 | val_f1_macro=0.7608
# [Fold 1 | Epoch 009] train_loss=0.1799 | val_acc=0.5938 | val_f1_macro=0.5847
# [Fold 1 | Epoch 010] train_loss=0.1549 | val_acc=0.5625 | val_f1_macro=0.5493
# [Fold 1 | Epoch 011] train_loss=0.1640 | val_acc=0.5938 | val_f1_macro=0.5897
# [Fold 1 | Epoch 012] train_loss=0.1517 | val_acc=0.6562 | val_f1_macro=0.6630
# [Fold 1 | Epoch 013] train_loss=0.0893 | val_acc=0.7500 | val_f1_macro=0.7645
# [Fold 1 | Epoch 014] train_loss=0.0798 | val_acc=0.7500 | val_f1_macro=0.7645
# [Fold 1 | Epoch 015] train_loss=0.0653 | val_acc=0.6250 | val_f1_macro=0.6215
# [Fold 1 | Epoch 016] train_loss=0.0324 | val_acc=0.5625 | val_f1_macro=0.5418
# [Fold 1 | Epoch 017] train_loss=0.0724 | val_acc=0.6875 | val_f1_macro=0.6930
# [Fold 1 | Epoch 018] train_loss=0.0486 | val_acc=0.7500 | val_f1_macro=0.7608
# [Fold 1 | Epoch 019] train_loss=0.0298 | val_acc=0.7812 | val_f1_macro=0.7900
# [Fold 1 | Epoch 020] train_loss=0.0343 | val_acc=0.7812 | val_f1_macro=0.7900
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [TRAIN] Fold 2: only real images, n=125
# [ID-STATS] fold2_train: unique patient IDs total = 125 | images = 125
#   - glioma: ids=44 images=44
#   - meningioma: ids=44 images=44
#   - pituitary: ids=37 images=37
# [ID-STATS] fold2_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=10 images=10
#   - meningioma: ids=14 images=14
#   - pituitary: ids=7 images=7
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 2 | Epoch 001] train_loss=1.0415 | val_acc=0.8387 | val_f1_macro=0.8589
# [Fold 2] New best (F1_macro=0.8589) saved.
# [Fold 2 | Epoch 002] train_loss=0.7818 | val_acc=0.3226 | val_f1_macro=0.2872
# [Fold 2 | Epoch 003] train_loss=0.7127 | val_acc=0.5806 | val_f1_macro=0.4306
# [Fold 2 | Epoch 004] train_loss=0.4706 | val_acc=0.7097 | val_f1_macro=0.6698
# [Fold 2 | Epoch 005] train_loss=0.3368 | val_acc=0.2258 | val_f1_macro=0.1228
# [Fold 2 | Epoch 006] train_loss=0.2975 | val_acc=0.3871 | val_f1_macro=0.3780
# [Fold 2 | Epoch 007] train_loss=0.1882 | val_acc=0.6452 | val_f1_macro=0.6561
# [Fold 2 | Epoch 008] train_loss=0.2580 | val_acc=0.5484 | val_f1_macro=0.5232
# [Fold 2 | Epoch 009] train_loss=0.2315 | val_acc=0.7097 | val_f1_macro=0.7064
# [Fold 2 | Epoch 010] train_loss=0.1013 | val_acc=0.5484 | val_f1_macro=0.5418
# [Fold 2 | Epoch 011] train_loss=0.0771 | val_acc=0.5806 | val_f1_macro=0.5824
# [Fold 2 | Epoch 012] train_loss=0.0631 | val_acc=0.8710 | val_f1_macro=0.8787
# [Fold 2] New best (F1_macro=0.8787) saved.
# [Fold 2 | Epoch 013] train_loss=0.0593 | val_acc=0.9032 | val_f1_macro=0.9074
# [Fold 2] New best (F1_macro=0.9074) saved.
# [Fold 2 | Epoch 014] train_loss=0.1067 | val_acc=0.9032 | val_f1_macro=0.9074
# [Fold 2 | Epoch 015] train_loss=0.0410 | val_acc=0.8065 | val_f1_macro=0.8144
# [Fold 2 | Epoch 016] train_loss=0.0268 | val_acc=0.8065 | val_f1_macro=0.8102
# [Fold 2 | Epoch 017] train_loss=0.0422 | val_acc=0.8065 | val_f1_macro=0.8102
# [Fold 2 | Epoch 018] train_loss=0.0451 | val_acc=0.8065 | val_f1_macro=0.8093
# [Fold 2 | Epoch 019] train_loss=0.0242 | val_acc=0.8065 | val_f1_macro=0.8093
# [Fold 2 | Epoch 020] train_loss=0.0234 | val_acc=0.8387 | val_f1_macro=0.8412
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [TRAIN] Fold 3: only real images, n=125
# [ID-STATS] fold3_train: unique patient IDs total = 125 | images = 125
#   - glioma: ids=45 images=45
#   - meningioma: ids=46 images=46
#   - pituitary: ids=34 images=34
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=9 images=9
#   - meningioma: ids=12 images=12
#   - pituitary: ids=10 images=10
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 3 | Epoch 001] train_loss=1.0125 | val_acc=0.5161 | val_f1_macro=0.4103
# [Fold 3] New best (F1_macro=0.4103) saved.
# [Fold 3 | Epoch 002] train_loss=0.8793 | val_acc=0.2903 | val_f1_macro=0.1500
# [Fold 3 | Epoch 003] train_loss=0.4474 | val_acc=0.2903 | val_f1_macro=0.1500
# [Fold 3 | Epoch 004] train_loss=0.6881 | val_acc=0.2903 | val_f1_macro=0.1500
# [Fold 3 | Epoch 005] train_loss=0.5346 | val_acc=0.2903 | val_f1_macro=0.1500
# [Fold 3 | Epoch 006] train_loss=0.3927 | val_acc=0.3226 | val_f1_macro=0.2145
# [Fold 3 | Epoch 007] train_loss=0.3199 | val_acc=0.3226 | val_f1_macro=0.2145
# [Fold 3 | Epoch 008] train_loss=0.2428 | val_acc=0.5806 | val_f1_macro=0.5586
# [Fold 3] New best (F1_macro=0.5586) saved.
# [Fold 3 | Epoch 009] train_loss=0.2028 | val_acc=0.7419 | val_f1_macro=0.7164
# [Fold 3] New best (F1_macro=0.7164) saved.
# [Fold 3 | Epoch 010] train_loss=0.2613 | val_acc=0.6774 | val_f1_macro=0.6455
# [Fold 3 | Epoch 011] train_loss=0.1252 | val_acc=0.7742 | val_f1_macro=0.7524
# [Fold 3] New best (F1_macro=0.7524) saved.
# [Fold 3 | Epoch 012] train_loss=0.0850 | val_acc=0.8710 | val_f1_macro=0.8678
# [Fold 3] New best (F1_macro=0.8678) saved.
# [Fold 3 | Epoch 013] train_loss=0.1230 | val_acc=0.8387 | val_f1_macro=0.8380
# [Fold 3 | Epoch 014] train_loss=0.0857 | val_acc=0.8387 | val_f1_macro=0.8384
# [Fold 3 | Epoch 015] train_loss=0.0846 | val_acc=0.8387 | val_f1_macro=0.8384
# [Fold 3 | Epoch 016] train_loss=0.0533 | val_acc=0.8387 | val_f1_macro=0.8384
# [Fold 3 | Epoch 017] train_loss=0.0915 | val_acc=0.8387 | val_f1_macro=0.8384
# [Fold 3 | Epoch 018] train_loss=0.0295 | val_acc=0.8387 | val_f1_macro=0.8371
# [Fold 3 | Epoch 019] train_loss=0.0390 | val_acc=0.7742 | val_f1_macro=0.7785
# [Fold 3 | Epoch 020] train_loss=0.0204 | val_acc=0.7742 | val_f1_macro=0.7785
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [TRAIN] Fold 4: only real images, n=125
# [ID-STATS] fold4_train: unique patient IDs total = 125 | images = 125
#   - glioma: ids=43 images=43
#   - meningioma: ids=48 images=48
#   - pituitary: ids=34 images=34
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=11 images=11
#   - meningioma: ids=10 images=10
#   - pituitary: ids=10 images=10
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 4 | Epoch 001] train_loss=0.9585 | val_acc=0.3871 | val_f1_macro=0.2707
# [Fold 4] New best (F1_macro=0.2707) saved.
# [Fold 4 | Epoch 002] train_loss=0.8262 | val_acc=0.4194 | val_f1_macro=0.2944
# [Fold 4] New best (F1_macro=0.2944) saved.
# [Fold 4 | Epoch 003] train_loss=0.5489 | val_acc=0.3548 | val_f1_macro=0.1746
# [Fold 4 | Epoch 004] train_loss=0.5804 | val_acc=0.3548 | val_f1_macro=0.1746
# [Fold 4 | Epoch 005] train_loss=0.4455 | val_acc=0.5161 | val_f1_macro=0.4606
# [Fold 4] New best (F1_macro=0.4606) saved.
# [Fold 4 | Epoch 006] train_loss=0.4358 | val_acc=0.4516 | val_f1_macro=0.3580
# [Fold 4 | Epoch 007] train_loss=0.2848 | val_acc=0.4839 | val_f1_macro=0.4236
# [Fold 4 | Epoch 008] train_loss=0.2559 | val_acc=0.4516 | val_f1_macro=0.4246
# [Fold 4 | Epoch 009] train_loss=0.1620 | val_acc=0.7097 | val_f1_macro=0.7117
# [Fold 4] New best (F1_macro=0.7117) saved.
# [Fold 4 | Epoch 010] train_loss=0.1650 | val_acc=0.7097 | val_f1_macro=0.6974
# [Fold 4 | Epoch 011] train_loss=0.1172 | val_acc=0.6774 | val_f1_macro=0.6696
# [Fold 4 | Epoch 012] train_loss=0.1017 | val_acc=0.7419 | val_f1_macro=0.7294
# [Fold 4] New best (F1_macro=0.7294) saved.
# [Fold 4 | Epoch 013] train_loss=0.0927 | val_acc=0.8065 | val_f1_macro=0.8100
# [Fold 4] New best (F1_macro=0.8100) saved.
# [Fold 4 | Epoch 014] train_loss=0.0599 | val_acc=0.7419 | val_f1_macro=0.7301
# [Fold 4 | Epoch 015] train_loss=0.0917 | val_acc=0.6774 | val_f1_macro=0.6738
# [Fold 4 | Epoch 016] train_loss=0.0625 | val_acc=0.6774 | val_f1_macro=0.6738
# [Fold 4 | Epoch 017] train_loss=0.0669 | val_acc=0.7419 | val_f1_macro=0.7424
# [Fold 4 | Epoch 018] train_loss=0.0234 | val_acc=0.7419 | val_f1_macro=0.7424
# [Fold 4 | Epoch 019] train_loss=0.0240 | val_acc=0.7419 | val_f1_macro=0.7413
# [Fold 4 | Epoch 020] train_loss=0.0322 | val_acc=0.7419 | val_f1_macro=0.7413
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [TRAIN] Fold 5: only real images, n=125
# [ID-STATS] fold5_train: unique patient IDs total = 125 | images = 125
#   - glioma: ids=42 images=42
#   - meningioma: ids=49 images=49
#   - pituitary: ids=34 images=34
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=12 images=12
#   - meningioma: ids=9 images=9
#   - pituitary: ids=10 images=10
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 5 | Epoch 001] train_loss=1.0347 | val_acc=0.3871 | val_f1_macro=0.2955
# [Fold 5] New best (F1_macro=0.2955) saved.
# [Fold 5 | Epoch 002] train_loss=0.6916 | val_acc=0.5484 | val_f1_macro=0.5577
# [Fold 5] New best (F1_macro=0.5577) saved.
# [Fold 5 | Epoch 003] train_loss=0.5053 | val_acc=0.3871 | val_f1_macro=0.1860
# [Fold 5 | Epoch 004] train_loss=0.3340 | val_acc=0.5484 | val_f1_macro=0.4883
# [Fold 5 | Epoch 005] train_loss=0.2885 | val_acc=0.8710 | val_f1_macro=0.8670
# [Fold 5] New best (F1_macro=0.8670) saved.
# [Fold 5 | Epoch 006] train_loss=0.2482 | val_acc=0.9355 | val_f1_macro=0.9337
# [Fold 5] New best (F1_macro=0.9337) saved.
# [Fold 5 | Epoch 007] train_loss=0.3033 | val_acc=0.4516 | val_f1_macro=0.3224
# [Fold 5 | Epoch 008] train_loss=0.2581 | val_acc=0.8387 | val_f1_macro=0.8424
# [Fold 5 | Epoch 009] train_loss=0.1308 | val_acc=0.6452 | val_f1_macro=0.6430
# [Fold 5 | Epoch 010] train_loss=0.2684 | val_acc=0.7097 | val_f1_macro=0.7190
# [Fold 5 | Epoch 011] train_loss=0.1539 | val_acc=0.8387 | val_f1_macro=0.8433
# [Fold 5 | Epoch 012] train_loss=0.1464 | val_acc=0.7742 | val_f1_macro=0.7723
# [Fold 5 | Epoch 013] train_loss=0.0802 | val_acc=0.7742 | val_f1_macro=0.7759
# [Fold 5 | Epoch 014] train_loss=0.1690 | val_acc=0.9355 | val_f1_macro=0.9296
# [Fold 5 | Epoch 015] train_loss=0.0626 | val_acc=0.9355 | val_f1_macro=0.9296
# [Fold 5 | Epoch 016] train_loss=0.0553 | val_acc=0.9355 | val_f1_macro=0.9296
# [Fold 5 | Epoch 017] train_loss=0.0573 | val_acc=0.9355 | val_f1_macro=0.9321
# [Fold 5 | Epoch 018] train_loss=0.0489 | val_acc=0.9677 | val_f1_macro=0.9649
# [Fold 5] New best (F1_macro=0.9649) saved.
# [Fold 5 | Epoch 019] train_loss=0.0363 | val_acc=0.9677 | val_f1_macro=0.9649
# [Fold 5 | Epoch 020] train_loss=0.0656 | val_acc=0.9677 | val_f1_macro=0.9649
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/5kcnn_oneimg/kfold_5f_run_20251116-194047
# Saved in: /content/drive/MyDrive/TESIS/StyleGan2/5kcnn_oneimg/kfold_5f_run_20251116-194047

# %%
from pathlib import Path

cfg = Config(
    data_root="/content/localdata/train_unzipped/trainreducido",
    test_root="/content/localdata/test_unzipped/testreducido",
    out_dir="/content/drive/MyDrive/TESIS/StyleGan2/5kcnn_oneimg",
    gan_pkl="/content/drive/MyDrive/TESIS/StyleGan2/Modelsinge/00000-finalnuevoinge-cond-mirror-24gb-gpu-kimg1000-batch32-ada-target0.6-bg/network-snapshot-000600.pkl",
    internal_test_ratio=0,
    kfolds=5,
    epochs=20,
    batch_size=32,
    pretrained=True,
    balance_gan_to_max=True,
    one_image_per_patient=True,   # <- clave
    one_image_strategy="random",   # o "random" si quieres samplear por paciente
)

run_dir = train_kfold(cfg)
print("Saved in:", run_dir)
# Out:
# [Device] Using cuda
# [Scan] Pool images (raw): 1601 | Classes: ['glioma', 'meningioma', 'pituitary']
# [OneImage] Pool collapsed to 1 image/patient: 1601 -> 156
# [Scan] External test images (raw): 702
# [OneImage] External test collapsed to 1 image/patient: 702 -> 68
# [Scan] External test images (sanitized): 68
# [Split] Using StratifiedGroupKFold
# [GAN] balance_gan_to_max=True -> global real counts per class = [54, 58, 44], using n_per_class=58
# [GAN] Saved 58 images for class 'glioma'
# [GAN] Saved 58 images for class 'meningioma'
# [GAN] Saved 58 images for class 'pituitary'
# [GAN] Synth images generated (global): 174
#
# ===== FOLD 1/5 =====
# [BAL] Real class counts (fold): [42, 45, 37] -> target=45
# [BAL] Fold 1: real=124 | train_balanced(real+GAN)=135
# [ID-STATS] fold1_train: unique patient IDs total = 125 | images = 135
#   - glioma: ids=43 images=45
#   - meningioma: ids=45 images=45
#   - pituitary: ids=38 images=45
# [ID-STATS] fold1_val: unique patient IDs total = 32 | images = 32
#   - glioma: ids=12 images=12
#   - meningioma: ids=13 images=13
#   - pituitary: ids=7 images=7
# [ID-STATS] fold1_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 1 | Epoch 001] train_loss=0.8868 | val_acc=0.6562 | val_f1_macro=0.5958
# [Fold 1] New best (F1_macro=0.5958) saved.
# [Fold 1 | Epoch 002] train_loss=0.6933 | val_acc=0.7188 | val_f1_macro=0.6578
# [Fold 1] New best (F1_macro=0.6578) saved.
# [Fold 1 | Epoch 003] train_loss=0.4661 | val_acc=0.5312 | val_f1_macro=0.4074
# [Fold 1 | Epoch 004] train_loss=0.5212 | val_acc=0.5000 | val_f1_macro=0.4157
# [Fold 1 | Epoch 005] train_loss=0.3865 | val_acc=0.6562 | val_f1_macro=0.6427
# [Fold 1 | Epoch 006] train_loss=0.2928 | val_acc=0.6875 | val_f1_macro=0.6677
# [Fold 1] New best (F1_macro=0.6677) saved.
# [Fold 1 | Epoch 007] train_loss=0.4014 | val_acc=0.7188 | val_f1_macro=0.7119
# [Fold 1] New best (F1_macro=0.7119) saved.
# [Fold 1 | Epoch 008] train_loss=0.3290 | val_acc=0.4062 | val_f1_macro=0.2337
# [Fold 1 | Epoch 009] train_loss=0.3993 | val_acc=0.5000 | val_f1_macro=0.4083
# [Fold 1 | Epoch 010] train_loss=0.2680 | val_acc=0.7500 | val_f1_macro=0.7313
# [Fold 1] New best (F1_macro=0.7313) saved.
# [Fold 1 | Epoch 011] train_loss=0.2410 | val_acc=0.8438 | val_f1_macro=0.8407
# [Fold 1] New best (F1_macro=0.8407) saved.
# [Fold 1 | Epoch 012] train_loss=0.2594 | val_acc=0.7500 | val_f1_macro=0.7543
# [Fold 1 | Epoch 013] train_loss=0.3307 | val_acc=0.7500 | val_f1_macro=0.7508
# [Fold 1 | Epoch 014] train_loss=0.2055 | val_acc=0.7500 | val_f1_macro=0.7550
# [Fold 1 | Epoch 015] train_loss=0.1684 | val_acc=0.7500 | val_f1_macro=0.7550
# [Fold 1 | Epoch 016] train_loss=0.1778 | val_acc=0.7812 | val_f1_macro=0.7902
# [Fold 1 | Epoch 017] train_loss=0.0959 | val_acc=0.7812 | val_f1_macro=0.7917
# [Fold 1 | Epoch 018] train_loss=0.1437 | val_acc=0.8125 | val_f1_macro=0.8278
# [Fold 1 | Epoch 019] train_loss=0.1823 | val_acc=0.8438 | val_f1_macro=0.8540
# [Fold 1] New best (F1_macro=0.8540) saved.
# [Fold 1 | Epoch 020] train_loss=0.1073 | val_acc=0.8438 | val_f1_macro=0.8540
# [Fold 1] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 1] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 2/5 =====
# [BAL] Real class counts (fold): [44, 44, 37] -> target=44
# [BAL] Fold 2: real=125 | train_balanced(real+GAN)=132
# [ID-STATS] fold2_train: unique patient IDs total = 126 | images = 132
#   - glioma: ids=44 images=44
#   - meningioma: ids=44 images=44
#   - pituitary: ids=38 images=44
# [ID-STATS] fold2_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=10 images=10
#   - meningioma: ids=14 images=14
#   - pituitary: ids=7 images=7
# [ID-STATS] fold2_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 2 | Epoch 001] train_loss=0.8226 | val_acc=0.7097 | val_f1_macro=0.7363
# [Fold 2] New best (F1_macro=0.7363) saved.
# [Fold 2 | Epoch 002] train_loss=0.5893 | val_acc=0.3871 | val_f1_macro=0.2963
# [Fold 2 | Epoch 003] train_loss=0.6755 | val_acc=0.5806 | val_f1_macro=0.4435
# [Fold 2 | Epoch 004] train_loss=0.4464 | val_acc=0.7742 | val_f1_macro=0.7591
# [Fold 2] New best (F1_macro=0.7591) saved.
# [Fold 2 | Epoch 005] train_loss=0.5253 | val_acc=0.5484 | val_f1_macro=0.3843
# [Fold 2 | Epoch 006] train_loss=0.4623 | val_acc=0.4839 | val_f1_macro=0.4482
# [Fold 2 | Epoch 007] train_loss=0.5380 | val_acc=0.7419 | val_f1_macro=0.7412
# [Fold 2 | Epoch 008] train_loss=0.4466 | val_acc=0.7742 | val_f1_macro=0.7862
# [Fold 2] New best (F1_macro=0.7862) saved.
# [Fold 2 | Epoch 009] train_loss=0.3230 | val_acc=0.7097 | val_f1_macro=0.6504
# [Fold 2 | Epoch 010] train_loss=0.2079 | val_acc=0.7419 | val_f1_macro=0.6819
# [Fold 2 | Epoch 011] train_loss=0.1935 | val_acc=0.6774 | val_f1_macro=0.5833
# [Fold 2 | Epoch 012] train_loss=0.1811 | val_acc=0.8065 | val_f1_macro=0.8079
# [Fold 2] New best (F1_macro=0.8079) saved.
# [Fold 2 | Epoch 013] train_loss=0.1997 | val_acc=0.8387 | val_f1_macro=0.8462
# [Fold 2] New best (F1_macro=0.8462) saved.
# [Fold 2 | Epoch 014] train_loss=0.2386 | val_acc=0.7742 | val_f1_macro=0.7802
# [Fold 2 | Epoch 015] train_loss=0.1693 | val_acc=0.8387 | val_f1_macro=0.8323
# [Fold 2 | Epoch 016] train_loss=0.1202 | val_acc=0.8710 | val_f1_macro=0.8714
# [Fold 2] New best (F1_macro=0.8714) saved.
# [Fold 2 | Epoch 017] train_loss=0.2052 | val_acc=0.8710 | val_f1_macro=0.8775
# [Fold 2] New best (F1_macro=0.8775) saved.
# [Fold 2 | Epoch 018] train_loss=0.1705 | val_acc=0.8387 | val_f1_macro=0.8440
# [Fold 2 | Epoch 019] train_loss=0.1706 | val_acc=0.8065 | val_f1_macro=0.8116
# [Fold 2 | Epoch 020] train_loss=0.1411 | val_acc=0.8387 | val_f1_macro=0.8412
# [Fold 2] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 2] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 3/5 =====
# [BAL] Real class counts (fold): [45, 46, 34] -> target=46
# [BAL] Fold 3: real=125 | train_balanced(real+GAN)=138
# [ID-STATS] fold3_train: unique patient IDs total = 126 | images = 138
#   - glioma: ids=46 images=46
#   - meningioma: ids=46 images=46
#   - pituitary: ids=35 images=46
# [ID-STATS] fold3_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=9 images=9
#   - meningioma: ids=12 images=12
#   - pituitary: ids=10 images=10
# [ID-STATS] fold3_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 3 | Epoch 001] train_loss=0.8873 | val_acc=0.5806 | val_f1_macro=0.5615
# [Fold 3] New best (F1_macro=0.5615) saved.
# [Fold 3 | Epoch 002] train_loss=0.7317 | val_acc=0.5484 | val_f1_macro=0.4743
# [Fold 3 | Epoch 003] train_loss=0.5477 | val_acc=0.6774 | val_f1_macro=0.6801
# [Fold 3] New best (F1_macro=0.6801) saved.
# [Fold 3 | Epoch 004] train_loss=0.7842 | val_acc=0.4839 | val_f1_macro=0.4542
# [Fold 3 | Epoch 005] train_loss=0.4590 | val_acc=0.6129 | val_f1_macro=0.5896
# [Fold 3 | Epoch 006] train_loss=0.3237 | val_acc=0.8065 | val_f1_macro=0.7938
# [Fold 3] New best (F1_macro=0.7938) saved.
# [Fold 3 | Epoch 007] train_loss=0.3430 | val_acc=0.6129 | val_f1_macro=0.5139
# [Fold 3 | Epoch 008] train_loss=0.2566 | val_acc=0.8065 | val_f1_macro=0.8177
# [Fold 3] New best (F1_macro=0.8177) saved.
# [Fold 3 | Epoch 009] train_loss=0.2867 | val_acc=0.6774 | val_f1_macro=0.6718
# [Fold 3 | Epoch 010] train_loss=0.3034 | val_acc=0.7097 | val_f1_macro=0.6705
# [Fold 3 | Epoch 011] train_loss=0.1627 | val_acc=0.5806 | val_f1_macro=0.4618
# [Fold 3 | Epoch 012] train_loss=0.1355 | val_acc=0.6774 | val_f1_macro=0.6455
# [Fold 3 | Epoch 013] train_loss=0.1125 | val_acc=0.6774 | val_f1_macro=0.6821
# [Fold 3 | Epoch 014] train_loss=0.2207 | val_acc=0.7419 | val_f1_macro=0.7509
# [Fold 3 | Epoch 015] train_loss=0.1012 | val_acc=0.8387 | val_f1_macro=0.8429
# [Fold 3] New best (F1_macro=0.8429) saved.
# [Fold 3 | Epoch 016] train_loss=0.0817 | val_acc=0.8387 | val_f1_macro=0.8418
# [Fold 3 | Epoch 017] train_loss=0.0806 | val_acc=0.9032 | val_f1_macro=0.9019
# [Fold 3] New best (F1_macro=0.9019) saved.
# [Fold 3 | Epoch 018] train_loss=0.0645 | val_acc=0.9355 | val_f1_macro=0.9321
# [Fold 3] New best (F1_macro=0.9321) saved.
# [Fold 3 | Epoch 019] train_loss=0.0674 | val_acc=0.9355 | val_f1_macro=0.9321
# [Fold 3 | Epoch 020] train_loss=0.0765 | val_acc=0.9355 | val_f1_macro=0.9321
# [Fold 3] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 3] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 4/5 =====
# [BAL] Real class counts (fold): [43, 48, 34] -> target=48
# [BAL] Fold 4: real=125 | train_balanced(real+GAN)=144
# [ID-STATS] fold4_train: unique patient IDs total = 126 | images = 144
#   - glioma: ids=44 images=48
#   - meningioma: ids=48 images=48
#   - pituitary: ids=35 images=48
# [ID-STATS] fold4_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=11 images=11
#   - meningioma: ids=10 images=10
#   - pituitary: ids=10 images=10
# [ID-STATS] fold4_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 4 | Epoch 001] train_loss=0.8684 | val_acc=0.5161 | val_f1_macro=0.4794
# [Fold 4] New best (F1_macro=0.4794) saved.
# [Fold 4 | Epoch 002] train_loss=0.6127 | val_acc=0.5806 | val_f1_macro=0.5473
# [Fold 4] New best (F1_macro=0.5473) saved.
# [Fold 4 | Epoch 003] train_loss=0.4348 | val_acc=0.6129 | val_f1_macro=0.4908
# [Fold 4 | Epoch 004] train_loss=0.5011 | val_acc=0.3548 | val_f1_macro=0.1746
# [Fold 4 | Epoch 005] train_loss=0.4198 | val_acc=0.3548 | val_f1_macro=0.1746
# [Fold 4 | Epoch 006] train_loss=0.4393 | val_acc=0.4839 | val_f1_macro=0.4542
# [Fold 4 | Epoch 007] train_loss=0.2316 | val_acc=0.5484 | val_f1_macro=0.5190
# [Fold 4 | Epoch 008] train_loss=0.3081 | val_acc=0.6452 | val_f1_macro=0.6263
# [Fold 4] New best (F1_macro=0.6263) saved.
# [Fold 4 | Epoch 009] train_loss=0.2217 | val_acc=0.6129 | val_f1_macro=0.5928
# [Fold 4 | Epoch 010] train_loss=0.1656 | val_acc=0.6774 | val_f1_macro=0.6655
# [Fold 4] New best (F1_macro=0.6655) saved.
# [Fold 4 | Epoch 011] train_loss=0.1618 | val_acc=0.8387 | val_f1_macro=0.8344
# [Fold 4] New best (F1_macro=0.8344) saved.
# [Fold 4 | Epoch 012] train_loss=0.0763 | val_acc=0.8065 | val_f1_macro=0.8030
# [Fold 4 | Epoch 013] train_loss=0.0619 | val_acc=0.8387 | val_f1_macro=0.8376
# [Fold 4] New best (F1_macro=0.8376) saved.
# [Fold 4 | Epoch 014] train_loss=0.0766 | val_acc=0.7419 | val_f1_macro=0.7317
# [Fold 4 | Epoch 015] train_loss=0.0837 | val_acc=0.7419 | val_f1_macro=0.7317
# [Fold 4 | Epoch 016] train_loss=0.0481 | val_acc=0.8387 | val_f1_macro=0.8398
# [Fold 4] New best (F1_macro=0.8398) saved.
# [Fold 4 | Epoch 017] train_loss=0.0481 | val_acc=0.8387 | val_f1_macro=0.8398
# [Fold 4 | Epoch 018] train_loss=0.0362 | val_acc=0.8387 | val_f1_macro=0.8398
# [Fold 4 | Epoch 019] train_loss=0.0438 | val_acc=0.7742 | val_f1_macro=0.7709
# [Fold 4 | Epoch 020] train_loss=0.0401 | val_acc=0.7742 | val_f1_macro=0.7709
# [Fold 4] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 4] Evaluating on EXTERNAL TEST...
#
# ===== FOLD 5/5 =====
# [BAL] Real class counts (fold): [42, 49, 34] -> target=49
# [BAL] Fold 5: real=125 | train_balanced(real+GAN)=147
# [ID-STATS] fold5_train: unique patient IDs total = 126 | images = 147
#   - glioma: ids=43 images=49
#   - meningioma: ids=49 images=49
#   - pituitary: ids=35 images=49
# [ID-STATS] fold5_val: unique patient IDs total = 31 | images = 31
#   - glioma: ids=12 images=12
#   - meningioma: ids=9 images=9
#   - pituitary: ids=10 images=10
# [ID-STATS] fold5_test: unique patient IDs total = 68 | images = 68
#   - glioma: ids=29 images=29
#   - meningioma: ids=21 images=21
#   - pituitary: ids=18 images=18
# [Fold 5 | Epoch 001] train_loss=0.9010 | val_acc=0.5806 | val_f1_macro=0.5143
# [Fold 5] New best (F1_macro=0.5143) saved.
# [Fold 5 | Epoch 002] train_loss=0.7361 | val_acc=0.3871 | val_f1_macro=0.1860
# [Fold 5 | Epoch 003] train_loss=0.8118 | val_acc=0.7419 | val_f1_macro=0.7171
# [Fold 5] New best (F1_macro=0.7171) saved.
# [Fold 5 | Epoch 004] train_loss=0.5780 | val_acc=0.5161 | val_f1_macro=0.3937
# [Fold 5 | Epoch 005] train_loss=0.3810 | val_acc=0.9032 | val_f1_macro=0.8970
# [Fold 5] New best (F1_macro=0.8970) saved.
# [Fold 5 | Epoch 006] train_loss=0.3722 | val_acc=0.4839 | val_f1_macro=0.3778
# [Fold 5 | Epoch 007] train_loss=0.3419 | val_acc=0.6774 | val_f1_macro=0.5913
# [Fold 5 | Epoch 008] train_loss=0.3027 | val_acc=0.7419 | val_f1_macro=0.7296
# [Fold 5 | Epoch 009] train_loss=0.2006 | val_acc=0.7419 | val_f1_macro=0.7009
# [Fold 5 | Epoch 010] train_loss=0.2193 | val_acc=0.7742 | val_f1_macro=0.7405
# [Fold 5 | Epoch 011] train_loss=0.1703 | val_acc=0.8065 | val_f1_macro=0.8078
# [Fold 5 | Epoch 012] train_loss=0.1404 | val_acc=0.8387 | val_f1_macro=0.8297
# [Fold 5 | Epoch 013] train_loss=0.1221 | val_acc=0.8387 | val_f1_macro=0.8297
# [Fold 5 | Epoch 014] train_loss=0.1199 | val_acc=0.8710 | val_f1_macro=0.8621
# [Fold 5 | Epoch 015] train_loss=0.0970 | val_acc=0.7419 | val_f1_macro=0.7412
# [Fold 5 | Epoch 016] train_loss=0.1372 | val_acc=0.7419 | val_f1_macro=0.7412
# [Fold 5 | Epoch 017] train_loss=0.0908 | val_acc=0.7742 | val_f1_macro=0.7763
# [Fold 5 | Epoch 018] train_loss=0.0528 | val_acc=0.8065 | val_f1_macro=0.8047
# [Fold 5 | Epoch 019] train_loss=0.1225 | val_acc=0.8710 | val_f1_macro=0.8621
# [Fold 5 | Epoch 020] train_loss=0.0574 | val_acc=0.8710 | val_f1_macro=0.8621
# [Fold 5] Re-evaluating BEST on VAL (and collecting OOF)...
# [Fold 5] Evaluating on EXTERNAL TEST...
# [CV] Summary (mean±std) written to cv_summary_full.{json,csv}
#
# [Artifacts] Saved at: /content/drive/MyDrive/TESIS/StyleGan2/5kcnn_oneimg/kfold_5f_run_20251116-194313
# Saved in: /content/drive/MyDrive/TESIS/StyleGan2/5kcnn_oneimg/kfold_5f_run_20251116-194313
